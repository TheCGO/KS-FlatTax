# %% [markdown]
# # Notebook for replicating the analyses in "How does a Move to a Flat Tax Affect Household Filers? The Case of Kansas"
# ### Richard W. Evans and Patrick Neyland, June 2023
# This notebook replicates the analyses in the *Research in Focus* article by [Richard W. Evans](https://sites.google.com/site/rickecon) and Patrick Neyland entitled "How does a Move to a Flat Tax Affect Household Filers? The Case of Kansas".

# %% [markdown]
# ## 1. Introduction
# Before opening and running this notebook, make sure that you have downloaded or cloned the [`KS-FlatTax`](https://github.com/TheCGO/KS-FlatTax) repository (https://github.com/TheCGO/KS-FlatTax) and created and activated the associated conda environment `ks-flattax-dev` in the `environment.yml` file. You can also run this notebook easily in the cloud by going to this [Google Colab version](https://colab.research.google.com/drive/1phIZ1oJNs-IjRv7Av7uAHIX3T6P6XVQX?usp=sharing) of this notebook.
#
# The notebook for the introduction produces the following figures.
# * 1.1. Figure 1. Plot of US states by state employment income tax type
# * 1.2. Figure 2. Rainy Day Fund and Total Reserves as Percentages of General-Fund Expenditures, Kansas and 50-State Median: 2000-2022
# * 1.3. Figure 3. Estimated 2022 Rainy Day Fund Balances and Total Reserves and Balances as Percentages of General-Fund Expenditures

# %%
# Import packages
import pandas as pd
import numpy as np
import geopandas as gpd
from bokeh.io import output_file, output_notebook, export_png
from bokeh.plotting import figure, show
from bokeh.models import (ColumnDataSource, Title, Label, LabelSet, Legend,
                          LegendItem, CategoricalColorMapper, ColorBar,
                          HoverTool, NumeralTickFormatter, GeoJSONDataSource)
from bokeh.models.tickers import SingleIntervalTicker
from bokeh.sampledata.us_states import data as states

import random
import json

from fiscalsim_us import Simulation
from policyengine_core.reforms import Reform
from policyengine_core.periods import instant

# %% [markdown]
# ### 1.1. Figure 1. Plot of US states by state employment income tax type

# %% [markdown]
# Create the data for state tax type.

# %%
# Create a DataFrame of states and their tax types as of January 1, 2023
# 0 = No state income tax
# 1 = Flat state income tax rate
# 2 = Nearly flat state income tax rates
# 3 = Progressive state income tax rates
state_taxtype_list = [
    ["Alabama", "AL", 2],
    ["Alaska", "AK", 0],
    ["Arizona", "AZ", 1],
    ["Arkansas", "AR", 3],
    ["California", "CA", 3],
    ["Colorado", "CO", 1],
    ["Connecticut", "CT", 3],
    ["Delaware", "DE", 3],
    ["District of Columbia", "DC", 3],
    ["Florida", "FL", 0],
    ["Georgia", "GA", 2],
    ["Hawaii", "HI", 3],
    ["Idaho", "ID", 1],
    ["Illinois", "IL", 1],
    ["Indiana", "IN", 1],
    ["Iowa", "IA", 2],
    ["Kansas", "KS", 3],
    ["Kentucky", "KY", 1],
    ["Louisiana", "LA", 3],
    ["Maine", "ME", 3],
    ["Maryland", "MD", 3],
    ["Massachusetts", "MA", 1],
    ["Michigan", "MI", 1],
    ["Minnesota", "MN", 3],
    ["Mississippi", "MS", 1],
    ["Missouri", "MO", 2],
    ["Montana", "MT", 3],
    ["Nebraska", "NE", 3],
    ["Nevada", "NV", 0],
    ["New Hampshire", "NH", 0],
    ["New Jersey", "NJ", 3],
    ["New Mexico", "NM", 3],
    ["New York", "NY", 3],
    ["North Carolina", "NC", 1],
    ["North Dakota", "ND", 3],
    ["Ohio", "OH", 3],
    ["Oklahoma", "OK", 2],
    ["Oregon", "OR", 3],
    ["Pennsylvania", "PA", 1],
    ["Rhode Island", "RI", 3],
    ["South Carolina", "SC", 3],
    ["South Dakota", "SD", 0],
    ["Tennessee", "TN", 0],
    ["Texas", "TX", 0],
    ["Utah", "UT", 1],
    ["Vermont", "VT", 3],
    ["Virginia", "VA", 3],
    ["Washington", "WA", 0],
    ["West Virginia", "WV", 3], 
    ["Wisconsin", "WI", 3],
    ["Wyoming", "WY", 0],
]
state_taxtype_df = pd.DataFrame(
    state_taxtype_list, columns=["State", "Abbrev", "TaxType"]
)

# define state rates

state_rates_2023 = [
    ["Alabama", '2.00%', '4.00%', '5.00%'],
    ["Alaska", '0.00%'],
    ["Arizona", '2.50%'],
    ["Arkansas", '2.00%', '4.00%', '4.90%'],
    ["California", '1.00%', '2.00%', '4.00%', '6.00%', '8.00%',
    '9.30%', '10.30%', '11.30%', '12.30%', '13.30%'],
    ["Colorado", '4.40%'],
    ["Connecticut", '3.00%', '5.00%', '5.50%', '6.00%', '6.50%', '6.90%', '6.99%'],
    ["Delaware", '2.20%', '3.90%', '4.80%', '5.20%', '5.55%', '6.60%'],
    ["District of Columbia", '4.00%', '6.00%', '6.50%','8.50%', '9.25%', '9.75%', '10.75%'],
    ["Florida", '0.00%'],
    ["Georgia", '1.00%', '2.00%', '3.00%', '4.00%', '5.00%', '5.75%'],
    ["Hawaii", '1.40%', '3.20%', '5.50%', '6.40%', '6.80%',	
    '7.20%','7.60%','7.90%','8.25%','9.00%','10.00%','11.00%'],
    ["Idaho", '5.80%'],
    ["Illinois", '4.95%'],
    ["Indiana", '3.15%'],
    ["Iowa", '4.40%', '4.82%', '5.70%', '6.00%'],
    ["Kansas", '3.10%', '5.25%', '5.70%'],
    ["Kentucky", '4.50%'],
    ["Louisiana", '1.85%', '3.50%', '4.25%'],
    ["Maine", '5.80%', '6.75%', '7.15%'],
    ["Maryland", '2.00%', '3.00%', '4.00%', '4.75%', '5.00%', '5.25%', '5.50%', '5.75%'],
    ["Massachusetts", '5.00%', '9.00%'],
    ["Michigan", '4.25%'],
    ["Minnesota", '5.35%', '6.80%', '7.85%', '9.85%'],
    ["Mississippi", '5.00%'],
    ["Missouri", '2.00%', '2.50%', '3.00%', '3.50%', '4.00%', '4.50%', '4.95%'],
    ["Montana", '1.00%', '2.00%', '3.00%', '4.00%', '5.00%', '6.00%', '6.75%'],
    ["Nebraska", '2.46%', '3.51%', '5.01%', '6.64%'],
    ["Nevada",'0.00%'],
    ["New Hampshire",'0.00%'],
    ["New Jersey",'1.400%', '1.750%', '3.500%', '5.525%', '6.370%', '8.970%', '10.750%'],
    ["New Mexico",'1.70%', '3.20%', '4.70%', '4.90%', '5.90%'],
    ["New York",'4.00%', '4.50%', '5.25%', '5.50%', '6.00%', '6.85%', '9.65%', '10.30%', '10.90%'],
    ["North Carolina",'4.75%'],
    ["North Dakota", '1.10%', '2.04%', '2.27%', '2.64%', '2.90%'],
    ["Ohio",'2.765%', '3.226%', '3.688%', '3.990%'],
    ["Oklahoma",'0.25%', '0.75%', '1.75%', '2.75%', '3.75%', '4.75%'],
    ["Oregon",'4.75%', '6.75%', '8.75%', '9.90%'],
    ["Pennsylvania",'3.07%'],
    ["Rhode Island",'3.75%', '4.75%', '5.99%'],
    ["South Carolina",'0.00%', '3.00%', '6.50%'],
    ["South Dakota",'0.00%'],
    ["Tennessee",'0.00%'],
    ["Texas",'0.00%'],
    ["Utah",'4.85%'],
    ["Vermont",'3.35%', '6.60%', '7.60%', '8.75%'],
    ["Virginia",'2.00%', '3.00%', '5.00%', '5.75%'],
    ["Washington",'0.00%'],
    ["West Virginia",'3.00%', '4.00%', '4.50%', '6.00%', '6.50%'], 
    ["Wisconsin",'3.54%', '4.65%', '5.30%', '7.65%'],
    ["Wyoming",'0.00%'],
]

#Remove the state name from the list
state_rates_2023 = [lst[1:] for lst in state_rates_2023]

state_taxtype_df['rates'] = state_rates_2023




state_taxtype_df["TaxType_str"] = ""
state_taxtype_df["TaxType_str"][state_taxtype_df["TaxType"]==0] = \
    "No state labor income tax"
state_taxtype_df["TaxType_str"][state_taxtype_df["TaxType"]==1] = \
    "Flat state income tax rate"
state_taxtype_df["TaxType_str"][state_taxtype_df["TaxType"]==2] = \
    "Nearly flat state income tax rates"
state_taxtype_df["TaxType_str"][state_taxtype_df["TaxType"]==3] = \
    "Progressive state income tax rates"
state_taxtype_df["TaxType_str_short"] = ""
state_taxtype_df["TaxType_str_short"][state_taxtype_df["TaxType"]==0] = \
    "No income tax"
state_taxtype_df["TaxType_str_short"][state_taxtype_df["TaxType"]==1] = \
    "Flat income tax rate"
state_taxtype_df["TaxType_str_short"][state_taxtype_df["TaxType"]==2] = \
    "Nearly flat income tax rates"
state_taxtype_df["TaxType_str_short"][state_taxtype_df["TaxType"]==3] = \
    "Progressive income tax rates"
state_taxtype_df["fill_color"] = ""
state_taxtype_df["fill_color"][state_taxtype_df["TaxType"]==0] = "white"
state_taxtype_df["fill_color"][state_taxtype_df["TaxType"]==1] = "red"
state_taxtype_df["fill_color"][state_taxtype_df["TaxType"]==2] = "purple"
state_taxtype_df["fill_color"][state_taxtype_df["TaxType"]==3] = "blue"

# Sort alphabetically by full state name
state_taxtype_df.sort_values("State", inplace=True, ignore_index=True)

# Create sub-DataFrames for each tax type
no_tax_states_df = \
    state_taxtype_df[state_taxtype_df["TaxType"]==0].reset_index(drop=True)
flat_tax_states_df = \
    state_taxtype_df[state_taxtype_df["TaxType"]==1].reset_index(drop=True)
nflat_tax_states_df = \
    state_taxtype_df[state_taxtype_df["TaxType"]==2].reset_index(drop=True)
prog_tax_states_df = \
    state_taxtype_df[state_taxtype_df["TaxType"]==3].reset_index(drop=True)
print(state_taxtype_df.groupby("TaxType").count())

# Save state_data_df as .csv
state_taxtype_df.to_csv('./data/state_taxtype.csv', index=False)
state_taxtype_df
# Out:
#          State  Abbrev  rates  TaxType_str  TaxType_str_short  fill_color
# TaxType
# 0            9       9      9            9                  9           9
# 1           12      12     12           12                 12          12
# 2            5       5      5            5                  5           5
# 3           25      25     25           25                 25          25
#                    State Abbrev  TaxType  \
# 0                Alabama     AL        2
# 1                 Alaska     AK        0
# 2                Arizona     AZ        1
# 3               Arkansas     AR        3
# 4             California     CA        3
# 5               Colorado     CO        1
# 6            Connecticut     CT        3
# 7               Delaware     DE        3
# 8   District of Columbia     DC        3
# 9                Florida     FL        0
# 10               Georgia     GA        2
# 11                Hawaii     HI        3
# 12                 Idaho     ID        1
# 13              Illinois     IL        1
# 14               Indiana     IN        1
# 15                  Iowa     IA        2
# 16                Kansas     KS        3
# 17              Kentucky     KY        1
# 18             Louisiana     LA        3
# 19                 Maine     ME        3
# 20              Maryland     MD        3
# 21         Massachusetts     MA        1
# 22              Michigan     MI        1
# 23             Minnesota     MN        3
# 24           Mississippi     MS        1
# 25              Missouri     MO        2
# 26               Montana     MT        3
# 27              Nebraska     NE        3
# 28                Nevada     NV        0
# 29         New Hampshire     NH        0
# 30            New Jersey     NJ        3
# 31            New Mexico     NM        3
# 32              New York     NY        3
# 33        North Carolina     NC        1
# 34          North Dakota     ND        3
# 35                  Ohio     OH        3
# 36              Oklahoma     OK        2
# 37                Oregon     OR        3
# 38          Pennsylvania     PA        1
# 39          Rhode Island     RI        3
# 40        South Carolina     SC        3
# 41          South Dakota     SD        0
# 42             Tennessee     TN        0
# 43                 Texas     TX        0
# 44                  Utah     UT        1
# 45               Vermont     VT        3
# 46              Virginia     VA        3
# 47            Washington     WA        0
# 48         West Virginia     WV        3
# 49             Wisconsin     WI        3
# 50               Wyoming     WY        0
#
#                                                 rates  \
# 0                               [2.00%, 4.00%, 5.00%]
# 1                                             [0.00%]
# 2                                             [2.50%]
# 3                               [2.00%, 4.00%, 4.90%]
# 4   [1.00%, 2.00%, 4.00%, 6.00%, 8.00%, 9.30%, 10....
# 5                                             [4.40%]
# 6   [3.00%, 5.00%, 5.50%, 6.00%, 6.50%, 6.90%, 6.99%]
# 7          [2.20%, 3.90%, 4.80%, 5.20%, 5.55%, 6.60%]
# 8   [4.00%, 6.00%, 6.50%, 8.50%, 9.25%, 9.75%, 10....
# 9                                             [0.00%]
# 10         [1.00%, 2.00%, 3.00%, 4.00%, 5.00%, 5.75%]
# 11  [1.40%, 3.20%, 5.50%, 6.40%, 6.80%, 7.20%, 7.6...
# 12                                            [5.80%]
# 13                                            [4.95%]
# 14                                            [3.15%]
# 15                       [4.40%, 4.82%, 5.70%, 6.00%]
# 16                              [3.10%, 5.25%, 5.70%]
# 17                                            [4.50%]
# 18                              [1.85%, 3.50%, 4.25%]
# 19                              [5.80%, 6.75%, 7.15%]
# 20  [2.00%, 3.00%, 4.00%, 4.75%, 5.00%, 5.25%, 5.5...
# 21                                     [5.00%, 9.00%]
# 22                                            [4.25%]
# 23                       [5.35%, 6.80%, 7.85%, 9.85%]
# 24                                            [5.00%]
# 25  [2.00%, 2.50%, 3.00%, 3.50%, 4.00%, 4.50%, 4.95%]
# 26  [1.00%, 2.00%, 3.00%, 4.00%, 5.00%, 6.00%, 6.75%]
# 27                       [2.46%, 3.51%, 5.01%, 6.64%]
# 28                                            [0.00%]
# 29                                            [0.00%]
# 30  [1.400%, 1.750%, 3.500%, 5.525%, 6.370%, 8.970...
# 31                [1.70%, 3.20%, 4.70%, 4.90%, 5.90%]
# 32  [4.00%, 4.50%, 5.25%, 5.50%, 6.00%, 6.85%, 9.6...
# 33                                            [4.75%]
# 34                [1.10%, 2.04%, 2.27%, 2.64%, 2.90%]
# 35                   [2.765%, 3.226%, 3.688%, 3.990%]
# 36         [0.25%, 0.75%, 1.75%, 2.75%, 3.75%, 4.75%]
# 37                       [4.75%, 6.75%, 8.75%, 9.90%]
# 38                                            [3.07%]
# 39                              [3.75%, 4.75%, 5.99%]
# 40                              [0.00%, 3.00%, 6.50%]
# 41                                            [0.00%]
# 42                                            [0.00%]
# 43                                            [0.00%]
# 44                                            [4.85%]
# 45                       [3.35%, 6.60%, 7.60%, 8.75%]
# 46                       [2.00%, 3.00%, 5.00%, 5.75%]
# 47                                            [0.00%]
# 48                [3.00%, 4.00%, 4.50%, 6.00%, 6.50%]
# 49                       [3.54%, 4.65%, 5.30%, 7.65%]
# 50                                            [0.00%]
#
#                            TaxType_str             TaxType_str_short  \
# 0   Nearly flat state income tax rates  Nearly flat income tax rates
# 1            No state labor income tax                 No income tax
# 2           Flat state income tax rate          Flat income tax rate
# 3   Progressive state income tax rates  Progressive income tax rates
# 4   Progressive state income tax rates  Progressive income tax rates
# 5           Flat state income tax rate          Flat income tax rate
# 6   Progressive state income tax rates  Progressive income tax rates
# 7   Progressive state income tax rates  Progressive income tax rates
# 8   Progressive state income tax rates  Progressive income tax rates
# 9            No state labor income tax                 No income tax
# 10  Nearly flat state income tax rates  Nearly flat income tax rates
# 11  Progressive state income tax rates  Progressive income tax rates
# 12          Flat state income tax rate          Flat income tax rate
# 13          Flat state income tax rate          Flat income tax rate
# 14          Flat state income tax rate          Flat income tax rate
# 15  Nearly flat state income tax rates  Nearly flat income tax rates
# 16  Progressive state income tax rates  Progressive income tax rates
# 17          Flat state income tax rate          Flat income tax rate
# 18  Progressive state income tax rates  Progressive income tax rates
# 19  Progressive state income tax rates  Progressive income tax rates
# 20  Progressive state income tax rates  Progressive income tax rates
# 21          Flat state income tax rate          Flat income tax rate
# 22          Flat state income tax rate          Flat income tax rate
# 23  Progressive state income tax rates  Progressive income tax rates
# 24          Flat state income tax rate          Flat income tax rate
# 25  Nearly flat state income tax rates  Nearly flat income tax rates
# 26  Progressive state income tax rates  Progressive income tax rates
# 27  Progressive state income tax rates  Progressive income tax rates
# 28           No state labor income tax                 No income tax
# 29           No state labor income tax                 No income tax
# 30  Progressive state income tax rates  Progressive income tax rates
# 31  Progressive state income tax rates  Progressive income tax rates
# 32  Progressive state income tax rates  Progressive income tax rates
# 33          Flat state income tax rate          Flat income tax rate
# 34  Progressive state income tax rates  Progressive income tax rates
# 35  Progressive state income tax rates  Progressive income tax rates
# 36  Nearly flat state income tax rates  Nearly flat income tax rates
# 37  Progressive state income tax rates  Progressive income tax rates
# 38          Flat state income tax rate          Flat income tax rate
# 39  Progressive state income tax rates  Progressive income tax rates
# 40  Progressive state income tax rates  Progressive income tax rates
# 41           No state labor income tax                 No income tax
# 42           No state labor income tax                 No income tax
# 43           No state labor income tax                 No income tax
# 44          Flat state income tax rate          Flat income tax rate
# 45  Progressive state income tax rates  Progressive income tax rates
# 46  Progressive state income tax rates  Progressive income tax rates
# 47           No state labor income tax                 No income tax
# 48  Progressive state income tax rates  Progressive income tax rates
# 49  Progressive state income tax rates  Progressive income tax rates
# 50           No state labor income tax                 No income tax
#
#    fill_color
# 0      purple
# 1       white
# 2         red
# 3        blue
# 4        blue
# 5         red
# 6        blue
# 7        blue
# 8        blue
# 9       white
# 10     purple
# 11       blue
# 12        red
# 13        red
# 14        red
# 15     purple
# 16       blue
# 17        red
# 18       blue
# 19       blue
# 20       blue
# 21        red
# 22        red
# 23       blue
# 24        red
# 25     purple
# 26       blue
# 27       blue
# 28      white
# 29      white
# 30       blue
# 31       blue
# 32       blue
# 33        red
# 34       blue
# 35       blue
# 36     purple
# 37       blue
# 38        red
# 39       blue
# 40       blue
# 41      white
# 42      white
# 43      white
# 44        red
# 45       blue
# 46       blue
# 47      white
# 48       blue
# 49       blue
# 50      white

# %%
# Print the no tax states
no_tax_states_df
# Out:
#            State Abbrev  TaxType    rates                TaxType_str  \
# 0         Alaska     AK        0  [0.00%]  No state labor income tax
# 1        Florida     FL        0  [0.00%]  No state labor income tax
# 2         Nevada     NV        0  [0.00%]  No state labor income tax
# 3  New Hampshire     NH        0  [0.00%]  No state labor income tax
# 4   South Dakota     SD        0  [0.00%]  No state labor income tax
# 5      Tennessee     TN        0  [0.00%]  No state labor income tax
# 6          Texas     TX        0  [0.00%]  No state labor income tax
# 7     Washington     WA        0  [0.00%]  No state labor income tax
# 8        Wyoming     WY        0  [0.00%]  No state labor income tax
#
#   TaxType_str_short fill_color
# 0     No income tax      white
# 1     No income tax      white
# 2     No income tax      white
# 3     No income tax      white
# 4     No income tax      white
# 5     No income tax      white
# 6     No income tax      white
# 7     No income tax      white
# 8     No income tax      white

# %%
# Print the flat tax states
flat_tax_states_df
# Out:
#              State Abbrev  TaxType           rates  \
# 0          Arizona     AZ        1         [2.50%]
# 1         Colorado     CO        1         [4.40%]
# 2            Idaho     ID        1         [5.80%]
# 3         Illinois     IL        1         [4.95%]
# 4          Indiana     IN        1         [3.15%]
# 5         Kentucky     KY        1         [4.50%]
# 6    Massachusetts     MA        1  [5.00%, 9.00%]
# 7         Michigan     MI        1         [4.25%]
# 8      Mississippi     MS        1         [5.00%]
# 9   North Carolina     NC        1         [4.75%]
# 10    Pennsylvania     PA        1         [3.07%]
# 11            Utah     UT        1         [4.85%]
#
#                    TaxType_str     TaxType_str_short fill_color
# 0   Flat state income tax rate  Flat income tax rate        red
# 1   Flat state income tax rate  Flat income tax rate        red
# 2   Flat state income tax rate  Flat income tax rate        red
# 3   Flat state income tax rate  Flat income tax rate        red
# 4   Flat state income tax rate  Flat income tax rate        red
# 5   Flat state income tax rate  Flat income tax rate        red
# 6   Flat state income tax rate  Flat income tax rate        red
# 7   Flat state income tax rate  Flat income tax rate        red
# 8   Flat state income tax rate  Flat income tax rate        red
# 9   Flat state income tax rate  Flat income tax rate        red
# 10  Flat state income tax rate  Flat income tax rate        red
# 11  Flat state income tax rate  Flat income tax rate        red

# %%
# Print the nearly flat tax states
nflat_tax_states_df
# Out:
#       State Abbrev  TaxType  \
# 0   Alabama     AL        2
# 1   Georgia     GA        2
# 2      Iowa     IA        2
# 3  Missouri     MO        2
# 4  Oklahoma     OK        2
#
#                                                rates  \
# 0                              [2.00%, 4.00%, 5.00%]
# 1         [1.00%, 2.00%, 3.00%, 4.00%, 5.00%, 5.75%]
# 2                       [4.40%, 4.82%, 5.70%, 6.00%]
# 3  [2.00%, 2.50%, 3.00%, 3.50%, 4.00%, 4.50%, 4.95%]
# 4         [0.25%, 0.75%, 1.75%, 2.75%, 3.75%, 4.75%]
#
#                           TaxType_str             TaxType_str_short fill_color
# 0  Nearly flat state income tax rates  Nearly flat income tax rates     purple
# 1  Nearly flat state income tax rates  Nearly flat income tax rates     purple
# 2  Nearly flat state income tax rates  Nearly flat income tax rates     purple
# 3  Nearly flat state income tax rates  Nearly flat income tax rates     purple
# 4  Nearly flat state income tax rates  Nearly flat income tax rates     purple

# %%
# Print the progressive tax states
prog_tax_states_df
# Out:
#                    State Abbrev  TaxType  \
# 0               Arkansas     AR        3
# 1             California     CA        3
# 2            Connecticut     CT        3
# 3               Delaware     DE        3
# 4   District of Columbia     DC        3
# 5                 Hawaii     HI        3
# 6                 Kansas     KS        3
# 7              Louisiana     LA        3
# 8                  Maine     ME        3
# 9               Maryland     MD        3
# 10             Minnesota     MN        3
# 11               Montana     MT        3
# 12              Nebraska     NE        3
# 13            New Jersey     NJ        3
# 14            New Mexico     NM        3
# 15              New York     NY        3
# 16          North Dakota     ND        3
# 17                  Ohio     OH        3
# 18                Oregon     OR        3
# 19          Rhode Island     RI        3
# 20        South Carolina     SC        3
# 21               Vermont     VT        3
# 22              Virginia     VA        3
# 23         West Virginia     WV        3
# 24             Wisconsin     WI        3
#
#                                                 rates  \
# 0                               [2.00%, 4.00%, 4.90%]
# 1   [1.00%, 2.00%, 4.00%, 6.00%, 8.00%, 9.30%, 10....
# 2   [3.00%, 5.00%, 5.50%, 6.00%, 6.50%, 6.90%, 6.99%]
# 3          [2.20%, 3.90%, 4.80%, 5.20%, 5.55%, 6.60%]
# 4   [4.00%, 6.00%, 6.50%, 8.50%, 9.25%, 9.75%, 10....
# 5   [1.40%, 3.20%, 5.50%, 6.40%, 6.80%, 7.20%, 7.6...
# 6                               [3.10%, 5.25%, 5.70%]
# 7                               [1.85%, 3.50%, 4.25%]
# 8                               [5.80%, 6.75%, 7.15%]
# 9   [2.00%, 3.00%, 4.00%, 4.75%, 5.00%, 5.25%, 5.5...
# 10                       [5.35%, 6.80%, 7.85%, 9.85%]
# 11  [1.00%, 2.00%, 3.00%, 4.00%, 5.00%, 6.00%, 6.75%]
# 12                       [2.46%, 3.51%, 5.01%, 6.64%]
# 13  [1.400%, 1.750%, 3.500%, 5.525%, 6.370%, 8.970...
# 14                [1.70%, 3.20%, 4.70%, 4.90%, 5.90%]
# 15  [4.00%, 4.50%, 5.25%, 5.50%, 6.00%, 6.85%, 9.6...
# 16                [1.10%, 2.04%, 2.27%, 2.64%, 2.90%]
# 17                   [2.765%, 3.226%, 3.688%, 3.990%]
# 18                       [4.75%, 6.75%, 8.75%, 9.90%]
# 19                              [3.75%, 4.75%, 5.99%]
# 20                              [0.00%, 3.00%, 6.50%]
# 21                       [3.35%, 6.60%, 7.60%, 8.75%]
# 22                       [2.00%, 3.00%, 5.00%, 5.75%]
# 23                [3.00%, 4.00%, 4.50%, 6.00%, 6.50%]
# 24                       [3.54%, 4.65%, 5.30%, 7.65%]
#
#                            TaxType_str             TaxType_str_short  \
# 0   Progressive state income tax rates  Progressive income tax rates
# 1   Progressive state income tax rates  Progressive income tax rates
# 2   Progressive state income tax rates  Progressive income tax rates
# 3   Progressive state income tax rates  Progressive income tax rates
# 4   Progressive state income tax rates  Progressive income tax rates
# 5   Progressive state income tax rates  Progressive income tax rates
# 6   Progressive state income tax rates  Progressive income tax rates
# 7   Progressive state income tax rates  Progressive income tax rates
# 8   Progressive state income tax rates  Progressive income tax rates
# 9   Progressive state income tax rates  Progressive income tax rates
# 10  Progressive state income tax rates  Progressive income tax rates
# 11  Progressive state income tax rates  Progressive income tax rates
# 12  Progressive state income tax rates  Progressive income tax rates
# 13  Progressive state income tax rates  Progressive income tax rates
# 14  Progressive state income tax rates  Progressive income tax rates
# 15  Progressive state income tax rates  Progressive income tax rates
# 16  Progressive state income tax rates  Progressive income tax rates
# 17  Progressive state income tax rates  Progressive income tax rates
# 18  Progressive state income tax rates  Progressive income tax rates
# 19  Progressive state income tax rates  Progressive income tax rates
# 20  Progressive state income tax rates  Progressive income tax rates
# 21  Progressive state income tax rates  Progressive income tax rates
# 22  Progressive state income tax rates  Progressive income tax rates
# 23  Progressive state income tax rates  Progressive income tax rates
# 24  Progressive state income tax rates  Progressive income tax rates
#
#    fill_color
# 0        blue
# 1        blue
# 2        blue
# 3        blue
# 4        blue
# 5        blue
# 6        blue
# 7        blue
# 8        blue
# 9        blue
# 10       blue
# 11       blue
# 12       blue
# 13       blue
# 14       blue
# 15       blue
# 16       blue
# 17       blue
# 18       blue
# 19       blue
# 20       blue
# 21       blue
# 22       blue
# 23       blue
# 24       blue

# %% [markdown]
# Create the Bokeh state map figure

# %%
fig1_title = "Type of state employment income tax system as of January 2023"
output_file(
    "./images/state_taxtype_2023.html", title=fig1_title, mode='inline'
)
output_notebook()

# Download U.S. states shape files from US Census Bureau
# https://www.census.gov/geographies/mapping-files/2018/geo/carto-boundary-file.html
us_shapefile_path = ("https://github.com/TheCGO/KS-FlatTax/raw/main/data/" +
                     "cb_2018_us_state_20m/cb_2018_us_state_20m.shp")
gdf = gpd.GeoDataFrame.from_file(us_shapefile_path)
gdf_json = gdf.to_json()
gjson = json.loads(gdf_json)

# Remove Puerto Rico from data
del(gjson["features"][7])

# Alaska
# Fix positive longitudes
min_lat_ak = 180  # initial value that will be adjusted
min_abs_lon_ak = 180  # initial value that will be adjusted
coords_list = gjson["features"][24]["geometry"]["coordinates"]
for ind_isl, island in enumerate(coords_list):
    for ind_pnt, point in enumerate(island[0]):
        min_lat_ak = np.minimum(min_lat_ak, point[1])
        if point[0] > 0:
            gjson["features"][24]["geometry"][
                "coordinates"
            ][ind_isl][0][ind_pnt][0] = -180 - (180 - point[0])
        else:
            min_abs_lon_ak = np.minimum(min_abs_lon_ak, -point[0])

# Shrink the size of Alaska relative to its southestern most minimum lattitude
# and longitude
shrink_pct_ak = 0.65
coords_list_ak = gjson["features"][24]["geometry"]["coordinates"]
for ind_isl, island in enumerate(coords_list_ak):
    for ind_pnt, point in enumerate(island[0]):
        gjson["features"][24]["geometry"][
            "coordinates"
        ][ind_isl][0][ind_pnt][0] = point[0] - shrink_pct_ak * (point[0] +
                                                                min_abs_lon_ak)
        gjson["features"][24]["geometry"][
            "coordinates"
        ][ind_isl][0][ind_pnt][1] = point[1] - shrink_pct_ak * (point[1] -
                                                                min_lat_ak)

# Move Alaska closer to the mainland such that the minimum minimum absolute
# longitude and lattitude are (-127, 44)
min_lat_ak_new = 44
min_abs_lon_ak_new = 127
for ind_isl, island in enumerate(coords_list):
    for ind_pnt, point in enumerate(island[0]):
        gjson["features"][24]["geometry"][
            "coordinates"
        ][ind_isl][0][ind_pnt][0] = point[0] + (min_abs_lon_ak -
                                                min_abs_lon_ak_new)
        gjson["features"][24]["geometry"][
            "coordinates"
        ][ind_isl][0][ind_pnt][1] = point[1] - (min_lat_ak - min_lat_ak_new)

# Hawaii
list_ind_hi = 47
# Get minimum lattitude and minimum absolute longitude for Hawaii
min_lat_hi = 180  # initial value that will be adjusted
min_abs_lon_hi = 180  # initial value that will be adjusted
coords_list = gjson["features"][list_ind_hi]["geometry"]["coordinates"]
for ind_isl, island in enumerate(coords_list):
    for ind_pnt, point in enumerate(island[0]):
        min_lat_hi = np.minimum(min_lat_hi, point[1])
        min_abs_lon_hi = np.minimum(min_abs_lon_hi, -point[0])
# print("Minimum lattitude for Hawaii is", min_lat_hi)
# print("Minimum absolute longitude for Hawaii is", min_abs_lon_hi)

# Increase the size of Hawaii
incr_pct_hi = 0.4
coords_list_hi = gjson["features"][list_ind_hi]["geometry"]["coordinates"]
for ind_isl, island in enumerate(coords_list_hi):
    for ind_pnt, point in enumerate(island[0]):
        gjson["features"][list_ind_hi]["geometry"][
            "coordinates"
        ][ind_isl][0][ind_pnt][0] = point[0] + incr_pct_hi * (point[0] +
                                                              min_abs_lon_hi)
        gjson["features"][list_ind_hi]["geometry"][
            "coordinates"
        ][ind_isl][0][ind_pnt][1] = point[1] + incr_pct_hi * (point[1] -
                                                              min_lat_hi)

# Move Hawaii closer to the mainland such that the minimum minimum absolute
# longitude and lattitude are (-125, 27)
min_lat_hi_new = 27.5
min_abs_lon_hi_new = 124.5
for ind_isl, island in enumerate(coords_list):
    for ind_pnt, point in enumerate(island[0]):
        gjson["features"][list_ind_hi]["geometry"][
            "coordinates"
        ][ind_isl][0][ind_pnt][0] = point[0] + (min_abs_lon_hi -
                                                min_abs_lon_hi_new)
        gjson["features"][list_ind_hi]["geometry"][
            "coordinates"
        ][ind_isl][0][ind_pnt][1] = point[1] - (min_lat_hi - min_lat_hi_new)

# Add a state box around Delaware abbreviation DE
st_list_num = 2
de_coord_list = [gjson["features"][st_list_num]["geometry"]["coordinates"]]
new_box_de = [[
    [-75.4, 38.8],
    [-72.4, 38.3],
    [-72.4, 38.9],
    [-70.2, 38.9],
    [-70.2, 37.7],
    [-72.4, 37.7],
    [-72.4, 38.3]
]]
de_coord_list.append(new_box_de)
gjson["features"][st_list_num]["geometry"]["coordinates"] = de_coord_list
gjson["features"][st_list_num]["geometry"]["type"] = "MultiPolygon"

# Add a state box around Washington, DC (District of Columbia) abbreviation DC
st_list_num = 35
dc_coord_list = [gjson["features"][st_list_num]["geometry"]["coordinates"]]
new_box_dc = [[
    [-77.0, 38.9],
    [-73.3, 35.5],
    [-73.3, 36.1],
    [-71.1, 36.1],
    [-71.1, 34.9],
    [-73.3, 34.9],
    [-73.3, 35.5]
]]
dc_coord_list.append(new_box_dc)
gjson["features"][st_list_num]["geometry"]["coordinates"] = dc_coord_list
gjson["features"][st_list_num]["geometry"]["type"] = "MultiPolygon"

# Add a state box around Massachusetts abbreviation MD
st_list_num = 0
md_coord_list = gjson["features"][st_list_num]["geometry"]["coordinates"]
new_box_md = [[
    [-76.8, 39.3],
    [-72.7, 37.0],
    [-72.7, 37.6],
    [-70.5, 37.6],
    [-70.5, 36.4],
    [-72.7, 36.4],
    [-72.7, 37.0]
]]
md_coord_list.append(new_box_md)
gjson["features"][st_list_num]["geometry"]["coordinates"] = md_coord_list

# Add a state box around Massachusetts abbreviation MA
st_list_num = 29
ma_coord_list = gjson["features"][st_list_num]["geometry"]["coordinates"]
new_box_ma = [[
    [-71.7, 42.2],
    [-68.5, 42.2],
    [-68.5, 42.8],
    [-66.3, 42.8],
    [-66.3, 41.6],
    [-68.5, 41.6],
    [-68.5, 42.2]
]]
ma_coord_list.append(new_box_ma)
gjson["features"][st_list_num]["geometry"]["coordinates"] = ma_coord_list

# Add a state box around New Jersey abbreviation NJ
st_list_num = 34
nj_coord_list = [gjson["features"][st_list_num]["geometry"]["coordinates"]]
new_box_nj = [[
    [-74.4, 40.1],
    [-72.0, 39.7],
    [-72.0, 40.3],
    [-69.8, 40.3],
    [-69.8, 39.1],
    [-72.0, 39.1],
    [-72.0, 39.7]
]]
nj_coord_list.append(new_box_nj)
gjson["features"][st_list_num]["geometry"]["coordinates"] = nj_coord_list
gjson["features"][st_list_num]["geometry"]["type"] = "MultiPolygon"

# Add a state box around Rhode Island abbreviation RI
st_list_num = 50
ri_coord_list = gjson["features"][st_list_num]["geometry"]["coordinates"]
new_box_ri = [[
    [-71.5, 41.7],
    [-69.5, 40.4],
    [-69.5, 41.0],
    [-67.3, 41.0],
    [-67.3, 39.8],
    [-69.5, 39.8],
    [-69.5, 40.4]
]]
ri_coord_list.append(new_box_ri)
gjson["features"][st_list_num]["geometry"]["coordinates"] = ri_coord_list

# Merge the state tax type data into gjson for each state
state_taxtype_df
for ind_st, state in enumerate(gjson["features"]):
    st_abbrev = state["properties"]["STUSPS"]
    state["properties"]["rates"] = state_taxtype_df[
        state_taxtype_df["Abbrev"]==st_abbrev]["rates"].iloc[0]
    state["properties"]["tax_type"] = state_taxtype_df[
        state_taxtype_df["Abbrev"]==st_abbrev
    ]["TaxType_str_short"].iloc[0]

tax_type_labels = [
    'No income tax', 'Flat income tax rate', 'Nearly flat income tax rates',
    'Progressive income tax rates'
]
tax_type_colors = ["white", "red", "purple", "blue"]

source_shapes = {}
for category in tax_type_labels:
    source_shapes[category] = {"type": "FeatureCollection", "features": []}

for item in gjson["features"]:
    source_shapes[item["properties"]["tax_type"]]['features'].append(item)

TOOLS = "pan, box_zoom, wheel_zoom, hover, save, reset, help"

fig1 = figure(
    title=fig1_title,
    height=500,
    width=1050,
    tools=TOOLS,
    # tooltips=[
    #     ("State", @state_names), ("Tax type", @tax_type)
    # ]
    # match_aspect = True,
    min_border = 0,
    x_axis_location = None, y_axis_location = None,
    toolbar_location="right"
)
fig1.toolbar.logo = None
fig1.grid.grid_line_color = None

cmap = CategoricalColorMapper(
    palette=tax_type_colors, factors=tax_type_labels
)
for category in tax_type_labels:
    source_shape_1 = GeoJSONDataSource(
        geojson = json.dumps(source_shapes[category])
    )
    fig1.patches(
        'xs', 'ys', source=source_shape_1, fill_alpha=0.7,
        fill_color = {'field': 'tax_type', 'transform': cmap},
        line_color ='black', line_width=1.0, line_alpha=0.3,
        hover_line_color="black", hover_line_width=3.0, legend_label=category)
    
    hover = fig1.select_one(HoverTool)
    hover.point_policy = "follow_mouse"
    hover.tooltips = [
        ("State", "@NAME"),
        ("Tax type", "@tax_type"),
        ("Tax rate(s)", "@rates")
    ]

# Add 2-letter state abbreviation labels. See Bokeh documentation for labels at
# https://docs.bokeh.org/en/latest/docs/user_guide/basic/annotations.html.
label_lon_lat =[
    ["AL",  -87.40, 32.10],
    ["AK", -135.00, 48.30],
    ["AZ", -112.40, 34.00],
    ["AR",  -93.20, 34.30],
    ["CA", -121.00, 37.00],
    ["CO", -106.50, 38.50],
    ["CT",  -73.40, 41.15],
    ["DE",  -72.10, 37.80],
    ["DC",  -73.00, 35.00],
    ["FL",  -82.40, 28.00],
    ["GA",  -84.20, 32.20],
    ["HI", -125.00, 29.00],
    ["ID", -115.00, 43.00],
    ["IL",  -89.60, 39.50],
    ["IN",  -86.90, 39.60],
    ["IA",  -94.40, 41.60],
    ["KS",  -99.50, 38.00],
    ["KY",  -86.00, 37.00],
    ["LA",  -93.00, 30.20],
    ["ME",  -70.00, 44.50],
    ["MD",  -72.40, 36.50],
    ["MA",  -68.20, 41.80],
    ["MI",  -85.40, 42.70],
    ["MN",  -95.30, 45.50],
    ["MS",  -90.60, 32.10],
    ["MO",  -93.50, 38.00],
    ["MT", -110.50, 46.50],
    ["NE", -100.50, 41.00],
    ["NV", -118.00, 39.00],
    ["NH",  -72.45, 42.70],
    ["NM", -107.00, 34.00],
    ["NJ",  -71.60, 39.20],
    ["NY",  -76.00, 42.50],
    ["NC",  -79.20, 35.00],
    ["ND", -101.50, 46.80],
    ["OH",  -83.80, 39.90],
    ["OK",  -98.00, 35.00],
    ["OR", -121.50, 43.50],
    ["PA",  -78.50, 40.40],
    ["RI",  -69.00, 39.90],
    ["SC",  -81.50, 33.30],
    ["SD", -101.00, 44.00],
    ["TN",  -87.10, 35.40],
    ["TX", -100.00, 31.00],
    ["UT", -112.50, 39.00],
    ["VT",  -73.20, 44.10],
    ["VA",  -79.00, 37.10],
    ["WA", -121.00, 47.00],
    ["WV",  -81.90, 38.00],
    ["WI",  -90.40, 44.00],
    ["WY", -108.50, 42.50]
]
label_abbrev = [state[0] for state in label_lon_lat]
label_lon = [state[1] for state in label_lon_lat]
label_lat = [state[2] for state in label_lon_lat]
state_cds = ColumnDataSource(data=dict(
    lon=label_lon,
    lat=label_lat,
    abbrev=label_abbrev
))

state_labels = LabelSet(
    x='lon', y='lat', text='abbrev', text_font_size="9pt",
    text_font_style="bold", x_offset=0, y_offset=0, source=state_cds
)

fig1.add_layout(state_labels)

# Legend properties
fig1.legend.click_policy = 'mute'
fig1.legend.location = "center_left"

fig1.add_layout(
    Title(
        text="  Source: Richard W. Evans (@RickEcon), updated June 8, 2023.",
        align="left",
        text_font_size="3mm",
        text_font_style="italic",
    ),
    "below"
)
show(fig1)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="e096b3b9-02cf-4640-b13b-06a562ae2aa2">Loading BokehJS ...</span>
#     </div>
#   <div id="a8841fea-7c23-4574-b958-d3ef7c0703ba" data-root-id="p2089" style="display: contents;"></div>

# %%
gjson
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'id': '0',
#    'type': 'Feature',
#    'properties': {'STATEFP': '24',
#     'STATENS': '01714934',
#     'AFFGEOID': '0400000US24',
#     'GEOID': '24',
#     'STUSPS': 'MD',
#     'NAME': 'Maryland',
#     'LSAD': '00',
#     'ALAND': 25151100280,
#     'AWATER': 6979966958,
#     'rates': ['2.00%',
#      '3.00%',
#      '4.00%',
#      '4.75%',
#      '5.00%',
#      '5.25%',
#      '5.50%',
#      '5.75%'],
#     'tax_type': 'Progressive income tax rates'},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-76.046213, 38.025532999999996],
#        [-76.00733699999999, 38.036705999999995],
#        [-75.98008899999999, 38.004891],
#        [-75.98464799999999, 37.938120999999995],
#        [-76.04652999999999, 37.953586],
#        [-76.046213, 38.025532999999996]]],
#      [[[-79.484372, 39.344300000000004],
#        [-79.482366, 39.531689],
#        [-79.47666199999999, 39.721078],
#        [-79.3924584050224, 39.7214393586401],
#        [-79.045576, 39.722927999999996],
#        [-78.9284161298889, 39.7229985874409],
#        [-78.80829952962159, 39.7230709562769],
#        [-78.723578, 39.723122],
#        [-78.380477064564, 39.72270413884],
#        [-78.3428335185744, 39.722658292926496],
#        [-78.342593, 39.722657999999996],
#        [-78.09897069616669, 39.722466194428094],
#        [-78.075861, 39.722448],
#        [-77.768644, 39.721537999999995],
#        [-77.469274, 39.720228999999996],
#        [-77.4691450036804, 39.72022900225],
#        [-77.45943341952389, 39.720229171644995],
#        [-77.23995, 39.720233],
#        [-77.21702375523739, 39.720217248385396],
#        [-76.9993180263332, 39.7200676723526],
#        [-76.991062, 39.720062],
#        [-76.7870971997576, 39.72104814611129],
#        [-76.71577099999999, 39.721393],
#        [-76.5694491257313, 39.721458570752695],
#        [-76.41897999999999, 39.721526],
#        [-76.2396837411146, 39.7216419899246],
#        [-76.233485, 39.721646],
#        [-76.23327934711659, 39.7216462556279],
#        [-76.13569742699019, 39.7217675506067],
#        [-75.788596, 39.722198999999996],
#        [-75.76690460670919, 39.3776515935512],
#        [-75.76689499999999, 39.377499],
#        [-75.7604414164505, 39.296789621100096],
#        [-75.7564352155685, 39.246687537125304],
#        [-75.7481548142541, 39.143131730959695],
#        [-75.72310269333269, 38.8298265565277],
#        [-75.707555026429, 38.6353853550599],
#        [-75.707551, 38.635335],
#        [-75.701777515245, 38.5607669290786],
#        [-75.70038199999999, 38.542743],
#        [-75.693721, 38.460128],
#        [-75.479283, 38.453697999999996],
#        [-75.3412873203482, 38.4524365259555],
#        [-75.18545499999999, 38.451012],
#        [-75.04893899999999, 38.451263],
#        [-75.085518, 38.32427],
#        [-75.102947, 38.311524999999996],
#        [-75.14322899999999, 38.220475],
#        [-75.17739399999999, 38.130013999999996],
#        [-75.19379599999999, 38.096013],
#        [-75.242266, 38.027209],
#        [-75.624341, 37.994211],
#        [-75.66971099999999, 37.950796],
#        [-75.722662, 37.971309999999995],
#        [-75.78381499999999, 37.972594],
#        [-75.860727, 37.91831],
#        [-75.892686, 37.916848],
#        [-75.898956, 37.974514],
#        [-75.857507, 38.038778],
#        [-75.858881, 38.060134999999995],
#        [-75.86381, 38.100968],
#        [-75.937089, 38.124209],
#        [-75.942375, 38.187066],
#        [-75.864104, 38.200858],
#        [-75.8754473114647, 38.219709301961004],
#        [-75.888513, 38.241423],
#        [-75.9237660824283, 38.246285277002],
#        [-75.9445, 38.249145],
#        [-76.038935, 38.254932],
#        [-76.031988, 38.187419999999996],
#        [-76.011916, 38.122214],
#        [-76.005904, 38.077169999999995],
#        [-76.048692, 38.086728],
#        [-76.095548, 38.125122999999995],
#        [-76.088639, 38.192648999999996],
#        [-76.135513, 38.232185],
#        [-76.217613, 38.305682999999995],
#        [-76.257667, 38.324855],
#        [-76.25, 38.362304],
#        [-76.280551, 38.403143],
#        [-76.33636, 38.492235],
#        [-76.277461, 38.541851],
#        [-76.290043, 38.569158],
#        [-76.279589, 38.609519999999996],
#        [-76.23118699999999, 38.61401],
#        [-76.203065, 38.610741],
#        [-76.165435, 38.6102],
#        [-76.1701618745873, 38.6408420471501],
#        [-76.175159, 38.673235999999996],
#        [-76.200334, 38.670774],
#        [-76.238725, 38.712845],
#        [-76.275015, 38.712714],
#        [-76.322418, 38.679303999999995],
#        [-76.34799799999999, 38.686234],
#        [-76.340543, 38.730337999999996],
#        [-76.39035, 38.757003999999995],
#        [-76.379739, 38.788314],
#        [-76.310081, 38.796845999999995],
#        [-76.271575, 38.851771],
#        [-76.21932799999999, 38.812371],
#        [-76.19109, 38.82966],
#        [-76.196868759948, 38.8557419634207],
#        [-76.205063, 38.892725999999996],
#        [-76.203638, 38.928382],
#        [-76.250868, 38.92825],
#        [-76.31794699999999, 38.911311999999995],
#        [-76.334019, 38.860237999999995],
#        [-76.37620199999999, 38.850460999999996],
#        [-76.361727, 38.939175],
#        [-76.322296, 39.006375],
#        [-76.301847, 39.039651],
#        [-76.2650366404087, 39.0285509553488],
#        [-76.231765, 39.018518],
#        [-76.233457, 39.091384999999995],
#        [-76.246481, 39.119588],
#        [-76.278527, 39.145764],
#        [-76.243166, 39.213362],
#        [-76.211253, 39.269812],
#        [-76.17770399999999, 39.298701],
#        [-76.159673, 39.335909],
#        [-76.11052699999999, 39.372257],
#        [-76.0614988219557, 39.3877481141151],
#        [-76.040962, 39.394237],
#        [-76.00688, 39.414527],
#        [-76.012312, 39.453115],
#        [-76.0376462883158, 39.4526423823093],
#        [-76.060931, 39.452208],
#        [-76.146373, 39.40531],
#        [-76.224161, 39.352779999999996],
#        [-76.29660899999999, 39.301137],
#        [-76.3254183419569, 39.2729050860827],
#        [-76.349994, 39.248822],
#        [-76.39550899999999, 39.231702],
#        [-76.425281, 39.205708],
#        [-76.463483, 39.205908],
#        [-76.498384, 39.204808],
#        [-76.5040085909181, 39.199286249126004],
#        [-76.525785, 39.177907999999995],
#        [-76.428681, 39.131709],
#        [-76.42186, 39.081441999999996],
#        [-76.420394, 39.042069999999995],
#        [-76.39408, 39.011311],
#        [-76.448981, 38.982811],
#        [-76.47128099999999, 38.956512],
#        [-76.45027999999999, 38.941113],
#        [-76.46938, 38.907613],
#        [-76.4739761636555, 38.9026933786299],
#        [-76.49068, 38.884814],
#        [-76.516944, 38.851157],
#        [-76.48987799999999, 38.838715],
#        [-76.526979, 38.787016],
#        [-76.55874299999999, 38.756352],
#        [-76.52665499999999, 38.72443],
#        [-76.52709254739419, 38.7127503012383],
#        [-76.52892299999999, 38.663889],
#        [-76.51127799999999, 38.615745],
#        [-76.517506, 38.539148999999995],
#        [-76.492699, 38.482849],
#        [-76.450937, 38.442422],
#        [-76.393378, 38.389477],
#        [-76.387002, 38.361267],
#        [-76.400194624698, 38.3198719439614],
#        [-76.402894, 38.311402],
#        [-76.374481, 38.296347999999995],
#        [-76.392668, 38.239663],
#        [-76.353516, 38.178135],
#        [-76.32013599999999, 38.138338999999995],
#        [-76.330794, 38.099331],
#        [-76.322093, 38.036502999999996],
#        [-76.37178999999999, 38.079564999999995],
#        [-76.430425, 38.119383],
#        [-76.481036, 38.115873],
#        [-76.54038, 38.152991],
#        [-76.590637, 38.214211999999996],
#        [-76.673462, 38.234401],
#        [-76.740055, 38.235226999999995],
#        [-76.805949, 38.252275],
#        [-76.8270361292819, 38.2583001006141],
#        [-76.86429199999999, 38.268944999999995],
#        [-76.92217699999999, 38.311339],
#        [-76.975492, 38.347327],
#        [-77.001638, 38.421952],
#        [-77.01637099999999, 38.445572],
#        [-77.07548899999999, 38.42471],
#        [-77.123325, 38.410646],
#        [-77.21118799999999, 38.380662],
#        [-77.259962, 38.435821],
#        [-77.246584, 38.538340999999996],
#        [-77.183767, 38.600699],
#        [-77.12908399999999, 38.614363999999995],
#        [-77.1302, 38.635017],
#        [-77.13250099999999, 38.673815999999995],
#        [-77.08578476515639, 38.7052812818324],
#        [-77.079499, 38.709514999999996],
#        [-77.05319899999999, 38.709914999999995],
#        [-77.040998, 38.737913999999996],
#        [-77.0406725707781, 38.746691930482896],
#        [-77.0392398850823, 38.785336325623604],
#        [-77.039006, 38.791644999999995],
#        [-76.979497, 38.837812],
#        [-76.909393, 38.892852],
#        [-77.002546244247, 38.9655317004459],
#        [-77.041018, 38.995548],
#        [-77.119759, 38.934343],
#        [-77.1197891567342, 38.9343765552932],
#        [-77.14660099999999, 38.96421],
#        [-77.202502, 38.967909999999996],
#        [-77.249803, 38.985909],
#        [-77.2484037049754, 39.026888354292296],
#        [-77.248403, 39.026908999999996],
#        [-77.310705, 39.052008],
#        [-77.33003770595408, 39.055952113491],
#        [-77.359702, 39.062004],
#        [-77.462617, 39.076248],
#        [-77.481279, 39.105658],
#        [-77.51992899999999, 39.120925],
#        [-77.521222, 39.161057],
#        [-77.48597099999999, 39.185665],
#        [-77.45988299999999, 39.218682],
#        [-77.4600656264978, 39.21884294385939],
#        [-77.496606, 39.251045],
#        [-77.553114, 39.279267999999995],
#        [-77.588235, 39.301955],
#        [-77.66613, 39.317008],
#        [-77.6776957620787, 39.317940817088],
#        [-77.71951899999999, 39.321314],
#        [-77.74593, 39.353221],
#        [-77.740012, 39.401694],
#        [-77.79820099999999, 39.475719],
#        [-77.81094389626219, 39.5007391665665],
#        [-77.823762, 39.525907],
#        [-77.829814, 39.587288],
#        [-77.92598799999999, 39.607642],
#        [-78.006734, 39.601337],
#        [-78.02762910017319, 39.6206559623441],
#        [-78.08225999999999, 39.671166],
#        [-78.22507499999999, 39.658878],
#        [-78.31303299999999, 39.631001],
#        [-78.3327880214991, 39.6285275964988],
#        [-78.382959, 39.622246],
#        [-78.43817899999999, 39.563524],
#        [-78.460951, 39.525987],
#        [-78.4682695950029, 39.5262242704717],
#        [-78.590654, 39.530192],
#        [-78.6550361715467, 39.544382241083696],
#        [-78.707098, 39.555856999999996],
#        [-78.73904999999999, 39.609697],
#        [-78.77114, 39.638387],
#        [-78.851016, 39.554044],
#        [-78.942618, 39.479614],
#        [-78.956751, 39.440264],
#        [-79.035623, 39.473344],
#        [-79.0674474080724, 39.4728086991282],
#        [-79.091329, 39.472407],
#        [-79.16649699999999, 39.400887999999995],
#        [-79.26239211717609, 39.3262438284674],
#        [-79.283723, 39.30964],
#        [-79.35374999999999, 39.278039],
#        [-79.424413, 39.228170999999996],
#        [-79.486873, 39.205960999999995],
#        [-79.484372, 39.344300000000004]]],
#      [[[-76.8, 39.3],
#        [-72.7, 37.0],
#        [-72.7, 37.6],
#        [-70.5, 37.6],
#        [-70.5, 36.4],
#        [-72.7, 36.4],
#        [-72.7, 37.0]]]]}},
#   {'id': '1',
#    'type': 'Feature',
#    'properties': {'STATEFP': '19',
#     'STATENS': '01779785',
#     'AFFGEOID': '0400000US19',
#     'GEOID': '19',
#     'STUSPS': 'IA',
#     'NAME': 'Iowa',
#     'LSAD': '00',
#     'ALAND': 144661267977,
#     'AWATER': 1084180812,
#     'rates': ['4.40%', '4.82%', '5.70%', '6.00%'],
#     'tax_type': 'Nearly flat income tax rates'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-96.62187499999999, 42.779255],
#       [-96.57793699999999, 42.827645],
#       [-96.53785099999999, 42.878474999999995],
#       [-96.54047232919329, 42.908595697956],
#       [-96.54168899999999, 42.922576],
#       [-96.50030799999999, 42.959391],
#       [-96.520246, 42.977643],
#       [-96.492693, 43.005089],
#       [-96.51160499999999, 43.039927],
#       [-96.458201, 43.067554],
#       [-96.4520975160537, 43.0825529251945],
#       [-96.439335, 43.113915999999996],
#       [-96.458854, 43.143356],
#       [-96.475571, 43.221053999999995],
#       [-96.52208399999999, 43.22096],
#       [-96.55296299999999, 43.247281],
#       [-96.5590273427097, 43.257555675618],
#       [-96.578823, 43.291095],
#       [-96.53039199999999, 43.300034],
#       [-96.524289, 43.347214],
#       [-96.52157199999999, 43.385639999999995],
#       [-96.59425399999999, 43.434152999999995],
#       [-96.584603, 43.469609999999996],
#       [-96.598928, 43.500457],
#       [-96.45326, 43.500389999999996],
#       [-96.198484, 43.500335],
#       [-96.05316283451, 43.5001877081575],
#       [-95.8609462015723, 43.4999928849056],
#       [-95.83442099999999, 43.499966],
#       [-95.486803, 43.500246],
#       [-95.4544322386606, 43.500322085250005],
#       [-95.38778759402189, 43.5004787289074],
#       [-95.21493799999999, 43.500885],
#       [-94.9146134847136, 43.500595872986096],
#       [-94.874235, 43.500557],
#       [-94.85455506761069, 43.5005534191522],
#       [-94.4428499897182, 43.5004785076547],
#       [-94.390597, 43.500468999999995],
#       [-94.2479674415552, 43.5001754767076],
#       [-93.97076, 43.499604999999995],
#       [-93.6485330311736, 43.4995354896751],
#       [-93.576728, 43.49952],
#       [-93.4973513252204, 43.4995307245117],
#       [-93.228861, 43.499567],
#       [-93.04919200781649, 43.4995574800246],
#       [-93.0243479005419, 43.499556163630004],
#       [-92.870277, 43.499548],
#       [-92.553161, 43.5003],
#       [-92.5531280905188, 43.5003000363123],
#       [-92.44894795143779, 43.500414988562696],
#       [-92.17886299999999, 43.500713],
#       [-92.07980199312829, 43.500704885176596],
#       [-91.824848, 43.500684],
#       [-91.7302169978377, 43.5006857009461],
#       [-91.61083500055439, 43.5006878467793],
#       [-91.491042, 43.50069],
#       [-91.21770599999999, 43.50055],
#       [-91.232276, 43.450952],
#       [-91.2106633577727, 43.4194417829033],
#       [-91.19940799999999, 43.403031999999996],
#       [-91.20736699999999, 43.373658999999996],
#       [-91.154806, 43.334826],
#       [-91.107237, 43.313645],
#       [-91.05790999999999, 43.253968],
#       [-91.08745599999999, 43.221891],
#       [-91.13417299999999, 43.174405],
#       [-91.175253, 43.134665],
#       [-91.17493491391119, 43.0802603718452],
#       [-91.174692, 43.038713],
#       [-91.15908430594749, 42.987477791322796],
#       [-91.155519, 42.975774],
#       [-91.138, 42.903772],
#       [-91.09881999999999, 42.864421],
#       [-91.07071599999999, 42.775501999999996],
#       [-91.01723899999999, 42.719566],
#       [-90.94156699999999, 42.683844],
#       [-90.89696202715841, 42.6743180564343],
#       [-90.852497, 42.664822],
#       [-90.74367699999999, 42.645559999999996],
#       [-90.700856, 42.626445],
#       [-90.672727, 42.576598999999995],
#       [-90.642843, 42.508480999999996],
#       [-90.646727, 42.471903999999995],
#       [-90.59041599999999, 42.447493],
#       [-90.565248, 42.438742],
#       [-90.517516, 42.403019],
#       [-90.48434567271629, 42.381597778191896],
#       [-90.44632, 42.357040999999995],
#       [-90.417125, 42.319942999999995],
#       [-90.43088399999999, 42.27823],
#       [-90.40065299999999, 42.239292999999996],
#       [-90.338169, 42.203320999999995],
#       [-90.31569651427151, 42.193946432251394],
#       [-90.26908, 42.1745],
#       [-90.207421, 42.149108999999996],
#       [-90.161159, 42.106372],
#       [-90.163446, 42.040406999999995],
#       [-90.15968245112269, 42.0330872575859],
#       [-90.140613, 41.995999],
#       [-90.156902, 41.938181],
#       [-90.1581530337095, 41.9298432273761],
#       [-90.165065, 41.883776999999995],
#       [-90.181401, 41.844646999999995],
#       [-90.18064299999999, 41.811979],
#       [-90.2423682473972, 41.782768725984596],
#       [-90.24863099999999, 41.779804999999996],
#       [-90.31070799999999, 41.742214],
#       [-90.31185685041619, 41.7285328921536],
#       [-90.31468699999999, 41.694829999999996],
#       [-90.33672899999999, 41.664532],
#       [-90.339528, 41.598633],
#       [-90.364128, 41.579633],
#       [-90.41583, 41.562933],
#       [-90.461432, 41.523533],
#       [-90.513134, 41.519532999999996],
#       [-90.571136, 41.516332],
#       [-90.61853699999999, 41.485032],
#       [-90.70115899999999, 41.454743],
#       [-90.786282, 41.452888],
#       [-90.86728199999999, 41.448215],
#       [-90.924343, 41.42286],
#       [-90.966662, 41.430051],
#       [-91.02778699999999, 41.423603],
#       [-91.065058, 41.369101],
#       [-91.071552, 41.339650999999996],
#       [-91.07408762367409, 41.3343208019205],
#       [-91.0744154980196, 41.3336315690407],
#       [-91.11418599999999, 41.250029],
#       [-91.081445, 41.214428999999996],
#       [-91.041536, 41.166138],
#       [-90.997906, 41.162563999999996],
#       [-90.957246, 41.111084999999996],
#       [-90.95226541648219, 41.072731749670005],
#       [-90.9518941426813, 41.0698727358664],
#       [-90.945324, 41.019279],
#       [-90.95223299999999, 40.954046999999996],
#       [-90.985462, 40.912141],
#       [-91.044653, 40.868356],
#       [-91.09299299999999, 40.821079],
#       [-91.091703, 40.779708],
#       [-91.115735, 40.725168],
#       [-91.11822293839751, 40.6995346508191],
#       [-91.12082, 40.672776999999996],
#       [-91.18546060870429, 40.63811181262349],
#       [-91.18697999999999, 40.637297],
#       [-91.247851, 40.63839],
#       [-91.339719, 40.613488],
#       [-91.374252, 40.582589999999996],
#       [-91.394475, 40.534543],
#       [-91.367876, 40.510479],
#       [-91.379907, 40.45211],
#       [-91.37292099999999, 40.399108],
#       [-91.419422, 40.378264],
#       [-91.498093, 40.401925999999996],
#       [-91.519134, 40.432822],
#       [-91.56384399999999, 40.460988],
#       [-91.608347, 40.50004],
#       [-91.618999, 40.539083999999995],
#       [-91.670993, 40.550937],
#       [-91.68538099999999, 40.578891999999996],
#       [-91.71665498768189, 40.603740139296],
#       [-91.729115, 40.61364],
#       [-91.939292, 40.60615],
#       [-91.9431174596857, 40.606060586354005],
#       [-92.17978, 40.600529],
#       [-92.35080418672639, 40.5972572763761],
#       [-92.453745, 40.595288],
#       [-92.63790329359949, 40.590956547097896],
#       [-92.68669299999999, 40.589808999999995],
#       [-92.71459726304501, 40.5895828338363],
#       [-92.94159499999999, 40.587742999999996],
#       [-93.0972912037498, 40.5838234773251],
#       [-93.135802, 40.582854],
#       [-93.34544199999999, 40.580514],
#       [-93.3743862587638, 40.5803970326092],
#       [-93.5568966742717, 40.579659485060496],
#       [-93.597352, 40.579496],
#       [-93.7743442040303, 40.5775304533911],
#       [-93.84093, 40.576791],
#       [-94.015492, 40.574073707009596],
#       [-94.09108499999999, 40.572897],
#       [-94.23224071020829, 40.572014612126594],
#       [-94.310724, 40.571524],
#       [-94.47120772712319, 40.570959458357],
#       [-94.533878, 40.570738999999996],
#       [-94.6320259176948, 40.5717595874],
#       [-94.81997799999999, 40.573713999999995],
#       [-94.9148978673616, 40.5749211691113],
#       [-95.06892099999999, 40.576879999999996],
#       [-95.20226600083029, 40.578375628996],
#       [-95.335588, 40.579871],
#       [-95.3739250533987, 40.580332377941495],
#       [-95.533182, 40.582249],
#       [-95.76564499999999, 40.585208],
#       [-95.748626, 40.603355],
#       [-95.781909, 40.653272],
#       [-95.84603399999999, 40.682604999999995],
#       [-95.888697, 40.736292],
#       [-95.834156, 40.783015999999996],
#       [-95.8342438167144, 40.7837843870431],
#       [-95.841309, 40.845604],
#       [-95.81070899999999, 40.886680999999996],
#       [-95.8187272785699, 40.8979480664065],
#       [-95.837774, 40.924712],
#       [-95.828329, 40.972378],
#       [-95.865878, 41.017403],
#       [-95.8647847640853, 41.0528455046135],
#       [-95.863839, 41.083507],
#       [-95.86868799999999, 41.124697999999995],
#       [-95.8618980682094, 41.1603023482127],
#       [-95.856788, 41.187098],
#       [-95.90969, 41.184398],
#       [-95.9099084912548, 41.1912828508279],
#       [-95.911391, 41.237998],
#       [-95.890152, 41.278307999999996],
#       [-95.92568999999999, 41.322196999999996],
#       [-95.92878999999999, 41.370096],
#       [-95.9273362423201, 41.3899879374596],
#       [-95.922529, 41.455766],
#       [-95.982962, 41.469778],
#       [-95.9940203930119, 41.5068906409415],
#       [-96.005079, 41.544004],
#       [-96.08049299999999, 41.528199],
#       [-96.09182, 41.561085999999996],
#       [-96.118105, 41.613495],
#       [-96.11148299999999, 41.668548],
#       [-96.10793787174649, 41.6765089897621],
#       [-96.08760000000001, 41.72218],
#       [-96.064537, 41.793002],
#       [-96.107911, 41.840339],
#       [-96.1268212534654, 41.8660952477016],
#       [-96.159098, 41.910056999999995],
#       [-96.132537, 41.974624999999996],
#       [-96.22361099999999, 42.022652],
#       [-96.272877, 42.047238],
#       [-96.2689, 42.113589999999995],
#       [-96.347752, 42.166806],
#       [-96.3372160947059, 42.214849506895604],
#       [-96.336323, 42.218922],
#       [-96.33600299999999, 42.264806],
#       [-96.351957192496, 42.28089470454329],
#       [-96.40799799999999, 42.337407999999996],
#       [-96.411808, 42.410894],
#       [-96.38130699999999, 42.461694],
#       [-96.44550799999999, 42.490629999999996],
#       [-96.477454, 42.509589],
#       [-96.49297, 42.517282],
#       [-96.476952, 42.556079],
#       [-96.48002247898, 42.561324776560696],
#       [-96.526766, 42.641183999999996],
#       [-96.591602, 42.688081],
#       [-96.624704, 42.725497],
#       [-96.62187499999999, 42.779255]]]}},
#   {'id': '2',
#    'type': 'Feature',
#    'properties': {'STATEFP': '10',
#     'STATENS': '01779781',
#     'AFFGEOID': '0400000US10',
#     'GEOID': '10',
#     'STUSPS': 'DE',
#     'NAME': 'Delaware',
#     'LSAD': '00',
#     'ALAND': 5045925646,
#     'AWATER': 1399985648,
#     'rates': ['2.20%', '3.90%', '4.80%', '5.20%', '5.55%', '6.60%'],
#     'tax_type': 'Progressive income tax rates'},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-75.773786, 39.7222],
#        [-75.753228, 39.757988999999995],
#        [-75.71705899999999, 39.792325],
#        [-75.662846, 39.821425],
#        [-75.5943169052201, 39.8345949730913],
#        [-75.5925626443241, 39.8349321082726],
#        [-75.5796477422344, 39.8374141038914],
#        [-75.570433, 39.839185],
#        [-75.481207, 39.829191],
#        [-75.41506199999999, 39.801919],
#        [-75.459439, 39.765813],
#        [-75.47764, 39.715013],
#        [-75.509742, 39.686113],
#        [-75.535144, 39.647211999999996],
#        [-75.559446, 39.629812],
#        [-75.543965, 39.596000000000004],
#        [-75.512732, 39.578],
#        [-75.527676, 39.535278],
#        [-75.528088, 39.498114],
#        [-75.593068, 39.479186],
#        [-75.57182999999999, 39.438897],
#        [-75.521682, 39.387871],
#        [-75.5056428576184, 39.370394222582796],
#        [-75.469324, 39.330819999999996],
#        [-75.40837599999999, 39.264697999999996],
#        [-75.39479, 39.188354],
#        [-75.407473, 39.133706],
#        [-75.396277, 39.057884],
#        [-75.34089, 39.01996],
#        [-75.3066521095097, 38.9476601633284],
#        [-75.30255199999999, 38.939001999999995],
#        [-75.30407799999999, 38.91316],
#        [-75.232029, 38.844254],
#        [-75.159022, 38.790192999999995],
#        [-75.113331, 38.782998],
#        [-75.089473, 38.797198],
#        [-75.071805, 38.696497],
#        [-75.053973, 38.536273],
#        [-75.04893899999999, 38.451263],
#        [-75.18545499999999, 38.451012],
#        [-75.3412873203482, 38.4524365259555],
#        [-75.479283, 38.453697999999996],
#        [-75.693721, 38.460128],
#        [-75.70038199999999, 38.542743],
#        [-75.701777515245, 38.5607669290786],
#        [-75.707551, 38.635335],
#        [-75.707555026429, 38.6353853550599],
#        [-75.72310269333269, 38.8298265565277],
#        [-75.7481548142541, 39.143131730959695],
#        [-75.7564352155685, 39.246687537125304],
#        [-75.7604414164505, 39.296789621100096],
#        [-75.76689499999999, 39.377499],
#        [-75.76690460670919, 39.3776515935512],
#        [-75.788596, 39.722198999999996],
#        [-75.773786, 39.7222]]],
#      [[[-75.4, 38.8],
#        [-72.4, 38.3],
#        [-72.4, 38.9],
#        [-70.2, 38.9],
#        [-70.2, 37.7],
#        [-72.4, 37.7],
#        [-72.4, 38.3]]]]}},
#   {'id': '3',
#    'type': 'Feature',
#    'properties': {'STATEFP': '39',
#     'STATENS': '01085497',
#     'AFFGEOID': '0400000US39',
#     'GEOID': '39',
#     'STUSPS': 'OH',
#     'NAME': 'Ohio',
#     'LSAD': '00',
#     'ALAND': 105828882568,
#     'AWATER': 10268850702,
#     'rates': ['2.765%', '3.226%', '3.688%', '3.990%'],
#     'tax_type': 'Progressive income tax rates'},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-82.863342, 41.693692999999996],
#        [-82.82571999999999, 41.722809999999996],
#        [-82.782719, 41.694002999999995],
#        [-82.788876, 41.643046999999996],
#        [-82.84209899999999, 41.628322999999995],
#        [-82.863342, 41.693692999999996]]],
#      [[[-84.82015899999999, 39.227225],
#        [-84.8188774692751, 39.3051435835594],
#        [-84.8188770978104, 39.3051661690523],
#        [-84.817453, 39.391753],
#        [-84.8161601949108, 39.5219681089929],
#        [-84.8157059432555, 39.567721664027395],
#        [-84.814129, 39.726555999999995],
#        [-84.8141281379328, 39.7266165116193],
#        [-84.81141710638049, 39.9169136295798],
#        [-84.81016123847449, 40.0050675438482],
#        [-84.808706, 40.107216],
#        [-84.8049173025784, 40.3100959150341],
#        [-84.8041205270149, 40.352762230297095],
#        [-84.804119, 40.352844],
#        [-84.8029313665713, 40.465386621719794],
#        [-84.80254699999999, 40.50181],
#        [-84.8024138785794, 40.5722128806467],
#        [-84.80211903226379, 40.7281459368726],
#        [-84.80211899999999, 40.728162999999995],
#        [-84.8026702061534, 40.922568713921],
#        [-84.8028596219514, 40.9893740520086],
#        [-84.80323399999999, 41.121414],
#        [-84.80364498225559, 41.2525616835482],
#        [-84.8037035726169, 41.271258330570596],
#        [-84.804133, 41.408291999999996],
#        [-84.8042532576115, 41.4260497115499],
#        [-84.80495815623959, 41.530137813388194],
#        [-84.80608199999999, 41.696089],
#        [-84.43806699999999, 41.704903],
#        [-84.3995487854742, 41.70592135740559],
#        [-84.3604190413973, 41.7069558826335],
#        [-84.134417, 41.712931],
#        [-83.88039046535329, 41.7201944903196],
#        [-83.7631498513652, 41.7235468017856],
#        [-83.763038, 41.723549999999996],
#        [-83.5855418421088, 41.7287720285128],
#        [-83.45383199999999, 41.732647],
#        [-83.409531, 41.691247],
#        [-83.326825, 41.701561999999996],
#        [-83.23165999999999, 41.644217999999995],
#        [-83.1638214175228, 41.624130312973996],
#        [-83.066593, 41.59534],
#        [-83.028072, 41.555656],
#        [-82.93436899999999, 41.514353],
#        [-82.85953099999999, 41.576370999999995],
#        [-82.83410099999999, 41.587587],
#        [-82.717878, 41.54193],
#        [-82.6905671606649, 41.496705795438196],
#        [-82.687921, 41.492323999999996],
#        [-82.616952, 41.428425],
#        [-82.533208, 41.391157],
#        [-82.460599, 41.386316],
#        [-82.361784, 41.426643999999996],
#        [-82.3480192068912, 41.427263308734496],
#        [-82.268479, 41.430842],
#        [-82.181598, 41.471634],
#        [-82.07115045287361, 41.496911986784696],
#        [-81.994565, 41.51444],
#        [-81.968480702529, 41.5038610079018],
#        [-81.9603249700039, 41.50055329259779],
#        [-81.937862, 41.491443],
#        [-81.8225035796994, 41.4952594192894],
#        [-81.81075799999999, 41.495647999999996],
#        [-81.7685751416216, 41.4914896464763],
#        [-81.738755, 41.48855],
#        [-81.633652, 41.540458],
#        [-81.48868273340901, 41.634463927820896],
#        [-81.466038, 41.649148],
#        [-81.388632, 41.707144],
#        [-81.286925, 41.760242999999996],
#        [-81.18436799999999, 41.786671],
#        [-81.05192, 41.839557],
#        [-81.0022694065175, 41.849172466437594],
#        [-80.900342, 41.868911999999995],
#        [-80.800794, 41.909635],
#        [-80.581882, 41.957609999999995],
#        [-80.519425, 41.977523],
#        [-80.5193967266905, 41.8495629905593],
#        [-80.519357, 41.669767],
#        [-80.5191767503534, 41.499924051206],
#        [-80.5191651698956, 41.4890121901546],
#        [-80.5190001313643, 41.333502144193595],
#        [-80.51889299999999, 41.232555999999995],
#        [-80.519196690325, 41.1333865025489],
#        [-80.5192220860809, 41.1250935667958],
#        [-80.5196437725473, 40.9873926540058],
#        [-80.519891, 40.906661],
#        [-80.5198697076862, 40.9003239342489],
#        [-80.5197051125992, 40.85133677868539],
#        [-80.518991, 40.638801],
#        [-80.58363299999999, 40.61552],
#        [-80.62717099999999, 40.619935999999996],
#        [-80.667957, 40.582496],
#        [-80.62219499999999, 40.520497],
#        [-80.604895, 40.446667],
#        [-80.6273626299369, 40.3951709330172],
#        [-80.631596, 40.385467999999996],
#        [-80.606596, 40.303869],
#        [-80.644598, 40.25127],
#        [-80.684173210708, 40.1870179733507],
#        [-80.7025753036226, 40.1571413980097],
#        [-80.70599399999999, 40.151590999999996],
#        [-80.73680399999999, 40.080072],
#        [-80.7382184399836, 40.0335432260784],
#        [-80.74012599999999, 39.970793],
#        [-80.764479, 39.95025],
#        [-80.803394, 39.918762],
#        [-80.8234381047859, 39.8500320873964],
#        [-80.824276, 39.847159],
#        [-80.824969, 39.801092],
#        [-80.869933, 39.763555],
#        [-80.8355216930075, 39.7192518022001],
#        [-80.829764, 39.711839],
#        [-80.86557499999999, 39.662751],
#        [-80.943782, 39.606926],
#        [-81.03736504198709, 39.5380557124726],
#        [-81.07594999999999, 39.50966],
#        [-81.1212738561078, 39.45769741388919],
#        [-81.12853299999999, 39.449374999999996],
#        [-81.185946, 39.430731],
#        [-81.249088, 39.389992],
#        [-81.347567, 39.34577],
#        [-81.3703898088263, 39.3487006724034],
#        [-81.393794, 39.351706],
#        [-81.412706, 39.394618],
#        [-81.456143, 39.409273999999996],
#        [-81.50318899999999, 39.373242],
#        [-81.559647, 39.330774],
#        [-81.565247, 39.276174999999995],
#        [-81.613896, 39.275338999999995],
#        [-81.678331, 39.273755],
#        [-81.71162799999999, 39.219228],
#        [-81.7214681391725, 39.2109608092037],
#        [-81.752754, 39.184675999999996],
#        [-81.7522970367401, 39.181034747405896],
#        [-81.742953, 39.106578],
#        [-81.7502668434263, 39.1040311930998],
#        [-81.80785499999999, 39.083977999999995],
#        [-81.79330399999999, 39.040352999999996],
#        [-81.775734, 38.980737],
#        [-81.827354, 38.945898],
#        [-81.89847, 38.929603],
#        [-81.941829, 38.993294999999996],
#        [-82.00706199999999, 39.029578],
#        [-82.041563, 39.017877999999996],
#        [-82.08906499999999, 38.975978],
#        [-82.0988666505543, 38.960879284493295],
#        [-82.134766, 38.905578999999996],
#        [-82.16157, 38.824632],
#        [-82.20929, 38.802672],
#        [-82.201537, 38.760372],
#        [-82.18556699999999, 38.659583],
#        [-82.175167, 38.608484],
#        [-82.21896699999999, 38.591682999999996],
#        [-82.27427, 38.593683],
#        [-82.2821333440281, 38.579860796403494],
#        [-82.29327099999999, 38.560283],
#        [-82.304223, 38.496308],
#        [-82.323999, 38.449268],
#        [-82.381773, 38.434782999999996],
#        [-82.447076, 38.426981999999995],
#        [-82.5089669497313, 38.4146439126517],
#        [-82.560664, 38.404337999999996],
#        [-82.593673, 38.421808999999996],
#        [-82.61847399999999, 38.477089],
#        [-82.66411690751569, 38.507715590257],
#        [-82.675724, 38.515504],
#        [-82.724846, 38.5576],
#        [-82.800112, 38.563182999999995],
#        [-82.81154238465041, 38.572369589561895],
#        [-82.851314, 38.604334],
#        [-82.869592, 38.678177],
#        [-82.871192, 38.718377],
#        [-82.8822899936093, 38.7416192232696],
#        [-82.88919299999999, 38.756076],
#        [-82.943147, 38.74328],
#        [-83.011816, 38.730056999999995],
#        [-83.0303349312311, 38.7168676766561],
#        [-83.042338, 38.708318999999996],
#        [-83.112372, 38.671685],
#        [-83.128973, 38.640231],
#        [-83.172647, 38.620252],
#        [-83.239515, 38.628588],
#        [-83.2642989019587, 38.6131124968875],
#        [-83.286514, 38.599241],
#        [-83.320531, 38.622713],
#        [-83.376302, 38.661473],
#        [-83.440404, 38.669360999999995],
#        [-83.533339, 38.702104999999996],
#        [-83.626922, 38.679387],
#        [-83.642994, 38.643273],
#        [-83.6469114041267, 38.6418519345458],
#        [-83.679484, 38.630036],
#        [-83.70586163558559, 38.638037865066],
#        [-83.77216, 38.65815],
#        [-83.78362, 38.695640999999995],
#        [-83.834015, 38.716007999999995],
#        [-83.852085, 38.751433],
#        [-83.9043750861048, 38.7672838752678],
#        [-83.928454, 38.774583],
#        [-83.978814, 38.787104],
#        [-84.051642, 38.771397],
#        [-84.0526461732196, 38.7716146675358],
#        [-84.135088, 38.789485],
#        [-84.212904, 38.805707],
#        [-84.2261626339635, 38.829777141242005],
#        [-84.233265, 38.842670999999996],
#        [-84.23230504540349, 38.8747078960317],
#        [-84.232132, 38.880483],
#        [-84.288164, 38.955788999999996],
#        [-84.29725499999999, 38.989694],
#        [-84.3212072268568, 39.0205863526894],
#        [-84.326539, 39.027463],
#        [-84.40093999999999, 39.046361999999995],
#        [-84.432941, 39.083960999999995],
#        [-84.445242, 39.114461],
#        [-84.462042, 39.121759999999995],
#        [-84.480943, 39.11676],
#        [-84.493743, 39.10246],
#        [-84.49918784070239, 39.1021644008655],
#        [-84.5065187374369, 39.101766408188],
#        [-84.550844, 39.09936],
#        [-84.607928, 39.073237999999996],
#        [-84.62202768365981, 39.0783275466544],
#        [-84.677247, 39.098259999999996],
#        [-84.71404799999999, 39.132659],
#        [-84.750749, 39.147358],
#        [-84.820157, 39.10548],
#        [-84.82015899999999, 39.227225]]]]}},
#   {'id': '4',
#    'type': 'Feature',
#    'properties': {'STATEFP': '42',
#     'STATENS': '01779798',
#     'AFFGEOID': '0400000US42',
#     'GEOID': '42',
#     'STUSPS': 'PA',
#     'NAME': 'Pennsylvania',
#     'LSAD': '00',
#     'ALAND': 115884442321,
#     'AWATER': 3394589990,
#     'rates': ['3.07%'],
#     'tax_type': 'Flat income tax rate'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-80.519891, 40.906661],
#       [-80.5196437725473, 40.9873926540058],
#       [-80.5192220860809, 41.1250935667958],
#       [-80.519196690325, 41.1333865025489],
#       [-80.51889299999999, 41.232555999999995],
#       [-80.5190001313643, 41.333502144193595],
#       [-80.5191651698956, 41.4890121901546],
#       [-80.5191767503534, 41.499924051206],
#       [-80.519357, 41.669767],
#       [-80.5193967266905, 41.8495629905593],
#       [-80.519425, 41.977523],
#       [-80.329976, 42.036167999999996],
#       [-80.154084, 42.114757],
#       [-80.136213, 42.149937],
#       [-80.088512, 42.173184],
#       [-80.02032299999999, 42.163115999999995],
#       [-79.923924, 42.207546],
#       [-79.844661, 42.235486],
#       [-79.761951, 42.26986],
#       [-79.76212199999999, 42.131246],
#       [-79.761313, 41.998808],
#       [-79.6108357749867, 41.99851990410839],
#       [-79.472472, 41.998255],
#       [-79.0612644031599, 41.998838109911006],
#       [-78.983065, 41.998948999999996],
#       [-78.9188573636152, 41.9991031986894],
#       [-78.59665, 41.999877],
#       [-78.3081289604466, 41.9990711347414],
#       [-78.271204, 41.998968],
#       [-78.2066030378582, 41.9990883057576],
#       [-78.031177, 41.999415],
#       [-77.83203, 41.998523999999996],
#       [-77.74993092512729, 41.998755440329],
#       [-77.610020114476, 41.9991498540796],
#       [-77.007635, 42.000848],
#       [-76.9657287594267, 42.000783395046895],
#       [-76.9268463629543, 42.0007234518173],
#       [-76.558118, 42.000155],
#       [-76.55762414356938, 42.0001487163417],
#       [-76.473030885808, 41.999072381007004],
#       [-76.462155, 41.998934],
#       [-76.1455189947821, 41.998866463308005],
#       [-76.10584, 41.998858],
#       [-75.870677, 41.998827999999996],
#       [-75.5531125390951, 41.9992952284735],
#       [-75.4831492709589, 41.9993981645227],
#       [-75.477144, 41.999407],
#       [-75.3598599291505, 41.9936858889046],
#       [-75.34112499999999, 41.992771999999995],
#       [-75.29176199999999, 41.947092],
#       [-75.26300499999999, 41.885109],
#       [-75.190203, 41.862454],
#       [-75.1466648992859, 41.8501259301463],
#       [-75.11336899999999, 41.840697999999996],
#       [-75.074412, 41.802191],
#       [-75.053431, 41.752538],
#       [-75.049281, 41.641861999999996],
#       [-75.04619860591168, 41.6037640199027],
#       [-75.04387899999999, 41.575094],
#       [-74.982463, 41.496466999999996],
#       [-74.89035799999999, 41.455324],
#       [-74.79954599999999, 41.43129],
#       [-74.7562718347252, 41.4276274285434],
#       [-74.734893, 41.425818],
#       [-74.694914, 41.357423],
#       [-74.760325, 41.340325],
#       [-74.815703, 41.296150999999995],
#       [-74.86740499999999, 41.22777],
#       [-74.905256, 41.155668],
#       [-74.979873, 41.110423],
#       [-74.98304207424779, 41.1060175588568],
#       [-74.9923859951822, 41.0930282469934],
#       [-75.015271, 41.061215],
#       [-75.0523586008006, 41.0326279973019],
#       [-75.070532, 41.01862],
#       [-75.13308599999999, 40.980179],
#       [-75.12325394420849, 40.9653055343877],
#       [-75.09772, 40.926679],
#       [-75.065438, 40.885681999999996],
#       [-75.09096199999999, 40.849187],
#       [-75.108505, 40.791094],
#       [-75.1113587316723, 40.78998228921439],
#       [-75.177477, 40.764224999999996],
#       [-75.192612, 40.715874],
#       [-75.191059, 40.637971],
#       [-75.1892364013559, 40.60905696112209],
#       [-75.1881998781252, 40.5926133666486],
#       [-75.186737, 40.569406],
#       [-75.136748, 40.575731],
#       [-75.078503, 40.548296],
#       [-75.062227, 40.481390999999995],
#       [-75.070568, 40.455165],
#       [-75.056102, 40.416066],
#       [-75.02477499999999, 40.403455],
#       [-74.969597, 40.39977],
#       [-74.946006, 40.357306],
#       [-74.92811056909139, 40.3398284476893],
#       [-74.90330999999999, 40.315607],
#       [-74.85650799999999, 40.277407],
#       [-74.82390699999999, 40.241507999999996],
#       [-74.760605, 40.198909],
#       [-74.7484976572578, 40.184908614103996],
#       [-74.721604, 40.15381],
#       [-74.7233792971515, 40.152895546231704],
#       [-74.769488, 40.129145],
#       [-74.825907, 40.123909999999995],
#       [-74.863809, 40.082209999999996],
#       [-74.932211, 40.068411],
#       [-74.9728547564456, 40.0465053655363],
#       [-74.989914, 40.037310999999995],
#       [-75.059017, 39.992512],
#       [-75.0601299707226, 39.9920110032626],
#       [-75.11922, 39.965412],
#       [-75.1322646449748, 39.950944302846096],
#       [-75.13571999999999, 39.947112],
#       [-75.13458822241401, 39.922065762021795],
#       [-75.13342, 39.896212999999996],
#       [-75.1414355217473, 39.8939183724813],
#       [-75.18302299999999, 39.882013],
#       [-75.2111960614745, 39.8665186316821],
#       [-75.221025, 39.861112999999996],
#       [-75.293376, 39.848782],
#       [-75.341765, 39.846081999999996],
#       [-75.41049247763709, 39.8046722343221],
#       [-75.41506199999999, 39.801919],
#       [-75.481207, 39.829191],
#       [-75.570433, 39.839185],
#       [-75.5796477422344, 39.8374141038914],
#       [-75.5925626443241, 39.8349321082726],
#       [-75.5943169052201, 39.8345949730913],
#       [-75.662846, 39.821425],
#       [-75.71705899999999, 39.792325],
#       [-75.753228, 39.757988999999995],
#       [-75.773786, 39.7222],
#       [-75.788596, 39.722198999999996],
#       [-76.13569742699019, 39.7217675506067],
#       [-76.23327934711659, 39.7216462556279],
#       [-76.233485, 39.721646],
#       [-76.2396837411146, 39.7216419899246],
#       [-76.41897999999999, 39.721526],
#       [-76.5694491257313, 39.721458570752695],
#       [-76.71577099999999, 39.721393],
#       [-76.7870971997576, 39.72104814611129],
#       [-76.991062, 39.720062],
#       [-76.9993180263332, 39.7200676723526],
#       [-77.21702375523739, 39.720217248385396],
#       [-77.23995, 39.720233],
#       [-77.45943341952389, 39.720229171644995],
#       [-77.4691450036804, 39.72022900225],
#       [-77.469274, 39.720228999999996],
#       [-77.768644, 39.721537999999995],
#       [-78.075861, 39.722448],
#       [-78.09897069616669, 39.722466194428094],
#       [-78.342593, 39.722657999999996],
#       [-78.3428335185744, 39.722658292926496],
#       [-78.380477064564, 39.72270413884],
#       [-78.723578, 39.723122],
#       [-78.80829952962159, 39.7230709562769],
#       [-78.9284161298889, 39.7229985874409],
#       [-79.045576, 39.722927999999996],
#       [-79.3924584050224, 39.7214393586401],
#       [-79.47666199999999, 39.721078],
#       [-79.763774, 39.720776],
#       [-79.9160173560378, 39.7210559335188],
#       [-80.075947, 39.72135],
#       [-80.421388, 39.721188999999995],
#       [-80.519342, 39.721402999999995],
#       [-80.5191607943145, 39.962200052521894],
#       [-80.51912, 40.01641],
#       [-80.5190843704566, 40.159671995118096],
#       [-80.51903899999999, 40.342101],
#       [-80.5190296911941, 40.3996410563407],
#       [-80.51901711734739, 40.477363146237096],
#       [-80.518991, 40.638801],
#       [-80.5197051125992, 40.85133677868539],
#       [-80.5198697076862, 40.9003239342489],
#       [-80.519891, 40.906661]]]}},
#   {'id': '5',
#    'type': 'Feature',
#    'properties': {'STATEFP': '31',
#     'STATENS': '01779792',
#     'AFFGEOID': '0400000US31',
#     'GEOID': '31',
#     'STUSPS': 'NE',
#     'NAME': 'Nebraska',
#     'LSAD': '00',
#     'ALAND': 198956658395,
#     'AWATER': 1371829134,
#     'rates': ['2.46%', '3.51%', '5.01%', '6.64%'],
#     'tax_type': 'Progressive income tax rates'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-104.053142, 41.114457],
#       [-104.052453, 41.278202],
#       [-104.052287134121, 41.3932140001934],
#       [-104.052287, 41.393307],
#       [-104.05263457163299, 41.5642757795737],
#       [-104.052735, 41.613676],
#       [-104.052825235239, 41.69795385306401],
#       [-104.053026, 41.885464],
#       [-104.052762137092, 42.0017182658666],
#       [-104.052729, 42.016318],
#       [-104.052793, 42.249962],
#       [-104.053107, 42.499964],
#       [-104.052662191568, 42.6117663005415],
#       [-104.052586, 42.630917],
#       [-104.053127, 43.000585],
#       [-103.50509926163201, 43.0007588130312],
#       [-103.476133, 43.000768],
#       [-103.000609526033, 43.0002592867744],
#       [-102.792110939839, 43.0000362357704],
#       [-102.40864, 42.999626],
#       [-102.08254804307201, 42.999140640389996],
#       [-102.082486319192, 42.9991405485193],
#       [-101.22801339779402, 42.997868739647494],
#       [-101.000429, 42.99753],
#       [-100.19841379977501, 42.9979768839694],
#       [-100.19841261156601, 42.9979768846315],
#       [-99.850037, 42.998171],
#       [-99.53405501480901, 42.9981974883181],
#       [-99.2544550123166, 42.99822092678669],
#       [-98.84799199999999, 42.998255],
#       [-98.49855, 42.99856],
#       [-98.47891899999999, 42.963539],
#       [-98.43450299999999, 42.929227],
#       [-98.386445, 42.918406999999995],
#       [-98.3081868164513, 42.8864892074256],
#       [-98.280007, 42.874995999999996],
#       [-98.231922, 42.86114],
#       [-98.1525866548382, 42.8411533810637],
#       [-98.14806, 42.840013],
#       [-98.10470000000001, 42.808475],
#       [-98.035034, 42.764205],
#       [-97.950147, 42.769619],
#       [-97.905001, 42.798871999999996],
#       [-97.876887, 42.852663],
#       [-97.857957, 42.865092999999995],
#       [-97.801344, 42.858003],
#       [-97.70102999999999, 42.843796999999995],
#       [-97.6354420904415, 42.85180907518549],
#       [-97.59926, 42.856229],
#       [-97.515948, 42.853752],
#       [-97.48491687634201, 42.850003214867904],
#       [-97.45217699999999, 42.846047999999996],
#       [-97.41706599999999, 42.865918],
#       [-97.34118099999999, 42.855882],
#       [-97.302075, 42.86566],
#       [-97.23786799999999, 42.853139],
#       [-97.213957, 42.820142999999995],
#       [-97.1650703923738, 42.7916166414677],
#       [-97.13133099999999, 42.771929],
#       [-97.02485, 42.762429999999995],
#       [-97.0156311127472, 42.7565254624882],
#       [-96.965679, 42.724531999999996],
#       [-96.906797, 42.7338],
#       [-96.8073706000982, 42.700678985373],
#       [-96.80165199999999, 42.698774],
#       [-96.778182, 42.662993],
#       [-96.697639, 42.659143],
#       [-96.7093, 42.603753],
#       [-96.658754, 42.566426],
#       [-96.6279454569017, 42.5270961391418],
#       [-96.61148899999999, 42.506088],
#       [-96.525142, 42.510234],
#       [-96.50132099999999, 42.482749],
#       [-96.44550799999999, 42.490629999999996],
#       [-96.38130699999999, 42.461694],
#       [-96.411808, 42.410894],
#       [-96.40799799999999, 42.337407999999996],
#       [-96.351957192496, 42.28089470454329],
#       [-96.33600299999999, 42.264806],
#       [-96.336323, 42.218922],
#       [-96.3372160947059, 42.214849506895604],
#       [-96.347752, 42.166806],
#       [-96.2689, 42.113589999999995],
#       [-96.272877, 42.047238],
#       [-96.22361099999999, 42.022652],
#       [-96.132537, 41.974624999999996],
#       [-96.159098, 41.910056999999995],
#       [-96.1268212534654, 41.8660952477016],
#       [-96.107911, 41.840339],
#       [-96.064537, 41.793002],
#       [-96.08760000000001, 41.72218],
#       [-96.10793787174649, 41.6765089897621],
#       [-96.11148299999999, 41.668548],
#       [-96.118105, 41.613495],
#       [-96.09182, 41.561085999999996],
#       [-96.08049299999999, 41.528199],
#       [-96.005079, 41.544004],
#       [-95.9940203930119, 41.5068906409415],
#       [-95.982962, 41.469778],
#       [-95.922529, 41.455766],
#       [-95.9273362423201, 41.3899879374596],
#       [-95.92878999999999, 41.370096],
#       [-95.92568999999999, 41.322196999999996],
#       [-95.890152, 41.278307999999996],
#       [-95.911391, 41.237998],
#       [-95.9099084912548, 41.1912828508279],
#       [-95.90969, 41.184398],
#       [-95.856788, 41.187098],
#       [-95.8618980682094, 41.1603023482127],
#       [-95.86868799999999, 41.124697999999995],
#       [-95.863839, 41.083507],
#       [-95.8647847640853, 41.0528455046135],
#       [-95.865878, 41.017403],
#       [-95.828329, 40.972378],
#       [-95.837774, 40.924712],
#       [-95.8187272785699, 40.8979480664065],
#       [-95.81070899999999, 40.886680999999996],
#       [-95.841309, 40.845604],
#       [-95.8342438167144, 40.7837843870431],
#       [-95.834156, 40.783015999999996],
#       [-95.888697, 40.736292],
#       [-95.84603399999999, 40.682604999999995],
#       [-95.781909, 40.653272],
#       [-95.748626, 40.603355],
#       [-95.76564499999999, 40.585208],
#       [-95.75711, 40.52599],
#       [-95.71429099999999, 40.527208],
#       [-95.71228037180109, 40.5237544262074],
#       [-95.69472599999999, 40.493601999999996],
#       [-95.68436299999999, 40.463366],
#       [-95.649418, 40.396149],
#       [-95.641027, 40.366399],
#       [-95.653729, 40.322582],
#       [-95.59865699999999, 40.309809],
#       [-95.553292, 40.291157999999996],
#       [-95.5481820011801, 40.2644146728427],
#       [-95.54787031627029, 40.2627834608198],
#       [-95.54715999999999, 40.259066],
#       [-95.47254799999999, 40.236078],
#       [-95.48102, 40.188524],
#       [-95.432165, 40.141025],
#       [-95.394216, 40.108263],
#       [-95.414734, 40.06982],
#       [-95.38295699999999, 40.027111999999995],
#       [-95.348777, 40.029297],
#       [-95.30829, 39.999998],
#       [-95.33989597085029, 40.0000288571054],
#       [-95.78457499999999, 40.000462999999996],
#       [-95.7881109948917, 40.0004667793653],
#       [-96.0106788179345, 40.000704665772005],
#       [-96.02409, 40.000719],
#       [-96.154365, 40.000495],
#       [-96.239172, 40.000690999999996],
#       [-96.2392078784111, 40.0006910427544],
#       [-96.4637120767748, 40.000958572554495],
#       [-96.469945, 40.000966],
#       [-96.805768, 40.0013684550954],
#       [-96.873812, 40.00145],
#       [-96.91640700546579, 40.0014540910439],
#       [-97.009165, 40.001463],
#       [-97.369199035315, 40.0019393057605],
#       [-97.41583299999999, 40.002001],
#       [-97.777155, 40.002167],
#       [-97.8215008122752, 40.00218688208889],
#       [-97.93182492631719, 40.0022363450196],
#       [-98.07603399999999, 40.002300999999996],
#       [-98.27401705975291, 40.0023374507299],
#       [-98.50445498363679, 40.00237987673601],
#       [-98.613755, 40.0024],
#       [-98.72637296393901, 40.0023362731669],
#       [-99.06701834989809, 40.0021435130522],
#       [-99.08559699999999, 40.002133],
#       [-99.17913315086109, 40.0021089526949],
#       [-99.501792, 40.002026],
# ...
#        [-131.1213098, 32.1259206],
#        [-131.07487460000004, 32.1005148],
#        [-131.0429308, 32.13686440000001],
#        [-130.964206, 32.1235686],
#        [-130.92326860000003, 32.1411918],
#        [-130.865926, 32.1152764],
#        [-130.79702640000002, 32.0718624],
#        [-130.77003440000001, 31.9876916],
#        [-130.8054082, 31.901531400000003],
#        [-130.8281008, 31.873924800000005],
#        [-130.8254058, 31.814640400000002],
#        [-130.83256820000003, 31.747189800000005],
#        [-130.89919559999998, 31.692962200000004],
#        [-130.9826314, 31.631625400000004],
#        [-131.0975014, 31.652988000000004],
#        [-131.1641456, 31.665476000000005],
#        [-131.2044068, 31.664694800000003],
#        [-131.26948860000002, 31.7229348],
#        [-131.35072920000002, 31.761268200000004],
#        [-131.4165292, 31.7844284],
#        [-131.461199, 31.841869000000003],
#        [-131.45706060000003, 31.906403400000002]]],
#      [[[-132.1092702, 31.5567506],
#        [-132.08036719999998, 31.6603114],
#        [-132.03135880000002, 31.706888000000003],
#        [-131.95168619999998, 31.743632400000003],
#        [-131.93098300000003, 31.763581000000002],
#        [-131.9176606, 31.808890600000005],
#        [-131.86078840000002, 31.820215200000003],
#        [-131.8417764, 31.8104796],
#        [-131.83139540000002, 31.7890316],
#        [-131.858225, 31.765079],
#        [-131.87991799999998, 31.7137606],
#        [-131.87050720000002, 31.670059600000002],
#        [-131.9338124, 31.643052200000003],
#        [-131.97834500000002, 31.6306496],
#        [-132.00453060000004, 31.601239800000005],
#        [-132.025511, 31.566977600000005],
#        [-132.0480076, 31.506872800000004],
#        [-132.0823384, 31.521092600000003],
#        [-132.1092702, 31.5567506]]]]}},
#   {'id': '49',
#    'type': 'Feature',
#    'properties': {'STATEFP': '33',
#     'STATENS': '01779794',
#     'AFFGEOID': '0400000US33',
#     'GEOID': '33',
#     'STUSPS': 'NH',
#     'NAME': 'New Hampshire',
#     'LSAD': '00',
#     'ALAND': 23189413166,
#     'AWATER': 1026675248,
#     'rates': ['0.00%'],
#     'tax_type': 'No income tax'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-72.556112, 42.866251999999996],
#       [-72.531469, 42.89795],
#       [-72.532186, 42.954944999999995],
#       [-72.492597, 42.967648],
#       [-72.444977, 43.004416],
#       [-72.4519547090682, 43.0204949106303],
#       [-72.462248, 43.044214],
#       [-72.435191, 43.086622],
#       [-72.451802, 43.153486],
#       [-72.4503959392159, 43.16121351690639],
#       [-72.440563, 43.215253999999995],
#       [-72.4336111979595, 43.2329038122618],
#       [-72.421583, 43.263442],
#       [-72.402532, 43.32038],
#       [-72.40690185803169, 43.337448838734794],
#       [-72.413377, 43.362741],
#       [-72.3969230250359, 43.4289221159986],
#       [-72.3968907962909, 43.4290517463351],
#       [-72.380894, 43.493393999999995],
#       [-72.37944, 43.574069],
#       [-72.3335965013563, 43.6055913415891],
#       [-72.329522, 43.608393],
#       [-72.28480499999999, 43.72036],
#       [-72.22206899999999, 43.759831],
#       [-72.2115021223499, 43.7730194104417],
#       [-72.18333299999999, 43.808177],
#       [-72.16978, 43.873425],
#       [-72.105875, 43.949369999999995],
#       [-72.116706, 43.991954],
#       [-72.0799442240026, 44.0300000301807],
#       [-72.0796962728478, 44.030256643384604],
#       [-72.075486, 44.034614],
#       [-72.036883, 44.103119],
#       [-72.0538268836147, 44.1598170938034],
#       [-72.06133799999999, 44.184951],
#       [-72.05399, 44.246925999999995],
#       [-72.046302, 44.291982999999995],
#       [-72.002314, 44.324870999999995],
#       [-71.945163, 44.337744],
#       [-71.875863, 44.33737],
#       [-71.8377906263888, 44.347764542477],
#       [-71.818838, 44.352939],
#       [-71.77861299999999, 44.399798999999994],
#       [-71.7631925213134, 44.4035682627764],
#       [-71.69091999999999, 44.421234],
#       [-71.646551, 44.468869],
#       [-71.57997399999999, 44.501777999999995],
#       [-71.588076, 44.54785],
#       [-71.544922, 44.579277999999995],
#       [-71.551722, 44.627598],
#       [-71.584574, 44.665351],
#       [-71.626909, 44.747223999999996],
#       [-71.570402, 44.805276],
#       [-71.522393, 44.880811],
#       [-71.49440299999999, 44.911837],
#       [-71.531605, 44.976023],
#       [-71.501088, 45.013377],
#       [-71.49839899999999, 45.069629],
#       [-71.448678, 45.109001],
#       [-71.41905799999999, 45.170488],
#       [-71.405636, 45.198139],
#       [-71.438546, 45.239004],
#       [-71.360664, 45.269835],
#       [-71.283684, 45.301977],
#       [-71.24449899999999, 45.268139],
#       [-71.182587, 45.241068999999996],
#       [-71.13942999999999, 45.242957999999994],
#       [-71.109349, 45.282222],
#       [-71.083924, 45.305451],
#       [-71.057861, 45.000049],
#       [-71.036705, 44.736498],
#       [-71.022992, 44.500057999999996],
#       [-71.0194617294855, 44.440363239787494],
#       [-71.0135759038146, 44.3408374525595],
#       [-71.01127, 44.301846],
#       [-71.0102711678683, 44.284888321572005],
#       [-71.008736, 44.258824999999995],
#       [-71.001367, 44.092931],
#       [-70.989929, 43.839239],
#       [-70.987258046746, 43.792973592884195],
#       [-70.981946, 43.700959999999995],
#       [-70.97271599999999, 43.570254999999996],
#       [-70.9637926798064, 43.5402209553665],
#       [-70.95475499999999, 43.509802],
#       [-70.960788896047, 43.47408873362159],
#       [-70.96835899999999, 43.429283],
#       [-70.984335, 43.376128],
#       [-70.923949, 43.324768],
#       [-70.872585, 43.270151999999996],
#       [-70.813119, 43.217251999999995],
#       [-70.8247767120681, 43.179763105182204],
#       [-70.824801, 43.179685],
#       [-70.8281, 43.129086],
#       [-70.81954928571301, 43.1232309734312],
#       [-70.75639699999999, 43.079988],
#       [-70.703818, 43.059825],
#       [-70.735477, 43.012201],
#       [-70.765222, 42.975349],
#       [-70.798636, 42.924288],
#       [-70.81143912677429, 42.8886107767412],
#       [-70.817296, 42.87229],
#       [-70.86475, 42.870258],
#       [-70.930799, 42.884589],
#       [-70.9665, 42.868989],
#       [-71.031201, 42.859089],
#       [-71.0487164136986, 42.8310643380822],
#       [-71.064201, 42.806289],
#       [-71.11637501217749, 42.811902914435095],
#       [-71.149703, 42.815489],
#       [-71.186104, 42.790689],
#       [-71.181803, 42.73759],
#       [-71.2453840329207, 42.736555328574596],
#       [-71.2551101218106, 42.7363970532872],
#       [-71.255605, 42.736388999999996],
#       [-71.29420499999999, 42.69699],
#       [-71.351874, 42.698153999999995],
#       [-71.636214, 42.704888],
#       [-71.745817, 42.707287],
#       [-71.80538960273829, 42.7089149435285],
#       [-71.89876877193659, 42.7114667208088],
#       [-71.9290300590535, 42.712293672532596],
#       [-72.081365050188, 42.7164565385412],
#       [-72.124526, 42.717636],
#       [-72.20361347980679, 42.719818528679895],
#       [-72.2830340925109, 42.722010250624],
#       [-72.4120300647523, 42.7255700733633],
#       [-72.4511950518227, 42.7266508854936],
#       [-72.458519, 42.726853],
#       [-72.477615, 42.761244999999995],
#       [-72.53960000000001, 42.804832],
#       [-72.55390205084859, 42.8580316101697],
#       [-72.556112, 42.866251999999996]]]}},
#   {'id': '50',
#    'type': 'Feature',
#    'properties': {'STATEFP': '04',
#     'STATENS': '01779777',
#     'AFFGEOID': '0400000US04',
#     'GEOID': '04',
#     'STUSPS': 'AZ',
#     'NAME': 'Arizona',
#     'LSAD': '00',
#     'ALAND': 294198551143,
#     'AWATER': 1027337603,
#     'rates': ['2.50%'],
#     'tax_type': 'Flat income tax rate'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-114.799683, 32.593621],
#       [-114.809393, 32.617118999999995],
#       [-114.76495, 32.649391],
#       [-114.719633, 32.718762999999996],
#       [-114.70571699999999, 32.741581],
#       [-114.667493, 32.734226],
#       [-114.617386523962, 32.7410527731766],
#       [-114.570675, 32.747417],
#       [-114.531746, 32.782503],
#       [-114.468971, 32.845155],
#       [-114.463127, 32.901883999999995],
#       [-114.47664, 32.923628],
#       [-114.481315, 32.972063999999996],
#       [-114.511343, 33.023455],
#       [-114.517066790281, 33.0246287635685],
#       [-114.575161, 33.036542],
#       [-114.628293, 33.031051999999995],
#       [-114.670803, 33.037984],
#       [-114.706175, 33.105335],
#       [-114.679359, 33.159518999999996],
#       [-114.678097, 33.2303],
#       [-114.674491, 33.255597],
#       [-114.723259, 33.288078999999996],
#       [-114.707962, 33.323420999999996],
#       [-114.707348, 33.376628],
#       [-114.72528199999999, 33.405048],
#       [-114.673901, 33.418299],
#       [-114.635183, 33.422726],
#       [-114.629146518189, 33.433544999999796],
#       [-114.597283, 33.490653],
#       [-114.524599, 33.552231],
#       [-114.529186, 33.60665],
#       [-114.525201, 33.661583],
#       [-114.504993, 33.693022],
#       [-114.496565, 33.719155],
#       [-114.504863, 33.760464999999996],
#       [-114.520465, 33.827777999999995],
#       [-114.505638, 33.864276],
#       [-114.508708, 33.900639999999996],
#       [-114.534987, 33.928498999999995],
#       [-114.509568, 33.957263999999995],
#       [-114.454807, 34.010968],
#       [-114.435504, 34.042615],
#       [-114.43009113852001, 34.078931406279494],
#       [-114.428026, 34.092787],
#       [-114.405941, 34.11154],
#       [-114.348052, 34.134457999999995],
#       [-114.292806, 34.166725],
#       [-114.229715, 34.186928],
#       [-114.17805, 34.239968999999995],
#       [-114.139055, 34.259538],
#       [-114.14081715128, 34.3031275138817],
#       [-114.14093, 34.305918999999996],
#       [-114.172845, 34.344978999999995],
#       [-114.264317, 34.401329],
#       [-114.335372, 34.450038],
#       [-114.378852, 34.450376],
#       [-114.378223, 34.516521],
#       [-114.422382, 34.580711],
#       [-114.465246, 34.691202],
#       [-114.490971, 34.724848],
#       [-114.576452, 34.8153],
#       [-114.634382, 34.87289],
#       [-114.629769, 34.943039999999996],
#       [-114.633487, 35.001857],
#       [-114.625069, 35.068478],
#       [-114.619905, 35.121632],
#       [-114.59912, 35.12105],
#       [-114.57274699999999, 35.138725],
#       [-114.587129, 35.262375999999996],
#       [-114.627137, 35.409504],
#       [-114.6645, 35.449497],
#       [-114.663105, 35.524491],
#       [-114.653406, 35.610789],
#       [-114.689407, 35.651412],
#       [-114.697309, 35.733686],
#       [-114.70371, 35.814585],
#       [-114.669687, 35.865083999999996],
#       [-114.700271, 35.901772],
#       [-114.731159, 35.943916],
#       [-114.742779, 36.009963],
#       [-114.743299245886, 36.065935173760096],
#       [-114.743342, 36.070535],
#       [-114.736165, 36.104366999999996],
#       [-114.666538, 36.117343],
#       [-114.627855, 36.141011999999996],
#       [-114.572031, 36.15161],
#       [-114.511721, 36.150956],
#       [-114.487034, 36.129396],
#       [-114.448654, 36.12641],
#       [-114.41695, 36.145761],
#       [-114.372106, 36.143114],
#       [-114.337273, 36.108019999999996],
#       [-114.316109, 36.063109],
#       [-114.270645, 36.03572],
#       [-114.21369, 36.015613],
#       [-114.151725, 36.024563],
#       [-114.138203, 36.053160999999996],
#       [-114.09987, 36.121654],
#       [-114.046838, 36.194069],
#       [-114.048226, 36.268874],
#       [-114.047584, 36.325573],
#       [-114.049493, 36.604059],
#       [-114.050160776088, 36.8431415396894],
#       [-114.0506, 37.000395999999995],
#       [-113.965907, 37.000025],
#       [-112.966471, 37.000219],
#       [-112.89919089761601, 37.0003012286284],
#       [-112.82950194437201, 37.0003864013144],
#       [-112.545094, 37.000734],
#       [-112.538571, 37.000744128882005],
#       [-112.35769, 37.001025],
#       [-111.412783987873, 37.001477687156004],
#       [-111.405869, 37.001481],
#       [-111.278286, 37.000465],
#       [-111.066496, 37.002389],
#       [-110.75068999999999, 37.003197],
#       [-110.47019, 36.997997],
#       [-110.000677, 36.997968],
#       [-109.495338, 36.999105],
#       [-109.045223, 36.999083999999996],
#       [-109.045433, 36.874589],
#       [-109.045729, 36.117028],
#       [-109.045871168205, 36.002701630519006],
#       [-109.046024, 35.8798],
#       [-109.046296, 35.614250999999996],
#       [-109.046796, 35.363606],
#       [-109.046355894384, 35.1755071883512],
#       [-109.045851235183, 34.9598185158367],
#       [-109.045851, 34.959717999999995],
#       [-109.046138935363, 34.5792910128179],
#       [-109.046182, 34.522393],
#       [-109.046426, 33.875052],
#       [-109.04660747392201, 33.778223800350496],
#       [-109.047298, 33.409783],
#       [-109.047237, 33.208965],
#       [-109.04723698053701, 33.208895031550796],
#       [-109.04711706231, 32.7777940009477],
#       [-109.047117, 32.77757],
#       [-109.047612, 32.426376999999995],
#       [-109.048296, 32.084092999999996],
#       [-109.049195, 31.796550999999997],
#       [-109.050044, 31.332501999999998],
#       [-109.829689, 31.334066999999997],
#       [-110.46017261044501, 31.3331413789916],
#       [-111.074825, 31.332238999999998],
#       [-111.366969371164, 31.424824287191598],
#       [-112.365043, 31.74113],
#       [-113.33376797301501, 32.0402490800901],
#       [-113.750756, 32.169005],
#       [-114.813613, 32.494277],
#       [-114.811536, 32.522833999999996],
#       [-114.795635, 32.550956],
#       [-114.814185, 32.564788],
#       [-114.799683, 32.593621]]]}},
#   {'id': '51',
#    'type': 'Feature',
#    'properties': {'STATEFP': '44',
#     'STATENS': '01219835',
#     'AFFGEOID': '0400000US44',
#     'GEOID': '44',
#     'STUSPS': 'RI',
#     'NAME': 'Rhode Island',
#     'LSAD': '00',
#     'ALAND': 2677779902,
#     'AWATER': 1323670487,
#     'rates': ['3.75%', '4.75%', '5.99%'],
#     'tax_type': 'Progressive income tax rates'},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-71.631472, 41.166678],
#        [-71.59334199999999, 41.237428],
#        [-71.54540999999999, 41.24273],
#        [-71.534084, 41.181861999999995],
#        [-71.51921, 41.149623999999996],
#        [-71.5937, 41.146339],
#        [-71.631472, 41.166678]]],
#      [[[-71.860513, 41.320248],
#        [-71.835951, 41.353935],
#        [-71.839649, 41.412119],
#        [-71.79768299999999, 41.416709],
#        [-71.79170363082619, 41.5461059382128],
#        [-71.7893586727423, 41.5968521603427],
#        [-71.789356, 41.59691],
#        [-71.789464590839, 41.6400171907069],
#        [-71.789678, 41.724734],
#        [-71.78969543168239, 41.7251982448091],
#        [-71.792767, 41.807001],
#        [-71.79924199999999, 42.008064999999995],
#        [-71.6066944190753, 42.013105058570794],
#        [-71.59109652763101, 42.01351334355719],
#        [-71.559439, 42.014342],
#        [-71.4982240131247, 42.0158741110185],
#        [-71.4580809945561, 42.0168788251287],
#        [-71.381401, 42.018798],
#        [-71.3814313468931, 41.9850841191295],
#        [-71.381461, 41.952141],
#        [-71.38170000000001, 41.893198999999996],
#        [-71.339298, 41.893398999999995],
#        [-71.339597, 41.832],
#        [-71.329396, 41.7826],
#        [-71.31740200793121, 41.7772561089687],
#        [-71.261392, 41.752300999999996],
#        [-71.20860053289509, 41.6903092436027],
#        [-71.2013271875249, 41.6817683282027],
#        [-71.19564, 41.67509],
#        [-71.132888, 41.660101999999995],
#        [-71.137492, 41.602561],
#        [-71.12057, 41.497448],
#        [-71.140224, 41.485855],
#        [-71.19301999999999, 41.457930999999995],
#        [-71.21267275910739, 41.466601705903095],
#        [-71.2398044238189, 41.4785720701705],
#        [-71.245992, 41.481302],
#        [-71.285639, 41.487805],
#        [-71.312694, 41.451402],
#        [-71.351096, 41.450801999999996],
#        [-71.389284, 41.460605],
#        [-71.41721279148369, 41.45603131277439],
#        [-71.428652, 41.454158],
#        [-71.455371, 41.407962],
#        [-71.483295, 41.371722],
#        [-71.555381, 41.373315999999996],
#        [-71.624505, 41.36087],
#        [-71.70163099999999, 41.336968],
#        [-71.7292965762004, 41.333284002713796],
#        [-71.785957, 41.325739],
#        [-71.86277199999999, 41.309791],
#        [-71.860513, 41.320248]]],
#      [[[-71.5, 41.7],
#        [-69.5, 40.4],
#        [-69.5, 41.0],
#        [-67.3, 41.0],
#        [-67.3, 39.8],
#        [-69.5, 39.8],
#        [-69.5, 40.4]]]]}}],
#  'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4269'}}}

# %% [markdown]
# ### 1.2. Figure 2. Rainy Day Fund and Total Reserves as Percentages of General-Fund Expenditures, Kansas and 50-State Median: 2000-2023

# %% [markdown]
# Get the Pew state rainy day fund data. This does not include District of Columbia. The 2022 data is now final. The 2023 data is labeled as "Enacted" which means projected based on enacted legislation. The Kanasas Rainy Day fund was established May 17, 2016, with the enactment of House Bill 2739. This made Kansas the 47th state with a Rainy Day Fund. See Robert Zahradnik and Steve Bailey, "[Kansas Becomes the 47th State to Create a Rainy Day Fund](https://www.pewtrusts.org/en/research-and-analysis/articles/2016/05/18/kansas-becomes-the-47th-state-to-create-a-rainy-day-fund), Article, Pew Charitable Trusts, May 18, 2016. For this reason, the Pew data for the Kansas Rainy Day fund start in 2020.
#
# Note that I needed to fix New Jersey's 2022 and 2023 Rainy Day fund amounts in millions of dollars. In the dataset, the value is NaN. But it should be zero in 2022 and 2023. See John Reitmeyer, [Billions more int taxes came in, but state drained its 'rainy day' fund](https://www.njspotlightnews.org/2021/07/rainy-day-fund-drained-2-billion-general-fund-transferred/)," NJ Spotlight News, July 1, 2021.

# %%
# Read in the Pew data on rainy day funds by year and state from worksheet
rain_totbal_path = (
    "https://github.com/TheCGO/KS-FlatTax/blob/main/data/" +
    "ReservesBalancesData.xlsx?raw=true"
)
rain_df = pd.read_excel(
    rain_totbal_path,
    sheet_name="Rainy Day Fund Data",
    header=5,
    index_col=0,
    skipfooter=2
)
rain_df.replace(0, np.nan, inplace=True)

# Create a DataFrame of just the rainy day funds in $millions
# by state and by year
rain_dol_df = rain_df.loc[:'Wyoming', 'FY 2000.1':'FY 2023 Enacted']
rain_dol_df.rename(columns = {
    'FY 2000.1': '2000',
    'FY 2001.1': '2001',
    'FY 2002.1': '2002',
    'FY 2003.1': '2003',
    'FY 2004.1': '2004',
    'FY 2005.1': '2005',
    'FY 2006.1': '2006',
    'FY 2007.1': '2007',
    'FY 2008.1': '2008',
    'FY 2009.1': '2009',
    'FY 2010.1': '2010',
    'FY 2011.1': '2011',
    'FY 2012.1': '2012',
    'FY 2013.1': '2013',
    'FY 2014.1': '2014',
    'FY 2015.1': '2015',
    ' FY 2016.1': '2016',
    ' FY 2017.1': '2017',
    ' FY 2018.1': '2018',
    'FY 2019.1': '2019',
    'FY 2020.1': '2020',
    'FY 2021.1': '2021',
    'FY2022.1': '2022',
    'FY 2023 Enacted': '2023'
}, inplace = True)

# Create a DataFrame of just the rainy day funds as a percent of
# general fund expenditures by state and by year
rain_pct_df = rain_df.loc[:, 'FY 2000.2':'FY 2023 Enacted.1']
rain_pct_df.rename(columns = {
    'FY 2000.2': '2000',
    'FY 2001.2': '2001',
    'FY 2002.2': '2002',
    'FY 2003.2': '2003',
    'FY 2004.2': '2004',
    'FY 2005.2': '2005',
    'FY 2006.2': '2006',
    'FY 2007.2': '2007',
    'FY 2008.2': '2008',
    'FY 2009.2': '2009',
    'FY 2010.2': '2010',
    'FY 2011.2': '2011',
    'FY 2012.2': '2012',
    'FY 2013.2': '2013',
    'FY 2014.2': '2014',
    'FY 2015.2': '2015',
    ' FY 2016.2': '2016',
    ' FY 2017.2': '2017',
    ' FY 2018.2': '2018',
    'FY 2019.2': '2019',
    'FY 2020.2': '2020',
    'FY 2021.2': '2021',
    'FY2022.2': '2022',
    'FY 2023 Enacted.1': '2023'
}, inplace = True)

# Replace New Jersey NaN values with zeros in 2022 and 2023
rain_dol_df[["2022", "2023"]] = \
    rain_dol_df[["2022", "2023"]].replace(np.nan, 0.0)
rain_pct_df[["2022", "2023"]] = \
    rain_pct_df[["2022", "2023"]].replace(np.nan, 0.0)

# %%
# Read in the PEW data on total reserves and balances by year and state from
# worksheet
totbal_df = pd.read_excel(
    rain_totbal_path,
    sheet_name="Total Balances Data",
    header=5,
    index_col=0,
    skipfooter=2
)
totbal_df.replace(0, np.nan, inplace=True)

# Create a DataFrame of just the total reserves and balances funds in $millions
# by state and by year
totbal_dol_df = totbal_df.loc[:'Wyoming', 'FY 2000.1':'FY 2023 Enacted.1']
totbal_dol_df.rename(columns = {
    'FY 2000.1': '2000',
    'FY 2001.1': '2001',
    'FY 2002.1': '2002',
    'FY 2003.1': '2003',
    'FY 2004.1': '2004',
    'FY 2005.1': '2005',
    'FY 2006.1': '2006',
    'FY 2007.1': '2007',
    'FY 2008.1': '2008',
    'FY 2009.1': '2009',
    'FY 2010.1': '2010',
    'FY 2011.1': '2011',
    'FY 2012.1': '2012',
    'FY 2013.1': '2013',
    'FY 2014.1': '2014',
    'FY 2015.1': '2015',
    ' FY 2016.1': '2016',
    ' FY 2017.1': '2017',
    ' FY 2018.1': '2018',
    'FY 2019.1': '2019',
    'FY 2020.1': '2020',
    'FY 2021.1': '2021',
    'FY2022.1': '2022',
    'FY 2023 Enacted.1': '2023'
}, inplace = True)

# Create a DataFrame of just the total reserves and balances funds as percent of
# general fund expenditures by state and by year
totbal_pct_df = totbal_df.loc[:, 'FY 2000.2':'FY 2023 Enacted.2']
totbal_pct_df.rename(columns = {
    'FY 2000.2': '2000',
    'FY 2001.2': '2001',
    'FY 2002.2': '2002',
    'FY 2003.2': '2003',
    'FY 2004.2': '2004',
    'FY 2005.2': '2005',
    'FY 2006.2': '2006',
    'FY 2007.2': '2007',
    'FY 2008.2': '2008',
    'FY 2009.2': '2009',
    'FY 2010.2': '2010',
    'FY 2011.2': '2011',
    'FY 2012.2': '2012',
    'FY 2013.2': '2013',
    'FY 2014.2': '2014',
    'FY 2015.2': '2015',
    ' FY 2016.2': '2016',
    ' FY 2017.2': '2017',
    ' FY 2018.2': '2018',
    'FY 2019.2': '2019',
    'FY 2020.2': '2020',
    'FY 2021.2': '2021',
    'FY2022.2': '2022',
    'FY 2023 Enacted.2': '2023'
}, inplace = True)

# %% [markdown]
# Executing the cell below and the following cell will create the rain_totbal_50_ks_timeseries.html file and save it to the `./images/` directory in the repository. I created the .png version of the file by just screenshotting the `.html` image. These cells also save the source data used to create the image as `./data/fig2_source.csv`.

# %%
rain_pct_50_df = rain_pct_df.loc["50-state median", :].to_frame().reset_index()
rain_pct_50_df.rename(
    columns = {"index":"year", "50-state median":"fraction"}, inplace = True
)
rain_pct_50_df["percent"] = 100 * rain_pct_50_df["fraction"]

rain_pct_ks_df = rain_pct_df.loc["Kansas", :].to_frame().reset_index()
rain_pct_ks_df.rename(
    columns = {"index":"year", "Kansas":"fraction"}, inplace = True
)
rain_pct_ks_df["percent"] = 100 * rain_pct_ks_df["fraction"]

totbal_pct_50_df = \
    totbal_pct_df.loc["50-state median", :].to_frame().reset_index()
totbal_pct_50_df.rename(
    columns = {"index":"year", "50-state median":"fraction"}, inplace = True
)
totbal_pct_50_df["percent"] = 100 * totbal_pct_50_df["fraction"]

totbal_pct_ks_df = totbal_pct_df.loc["Kansas", :].to_frame().reset_index()
totbal_pct_ks_df.rename(
    columns = {'index':'year', "Kansas":"fraction"}, inplace = True
)
totbal_pct_ks_df["percent"] = 100 * totbal_pct_ks_df["fraction"]

# Merge the four DataFrames to save the joint dataframe as a .csv
fig2_source_df = rain_pct_50_df[['year', 'percent']].rename(
    columns={'percent':'rain_50m_pct'}
)
fig2_source_df = pd.merge(
    fig2_source_df,
    rain_pct_ks_df[['year', 'percent']].rename(
        columns={'percent':'rain_ks_pct'}
    ),
    on='year', how='inner'
)
fig2_source_df = pd.merge(
    fig2_source_df,
    totbal_pct_50_df[['year', 'percent']].rename(
        columns={'percent':'totbal_50m_pct'}
    ),
    on='year', how='inner'
)
fig2_source_df = pd.merge(
    fig2_source_df,
    totbal_pct_ks_df[['year', 'percent']].rename(
        columns={'percent':'totbal_ks_pct'}
    ),
    on='year', how='inner'
)
fig2_source_df.to_csv('./data/fig2_source.csv', index=False)
fig2_source_df
# Out:
#     year  rain_50m_pct  rain_ks_pct  totbal_50m_pct  totbal_ks_pct
# 0   2000      4.127259          NaN        8.766520       8.654639
# 1   2001      4.614270          NaN        7.148315       8.255824
# 2   2002      1.655668          NaN        2.887308       0.270930
# 3   2003      0.722015          NaN        2.656212       2.965559
# 4   2004      1.844196          NaN        5.246650       7.587166
# 5   2005      2.459819          NaN        9.016673      10.206605
# 6   2006      4.553273          NaN       11.801597      14.274318
# 7   2007      4.738918          NaN       11.327766      16.673503
# 8   2008      4.834502          NaN        8.292193       8.630240
# 9   2009      2.728263          NaN        4.582794       0.819550
# 10  2010      1.638317          NaN        4.488299      -0.514427
# 11  2011      1.761059          NaN        6.368404       3.322980
# 12  2012      2.486130          NaN        7.907533       8.248471
# 13  2013      3.558071          NaN        9.956752      11.561909
# 14  2014      4.524613          NaN        7.292836       6.346315
# 15  2015      4.918311          NaN        9.204278       1.146384
# 16  2016      5.339670          NaN        9.739579       0.607302
# 17  2017      5.613689          NaN        8.315685       1.730264
# 18  2018      6.547734          NaN       11.724584      11.455686
# 19  2019      7.929661          NaN       13.993790      15.713514
# 20  2020      8.439704     1.088734       12.711729       7.667664
# 21  2021     10.288484     1.126888       27.123898      29.949916
# 22  2022     11.595619    11.824992       34.593405      34.208536
# 23  2023     12.178619    10.378791       27.068067      23.653351

# %%
# fig2_title = ("Rainy Day fund and total reserves as a percentage of " +
#               "general fund expenditures: 2000-2023")
fig2_title = ""
output_file(
    "./images/rain_totbal_50_ks_timeseries.html", title=fig2_title,
    mode='inline'
)
output_notebook()
min_year = 2000
max_year = 2023
min_pct = 2.0
max_pct = 0.0
pct_buffer = 0.05

var_list = [rain_pct_50_df, rain_pct_ks_df, totbal_pct_50_df, totbal_pct_ks_df]
color_list = ["#3477A5", "#D5AB53", "#3477A5", "#D5AB53"]
marker_list = ["circle", "circle", "square", "square"]
legend_label_list = [
    "Rainy Day Fund, 50-state median",
    "Rainy Day Fund, Kansas",
    "Total balances, 50-state median",
    "Total balances, Kansas"
]
cds_list = []

for k, df in enumerate(var_list):
    min_pct = np.minimum(min_pct, df["percent"].min())
    max_pct = np.maximum(max_pct, df["percent"].max())
    cds_list.append(ColumnDataSource(df))

fig2 = figure(title=fig2_title,
              height=420,
              width=700,
              x_axis_label='Year',
              x_range=(min_year - 1, max_year + 1.5),
              y_axis_label='Percent of general fund expenditures',
              y_range=(min_pct - pct_buffer * (max_pct - min_pct),
                       max_pct + pct_buffer * (max_pct - min_pct)),
              toolbar_location=None)

# Turn off any pan, drag, or scrolling ability
fig2.toolbar.active_drag = None
fig2.toolbar.active_scroll = None
fig2.toolbar.active_tap = None

# Set title font size and axes font sizes
fig2.title.text_font_size = '0pt'  # Hide title by setting font size to 0
fig2.title.text_color = '#434244'
fig2.xaxis.axis_label_text_font_size = '12pt'
fig2.xaxis.major_label_text_font_size = '12pt'
fig2.xaxis.major_label_text_color = '#434244'
fig2.yaxis.axis_label_text_font_size = '12pt'
fig2.yaxis.major_label_text_font_size = '12pt'
fig2.yaxis.major_label_text_color = '#434244'

# Modify tick intervals for X-axis and Y-axis
fig2.xaxis.ticker = SingleIntervalTicker(interval=2, num_minor_ticks=2)
fig2.xaxis.axis_line_color = '#434244'
fig2.xaxis.major_tick_line_color = '#434244'
fig2.xaxis.minor_tick_line_color = '#434244'
fig2.xgrid.ticker = SingleIntervalTicker(interval=2)
fig2.yaxis.ticker = SingleIntervalTicker(interval=10, num_minor_ticks=5)
fig2.yaxis.axis_line_color = '#434244'
fig2.yaxis.major_tick_line_color = '#434244'
fig2.yaxis.minor_tick_line_color = '#434244'
fig2.ygrid.ticker = SingleIntervalTicker(interval=10)

# Create lines and markers for time series
for k, yvar in enumerate(var_list):
    fig2.line(x='year', y='percent', source=cds_list[k], color=color_list[k],
              line_width=4, alpha=0.7)
    fig2.scatter(x='year', y='percent', source=cds_list[k], size=10,
                 line_width=1, line_color='black', fill_color=color_list[k],
                 marker=marker_list[k], line_alpha=0.7, fill_alpha=0.7,
                 legend_label=legend_label_list[k])

fig2.segment(x0=2022.4, y0=min_pct - pct_buffer * (max_pct - min_pct),
             x1=2022.4, y1=max_pct + pct_buffer * (max_pct - min_pct),
             color='#434244', line_dash='6 2', line_width=2)
    
label_temp = Label(
    x=2022.5, y=17.0, x_units='data', y_units='data', text='Projected',
    text_font_size='9pt', text_color='#434244'
)
fig2.add_layout(label_temp)

# Add information on hover
tooltips = [('Year', '@year'),
            ('Pct of gen. fund exps.','@percent{0.0}' + '%')]
fig2.add_tools(HoverTool(tooltips=tooltips, toggleable=False))

# Add legend
fig2.legend.location = 'top_center'
fig2.legend.border_line_width = 1
fig2.legend.border_line_color = '#434244'
fig2.legend.border_line_alpha = 1
fig2.legend.label_text_font_size = '12pt'
fig2.legend.label_text_color = '#434244'

# Add notes below image
note_text_list2 = [
    (
        'Source: Pew Charitable Trusts, "Fiscal 50: State Trends and Analysis," ' +
        'May 17, 2023,'
    ),
    ('        accessed May 26, 2023.')    
]
for note_text in note_text_list2:
    caption = Title(
        text=note_text, align='left', text_font_size='11pt',
        text_font_style='normal',
        text_color='#434244',
        # text_font='Open Sans'
    )
    fig2.add_layout(caption, 'below')

show(fig2)
# # This export_png() function requires selenium package as well as firefox
# # and geckodriver packages
# # (see https://docs.bokeh.org/en/3.0.3/docs/user_guide/output/export.html)
# export_png(fig, filename="/images/rain_totbal_50_tn_timeseries.png")
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="e8384d1e-12eb-4591-a08d-261e9c7f30d7">Loading BokehJS ...</span>
#     </div>
#   <div id="c52d9013-f218-4cf5-8072-543bcb7cb85b" data-root-id="p2715" style="display: contents;"></div>

# %% [markdown]
# Create Figure 2 without the source text underneath (for web publication).

# %%
output_file(
    "./images/rain_totbal_50_ks_timeseries_nosubtxt.html", title=fig2_title,
    mode='inline'
)
output_notebook()
min_year = 2000
max_year = 2023
min_pct = 2.0
max_pct = 0.0
pct_buffer = 0.05

var_list = [rain_pct_50_df, rain_pct_ks_df, totbal_pct_50_df, totbal_pct_ks_df]
color_list = ["#3477A5", "#D5AB53", "#3477A5", "#D5AB53"]
marker_list = ["circle", "circle", "square", "square"]
legend_label_list = [
    "Rainy Day Fund, 50-state median",
    "Rainy Day Fund, Kansas",
    "Total balances, 50-state median",
    "Total balances, Kansas"
]
cds_list = []

for k, df in enumerate(var_list):
    min_pct = np.minimum(min_pct, df["percent"].min())
    max_pct = np.maximum(max_pct, df["percent"].max())
    cds_list.append(ColumnDataSource(df))

fig2_nosubtxt = figure(title=fig2_title,
                       height=420,
                       width=700,
                       x_axis_label='Year',
                       x_range=(min_year - 1, max_year + 1.5),
                       y_axis_label='Percent of general fund expenditures',
                       y_range=(min_pct - pct_buffer * (max_pct - min_pct),
                                max_pct + pct_buffer * (max_pct - min_pct)),
                       toolbar_location=None)

# Turn off any pan, drag, or scrolling ability
fig2_nosubtxt.toolbar.active_drag = None
fig2_nosubtxt.toolbar.active_scroll = None
fig2_nosubtxt.toolbar.active_tap = None

# Set title font size and axes font sizes
fig2_nosubtxt.title.text_font_size = '0pt'  # Hide title by setting font size=0
fig2_nosubtxt.title.text_color = '#434244'
fig2_nosubtxt.xaxis.axis_label_text_font_size = '12pt'
fig2_nosubtxt.xaxis.major_label_text_font_size = '12pt'
fig2_nosubtxt.xaxis.major_label_text_color = '#434244'
fig2_nosubtxt.yaxis.axis_label_text_font_size = '12pt'
fig2_nosubtxt.yaxis.major_label_text_font_size = '12pt'
fig2_nosubtxt.yaxis.major_label_text_color = '#434244'

# Modify tick intervals for X-axis and Y-axis
fig2_nosubtxt.xaxis.ticker = SingleIntervalTicker(interval=2,
                                                  num_minor_ticks=2)
fig2_nosubtxt.xaxis.axis_line_color = '#434244'
fig2_nosubtxt.xaxis.major_tick_line_color = '#434244'
fig2_nosubtxt.xaxis.minor_tick_line_color = '#434244'
fig2_nosubtxt.xgrid.ticker = SingleIntervalTicker(interval=2)
fig2_nosubtxt.yaxis.ticker = SingleIntervalTicker(interval=10,
                                                  num_minor_ticks=5)
fig2_nosubtxt.yaxis.axis_line_color = '#434244'
fig2_nosubtxt.yaxis.major_tick_line_color = '#434244'
fig2_nosubtxt.yaxis.minor_tick_line_color = '#434244'
fig2_nosubtxt.ygrid.ticker = SingleIntervalTicker(interval=10)

# Create lines and markers for time series
for k, yvar in enumerate(var_list):
    fig2_nosubtxt.line(
        x='year', y='percent', source=cds_list[k], color=color_list[k],
        line_width=4, alpha=0.7
    )
    fig2_nosubtxt.scatter(
        x='year', y='percent', source=cds_list[k], size=10, line_width=1,
        line_color='black', fill_color=color_list[k], marker=marker_list[k],
        line_alpha=0.7, fill_alpha=0.7, legend_label=legend_label_list[k]
    )

fig2_nosubtxt.segment(x0=2022.4, y0=min_pct - pct_buffer * (max_pct - min_pct),
                      x1=2022.4, y1=max_pct + pct_buffer * (max_pct - min_pct),
                      color='#434244', line_dash='6 2', line_width=2)
    
label_temp = Label(
    x=2022.5, y=16.0, x_units='data', y_units='data', text='Projected',
    text_font_size='9pt', text_color='#434244'
)
fig2_nosubtxt.add_layout(label_temp)

# Add information on hover
tooltips = [('Year', '@year'),
            ('Pct of gen. fund exps.','@percent{0.0}' + '%')]
fig2_nosubtxt.add_tools(HoverTool(tooltips=tooltips, toggleable=False))

# Add legend
fig2_nosubtxt.legend.location = 'top_center'
fig2_nosubtxt.legend.border_line_width = 1
fig2_nosubtxt.legend.border_line_color = '#434244'
fig2_nosubtxt.legend.border_line_alpha = 1
fig2_nosubtxt.legend.label_text_font_size = '12pt'
fig2_nosubtxt.legend.label_text_color = '#434244'

# # Add notes below image
# note_text_list2 = [
#     (
#         'Source: Pew Charitable Trusts, "Fiscal 50: State Trends and Analysis," ' +
#         'May 17, 2023,'
#     ),
#     ('        accessed May 26, 2023.')    
# ]
# for note_text in note_text_list2:
#     caption = Title(
#         text=note_text, align='left', text_font_size='11pt',
#         text_font_style='normal',
#         text_color='#434244',
#         # text_font='Open Sans'
#     )
#     fig2.add_layout(caption, 'below')

show(fig2_nosubtxt)

# # This export_png() function requires selenium package as well as firefox
# # and geckodriver packages
# # (see https://docs.bokeh.org/en/3.0.3/docs/user_guide/output/export.html)
# export_png(fig, filename="/images/rain_totbal_50_tn_timeseries.png")
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="c45a00ec-7fa2-4873-9d48-6019a26e31c3">Loading BokehJS ...</span>
#     </div>
#   <div id="ec10ab1c-8036-4b12-b1b5-0fb79fe2f691" data-root-id="p3529" style="display: contents;"></div>

# %% [markdown]
# ### 1.3. Figure 3. Estimated 2022 Rainy Day Fund Balances and Total Reserves and Balances as Percentages of General-Fund Expenditures

# %%
rain_pct_2022_df = rain_pct_df.loc[:'Wyoming', '2022'].to_frame().reset_index()
rain_pct_2022_df.rename(
    columns = {"index": "state", "2022": "rain_frac"}, inplace = True
)
rain_pct_2022_df["rain_pct"] = 100 * rain_pct_2022_df["rain_frac"]
rain_pct_2022_df.drop('rain_frac', axis=1, inplace=True)

rain_dol_2022_df = rain_dol_df.loc[:'Wyoming', '2022'].to_frame().reset_index()
rain_dol_2022_df.rename(
    columns = {"index": "state", "2022": "rain_dol"}, inplace = True
)

totbal_pct_2022_df = \
    totbal_pct_df.loc[:'Wyoming', '2022'].to_frame().reset_index()
totbal_pct_2022_df.rename(
    columns = {"index": "state", "2022": "totbal_frac"}, inplace = True
)
totbal_pct_2022_df["totbal_pct"] = 100 * totbal_pct_2022_df["totbal_frac"]
totbal_pct_2022_df.drop('totbal_frac', axis=1, inplace=True)

totbal_dol_2022_df = \
    totbal_dol_df.loc[:'Wyoming', '2022'].to_frame().reset_index()
totbal_dol_2022_df.rename(
    columns = {"index": "state", "2022": "totbal_dol"}, inplace = True
)

# Merge the four DataFrames
rain_totbal_pct_dol_2022_df = rain_pct_2022_df.copy()
rain_totbal_pct_dol_2022_df = pd.merge(
    rain_totbal_pct_dol_2022_df, rain_dol_2022_df, on='state', how='inner'
)
rain_totbal_pct_dol_2022_df["rain_color"] = "#D5AB53"
rain_totbal_pct_dol_2022_df["rain_color"][
    rain_totbal_pct_dol_2022_df["state"]=="Kansas"
] = "#EED17E"
rain_totbal_pct_dol_2022_df = pd.merge(
    rain_totbal_pct_dol_2022_df, totbal_pct_2022_df, on='state', how='inner'
)
rain_totbal_pct_dol_2022_df = pd.merge(
    rain_totbal_pct_dol_2022_df, totbal_dol_2022_df, on='state', how='inner'
)
rain_totbal_pct_dol_2022_df["totbal_color"] = "#3477A5"
rain_totbal_pct_dol_2022_df["totbal_color"][
    rain_totbal_pct_dol_2022_df["state"]=="Kansas"
] = "#74AAC7"

# Create a new variable that is totbal_pct - rain_pct
rain_totbal_pct_dol_2022_df["totbal_rain_pct_dif"] = (
    rain_totbal_pct_dol_2022_df["totbal_pct"] -
    rain_totbal_pct_dol_2022_df["rain_pct"]
)

# Sort by rainy day fund percent
rain_totbal_pct_dol_2022_sorted_df = rain_totbal_pct_dol_2022_df.sort_values(
    by=['rain_pct', 'totbal_pct'], ascending=[True, True]
)

rain_totbal_pct_dol_2022_sorted_df.to_csv('./data/fig3_source.csv',
                                          index=False)
rain_totbal_pct_dol_2022_sorted_df
# Out:
#              state   rain_pct      rain_dol rain_color  totbal_pct  \
# 29      New Jersey   0.000000      0.000000    #D5AB53   14.086556
# 46      Washington   1.106906    312.400000    #D5AB53   18.595958
# 12        Illinois   1.654149    751.000000    #D5AB53    4.030748
# 10          Hawaii   3.684520    325.800000    #D5AB53   33.303051
# 31        New York   3.931626   3319.000000    #D5AB53   39.153972
# 25         Montana   4.286700    118.000000    #D5AB53   71.653350
# 38    Rhode Island   5.330159    279.113537    #D5AB53    9.466316
# 19        Maryland   5.477720   1161.200000    #D5AB53   31.416697
# 7         Delaware   5.541826    280.300000    #D5AB53   51.511497
# 17       Louisiana   6.855598    772.437585    #D5AB53    6.889988
# 27          Nevada   7.313558    340.000000    #D5AB53   40.223148
# 24        Missouri   7.375129    772.100000    #D5AB53   54.171136
# 37    Pennsylvania   7.426217   2866.000000    #D5AB53   21.774674
# 8          Florida   7.599595   2730.200000    #D5AB53   67.583283
# 2          Arizona   7.670501    982.200000    #D5AB53   42.882803
# 13         Indiana   8.778856   1616.600000    #D5AB53   33.259841
# 48       Wisconsin   8.947860   1733.800000    #D5AB53   31.134300
# 41       Tennessee   9.040484   1550.000000    #D5AB53   37.005908
# 23     Mississippi   9.556674    556.100000    #D5AB53    9.632804
# 28   New Hampshire   9.948980    159.900000    #D5AB53   25.709308
# 45        Virginia  10.019657   2647.193310    #D5AB53   27.934115
# 34            Ohio  10.044018   2706.200000    #D5AB53   34.343104
# 43            Utah  10.076208   1033.200000    #D5AB53   42.718563
# 14            Iowa  10.221845    830.300000    #D5AB53   33.787610
# 44         Vermont  11.366247    265.220000    #D5AB53   18.968887
# 15          Kansas  11.824992    969.200000    #EED17E   34.208536
# 32  North Carolina  11.996889   3116.000000    #D5AB53   39.585499
# 36          Oregon  12.156919   1659.651044    #D5AB53   51.100513
# 22       Minnesota  12.381254   3218.345000    #D5AB53   33.404731
# 21        Michigan  13.191240   1598.000000    #D5AB53   60.619443
# 0          Alabama  13.193958   1449.000000    #D5AB53   37.893702
# 40    South Dakota  15.003909    307.100000    #D5AB53   20.646863
# 6      Connecticut  16.028677   3313.400000    #D5AB53   16.028677
# 35        Oklahoma  16.419876   1222.000000    #D5AB53   57.003305
# 42           Texas  16.790231  10614.700000    #D5AB53   42.390560
# 20   Massachusetts  17.216170   6937.500000    #D5AB53   44.705234
# 5         Colorado  18.645427   3208.300000    #D5AB53   18.645427
# 16        Kentucky  18.968631   2495.570000    #D5AB53   33.244681
# 4       California  19.216214  46684.700000    #D5AB53   20.976470
# 39  South Carolina  19.250529   1847.300000    #D5AB53   71.548858
# 26        Nebraska  19.852312    927.500000    #D5AB53   73.236301
# 11           Idaho  19.970575    882.300000    #D5AB53   26.878678
# 47   West Virginia  20.181841    956.700000    #D5AB53   62.245802
# 3         Arkansas  20.720782   1212.000000    #D5AB53   45.912262
# 18           Maine  22.268320    907.100000    #D5AB53   23.093163
# 9          Georgia  22.413037   5240.228297    #D5AB53   50.747908
# 33    North Dakota  26.171020    717.400000    #D5AB53   61.155698
# 30      New Mexico  29.932703   2734.418298    #D5AB53   34.843705
# 1           Alaska  50.687391   2709.900000    #D5AB53   50.687391
# 49         Wyoming  95.787427   1478.000000    #D5AB53   95.787427
#
#       totbal_dol totbal_color  totbal_rain_pct_dif
# 29   7360.000000      #3477A5            14.086556
# 46   5248.300000      #3477A5            17.489051
# 12   1830.000000      #3477A5             2.376600
# 10   2944.789000      #3477A5            29.618531
# 31  33053.000000      #3477A5            35.222346
# 25   1972.401760      #3477A5            67.366649
# 38    495.703197      #3477A5             4.136157
# 19   6659.900000      #3477A5            25.938977
# 7    2605.400000      #3477A5            45.969671
# 17    776.312398      #3477A5             0.034390
# 27   1869.933933      #3477A5            32.909590
# 24   5671.160000      #3477A5            46.796008
# 37   8403.500000      #3477A5            14.348457
# 8   24279.700000      #3477A5            59.983689
# 2    5491.100000      #3477A5            35.212302
# 13   6124.700000      #3477A5            24.480985
# 48   6032.800000      #3477A5            22.186440
# 41   6344.700000      #3477A5            27.965425
# 23    560.530000      #3477A5             0.076130
# 28    413.200000      #3477A5            15.760329
# 45   7380.193310      #3477A5            17.914459
# 34   9253.200000      #3477A5            24.299086
# 43   4380.300387      #3477A5            32.642355
# 14   2744.500000      #3477A5            23.565765
# 44    442.620000      #3477A5             7.602640
# 15   2803.800000      #74AAC7            22.383544
# 32  10281.700000      #3477A5            27.588610
# 36   6976.193545      #3477A5            38.943594
# 22   8683.123000      #3477A5            21.023478
# 21   7343.500000      #3477A5            47.428203
# 0    4161.600000      #3477A5            24.699744
# 40    422.600000      #3477A5             5.642955
# 6    3313.400000      #3477A5             0.000000
# 35   4242.300000      #3477A5            40.583430
# 42  26799.100000      #3477A5            25.600329
# 20  18014.608363      #3477A5            27.489064
# 5    3208.300000      #3477A5             0.000000
# 16   4373.770000      #3477A5            14.276050
# 4   50961.143000      #3477A5             1.760256
# 39   6865.900000      #3477A5            52.298330
# 26   3421.600000      #3477A5            53.383990
# 11   1187.500000      #3477A5             6.908103
# 47   2950.700000      #3477A5            42.063961
# 3    2685.500000      #3477A5            25.191479
# 18    940.700000      #3477A5             0.824844
# 9   11864.997144      #3477A5            28.334871
# 33   1676.400000      #3477A5            34.984678
# 30   3183.049201      #3477A5             4.911003
# 1    2709.900000      #3477A5             0.000000
# 49   1478.000000      #3477A5             0.000000

# %%
# fig3_title = ('2022 Rainy day Fund Balances and Total Fund ' +
#               'Balances as Percent of General Fund Expenditures')
fig3_title = ""
output_file("./images/rain_totbal_pct_2022.html", title=fig3_title,
            mode='inline')
output_notebook()

states = rain_totbal_pct_dol_2022_sorted_df['state'].tolist()
legend_label_list = ["Rainy day fund", "Total reserves and balances"]
rain_totbal_pct_dol_2022_cds = \
    ColumnDataSource(rain_totbal_pct_dol_2022_sorted_df)

min_pct = rain_totbal_pct_dol_2022_sorted_df['rain_pct'].min()
max_pct = rain_totbal_pct_dol_2022_sorted_df['totbal_pct'].max()
pct_buffer = 0.05

fig3 = figure(title=fig3_title,
              height=900,
              width=550,
              y_range=states,
              x_axis_label='Percent of general fund expenditures',
              x_range=(min_pct - pct_buffer * (max_pct - min_pct),
                       max_pct + pct_buffer * (max_pct - min_pct)),
              toolbar_location=None)

# Turn off any pan, drag, or scrolling ability
fig3.toolbar.active_drag = None
fig3.toolbar.active_scroll = None
fig3.toolbar.active_tap = None

# Set title font size and axes font sizes
fig3.title.text_font_size = '0pt'  # Hide title by setting font size to 0
fig3.title.text_color = '#434244'
fig3.xaxis.axis_label_text_font_size = '11pt'
fig3.xaxis.major_label_text_font_size = '11pt'
fig3.xaxis.major_label_text_color = '#434244'
fig3.yaxis.axis_label_text_font_size = '9pt'
fig3.yaxis.major_label_text_font_size = '9pt'
fig3.yaxis.major_label_text_color = '#434244'

# Modify tick intervals for X-axis and Y-axis
fig3.xaxis.ticker = SingleIntervalTicker(interval=10, num_minor_ticks=5)
fig3.xaxis.axis_line_color = '#434244'
fig3.xaxis.major_tick_line_color = '#434244'
fig3.xaxis.minor_tick_line_color = '#434244'
fig3.xgrid.ticker = SingleIntervalTicker(interval=10)
fig3.yaxis.axis_line_color = '#434244'
fig3.yaxis.major_tick_line_color = '#434244'
fig3.yaxis.minor_tick_line_color = '#434244'

fig3.hbar_stack(
    ['rain_pct', 'totbal_rain_pct_dif'], y='state', height=0.9,
    color=['rain_color', 'totbal_color'],
    source=rain_totbal_pct_dol_2022_cds, legend_label=legend_label_list
)

# Add information on hover
tooltips = [('State', '@state'),
            ('Rainy day fund % exps.','@rain_pct{0.0}' + '%'),
            ('Total balances % exps.','@totbal_pct{0.0}' + '%'),
           ]
fig3.add_tools(HoverTool(tooltips=tooltips, toggleable=False))

# Add legend
fig3.legend.location = (210, 240)
fig3.legend.border_line_width = 1
fig3.legend.border_line_color = '#434244'
fig3.legend.border_line_alpha = 1
fig3.legend.label_text_color = '#434244'
fig3.legend.label_text_font_size = '11pt'
fig3.legend.label_text_color = '#434244'
fig3.y_range.range_padding = 0.02

# Add notes below image
note_text_list3 = [
    (
        'Source: Pew Charitable Trusts, "Fiscal 50: State Trends and'
    ),
    (
        '        Analysis," May 17, 2023, accessed May 26, 2023.'
    ),
    (
        'Note: For states in which the blue bar is not visible for total ' +
        'balances'
    ),
    (
        '         and reserves, the value equals the rainy day fund balance'
    ),
    (
        '         percentage.'
    )
]
for note_text in note_text_list3:
    caption = Title(text=note_text, align='left', text_font_size='11pt',
                    text_font_style='normal', text_color='#434244')
    fig3.add_layout(caption, 'below')

show(fig3)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="b39bc527-cbca-40da-af5b-1c3d11fa79ad">Loading BokehJS ...</span>
#     </div>
#   <div id="dff20938-4c0b-47db-8d4e-c787bc03eaca" data-root-id="p4375" style="display: contents;"></div>

# %% [markdown]
# Create Figure 3 without the source text underneath (for web publication).

# %%
output_file(
    "./images/rain_totbal_pct_2022_nosubtxt.html", title=fig3_title,
    mode='inline'
)
output_notebook()

states = rain_totbal_pct_dol_2022_sorted_df['state'].tolist()
legend_label_list = ["Rainy day fund", "Total reserves and balances"]
rain_totbal_pct_dol_2022_cds = \
    ColumnDataSource(rain_totbal_pct_dol_2022_sorted_df)

min_pct = rain_totbal_pct_dol_2022_sorted_df['rain_pct'].min()
max_pct = rain_totbal_pct_dol_2022_sorted_df['totbal_pct'].max()
pct_buffer = 0.05

fig3_nosubtxt = figure(
    title=fig3_title,
    height=900,
    width=550,
    y_range=states,
    x_axis_label='Percent of general fund expenditures',
    x_range=(min_pct - pct_buffer * (max_pct - min_pct),
             max_pct + pct_buffer * (max_pct - min_pct)),
    toolbar_location=None
)

# Turn off any pan, drag, or scrolling ability
fig3_nosubtxt.toolbar.active_drag = None
fig3_nosubtxt.toolbar.active_scroll = None
fig3_nosubtxt.toolbar.active_tap = None

# Set title font size and axes font sizes
fig3_nosubtxt.title.text_font_size = '0pt'  # Hide title by setting font size to 0
fig3_nosubtxt.title.text_color = '#434244'
fig3_nosubtxt.xaxis.axis_label_text_font_size = '11pt'
fig3_nosubtxt.xaxis.major_label_text_font_size = '11pt'
fig3_nosubtxt.xaxis.major_label_text_color = '#434244'
fig3_nosubtxt.yaxis.axis_label_text_font_size = '9pt'
fig3_nosubtxt.yaxis.major_label_text_font_size = '9pt'
fig3_nosubtxt.yaxis.major_label_text_color = '#434244'

# Modify tick intervals for X-axis and Y-axis
fig3_nosubtxt.xaxis.ticker = SingleIntervalTicker(interval=10,
                                                  num_minor_ticks=5)
fig3_nosubtxt.xaxis.axis_line_color = '#434244'
fig3_nosubtxt.xaxis.major_tick_line_color = '#434244'
fig3_nosubtxt.xaxis.minor_tick_line_color = '#434244'
fig3_nosubtxt.xgrid.ticker = SingleIntervalTicker(interval=10)
fig3_nosubtxt.yaxis.axis_line_color = '#434244'
fig3_nosubtxt.yaxis.major_tick_line_color = '#434244'
fig3_nosubtxt.yaxis.minor_tick_line_color = '#434244'

fig3_nosubtxt.hbar_stack(
    ['rain_pct', 'totbal_rain_pct_dif'], y='state', height=0.9,
    color=['rain_color', 'totbal_color'],
    source=rain_totbal_pct_dol_2022_cds, legend_label=legend_label_list
)

# Add information on hover
tooltips = [('State', '@state'),
            ('Rainy day fund % exps.','@rain_pct{0.0}' + '%'),
            ('Total balances % exps.','@totbal_pct{0.0}' + '%'),
           ]
fig3_nosubtxt.add_tools(HoverTool(tooltips=tooltips, toggleable=False))

# Add legend
fig3_nosubtxt.legend.location = (210, 300)
fig3_nosubtxt.legend.border_line_width = 1
fig3_nosubtxt.legend.border_line_color = '#434244'
fig3_nosubtxt.legend.border_line_alpha = 1
fig3_nosubtxt.legend.label_text_color = '#434244'
fig3_nosubtxt.legend.label_text_font_size = '11pt'
fig3_nosubtxt.legend.label_text_color = '#434244'
fig3_nosubtxt.y_range.range_padding = 0.02

# # Add notes below image
# note_text_list3 = [
#     (
#         'Source: Pew Charitable Trusts, "Fiscal 50: State Trends and'
#     ),
#     (
#         '        Analysis," May 17, 2023, accessed May 26, 2023.'
#     ),
#     (
#         'Note: For states in which the blue bar is not visible for total ' +
#         'balances'
#     ),
#     (
#         '         and reserves, the value equals the rainy day fund balance'
#     ),
#     (
#         '         percentage.'
#     )
# ]
# for note_text in note_text_list3:
#     caption = Title(text=note_text, align='left', text_font_size='11pt',
#                     text_font_style='normal', text_color='#434244')
#     fig3.add_layout(caption, 'below')

show(fig3_nosubtxt)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="ff88d1c0-4e0f-44a6-a369-70c60f45427d">Loading BokehJS ...</span>
#     </div>
#   <div id="b524c294-5d61-4e07-afa4-3bbfb61002fa" data-root-id="p4831" style="display: contents;"></div>

# %% [markdown]
# ### 1.4. Table 1. Number of states for which 2022 amounts represent 23-year high for select categories of rainy day fund and total balances and reserves statistics: 2000-2022

# %%
# Number of states for which estimated 2022 rainy day fund balances
# represent a 23-year high
rain_dol_df["max_2021"] = False
rain_dol_df["max_2022"] = False
rain_dol_df["max_2021"][
    rain_dol_df["2021"] > rain_dol_df.loc[:, "2000":"2020"].max(axis=1)
] = True
rain_dol_df["max_2022"][
    rain_dol_df["2022"] > rain_dol_df.loc[:, "2000":"2021"].max(axis=1)
] = True
rain_dol_22high = rain_dol_df["max_2021"].sum()
rain_dol_23high = rain_dol_df["max_2022"].sum()
print("Number of states for which 2022 rainy day fund balances")
print("are 23-year high is", rain_dol_23high, "states.")
print("Number of states for which 2021 rainy day fund balances")
print("are 22-year high is", rain_dol_22high, "states.")
print("Kansas 2022:", rain_dol_df.loc["Kansas", "max_2022"])
print("Kansas 2021:", rain_dol_df.loc["Kansas", "max_2021"])
# Out:
# Number of states for which 2022 rainy day fund balances
# are 23-year high is 37 states.
# Number of states for which 2021 rainy day fund balances
# are 22-year high is 28 states.
# Kansas 2022: True
# Kansas 2021: False

# %%
# Number of states for which estimated 2022 rainy day fund balances
# as percent of general fund expenditures represent a 23-year high
rain_pct_df["max_2021"] = False
rain_pct_df["max_2022"] = False
rain_pct_df["max_2021"][
    rain_pct_df["2021"] > rain_pct_df.loc[:, "2000":"2020"].max(axis=1)
] = True
rain_pct_df["max_2022"][
    rain_pct_df["2022"] > rain_pct_df.loc[:, "2000":"2021"].max(axis=1)
] = True
rain_pct_22high = rain_pct_df["max_2021"].sum()
rain_pct_23high = rain_pct_df["max_2022"].sum()
print("")
print("Number of states for which 2022 rainy day fund balances")
print("as percent of general fund expenditures are 23-year high")
print("is", rain_pct_23high, "states.")
print("Number of states for which 2021 rainy day fund balances")
print("as percent of general fund expenditures are 22-year high")
print("is", rain_pct_22high, "states.")
print("Kansas 2022:", rain_pct_df.loc["Kansas", "max_2022"])
print("Kansas 2021:", rain_pct_df.loc["Kansas", "max_2021"])
# Out:
# Number of states for which 2022 rainy day fund balances
# as percent of general fund expenditures are 23-year high
# is 18 states.
# Number of states for which 2021 rainy day fund balances
# as percent of general fund expenditures are 22-year high
# is 24 states.
# Kansas 2022: True
# Kansas 2021: True

# %%
# Number of states for which estimated 2022 total balances and reserves
# represent a 23-year high
totbal_dol_df["max_2021"] = False
totbal_dol_df["max_2022"] = False
totbal_dol_df["max_2021"][
    totbal_dol_df["2021"] > totbal_dol_df.loc[:, "2000":"2020"].max(axis=1)
] = True
totbal_dol_df["max_2022"][
    totbal_dol_df["2022"] > totbal_dol_df.loc[:, "2000":"2021"].max(axis=1)
] = True
totbal_dol_22high = totbal_dol_df["max_2021"].sum()
totbal_dol_23high = totbal_dol_df["max_2022"].sum()
print("")
print("Number of states for which 2022 total balances and reserves")
print("are 23-year high is", totbal_dol_23high, "states.")
print("Number of states for which 2021 total balances and reserves")
print("are 22-year high is", totbal_dol_22high, "states.")
print("Kansas 2022:", totbal_dol_df.loc["Kansas", "max_2022"])
print("Kansas 2021:", totbal_dol_df.loc["Kansas", "max_2021"])
# Out:
# Number of states for which 2022 total balances and reserves
# are 23-year high is 43 states.
# Number of states for which 2021 total balances and reserves
# are 22-year high is 40 states.
# Kansas 2022: True
# Kansas 2021: True

# %%
# Number of states for which estimated 2022 total balances and reserves
# as percent of general fund expenditures represent a 23-year high
totbal_pct_df["max_2021"] = False
totbal_pct_df["max_2022"] = False
totbal_pct_df["max_2021"][
    totbal_pct_df["2021"] > totbal_pct_df.loc[:, "2000":"2020"].max(axis=1)
] = True
totbal_pct_df["max_2022"][
    totbal_pct_df["2022"] > totbal_pct_df.loc[:, "2000":"2021"].max(axis=1)
] = True
totbal_pct_22high = totbal_pct_df["max_2021"].sum()
totbal_pct_23high = totbal_pct_df["max_2022"].sum()
print("")
print("Number of states for which 2022 total balances and reserves")
print("as percent of general fund expenditures are 23-year high")
print("is", totbal_pct_23high, "states.")
print("Number of states for which 2021 total balances and reserves")
print("as percent of general fund expenditures are 22-year high")
print("is", totbal_pct_22high, "states.")
print("Kansas 2022:", totbal_pct_df.loc["Kansas", "max_2022"])
print("Kansas 2021:", totbal_pct_df.loc["Kansas", "max_2021"])
# Out:
# Number of states for which 2022 total balances and reserves
# as percent of general fund expenditures are 23-year high
# is 37 states.
# Number of states for which 2021 total balances and reserves
# as percent of general fund expenditures are 22-year high
# is 33 states.
# Kansas 2022: True
# Kansas 2021: True

# %% [markdown]
# ## 2. Kansas Individual Income Tax Rate Landscape

# %% [markdown]
# ## 3. Effects of different size rate cuts

# %%
from fiscalsim_us import Simulation
from policyengine_core.reforms import Reform
from policyengine_core.periods import instant
import pandas as pd

# %% [markdown]
# ### 3.1. Define the three household types

# %% [markdown]
# #### 3.1.1 Define the low income household (household before-tax income = $25,000)

# %%
situation_low = {
    "people": {
        "you": {
            "age": {"2023": "38"},
            "charitable_cash_donations": {"2023": "0"},
            "employment_income": {"2023": "25000"},
            "medical_out_of_pocket_expenses": {"2023": "200"},
        },
        "your partner": {
            "age": {"2023": "35"},
            "employment_income": {"2023": "0"},
        },
        "your first dependent": {
            "age": {"2023": "10"},
            "is_tax_unit_dependent": {"2023": True},
        },
        "your second dependent": {
            "age": {"2023": "6"},
            "is_tax_unit_dependent": {"2023": True},
        }
    },
    "families": {
        "your family": {
            "members": [
                "you",
                "your partner",
                "your first dependent",
                "your second dependent"
            ]
        }
    },
    "marital_units": {
        "your marital unit": {
            "members": ["you", "your partner"],
            "marital_unit_id": {"2023": 0}
        },
        "your first dependent's marital unit": {
            "members": ["your first dependent"],
            "marital_unit_id": {"2023": 2}
        },
        "your second dependent's marital unit": {
            "members": ["your second dependent"],
            "marital_unit_id": {"2023": 3}
        }
    },
    "tax_units": {
        "your tax unit": {
            "members": [
                "you",
                "your partner",
                "your first dependent",
                "your second dependent"
            ]
        }
    },
    "spm_units": {
        "your household": {
            "members": [
                "you",
                "your partner",
                "your first dependent",
                "your second dependent"
            ],
            "broadband_cost": {"2023": "600"},
            "childcare_expenses": {"2023": "0"},
            "housing_cost": {"2023": "8000"},
            "phone_cost": {"2023": "700"},
            "spm_unit_id": {"2023": "0"},
        }
    },
    "households": {
        "your household": {
            "members": [
                "you",
                "your partner",
                "your first dependent",
                "your second dependent"
            ],
            "state_living_arrangement": {"2023": "FULL_COST"},
            "state_name": {"2023": "UT"}
        }
    }
}

# %% [markdown]
# #### 3.1.2 Define the middle income household (household before-tax income = $80,000)

# %%
situation_mid = {
    "people": {
        "you": {
            "age": {"2023": "38"},
            "charitable_cash_donations": {"2023": "6000"},
            "employment_income": {"2023": "45000"},
            "medical_out_of_pocket_expenses": {"2023": "2000"},
        },
        "your partner": {
            "age": {"2023": "35"},
            "employment_income": {"2023": "35000"},
        },
        "your first dependent": {
            "age": {"2023": "10"},
            "is_tax_unit_dependent": {"2023": True},
        },
        "your second dependent": {
            "age": {"2023": "10"},
            "is_tax_unit_dependent": {"2023": True},
        }
    },
    "families": {
        "your family": {
            "members": [
                "you",
                "your partner",
                "your first dependent",
                "your second dependent"
            ]
        }
    },
    "marital_units": {
        "your marital unit": {
            "members": ["you", "your partner"],
            "marital_unit_id": {"2023": 0}
        },
        "your first dependent's marital unit": {
            "members": ["your first dependent"],
            "marital_unit_id": {"2023": 2}
        },
        "your second dependent's marital unit": {
            "members": ["your second dependent"],
            "marital_unit_id": {"2023": 3}
        }
    },
    "tax_units": {
        "your tax unit": {
            "members": [
                "you",
                "your partner",
                "your first dependent",
                "your second dependent"
            ]
        }
    },
    "spm_units": {
        "your household": {
            "members": [
                "you",
                "your partner",
                "your first dependent",
                "your second dependent"
            ],
            "broadband_cost": {"2023": "900"},
            "childcare_expenses": {"2023": "1000"},
            "housing_cost": {"2023": "20000"},
            "phone_cost": {"2023": "1500"},
            "spm_unit_id": {"2023": 0},
        }
    },
    "households": {
        "your household": {
            "members": [
                "you",
                "your partner",
                "your first dependent",
                "your second dependent"
            ],
            "state_living_arrangement": {"2023": "FULL_COST"},
            "state_name": {"2023": "UT"}
        }
    }
}

# %% [markdown]
# #### 3.1.3 Define the high income household (household before-tax income = $200,000)

# %%
situation_high = {
    "people": {
        "you": {
            "age": {"2023": "38"},
            "charitable_cash_donations": {"2023": "20000"},
            "employment_income": {"2023": "100000"},
            "medical_out_of_pocket_expenses": {"2023": "4000"},
        },
        "your partner": {
            "age": {"2023": "35"},
            "employment_income": {"2023": "100000"},
        },
        "your first dependent": {
            "age": {"2023": "10"},
            "is_tax_unit_dependent": {"2023": True},
        },
        "your second dependent": {
            "age": {"2023": "10"},
            "is_tax_unit_dependent": {"2023": True},
        }
    },
    "families": {
        "your family": {
            "members": [
                "you",
                "your partner",
                "your first dependent",
                "your second dependent"
            ]
        }
    },
    "marital_units": {
        "your marital unit": {
            "members": ["you", "your partner"],
            "marital_unit_id": {"2023": 0}
        },
        "your first dependent's marital unit": {
            "members": ["your first dependent"],
            "marital_unit_id": {"2023": 2}
        },
        "your second dependent's marital unit": {
            "members": ["your second dependent"],
            "marital_unit_id": {"2023": 3}
        }
    },
    "tax_units": {
        "your tax unit": {
            "members": [
                "you",
                "your partner",
                "your first dependent",
                "your second dependent"
            ]
        }
    },
    "spm_units": {
        "your household": {
            "members": [
                "you",
                "your partner",
                "your first dependent",
                "your second dependent"
            ],
            "broadband_cost": {"2023": "1200"},
            "childcare_expenses": {"2023": "1500"},
            "housing_cost": {"2023": "36000"},
            "phone_cost": {"2023": "2400"},
            "spm_unit_id": {"2023": 0},
        }
    },
    "households": {
        "your household": {
            "members": [
                "you",
                "your partner",
                "your first dependent",
                "your second dependent"
            ],
            "state_living_arrangement": {"2023": "FULL_COST"},
            "state_name": {"2023": "UT"}
        }
    }
}

# %% [markdown]
# ### 3.2. Solve for the baseline

# %% [markdown]
# #### 3.2.1. Baseline simulation for the low income household

# %%
def modify_parameters_b(parameters):
    pass
    return parameters


class reform_b(Reform):
    def apply(self):
        self.modify_parameters(modify_parameters_b)

simulation_b_l = Simulation(
    reform=reform_b,
    situation=situation_low,
)

simulation_b_l.trace = True
simulation_b_l.calculate("household_net_income", 2023)
simulation_b_l.tracer.print_computation_log()
# Out:
#   household_net_income<2023, (default)> = [42138.2]
#     household_market_income<2023, (default)> = [25000.]
#       employment_income<2023, (default)> = [25000.     0.     0.     0.]
#       self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#       pension_income<2023, (default)> = [0. 0. 0. 0.]
#         tax_exempt_pension_income<2023, (default)> = [0. 0. 0. 0.]
#         taxable_pension_income<2023, (default)> = [0. 0. 0. 0.]
#       dividend_income<2023, (default)> = [0. 0. 0. 0.]
#         qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#         non_qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#       interest_income<2023, (default)> = [0. 0. 0. 0.]
#         tax_exempt_interest_income<2023, (default)> = [0. 0. 0. 0.]
#         taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#       gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#       capital_gains<2023, (default)> = [0. 0. 0. 0.]
#         short_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#         long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#       rental_income<2023, (default)> = [0. 0. 0. 0.]
#       illicit_income<2023, (default)> = [0. 0. 0. 0.]
#       farm_income<2023, (default)> = [0. 0. 0. 0.]
#     household_benefits<2023, (default)> = [9246.7]
#       social_security<2023, (default)> = [0. 0. 0. 0.]
#         social_security_dependents<2023, (default)> = [0. 0. 0. 0.]
#         social_security_disability<2023, (default)> = [0. 0. 0. 0.]
#         social_security_retirement<2023, (default)> = [0. 0. 0. 0.]
#         social_security_survivors<2023, (default)> = [0. 0. 0. 0.]
#       ssi<2023, (default)> = [0. 0. 0. 0.]
#         uncapped_ssi<2023, (default)> = [0. 0. 0. 0.]
#           ssi_amount_if_eligible<2023, (default)> = [10968. 10968. 10968. 10968.]
#             ssi_claim_is_joint<2023, (default)> = [False False False False]
#               is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                 is_ssi_aged<2023, (default)> = [False False False False]
#                   age<2023, (default)> = [38. 35. 10.  6.]
#                 is_blind<2023, (default)> = [False False False False]
#                 is_ssi_disabled<2023, (default)> = [False False False False]
#                   is_ssi_aged<2023, (default)> = [False False False False]
#                   is_blind<2023, (default)> = [False False False False]
#                   ssi_reported<2023, (default)> = [0. 0. 0. 0.]
#               ssi_income_deemed_from_ineligible_spouse<2023, (default)> = [0. 0. 0. 0.]
#                 ssi_earned_income<2023, (default)> = [25000.     0.     0.     0.]
#                   employment_income<2023, (default)> = [25000.     0.     0.     0.]
#                   self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                 ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#                   dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                   interest_income<2023, (default)> = [0. 0. 0. 0.]
#                   gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#                   social_security<2023, (default)> = [0. 0. 0. 0.]
#                   alimony_income<2023, (default)> = [0. 0. 0. 0.]
#                   pension_income<2023, (default)> = [0. 0. 0. 0.]
#                   unemployment_compensation<2023, (default)> = [0. 0. 0. 0.]
#                 ssi_earned_income_deemed_from_ineligible_spouse<2023, (default)> = [0. 0. 0. 0.]
#                   is_ssi_ineligible_spouse<2023, (default)> = [False  True False False]
#                     is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                       is_child<2023, (default)> = [False False  True  True]
#                         age<2023, (default)> = [38. 35. 10.  6.]
#                       is_tax_unit_head<2023, (default)> = [ True False False False]
#                         is_child<2023, (default)> = [False False  True  True]
#                         age<2023, (default)> = [38. 35. 10.  6.]
#                       age<2023, (default)> = [38. 35. 10.  6.]
#                     is_ssi_eligible_spouse<2023, (default)> = [False False False False]
#                       is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                       is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                   ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#                   ssi_earned_income<2023, (default)> = [25000.     0.     0.     0.]
#                   ssi_ineligible_child_allocation<2023, (default)> = [   0.    0. 5484. 5484.]
#                     ssi_earned_income<2023, (default)> = [25000.     0.     0.     0.]
#                     ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#                     is_ssi_ineligible_child<2023, (default)> = [False False  True  True]
#                       is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                       is_child<2023, (default)> = [False False  True  True]
#                   is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                 ssi_unearned_income_deemed_from_ineligible_spouse<2023, (default)> = [0. 0. 0. 0.]
#                   is_ssi_ineligible_spouse<2023, (default)> = [False  True False False]
#                   ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#                   ssi_ineligible_child_allocation<2023, (default)> = [   0.    0. 5484. 5484.]
#                 is_ssi_ineligible_child<2023, (default)> = [False False  True  True]
#           meets_ssi_resource_test<2023, (default)> = [ True  True  True  True]
#             ssi_claim_is_joint<2023, (default)> = [False False False False]
#             ssi_countable_resources<2023, (default)> = [0. 0. 0. 0.]
#           is_ssi_eligible_individual<2023, (default)> = [False False False False]
#             is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#             is_ssi_eligible_spouse<2023, (default)> = [False False False False]
#           ssi_countable_income<2023, (default)> = [0. 0. 0. 0.]
#             ssi_earned_income<2023, (default)> = [25000.     0.     0.     0.]
#             ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#             ssi_unearned_income_deemed_from_ineligible_parent<2023, (default)> = [0. 0. 0. 0.]
#               is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#               is_child<2023, (default)> = [False False  True  True]
#               is_ssi_ineligible_parent<2023, (default)> = [False False False False]
#                 is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                 is_child<2023, (default)> = [False False  True  True]
#               ssi_earned_income<2023, (default)> = [25000.     0.     0.     0.]
#               ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#               ssi_ineligible_child_allocation<2023, (default)> = [   0.    0. 5484. 5484.]
#               ssi_ineligible_parent_allocation<2023, (default)> = [0. 0. 0. 0.]
#                 is_ssi_ineligible_parent<2023, (default)> = [False False False False]
#             ssi_income_deemed_from_ineligible_spouse<2023, (default)> = [0. 0. 0. 0.]
#             is_ssi_eligible_individual<2023, (default)> = [False False False False]
#       state_supplement<2023, (default)> = [0. 0. 0. 0.]
#         uncapped_ssi<2023, (default)> = [0. 0. 0. 0.]
#         maximum_state_supplement<2023, (default)> = [0. 0. 0. 0.]
#           is_ssi_eligible_individual<2023, (default)> = [False False False False]
#           state_code_str<2023, (default)> = ['UT']
#             state_code<2023, (default)> = ['UT']
#               state_name<2023, (default)> = ['UT']
#           state_living_arrangement<2023, (default)> = ['FULL_COST']
#           is_blind<2023, (default)> = [False False False False]
#           is_ssi_aged<2023, (default)> = [False False False False]
#           is_ssi_disabled<2023, (default)> = [False False False False]
#           ssi_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#           ssi_claim_is_joint<2023, (default)> = [False False False False]
#         is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#         meets_ssi_resource_test<2023, (default)> = [ True  True  True  True]
#         ssi_claim_is_joint<2023, (default)> = [False False False False]
#       ca_cvrp<2023, (default)> = [0. 0. 0. 0.]
#         CA<2023, (default)> = [False]
#           state_code_str<2023, (default)> = ['UT']
#       snap<2023, (default)> = [6860.5]
#         snap_normal_allotment<2023, (default)> = [5979.]
#           is_snap_eligible<2023, (default)> = [ True]
#             meets_snap_net_income_test<2023, (default)> = [ True]
#               snap_net_income_fpg_ratio<2023, (default)> = [0.5876667]
#                 snap_net_income<2023, (default)> = [17630.]
#                   snap_gross_income<2023, (default)> = [25000.]
#                     snap_earned_income<2023, (default)> = [25000.]
#                       employment_income<2023, (default)> = [25000.     0.     0.     0.]
#                       self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                     snap_unearned_income<2023, (default)> = [0.]
#                       dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                       interest_income<2023, (default)> = [0. 0. 0. 0.]
#                       gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#                       social_security<2023, (default)> = [0. 0. 0. 0.]
#                       ssi<2023, (default)> = [0. 0. 0. 0.]
#                   snap_deductions<2023, (default)> = [7370.]
#                     snap_standard_deduction<2023, (default)> = [2316.]
#                       state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#                         state_group<2023, (default)> = ['CONTIGUOUS_US']
#                           state_code<2023, (default)> = ['UT']
#                       spm_unit_size<2023, (default)> = [4]
#                     snap_earned_income_deduction<2023, (default)> = [5000.]
#                       snap_earned_income<2023, (default)> = [25000.]
#                     snap_dependent_care_deduction<2023, (default)> = [0.]
#                       childcare_expenses<2023, (default)> = [0.]
#                     snap_child_support_deduction<2023, (default)> = [0.]
#                       child_support_expense<2023, (default)> = [0. 0. 0. 0.]
#                       state_code_str<2023, (default)> = ['UT']
#                     snap_excess_medical_expense_deduction<2023, (default)> = [0.]
#                       is_usda_elderly<2023, (default)> = [False False False False]
#                         age<2023, (default)> = [38. 35. 10.  6.]
#                       is_usda_disabled<2023, (default)> = [False False False False]
#                         is_ssi_disabled<2023, (default)> = [False False False False]
#                         social_security_disability<2023, (default)> = [0. 0. 0. 0.]
#                         is_permanently_disabled_veteran<2023, (default)> = [False False False False]
#                         is_surviving_spouse_of_disabled_veteran<2023, (default)> = [False False False False]
#                         is_surviving_child_of_disabled_veteran<2023, (default)> = [False False False False]
#                       medical_out_of_pocket_expenses<2023, (default)> = [200.   0.   0.   0.]
#                       state_code_str<2023, (default)> = ['UT']
#                     snap_excess_shelter_expense_deduction<2023, (default)> = [54.]
#                       snap_net_income_pre_shelter<2023, (default)> = [17684.]
#                         snap_gross_income<2023, (default)> = [25000.]
#                         snap_standard_deduction<2023, (default)> = [2316.]
#                         snap_earned_income_deduction<2023, (default)> = [5000.]
#                         snap_dependent_care_deduction<2023, (default)> = [0.]
#                         snap_child_support_deduction<2023, (default)> = [0.]
#                         snap_excess_medical_expense_deduction<2023, (default)> = [0.]
#                       housing_cost<2023, (default)> = [8000.]
#                       snap_region_str<2023, (default)> = ['CONTIGUOUS_US']
#                         snap_region<2023, (default)> = ['CONTIGUOUS_US']
#                           state_group<2023, (default)> = ['CONTIGUOUS_US']
#                       has_usda_elderly_disabled<2023, (default)> = [False]
#                         is_usda_elderly<2023, (default)> = [False False False False]
#                         is_usda_disabled<2023, (default)> = [False False False False]
#                       snap_utility_allowance<2023, (default)> = [54.]
#                         snap_utility_allowance_type<2023, (default)> = ['IUA']
#                           count_distinct_utility_expenses<2023, (default)> = [1]
#                             heating_cooling_expense<2023, (default)> = [0.]
#                             electricity_expense<2023, (default)> = [0.]
#                             gas_expense<2023, (default)> = [0.]
#                             phone_expense<2023, (default)> = [700.]
#                               phone_cost<2023, (default)> = [700.]
#                             trash_expense<2023, (default)> = [0.]
#                             water_expense<2023, (default)> = [0.]
#                             sewage_expense<2023, (default)> = [0.]
#                           snap_utility_region_str<2023, (default)> = ['UT']
#                             snap_utility_region<2023, (default)> = ['UT']
#                               state_code<2023, (default)> = ['UT']
#                           has_heating_cooling_expense<2023, (default)> = [False]
#                             heating_cooling_expense<2023, (default)> = [0.]
#                         snap_utility_region_str<2023, (default)> = ['UT']
#                       state_code_str<2023, (default)> = ['UT']
#                       is_homeless<2023, (default)> = [False]
#                 spm_unit_fpg<2023, (default)> = [30000.]
#                   spm_unit_size<2023, (default)> = [4]
#                   state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#             meets_snap_gross_income_test<2023, (default)> = [ True]
#               snap_gross_income_fpg_ratio<2023, (default)> = [0.8333333]
#                 snap_gross_income<2023, (default)> = [25000.]
#                 spm_unit_fpg<2023, (default)> = [30000.]
#               has_usda_elderly_disabled<2023, (default)> = [False]
#             meets_snap_asset_test<2023, (default)> = [ True]
#               has_usda_elderly_disabled<2023, (default)> = [False]
#               snap_assets<2023, (default)> = [0.]
#             meets_snap_categorical_eligibility<2023, (default)> = [False]
#               ssi<2023, (default)> = [0. 0. 0. 0.]
#               is_tanf_non_cash_eligible<2023, (default)> = [False]
#                 meets_tanf_non_cash_gross_income_test<2023, (default)> = [False]
#                   state_code_str<2023, (default)> = ['UT']
#                   snap_gross_income_fpg_ratio<2023, (default)> = [0.8333333]
#                 meets_tanf_non_cash_net_income_test<2023, (default)> = [ True]
#                   state_code_str<2023, (default)> = ['UT']
#                   is_tanf_non_cash_hheod<2023, (default)> = [False]
#                     state_code_str<2023, (default)> = ['UT']
#                     has_all_usda_elderly_disabled<2023, (default)> = [False]
#                       is_usda_elderly<2023, (default)> = [False False False False]
#                       is_usda_disabled<2023, (default)> = [False False False False]
#                     has_usda_elderly_disabled<2023, (default)> = [False]
#                   snap_net_income_fpg_ratio<2023, (default)> = [0.5876667]
#                 meets_tanf_non_cash_asset_test<2023, (default)> = [False]
#                   snap_assets<2023, (default)> = [0.]
#                   state_code_str<2023, (default)> = ['UT']
#           snap_expected_contribution<2023, (default)> = [5289.]
#             snap_net_income<2023, (default)> = [17630.]
#           snap_max_allotment<2023, (default)> = [11268.]
#             snap_region_str<2023, (default)> = ['CONTIGUOUS_US']
#             spm_unit_size<2023, (default)> = [4]
#             spm_unit_size<2023, (default)> = [4]
#           snap_min_allotment<2023, (default)> = [0.]
#             snap_region_str<2023, (default)> = ['CONTIGUOUS_US']
#             spm_unit_size<2023, (default)> = [4]
#         snap_emergency_allotment<2023, (default)> = [881.5]
#           snap_emergency_allotment_monthly<2023-01, (default)> = [440.75]
#             is_snap_eligible<2023, (default)> = [ True]
#             snap_max_allotment<2023, (default)> = [11268.]
#             snap_normal_allotment<2023, (default)> = [5979.]
#             state_code<2023, (default)> = ['UT']
#           snap_emergency_allotment_monthly<2023-02, (default)> = [440.75]
#             is_snap_eligible<2023, (default)> = [ True]
#             snap_max_allotment<2023, (default)> = [11268.]
#             snap_normal_allotment<2023, (default)> = [5979.]
#             state_code<2023, (default)> = ['UT']
#           snap_emergency_allotment_monthly<2023-03, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-04, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-05, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-06, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-07, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-08, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-09, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-10, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-11, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-12, (default)> = [0.]
#       wic<2023, (default)> = [0. 0. 0. 0.]
#         meets_wic_income_test<2023, (default)> = [ True]
#           school_meal_countable_income<2023, (default)> = [25000.]
#             employment_income<2023, (default)> = [25000.     0.     0.     0.]
#             self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#             dividend_income<2023, (default)> = [0. 0. 0. 0.]
#             interest_income<2023, (default)> = [0. 0. 0. 0.]
#             gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#             social_security<2023, (default)> = [0. 0. 0. 0.]
#             ssi<2023, (default)> = [0. 0. 0. 0.]
#           wic_fpg<2023, (default)> = [30000.]
#             is_pregnant<2023, (default)> = [False False False False]
#             spm_unit_fpg<2023, (default)> = [30000.]
#             state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#         meets_wic_categorical_eligibility<2023, (default)> = [ True  True  True  True]
#           snap<2023, (default)> = [6860.5]
#           tanf<2023, (default)> = [0.]
#             tanf_reported<2023, (default)> = [0. 0. 0. 0.]
#             is_tanf_eligible<2023, (default)> = [False]
#               is_person_demographic_tanf_eligible<2023, (default)> = [False False  True  True]
#                 is_child<2023, (default)> = [False False  True  True]
#                 age<2023, (default)> = [38. 35. 10.  6.]
#                 is_full_time_student<2023, (default)> = [False False  True  True]
#                   is_full_time_college_student<2023, (default)> = [False False False False]
#                   is_in_k12_school<2023, (default)> = [False False  True  True]
#                     age<2023, (default)> = [38. 35. 10.  6.]
#                 is_pregnant<2023, (default)> = [False False False False]
#               is_tanf_enrolled<2023, (default)> = [False]
#               is_tanf_continuous_eligible<2023, (default)> = [False]
#                 tanf_gross_earned_income<2023, (default)> = [25000.]
#                   employment_income<2023, (default)> = [25000.     0.     0.     0.]
#                   self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                 tanf_gross_unearned_income<2023, (default)> = [0.]
#                   dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                   interest_income<2023, (default)> = [0. 0. 0. 0.]
#                   gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#                   social_security<2023, (default)> = [0. 0. 0. 0.]
#                   ssi<2023, (default)> = [0. 0. 0. 0.]
#                 tanf_max_amount<2023, (default)> = [0.]
#                   spm_unit_size<2023, (default)> = [4]
#                   state_code_str<2023, (default)> = ['UT']
#               is_tanf_initial_eligible<2023, (default)> = [False]
#                 tanf_initial_employment_deduction<2023, (default)> = [0.]
#                   spm_unit_size<2023, (default)> = [4]
#                   state_code_str<2023, (default)> = ['UT']
#                   market_income<2023, (default)> = [25000.     0.     0.     0.]
#                     employment_income<2023, (default)> = [25000.     0.     0.     0.]
#                     self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                     pension_income<2023, (default)> = [0. 0. 0. 0.]
#                     dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                     interest_income<2023, (default)> = [0. 0. 0. 0.]
#                     gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#                     capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                     rental_income<2023, (default)> = [0. 0. 0. 0.]
#                     illicit_income<2023, (default)> = [0. 0. 0. 0.]
#                     farm_income<2023, (default)> = [0. 0. 0. 0.]
#                 tanf_gross_earned_income<2023, (default)> = [25000.]
#                 tanf_gross_unearned_income<2023, (default)> = [0.]
#                 tanf_max_amount<2023, (default)> = [0.]
#             tanf_amount_if_eligible<2023, (default)> = [0.]
#               tanf_max_amount<2023, (default)> = [0.]
#               tanf_countable_income<2023, (default)> = [25000.]
#                 state_code_str<2023, (default)> = ['UT']
#                 tanf_gross_unearned_income<2023, (default)> = [0.]
#                 tanf_gross_earned_income<2023, (default)> = [25000.]
#           medicaid<2023, (default)> = [9966.585 9966.585 9966.585 9966.585]
#             is_medicaid_eligible<2023, (default)> = [ True  True  True  True]
#               medicaid_category<2023, (default)> = ['ADULT' 'ADULT' 'OLDER_CHILD' 'OLDER_CHILD']
#                 is_infant_for_medicaid<2023, (default)> = [False False False False]
#                   is_infant_for_medicaid_fc<2023, (default)> = [ True  True  True  True]
#                     medicaid_income_level<2023, (default)> = [0.8333333 0.8333333 0.8333333 0.8333333]
#                       tax_unit_medicaid_income_level<2023, (default)> = [0.8333333]
#                         medicaid_income<2023, (default)> = [25000.]
#                           adjusted_gross_income<2023, (default)> = [25000.]
#                             irs_gross_income<2023, (default)> = [25000.     0.     0.     0.]
#                               is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                               employment_income<2023, (default)> = [25000.     0.     0.     0.]
#                               self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                               partnership_s_corp_income<2023, (default)> = [0. 0. 0. 0.]
#                               farm_income<2023, (default)> = [0. 0. 0. 0.]
#                               farm_rent_income<2023, (default)> = [0. 0. 0. 0.]
#                               capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                               taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#                               rental_income<2023, (default)> = [0. 0. 0. 0.]
#                               dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                               taxable_pension_income<2023, (default)> = [0. 0. 0. 0.]
#                               debt_relief<2023, (default)> = [0. 0. 0. 0.]
#                               taxable_unemployment_compensation<2023, (default)> = [0. 0. 0. 0.]
#                                 is_tax_unit_head<2023, (default)> = [ True False False False]
#                                 tax_unit_taxable_unemployment_compensation<2023, (default)> = [0.]
#                                   tax_unit_unemployment_compensation<2023, (default)> = [0.]
#                                     unemployment_compensation<2023, (default)> = [0. 0. 0. 0.]
#                                   taxable_uc_agi<2023, (default)> = [25000.]
#                                     is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                                     employment_income<2023, (default)> = [25000.     0.     0.     0.]
#                                     self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                     partnership_s_corp_income<2023, (default)> = [0. 0. 0. 0.]
#                                     farm_income<2023, (default)> = [0. 0. 0. 0.]
#                                     farm_rent_income<2023, (default)> = [0. 0. 0. 0.]
#                                     capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                                     taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#                                     rental_income<2023, (default)> = [0. 0. 0. 0.]
#                                     dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                                     taxable_pension_income<2023, (default)> = [0. 0. 0. 0.]
#                                     debt_relief<2023, (default)> = [0. 0. 0. 0.]
#                                     taxable_social_security<2023, (default)> = [0. 0. 0. 0.]
#                                       tax_unit_taxable_social_security<2023, (default)> = [0.]
#                                         tax_unit_social_security<2023, (default)> = [0.]
#                                           social_security<2023, (default)> = [0. 0. 0. 0.]
#                                         taxable_ss_magi<2023, (default)> = [25000.]
#                                           is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                                           employment_income<2023, (default)> = [25000.     0.     0.     0.]
#                                           self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                           partnership_s_corp_income<2023, (default)> = [0. 0. 0. 0.]
#                                           farm_income<2023, (default)> = [0. 0. 0. 0.]
#                                           farm_rent_income<2023, (default)> = [0. 0. 0. 0.]
#                                           capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                                           taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#                                           rental_income<2023, (default)> = [0. 0. 0. 0.]
#                                           dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                                           taxable_pension_income<2023, (default)> = [0. 0. 0. 0.]
#                                           debt_relief<2023, (default)> = [0. 0. 0. 0.]
#                                           illicit_income<2023, (default)> = [0. 0. 0. 0.]
#                                           unemployment_compensation<2023, (default)> = [0. 0. 0. 0.]
#                                           tax_exempt_interest_income<2023, (default)> = [0. 0. 0. 0.]
#                                           loss_ald<2023, (default)> = [0.]
#                                             filing_status<2023, (default)> = ['JOINT']
#                                               is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                                               tax_unit_dependents<2023, (default)> = [2]
#                                                 is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                                             self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                             maximum_capital_loss<2023, (default)> = [0.]
#                                               tax_unit_capital_loss<2023, (default)> = [0.]
#                                                 capital_loss<2023, (default)> = [0. 0. 0. 0.]
#                                                   capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                                               filing_status<2023, (default)> = ['JOINT']
#                                           self_employment_tax_ald<2023, (default)> = [0.]
#                                             self_employment_tax_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employment_tax<2023, (default)> = [0. 0. 0. 0.]
#                                                 self_employment_social_security_tax<2023, (default)> = [0. 0. 0. 0.]
#                                                   social_security_taxable_self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                                     taxable_self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                                       sey<2023, (default)> = [0. 0. 0. 0.]
#                                                         self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                                         farm_income<2023, (default)> = [0. 0. 0. 0.]
#                                                         k1bx14<2023, (default)> = [0. 0. 0. 0.]
#                                                     taxable_earnings_for_social_security<2023, (default)> = [25000.     0.     0.     0.]
#                                                       payroll_tax_gross_wages<2023, (default)> = [25000.     0.     0.     0.]
#                                                         employment_income<2023, (default)> = [25000.     0.     0.     0.]
#                                                 self_employment_medicare_tax<2023, (default)> = [0. 0. 0. 0.]
#                                                   taxable_self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                           early_withdrawal_penalty<2023, (default)> = [0. 0. 0. 0.]
#                                           alimony_income<2023, (default)> = [0. 0. 0. 0.]
#                                           educator_expense<2023, (default)> = [0. 0. 0. 0.]
#                                           health_savings_account_ald<2023, (default)> = [0.]
#                                           self_employed_health_insurance_ald<2023, (default)> = [0.]
#                                             self_employed_health_insurance_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employed_health_insurance_premiums<2023, (default)> = [0. 0. 0. 0.]
#                                                 is_self_employed<2023, (default)> = [False False False False]
#                                                 health_insurance_premiums<2023, (default)> = [0. 0. 0. 0.]
#                                           self_employed_pension_contribution_ald<2023, (default)> = [0.]
#                                             self_employed_pension_contribution_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employed_pension_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                           ira_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                           sep_simple_qualified_plan_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                         filing_status<2023, (default)> = ['JOINT']
#                                       tax_unit_social_security<2023, (default)> = [0.]
#                                       social_security<2023, (default)> = [0. 0. 0. 0.]
#                                       is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                                       is_tax_unit_head<2023, (default)> = [ True False False False]
#                                     illicit_income<2023, (default)> = [0. 0. 0. 0.]
#                                     loss_ald<2023, (default)> = [0.]
#                                     self_employment_tax_ald<2023, (default)> = [0.]
#                                     student_loan_interest<2023, (default)> = [0. 0. 0. 0.]
#                                     early_withdrawal_penalty<2023, (default)> = [0. 0. 0. 0.]
#                                     alimony_income<2023, (default)> = [0. 0. 0. 0.]
#                                     educator_expense<2023, (default)> = [0. 0. 0. 0.]
#                                     health_savings_account_ald<2023, (default)> = [0.]
#                                     self_employed_health_insurance_ald<2023, (default)> = [0.]
#                                     self_employed_pension_contribution_ald<2023, (default)> = [0.]
#                                     ira_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                     sep_simple_qualified_plan_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                     qualified_adoption_assistance_expense<2023, (default)> = [0. 0. 0. 0.]
#                                     us_bonds_for_higher_ed<2023, (default)> = [0. 0. 0. 0.]
#                                     specified_possession_income<2023, (default)> = [0.]
#                                     puerto_rico_income<2023, (default)> = [0.]
#                                   filing_status<2023, (default)> = ['JOINT']
#                               taxable_social_security<2023, (default)> = [0. 0. 0. 0.]
#                               illicit_income<2023, (default)> = [0. 0. 0. 0.]
#                             above_the_line_deductions<2023, (default)> = [0.]
#                               loss_ald<2023, (default)> = [0.]
#                               self_employment_tax_ald<2023, (default)> = [0.]
#                               student_loan_interest<2023, (default)> = [0. 0. 0. 0.]
#                               early_withdrawal_penalty<2023, (default)> = [0. 0. 0. 0.]
#                               alimony_income<2023, (default)> = [0. 0. 0. 0.]
#                               educator_expense<2023, (default)> = [0. 0. 0. 0.]
#                               health_savings_account_ald<2023, (default)> = [0.]
#                               self_employed_health_insurance_ald<2023, (default)> = [0.]
#                               self_employed_pension_contribution_ald<2023, (default)> = [0.]
#                               ira_contributions<2023, (default)> = [0. 0. 0. 0.]
#                               sep_simple_qualified_plan_contributions<2023, (default)> = [0. 0. 0. 0.]
#                               qualified_adoption_assistance_expense<2023, (default)> = [0. 0. 0. 0.]
#                               us_bonds_for_higher_ed<2023, (default)> = [0. 0. 0. 0.]
#                               specified_possession_income<2023, (default)> = [0.]
#                               puerto_rico_income<2023, (default)> = [0.]
#                           foreign_earned_income_exclusion<2023, (default)> = [0.]
#                           student_loan_interest<2023, (default)> = [0. 0. 0. 0.]
#                           tax_exempt_social_security<2023, (default)> = [0.]
#                             tax_unit_social_security<2023, (default)> = [0.]
#                             tax_unit_taxable_social_security<2023, (default)> = [0.]
#                         tax_unit_fpg<2023, (default)> = [30000.]
#                           tax_unit_size<2023, (default)> = [4]
#                           state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#                     state_code_str<2023, (default)> = ['UT']
#                   is_infant_for_medicaid_nfc<2023, (default)> = [False False False False]
#                     age<2023, (default)> = [38. 35. 10.  6.]
#                 is_young_child_for_medicaid<2023, (default)> = [False False False False]
#                   is_young_child_for_medicaid_fc<2023, (default)> = [ True  True  True  True]
#                     medicaid_income_level<2023, (default)> = [0.8333333 0.8333333 0.8333333 0.8333333]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_young_child_for_medicaid_nfc<2023, (default)> = [False False False False]
#                     age<2023, (default)> = [38. 35. 10.  6.]
#                 is_older_child_for_medicaid<2023, (default)> = [False False  True  True]
#                   age<2023, (default)> = [38. 35. 10.  6.]
#                   medicaid_income_level<2023, (default)> = [0.8333333 0.8333333 0.8333333 0.8333333]
#                   state_code_str<2023, (default)> = ['UT']
#                 is_young_adult_for_medicaid<2023, (default)> = [False False False False]
#                   is_young_adult_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [0.8333333 0.8333333 0.8333333 0.8333333]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_young_adult_for_medicaid_nfc<2023, (default)> = [False False False False]
#                     age<2023, (default)> = [38. 35. 10.  6.]
#                 is_adult_for_medicaid<2023, (default)> = [ True  True False False]
#                   is_adult_for_medicaid_fc<2023, (default)> = [ True  True  True  True]
#                     medicaid_income_level<2023, (default)> = [0.8333333 0.8333333 0.8333333 0.8333333]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_adult_for_medicaid_nfc<2023, (default)> = [ True  True False False]
#                     age<2023, (default)> = [38. 35. 10.  6.]
#                 is_parent_for_medicaid<2023, (default)> = [False False False False]
#                   is_parent_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [0.8333333 0.8333333 0.8333333 0.8333333]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_parent_for_medicaid_nfc<2023, (default)> = [ True  True False False]
#                     is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                     tax_unit_count_dependents<2023, (default)> = [2]
#                       is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                 is_pregnant_for_medicaid<2023, (default)> = [False False False False]
#                   is_pregnant_for_medicaid_fc<2023, (default)> = [ True  True  True  True]
#                     medicaid_income_level<2023, (default)> = [0.8333333 0.8333333 0.8333333 0.8333333]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_pregnant_for_medicaid_nfc<2023, (default)> = [False False False False]
#                     is_pregnant<2023, (default)> = [False False False False]
#                     count_days_postpartum<2023, (default)> = [inf inf inf inf]
#                       under_60_days_postpartum<2023, (default)> = [False False False False]
#                       under_12_months_postpartum<2023, (default)> = [False False False False]
#                     state_code_str<2023, (default)> = ['UT']
#                 is_ssi_recipient_for_medicaid<2023, (default)> = [False False False False]
#                   state_code_str<2023, (default)> = ['UT']
#                   ssi<2023, (default)> = [0. 0. 0. 0.]
#             medicaid_benefit_value<2023, (default)> = [9966.585 9966.585 9966.585 9966.585]
#               state_code_str<2023, (default)> = ['UT']
#           is_pregnant<2023, (default)> = [False False False False]
#           wic_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#             is_pregnant<2023, (default)> = [False False False False]
#             is_mother<2023, (default)> = [False False False False]
#               is_female<2023, (default)> = [False False False False]
#               own_children_in_household<2023, (default)> = [0 0 0 0]
#               is_breastfeeding<2023, (default)> = [False False False False]
#             is_breastfeeding<2023, (default)> = [False False False False]
#             age<2023, (default)> = [38. 35. 10.  6.]
#         wic_category_str<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#           wic_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#         is_wic_at_nutritional_risk<2023, (default)> = [False False False False]
#           receives_wic<2023, (default)> = [False False False False]
#           meets_wic_income_test<2023, (default)> = [ True]
#           meets_wic_categorical_eligibility<2023, (default)> = [ True  True  True  True]
#           wic_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#         would_claim_wic<2023, (default)> = [ True  True  True  True]
#       free_school_meals<2023, (default)> = [1915.2]
#         school_meal_tier<2023, (default)> = ['FREE']
#           school_meal_fpg_ratio<2023, (default)> = [0.8333333]
#             school_meal_countable_income<2023, (default)> = [25000.]
#             spm_unit_fpg<2023, (default)> = [30000.]
#           meets_school_meal_categorical_eligibility<2023, (default)> = [ True]
#             snap<2023, (default)> = [6860.5]
#             tanf<2023, (default)> = [0.]
#             fdpir<2023, (default)> = [0.]
#         school_meal_net_subsidy<2023, (default)> = [1915.2]
#           school_meal_daily_subsidy<2023, (default)> = [6.04]
#             state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#             school_meal_tier<2023, (default)> = ['FREE']
#           school_meal_paid_daily_subsidy<2023, (default)> = [0.72]
#             state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#           is_in_k12_school<2023, (default)> = [False False  True  True]
#       reduced_price_school_meals<2023, (default)> = [0.]
#         school_meal_tier<2023, (default)> = ['FREE']
#         school_meal_net_subsidy<2023, (default)> = [1915.2]
#       lifeline<2023, (default)> = [111.]
#         is_rural<2023, (default)> = [False]
#         is_on_tribal_land<2023, (default)> = [False]
#         phone_cost<2023, (default)> = [700.]
#         broadband_cost<2023, (default)> = [600.]
#         is_lifeline_eligible<2023, (default)> = [ True]
#           medicaid<2023, (default)> = [9966.585 9966.585 9966.585 9966.585]
#           snap<2023, (default)> = [6860.5]
#           ssi<2023, (default)> = [0. 0. 0. 0.]
#           fcc_fpg_ratio<2023, (default)> = [0.8333333]
#             irs_gross_income<2023, (default)> = [25000.     0.     0.     0.]
#             spm_unit_fpg<2023, (default)> = [30000.]
#       acp<2023, (default)> = [360.]
#         is_acp_eligible<2023, (default)> = [ True]
#           lifeline<2023, (default)> = [111.]
#           free_school_meals<2023, (default)> = [1915.2]
#           reduced_price_school_meals<2023, (default)> = [0.]
#           pell_grant<2023, (default)> = [0.]
#           wic<2023, (default)> = [0. 0. 0. 0.]
#           medicaid<2023, (default)> = [9966.585 9966.585 9966.585 9966.585]
#           snap<2023, (default)> = [6860.5]
#           ssi<2023, (default)> = [0. 0. 0. 0.]
#           fcc_fpg_ratio<2023, (default)> = [0.8333333]
#           ebb<2023, (default)> = [0.]
#             is_ebb_eligible<2023, (default)> = [False]
#               is_lifeline_eligible<2023, (default)> = [ True]
#               free_school_meals<2023, (default)> = [1915.2]
#               reduced_price_school_meals<2023, (default)> = [0.]
#               pell_grant<2023, (default)> = [0.]
#               experienced_covid_income_loss<2023, (default)> = [False]
#               enrolled_in_ebb<2023, (default)> = [False]
#             broadband_cost_after_lifeline<2023, (default)> = [489.]
#               broadband_cost<2023, (default)> = [600.]
#               lifeline<2023, (default)> = [111.]
#             is_on_tribal_land<2023, (default)> = [False]
#         broadband_cost_after_lifeline<2023, (default)> = [489.]
#         is_on_tribal_land<2023, (default)> = [False]
#       ebb<2023, (default)> = [0.]
#       tanf<2023, (default)> = [0.]
#       high_efficiency_electric_home_rebate<2023, (default)> = [0.]
#         capped_electric_heat_pump_clothes_dryer_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#             tax_unit_income_ami_ratio<2023, (default)> = [0.]
#           electric_heat_pump_clothes_dryer_expenditures<2023, (default)> = [0.]
#         capped_electric_load_service_center_upgrade_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           electric_load_service_center_upgrade_expenditures<2023, (default)> = [0.]
#         capped_electric_stove_cooktop_range_or_oven_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           electric_stove_cooktop_range_or_oven_expenditures<2023, (default)> = [0.]
#         capped_electric_wiring_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           electric_wiring_expenditures<2023, (default)> = [0.]
#         capped_heat_pump_water_heater_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           heat_pump_water_heater_expenditures<2023, (default)> = [0.]
#         capped_heat_pump_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           heat_pump_expenditures<2023, (default)> = [0.]
#         capped_insulation_air_sealing_ventilation_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           energy_efficient_insulation_expenditures<2023, (default)> = [0.]
#           air_sealing_ventilation_expenditures<2023, (default)> = [0.]
#       residential_efficiency_electrification_rebate<2023, (default)> = [0.]
#         residential_efficiency_electrification_retrofit_expenditures<2023, (default)> = [0.]
#         residential_efficiency_electrification_retrofit_energy_savings<2023, (default)> = [0.]
#         current_home_energy_use<2023, (default)> = [0.]
#         household_income_ami_ratio<2023, (default)> = [0.]
#         average_home_energy_use_in_state<2023, (default)> = [0.]
#       basic_income<2023, (default)> = [0.]
#         basic_income_eligible<2023, (default)> = [ True]
#         basic_income_before_phase_out<2023, (default)> = [0.]
#           tax_unit_size<2023, (default)> = [4]
#           age<2023, (default)> = [38. 35. 10.  6.]
#           tax_unit_fpg<2023, (default)> = [30000.]
#         basic_income_phase_out<2023, (default)> = [0.]
#           basic_income_before_phase_out<2023, (default)> = [0.]
#           adjusted_gross_income<2023, (default)> = [25000.]
#           filing_status<2023, (default)> = ['JOINT']
#       spm_unit_capped_housing_subsidy<2023, (default)> = [0.]
#         spm_unit_capped_housing_subsidy_reported<2023, (default)> = [0.]
#     household_refundable_tax_credits<2023, (default)> = [9804.]
#       income_tax_refundable_credits<2023, (default)> = [9804.]
#         eitc<2023, (default)> = [6604.]
#           earned_income_tax_credit<2023, (default)> = [6604.]
#             eitc_eligible<2023, (default)> = [ True]
#               is_child<2023, (default)> = [False False  True  True]
#               age<2023, (default)> = [38. 35. 10.  6.]
#               tax_exempt_interest_income<2023, (default)> = [0. 0. 0. 0.]
#               taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#               dividend_income<2023, (default)> = [0. 0. 0. 0.]
#               c01000<2023, (default)> = [0.]
#                 sep<2023, (default)> = [1]
#                 c23650<2023, (default)> = [0.]
#                   long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   short_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#               tax_unit_rental_income<2023, (default)> = [0.]
#                 rental_income<2023, (default)> = [0. 0. 0. 0.]
# ...
#                       filing_status<2023, (default)> = ['JOINT']
#                       aged_blind_count<2023, (default)> = [0]
#                         blind_head<2023, (default)> = [False]
#                           is_blind<2023, (default)> = [False False False False]
#                           is_tax_unit_head<2023, (default)> = [ True False False False]
#                         blind_spouse<2023, (default)> = [False]
#                           is_blind<2023, (default)> = [False False False False]
#                           is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                         age_head<2023, (default)> = [38]
#                         age_spouse<2023, (default)> = [35]
#                 taxable_income_deductions_if_itemizing<2023, (default)> = [0.]
#                   charitable_deduction<2023, (default)> = [0.]
#                   interest_deduction<2023, (default)> = [0.]
#                   salt_deduction<2023, (default)> = [0.]
#                     state_and_local_sales_or_income_tax<2023, (default)> = [0.]
#                       state_income_tax<2023, (default)> = [0.]
#                         ma_income_tax<2023, (default)> = [0.]
#                           MA<2023, (default)> = [False]
#                         md_income_tax<2023, (default)> = [0.]
#                           MD<2023, (default)> = [False]
#                         ny_income_tax<2023, (default)> = [0.]
#                           NY<2023, (default)> = [False]
#                         or_income_tax<2023, (default)> = [0.]
#                           OR<2023, (default)> = [False]
#                         pa_income_tax<2023, (default)> = [0.]
#                           PA<2023, (default)> = [False]
#                             state_code_str<2023, (default)> = ['UT']
#                         wa_income_tax<2023, (default)> = [0.]
#                           WA<2023, (default)> = [False]
#                         ut_income_tax<2023, (default)> = [0.]
#                           UT<2023, (default)> = [ True]
#                           ut_income_tax_before_refundable_credits<2023, (default)> = [0.]
#                             ut_income_tax_after_credits<2023, (default)> = [0.]
#                               ut_income_tax_before_credits<2023, (default)> = [1212.5]
#                                 UT<2023, (default)> = [ True]
#                                 ut_taxable_income<2023, (default)> = [25000.]
#                                   UT<2023, (default)> = [ True]
#                                   ut_total_income<2023, (default)> = [25000.]
#                                     UT<2023, (default)> = [ True]
#                                     adjusted_gross_income<2023, (default)> = [25000.]
#                                     ut_additions_to_income<2023, (default)> = [0.]
#                                       UT<2023, (default)> = [ True]
#                                   salt_refund_last_year<2023, (default)> = [0.]
#                                   ut_subtractions_from_income<2023, (default)> = [0.]
#                                     UT<2023, (default)> = [ True]
#                               ut_taxpayer_credit<2023, (default)> = [1878.24]
#                                 UT<2023, (default)> = [ True]
#                                 ut_taxpayer_credit_max<2023, (default)> = [1878.24]
#                                   UT<2023, (default)> = [ True]
#                                   tax_unit_count_dependents<2023, (default)> = [2]
#                                   tax_unit_itemizes<2023, (default)> = [False]
#                                   standard_deduction<2023, (default)> = [27700.]
#                                   charitable_deduction<2023, (default)> = [0.]
#                                   interest_deduction<2023, (default)> = [0.]
#                                   medical_expense_deduction<2023, (default)> = [0.]
#                                   casualty_loss_deduction<2023, (default)> = [0.]
#                                 ut_taxpayer_credit_reduction<2023, (default)> = [0.]
#                                   UT<2023, (default)> = [ True]
#                                   filing_status<2023, (default)> = ['JOINT']
#                                   ut_taxable_income<2023, (default)> = [25000.]
#                             ut_apportionable_nonrefundable_credits<2023, (default)> = [0.]
#                               UT<2023, (default)> = [ True]
#                             ut_nonapportionable_nonrefundable_credits<2023, (default)> = [0.]
#                               UT<2023, (default)> = [ True]
#                             ut_recapture_low_inc_housing_credit<2023, (default)> = [0.]
#                               UT<2023, (default)> = [ True]
#                           ut_refundable_credits<2023, (default)> = [0.]
#                       local_income_tax<2023, (default)> = [0.]
#                       state_sales_tax<2023, (default)> = [0.]
#                       local_sales_tax<2023, (default)> = [0.]
#                     real_estate_taxes<2023, (default)> = [0. 0. 0. 0.]
#                     filing_status<2023, (default)> = ['JOINT']
#                   medical_expense_deduction<2023, (default)> = [0.]
#                   casualty_loss_deduction<2023, (default)> = [0.]
#                   qualified_business_income_deduction<2023, (default)> = [0.]
#                     qbid_amount<2023, (default)> = [0. 0. 0. 0.]
#                       qualified_business_income<2023, (default)> = [0. 0. 0. 0.]
#                         self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                         partnership_s_corp_income<2023, (default)> = [0. 0. 0. 0.]
#                         farm_income<2023, (default)> = [0. 0. 0. 0.]
#                         farm_rent_income<2023, (default)> = [0. 0. 0. 0.]
#                         self_employment_tax_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                         self_employed_health_insurance_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                         self_employed_pension_contribution_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                         business_is_qualified<2023, (default)> = [False False False False]
#                       w2_wages_from_qualified_business<2023, (default)> = [0. 0. 0. 0.]
#                       unadjusted_basis_qualified_property<2023, (default)> = [0. 0. 0. 0.]
#                       taxable_income_less_qbid<2023, (default)> = [0.]
#                         adjusted_gross_income<2023, (default)> = [25000.]
#                         charitable_deduction<2023, (default)> = [0.]
#                         interest_deduction<2023, (default)> = [0.]
#                         salt_deduction<2023, (default)> = [0.]
#                         medical_expense_deduction<2023, (default)> = [0.]
#                         casualty_loss_deduction<2023, (default)> = [0.]
#                         standard_deduction<2023, (default)> = [27700.]
#                       filing_status<2023, (default)> = ['JOINT']
#                       business_is_sstb<2023, (default)> = [False False False False]
#                     taxable_income_less_qbid<2023, (default)> = [0.]
#                     adjusted_net_capital_gain<2023, (default)> = [0.]
#                       net_capital_gain<2023, (default)> = [0.]
#                         net_long_term_capital_gain<2023, (default)> = [0.]
#                           long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                           long_term_capital_losses<2023, (default)> = [0. 0. 0. 0.]
#                         net_short_term_capital_loss<2023, (default)> = [0.]
#                           short_term_capital_losses<2023, (default)> = [0. 0. 0. 0.]
#                           short_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                         qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                       qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                       unrecaptured_section_1250_gain<2023, (default)> = [0.]
#                       capital_gains_28_percent_rate_gain<2023, (default)> = [0.]
#                         long_term_capital_gains_on_collectibles<2023, (default)> = [0. 0. 0. 0.]
#                         long_term_capital_gains_on_small_business_stock<2023, (default)> = [0. 0. 0. 0.]
#                 taxable_income_deductions_if_not_itemizing<2023, (default)> = [27700.]
#                   standard_deduction<2023, (default)> = [27700.]
#                   qualified_business_income_deduction<2023, (default)> = [0.]
#             capital_gains_excluded_from_taxable_income<2023, (default)> = [0.]
#               net_capital_gain<2023, (default)> = [0.]
#               adjusted_net_capital_gain<2023, (default)> = [0.]
#               taxable_income<2023, (default)> = [0.]
#               filing_status<2023, (default)> = ['JOINT']
#             filing_status<2023, (default)> = ['JOINT']
#           capital_gains_tax<2023, (default)> = [0.]
#             net_capital_gain<2023, (default)> = [0.]
#             taxable_income<2023, (default)> = [0.]
#             adjusted_net_capital_gain<2023, (default)> = [0.]
#             capital_gains_excluded_from_taxable_income<2023, (default)> = [0.]
#             filing_status<2023, (default)> = ['JOINT']
#             unrecaptured_section_1250_gain<2023, (default)> = [0.]
#             qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#             capital_gains_28_percent_rate_gain<2023, (default)> = [0.]
#           alternative_minimum_tax<2023, (default)> = [0.]
#             c09600<2023, (default)> = [0.]
#               c62100<2023, (default)> = [27700.]
#                 amt_income<2023, (default)> = [27700.]
#                   taxable_income<2023, (default)> = [0.]
#                   tax_unit_itemizes<2023, (default)> = [False]
#                   standard_deduction<2023, (default)> = [27700.]
#                   salt_deduction<2023, (default)> = [0.]
#                   filing_status<2023, (default)> = ['JOINT']
#               filing_status<2023, (default)> = ['JOINT']
#               age_head<2023, (default)> = [38]
#               age_spouse<2023, (default)> = [35]
#               filer_earned<2023, (default)> = [25000.]
#               sep<2023, (default)> = [1]
#               dwks10<2023, (default)> = [0.]
#                 dwks6<2023, (default)> = [0.]
#                   qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                   investment_income_form_4952<2023, (default)> = [0.]
#                 dwks9<2023, (default)> = [0.]
#                   long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                   c23650<2023, (default)> = [0.]
#                   non_sch_d_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   investment_income_form_4952<2023, (default)> = [0.]
#                 long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                 qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                 c23650<2023, (default)> = [0.]
#                 non_sch_d_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                 hasqdivltcg<2023, (default)> = [False]
#                   c01000<2023, (default)> = [0.]
#                   c23650<2023, (default)> = [0.]
#                   long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   non_sch_d_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#               dwks13<2023, (default)> = [0.]
#                 unrecaptured_section_1250_gain<2023, (default)> = [0.]
#                 capital_gains_28_percent_rate_gain<2023, (default)> = [0.]
#                 dwks9<2023, (default)> = [0.]
#                 dwks10<2023, (default)> = [0.]
#                 hasqdivltcg<2023, (default)> = [False]
#               dwks14<2023, (default)> = [0.]
#                 taxable_income<2023, (default)> = [0.]
#                 dwks13<2023, (default)> = [0.]
#                 hasqdivltcg<2023, (default)> = [False]
#               dwks19<2023, (default)> = [0.]
#                 dwks14<2023, (default)> = [0.]
#                 filing_status<2023, (default)> = ['JOINT']
#                 taxable_income<2023, (default)> = [0.]
#                 dwks10<2023, (default)> = [0.]
#                 hasqdivltcg<2023, (default)> = [False]
#               unrecaptured_section_1250_gain<2023, (default)> = [0.]
#               sep<2023, (default)> = [1]
#               foreign_tax_credit<2023, (default)> = [0.]
#               amt_form_completed<2023, (default)> = [False]
#               foreign_tax_credit<2023, (default)> = [0.]
#               taxbc<2023, (default)> = [0.]
#                 regular_tax_before_credits<2023, (default)> = [0.]
#                   filing_status<2023, (default)> = ['JOINT']
#                   taxable_income<2023, (default)> = [0.]
#                   dwks14<2023, (default)> = [0.]
#                   dwks13<2023, (default)> = [0.]
#                   dwks19<2023, (default)> = [0.]
#                   dwks9<2023, (default)> = [0.]
#                   unrecaptured_section_1250_gain<2023, (default)> = [0.]
#                   dwks10<2023, (default)> = [0.]
#                   income_tax_main_rates<2023, (default)> = [0.]
#                   hasqdivltcg<2023, (default)> = [False]
#               c05700<2023, (default)> = [0.]
#         net_investment_income_tax<2023, (default)> = [0.]
#           taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#           dividend_income<2023, (default)> = [0. 0. 0. 0.]
#           c01000<2023, (default)> = [0.]
#           rental_income<2023, (default)> = [0. 0. 0. 0.]
#           filing_status<2023, (default)> = ['JOINT']
#           adjusted_gross_income<2023, (default)> = [25000.]
#         recapture_of_investment_credit<2023, (default)> = [0.]
#         unreported_payroll_tax<2023, (default)> = [0.]
#         qualified_retirement_penalty<2023, (default)> = [0.]
#         income_tax_capped_non_refundable_credits<2023, (default)> = [0.]
#           income_tax_non_refundable_credits<2023, (default)> = [800.]
#             cdcc<2023, (default)> = [0.]
#             elderly_disabled_credit<2023, (default)> = [0.]
#             non_refundable_ctc<2023, (default)> = [800.]
#               ctc<2023, (default)> = [4000.]
#               refundable_ctc<2023, (default)> = [3200.]
#             non_refundable_american_opportunity_credit<2023, (default)> = [0.]
#             lifetime_learning_credit<2023, (default)> = [0.]
#             retirement_savings_credit<2023, (default)> = [0.]
#             residential_clean_energy_credit<2023, (default)> = [0.]
#             energy_efficient_home_improvement_credit<2023, (default)> = [0.]
#             new_clean_vehicle_credit<2023, (default)> = [0.]
#             used_clean_vehicle_credit<2023, (default)> = [0.]
#           income_tax_unavailable_non_refundable_credits<2023, (default)> = [800.]
#             income_tax_before_credits<2023, (default)> = [0.]
#             income_tax_non_refundable_credits<2023, (default)> = [800.]
#             income_tax_non_refundable_credits<2023, (default)> = [800.]
#       ma_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         MA<2023, (default)> = [False]
#       md_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         MD<2023, (default)> = [False]
#       ny_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         NY<2023, (default)> = [False]
#       or_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         or_income_tax_before_credits<2023, (default)> = [0.]
#           OR<2023, (default)> = [False]
#         or_non_refundable_credits<2023, (default)> = [0.]
#           or_exemption_credit<2023, (default)> = [0.]
#             OR<2023, (default)> = [False]
#       pa_income_tax<2023, (default)> = [0.]
#       ut_income_tax_before_refundable_credits<2023, (default)> = [0.]
#       wa_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         WA<2023, (default)> = [False]
#       flat_tax<2023, (default)> = [0.]
#         positive_agi<2023, (default)> = [25000.]

# %% [markdown]
# #### 3.2.2. Baseline simulation for the middle income household

# %%
simulation_b_m = Simulation(
    reform=reform_b,
    situation=situation_mid,
)

simulation_b_m.trace = True
simulation_b_m.calculate("household_net_income", 2023)
simulation_b_m.tracer.print_computation_log()
# Out:
#   household_net_income<2023, (default)> = [69606.484]
#     household_market_income<2023, (default)> = [80000.]
#       employment_income<2023, (default)> = [45000. 35000.     0.     0.]
#       self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#       pension_income<2023, (default)> = [0. 0. 0. 0.]
#         tax_exempt_pension_income<2023, (default)> = [0. 0. 0. 0.]
#         taxable_pension_income<2023, (default)> = [0. 0. 0. 0.]
#       dividend_income<2023, (default)> = [0. 0. 0. 0.]
#         qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#         non_qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#       interest_income<2023, (default)> = [0. 0. 0. 0.]
#         tax_exempt_interest_income<2023, (default)> = [0. 0. 0. 0.]
#         taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#       gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#       capital_gains<2023, (default)> = [0. 0. 0. 0.]
#         short_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#         long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#       rental_income<2023, (default)> = [0. 0. 0. 0.]
#       illicit_income<2023, (default)> = [0. 0. 0. 0.]
#       farm_income<2023, (default)> = [0. 0. 0. 0.]
#     household_benefits<2023, (default)> = [0.]
#       social_security<2023, (default)> = [0. 0. 0. 0.]
#         social_security_dependents<2023, (default)> = [0. 0. 0. 0.]
#         social_security_disability<2023, (default)> = [0. 0. 0. 0.]
#         social_security_retirement<2023, (default)> = [0. 0. 0. 0.]
#         social_security_survivors<2023, (default)> = [0. 0. 0. 0.]
#       ssi<2023, (default)> = [0. 0. 0. 0.]
#         uncapped_ssi<2023, (default)> = [0. 0. 0. 0.]
#           ssi_amount_if_eligible<2023, (default)> = [16452. 10968. 10968. 10968.]
#             ssi_claim_is_joint<2023, (default)> = [ True False False False]
#               is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                 is_ssi_aged<2023, (default)> = [False False False False]
#                   age<2023, (default)> = [38. 35. 10. 10.]
#                 is_blind<2023, (default)> = [False False False False]
#                 is_ssi_disabled<2023, (default)> = [False False False False]
#                   is_ssi_aged<2023, (default)> = [False False False False]
#                   is_blind<2023, (default)> = [False False False False]
#                   ssi_reported<2023, (default)> = [0. 0. 0. 0.]
#               ssi_income_deemed_from_ineligible_spouse<2023, (default)> = [17500.     0.     0.     0.]
#                 ssi_earned_income<2023, (default)> = [45000. 35000.     0.     0.]
#                   employment_income<2023, (default)> = [45000. 35000.     0.     0.]
#                   self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                 ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#                   dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                   interest_income<2023, (default)> = [0. 0. 0. 0.]
#                   gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#                   social_security<2023, (default)> = [0. 0. 0. 0.]
#                   alimony_income<2023, (default)> = [0. 0. 0. 0.]
#                   pension_income<2023, (default)> = [0. 0. 0. 0.]
#                   unemployment_compensation<2023, (default)> = [0. 0. 0. 0.]
#                 ssi_earned_income_deemed_from_ineligible_spouse<2023, (default)> = [35000.     0.     0.     0.]
#                   is_ssi_ineligible_spouse<2023, (default)> = [False  True False False]
#                     is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                       is_child<2023, (default)> = [False False  True  True]
#                         age<2023, (default)> = [38. 35. 10. 10.]
#                       is_tax_unit_head<2023, (default)> = [ True False False False]
#                         is_child<2023, (default)> = [False False  True  True]
#                         age<2023, (default)> = [38. 35. 10. 10.]
#                       age<2023, (default)> = [38. 35. 10. 10.]
#                     is_ssi_eligible_spouse<2023, (default)> = [False False False False]
#                       is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                       is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                   ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#                   ssi_earned_income<2023, (default)> = [45000. 35000.     0.     0.]
#                   ssi_ineligible_child_allocation<2023, (default)> = [   0.    0. 5484. 5484.]
#                     ssi_earned_income<2023, (default)> = [45000. 35000.     0.     0.]
#                     ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#                     is_ssi_ineligible_child<2023, (default)> = [False False  True  True]
#                       is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                       is_child<2023, (default)> = [False False  True  True]
#                   is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                 ssi_unearned_income_deemed_from_ineligible_spouse<2023, (default)> = [0. 0. 0. 0.]
#                   is_ssi_ineligible_spouse<2023, (default)> = [False  True False False]
#                   ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#                   ssi_ineligible_child_allocation<2023, (default)> = [   0.    0. 5484. 5484.]
#                 is_ssi_ineligible_child<2023, (default)> = [False False  True  True]
#           meets_ssi_resource_test<2023, (default)> = [ True  True  True  True]
#             ssi_claim_is_joint<2023, (default)> = [ True False False False]
#             ssi_countable_resources<2023, (default)> = [0. 0. 0. 0.]
#           is_ssi_eligible_individual<2023, (default)> = [False False False False]
#             is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#             is_ssi_eligible_spouse<2023, (default)> = [False False False False]
#           ssi_countable_income<2023, (default)> = [0. 0. 0. 0.]
#             ssi_earned_income<2023, (default)> = [45000. 35000.     0.     0.]
#             ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#             ssi_unearned_income_deemed_from_ineligible_parent<2023, (default)> = [0. 0. 0. 0.]
#               is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#               is_child<2023, (default)> = [False False  True  True]
#               is_ssi_ineligible_parent<2023, (default)> = [False False False False]
#                 is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                 is_child<2023, (default)> = [False False  True  True]
#               ssi_earned_income<2023, (default)> = [45000. 35000.     0.     0.]
#               ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#               ssi_ineligible_child_allocation<2023, (default)> = [   0.    0. 5484. 5484.]
#               ssi_ineligible_parent_allocation<2023, (default)> = [0. 0. 0. 0.]
#                 is_ssi_ineligible_parent<2023, (default)> = [False False False False]
#             ssi_income_deemed_from_ineligible_spouse<2023, (default)> = [17500.     0.     0.     0.]
#             is_ssi_eligible_individual<2023, (default)> = [False False False False]
#       state_supplement<2023, (default)> = [0. 0. 0. 0.]
#         uncapped_ssi<2023, (default)> = [0. 0. 0. 0.]
#         maximum_state_supplement<2023, (default)> = [0. 0. 0. 0.]
#           is_ssi_eligible_individual<2023, (default)> = [False False False False]
#           state_code_str<2023, (default)> = ['UT']
#             state_code<2023, (default)> = ['UT']
#               state_name<2023, (default)> = ['UT']
#           state_living_arrangement<2023, (default)> = ['FULL_COST']
#           is_blind<2023, (default)> = [False False False False]
#           is_ssi_aged<2023, (default)> = [False False False False]
#           is_ssi_disabled<2023, (default)> = [False False False False]
#           ssi_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#           ssi_claim_is_joint<2023, (default)> = [ True False False False]
#         is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#         meets_ssi_resource_test<2023, (default)> = [ True  True  True  True]
#         ssi_claim_is_joint<2023, (default)> = [ True False False False]
#       ca_cvrp<2023, (default)> = [0. 0. 0. 0.]
#         CA<2023, (default)> = [False]
#           state_code_str<2023, (default)> = ['UT']
#       snap<2023, (default)> = [0.]
#         snap_normal_allotment<2023, (default)> = [0.]
#           is_snap_eligible<2023, (default)> = [False]
#             meets_snap_net_income_test<2023, (default)> = [False]
#               snap_net_income_fpg_ratio<2023, (default)> = [2.021]
#                 snap_net_income<2023, (default)> = [60630.]
#                   snap_gross_income<2023, (default)> = [80000.]
#                     snap_earned_income<2023, (default)> = [80000.]
#                       employment_income<2023, (default)> = [45000. 35000.     0.     0.]
#                       self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                     snap_unearned_income<2023, (default)> = [0.]
#                       dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                       interest_income<2023, (default)> = [0. 0. 0. 0.]
#                       gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#                       social_security<2023, (default)> = [0. 0. 0. 0.]
#                       ssi<2023, (default)> = [0. 0. 0. 0.]
#                   snap_deductions<2023, (default)> = [19370.]
#                     snap_standard_deduction<2023, (default)> = [2316.]
#                       state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#                         state_group<2023, (default)> = ['CONTIGUOUS_US']
#                           state_code<2023, (default)> = ['UT']
#                       spm_unit_size<2023, (default)> = [4]
#                     snap_earned_income_deduction<2023, (default)> = [16000.]
#                       snap_earned_income<2023, (default)> = [80000.]
#                     snap_dependent_care_deduction<2023, (default)> = [1000.]
#                       childcare_expenses<2023, (default)> = [1000.]
#                     snap_child_support_deduction<2023, (default)> = [0.]
#                       child_support_expense<2023, (default)> = [0. 0. 0. 0.]
#                       state_code_str<2023, (default)> = ['UT']
#                     snap_excess_medical_expense_deduction<2023, (default)> = [0.]
#                       is_usda_elderly<2023, (default)> = [False False False False]
#                         age<2023, (default)> = [38. 35. 10. 10.]
#                       is_usda_disabled<2023, (default)> = [False False False False]
#                         is_ssi_disabled<2023, (default)> = [False False False False]
#                         social_security_disability<2023, (default)> = [0. 0. 0. 0.]
#                         is_permanently_disabled_veteran<2023, (default)> = [False False False False]
#                         is_surviving_spouse_of_disabled_veteran<2023, (default)> = [False False False False]
#                         is_surviving_child_of_disabled_veteran<2023, (default)> = [False False False False]
#                       medical_out_of_pocket_expenses<2023, (default)> = [2000.    0.    0.    0.]
#                       state_code_str<2023, (default)> = ['UT']
#                     snap_excess_shelter_expense_deduction<2023, (default)> = [54.]
#                       snap_net_income_pre_shelter<2023, (default)> = [60684.]
#                         snap_gross_income<2023, (default)> = [80000.]
#                         snap_standard_deduction<2023, (default)> = [2316.]
#                         snap_earned_income_deduction<2023, (default)> = [16000.]
#                         snap_dependent_care_deduction<2023, (default)> = [1000.]
#                         snap_child_support_deduction<2023, (default)> = [0.]
#                         snap_excess_medical_expense_deduction<2023, (default)> = [0.]
#                       housing_cost<2023, (default)> = [20000.]
#                       snap_region_str<2023, (default)> = ['CONTIGUOUS_US']
#                         snap_region<2023, (default)> = ['CONTIGUOUS_US']
#                           state_group<2023, (default)> = ['CONTIGUOUS_US']
#                       has_usda_elderly_disabled<2023, (default)> = [False]
#                         is_usda_elderly<2023, (default)> = [False False False False]
#                         is_usda_disabled<2023, (default)> = [False False False False]
#                       snap_utility_allowance<2023, (default)> = [54.]
#                         snap_utility_allowance_type<2023, (default)> = ['IUA']
#                           count_distinct_utility_expenses<2023, (default)> = [1]
#                             heating_cooling_expense<2023, (default)> = [0.]
#                             electricity_expense<2023, (default)> = [0.]
#                             gas_expense<2023, (default)> = [0.]
#                             phone_expense<2023, (default)> = [1500.]
#                               phone_cost<2023, (default)> = [1500.]
#                             trash_expense<2023, (default)> = [0.]
#                             water_expense<2023, (default)> = [0.]
#                             sewage_expense<2023, (default)> = [0.]
#                           snap_utility_region_str<2023, (default)> = ['UT']
#                             snap_utility_region<2023, (default)> = ['UT']
#                               state_code<2023, (default)> = ['UT']
#                           has_heating_cooling_expense<2023, (default)> = [False]
#                             heating_cooling_expense<2023, (default)> = [0.]
#                         snap_utility_region_str<2023, (default)> = ['UT']
#                       state_code_str<2023, (default)> = ['UT']
#                       is_homeless<2023, (default)> = [False]
#                 spm_unit_fpg<2023, (default)> = [30000.]
#                   spm_unit_size<2023, (default)> = [4]
#                   state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#             meets_snap_gross_income_test<2023, (default)> = [False]
#               snap_gross_income_fpg_ratio<2023, (default)> = [2.6666667]
#                 snap_gross_income<2023, (default)> = [80000.]
#                 spm_unit_fpg<2023, (default)> = [30000.]
#               has_usda_elderly_disabled<2023, (default)> = [False]
#             meets_snap_asset_test<2023, (default)> = [ True]
#               has_usda_elderly_disabled<2023, (default)> = [False]
#               snap_assets<2023, (default)> = [0.]
#             meets_snap_categorical_eligibility<2023, (default)> = [False]
#               ssi<2023, (default)> = [0. 0. 0. 0.]
#               is_tanf_non_cash_eligible<2023, (default)> = [False]
#                 meets_tanf_non_cash_gross_income_test<2023, (default)> = [False]
#                   state_code_str<2023, (default)> = ['UT']
#                   snap_gross_income_fpg_ratio<2023, (default)> = [2.6666667]
#                 meets_tanf_non_cash_net_income_test<2023, (default)> = [ True]
#                   state_code_str<2023, (default)> = ['UT']
#                   is_tanf_non_cash_hheod<2023, (default)> = [False]
#                     state_code_str<2023, (default)> = ['UT']
#                     has_all_usda_elderly_disabled<2023, (default)> = [False]
#                       is_usda_elderly<2023, (default)> = [False False False False]
#                       is_usda_disabled<2023, (default)> = [False False False False]
#                     has_usda_elderly_disabled<2023, (default)> = [False]
#                   snap_net_income_fpg_ratio<2023, (default)> = [2.021]
#                 meets_tanf_non_cash_asset_test<2023, (default)> = [False]
#                   snap_assets<2023, (default)> = [0.]
#                   state_code_str<2023, (default)> = ['UT']
#           snap_expected_contribution<2023, (default)> = [18189.]
#             snap_net_income<2023, (default)> = [60630.]
#           snap_max_allotment<2023, (default)> = [11268.]
#             snap_region_str<2023, (default)> = ['CONTIGUOUS_US']
#             spm_unit_size<2023, (default)> = [4]
#             spm_unit_size<2023, (default)> = [4]
#           snap_min_allotment<2023, (default)> = [0.]
#             snap_region_str<2023, (default)> = ['CONTIGUOUS_US']
#             spm_unit_size<2023, (default)> = [4]
#         snap_emergency_allotment<2023, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-01, (default)> = [0.]
#             is_snap_eligible<2023, (default)> = [False]
#             snap_max_allotment<2023, (default)> = [11268.]
#             snap_normal_allotment<2023, (default)> = [0.]
#             state_code<2023, (default)> = ['UT']
#           snap_emergency_allotment_monthly<2023-02, (default)> = [0.]
#             is_snap_eligible<2023, (default)> = [False]
#             snap_max_allotment<2023, (default)> = [11268.]
#             snap_normal_allotment<2023, (default)> = [0.]
#             state_code<2023, (default)> = ['UT']
#           snap_emergency_allotment_monthly<2023-03, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-04, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-05, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-06, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-07, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-08, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-09, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-10, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-11, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-12, (default)> = [0.]
#       wic<2023, (default)> = [0. 0. 0. 0.]
#         meets_wic_income_test<2023, (default)> = [False]
#           school_meal_countable_income<2023, (default)> = [80000.]
#             employment_income<2023, (default)> = [45000. 35000.     0.     0.]
#             self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#             dividend_income<2023, (default)> = [0. 0. 0. 0.]
#             interest_income<2023, (default)> = [0. 0. 0. 0.]
#             gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#             social_security<2023, (default)> = [0. 0. 0. 0.]
#             ssi<2023, (default)> = [0. 0. 0. 0.]
#           wic_fpg<2023, (default)> = [30000.]
#             is_pregnant<2023, (default)> = [False False False False]
#             spm_unit_fpg<2023, (default)> = [30000.]
#             state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#         meets_wic_categorical_eligibility<2023, (default)> = [False False False False]
#           snap<2023, (default)> = [0.]
#           tanf<2023, (default)> = [0.]
#             tanf_reported<2023, (default)> = [0. 0. 0. 0.]
#             is_tanf_eligible<2023, (default)> = [False]
#               is_person_demographic_tanf_eligible<2023, (default)> = [False False  True  True]
#                 is_child<2023, (default)> = [False False  True  True]
#                 age<2023, (default)> = [38. 35. 10. 10.]
#                 is_full_time_student<2023, (default)> = [False False  True  True]
#                   is_full_time_college_student<2023, (default)> = [False False False False]
#                   is_in_k12_school<2023, (default)> = [False False  True  True]
#                     age<2023, (default)> = [38. 35. 10. 10.]
#                 is_pregnant<2023, (default)> = [False False False False]
#               is_tanf_enrolled<2023, (default)> = [False]
#               is_tanf_continuous_eligible<2023, (default)> = [False]
#                 tanf_gross_earned_income<2023, (default)> = [80000.]
#                   employment_income<2023, (default)> = [45000. 35000.     0.     0.]
#                   self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                 tanf_gross_unearned_income<2023, (default)> = [0.]
#                   dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                   interest_income<2023, (default)> = [0. 0. 0. 0.]
#                   gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#                   social_security<2023, (default)> = [0. 0. 0. 0.]
#                   ssi<2023, (default)> = [0. 0. 0. 0.]
#                 tanf_max_amount<2023, (default)> = [0.]
#                   spm_unit_size<2023, (default)> = [4]
#                   state_code_str<2023, (default)> = ['UT']
#               is_tanf_initial_eligible<2023, (default)> = [False]
#                 tanf_initial_employment_deduction<2023, (default)> = [0.]
#                   spm_unit_size<2023, (default)> = [4]
#                   state_code_str<2023, (default)> = ['UT']
#                   market_income<2023, (default)> = [45000. 35000.     0.     0.]
#                     employment_income<2023, (default)> = [45000. 35000.     0.     0.]
#                     self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                     pension_income<2023, (default)> = [0. 0. 0. 0.]
#                     dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                     interest_income<2023, (default)> = [0. 0. 0. 0.]
#                     gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#                     capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                     rental_income<2023, (default)> = [0. 0. 0. 0.]
#                     illicit_income<2023, (default)> = [0. 0. 0. 0.]
#                     farm_income<2023, (default)> = [0. 0. 0. 0.]
#                 tanf_gross_earned_income<2023, (default)> = [80000.]
#                 tanf_gross_unearned_income<2023, (default)> = [0.]
#                 tanf_max_amount<2023, (default)> = [0.]
#             tanf_amount_if_eligible<2023, (default)> = [0.]
#               tanf_max_amount<2023, (default)> = [0.]
#               tanf_countable_income<2023, (default)> = [80000.]
#                 state_code_str<2023, (default)> = ['UT']
#                 tanf_gross_unearned_income<2023, (default)> = [0.]
#                 tanf_gross_earned_income<2023, (default)> = [80000.]
#           medicaid<2023, (default)> = [0. 0. 0. 0.]
#             is_medicaid_eligible<2023, (default)> = [False False False False]
#               medicaid_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#                 is_infant_for_medicaid<2023, (default)> = [False False False False]
#                   is_infant_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [2.6666667 2.6666667 2.6666667 2.6666667]
#                       tax_unit_medicaid_income_level<2023, (default)> = [2.6666667]
#                         medicaid_income<2023, (default)> = [80000.]
#                           adjusted_gross_income<2023, (default)> = [80000.]
#                             irs_gross_income<2023, (default)> = [45000. 35000.     0.     0.]
#                               is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                               employment_income<2023, (default)> = [45000. 35000.     0.     0.]
#                               self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                               partnership_s_corp_income<2023, (default)> = [0. 0. 0. 0.]
#                               farm_income<2023, (default)> = [0. 0. 0. 0.]
#                               farm_rent_income<2023, (default)> = [0. 0. 0. 0.]
#                               capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                               taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#                               rental_income<2023, (default)> = [0. 0. 0. 0.]
#                               dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                               taxable_pension_income<2023, (default)> = [0. 0. 0. 0.]
#                               debt_relief<2023, (default)> = [0. 0. 0. 0.]
#                               taxable_unemployment_compensation<2023, (default)> = [0. 0. 0. 0.]
#                                 is_tax_unit_head<2023, (default)> = [ True False False False]
#                                 tax_unit_taxable_unemployment_compensation<2023, (default)> = [0.]
#                                   tax_unit_unemployment_compensation<2023, (default)> = [0.]
#                                     unemployment_compensation<2023, (default)> = [0. 0. 0. 0.]
#                                   taxable_uc_agi<2023, (default)> = [80000.]
#                                     is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                                     employment_income<2023, (default)> = [45000. 35000.     0.     0.]
#                                     self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                     partnership_s_corp_income<2023, (default)> = [0. 0. 0. 0.]
#                                     farm_income<2023, (default)> = [0. 0. 0. 0.]
#                                     farm_rent_income<2023, (default)> = [0. 0. 0. 0.]
#                                     capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                                     taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#                                     rental_income<2023, (default)> = [0. 0. 0. 0.]
#                                     dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                                     taxable_pension_income<2023, (default)> = [0. 0. 0. 0.]
#                                     debt_relief<2023, (default)> = [0. 0. 0. 0.]
#                                     taxable_social_security<2023, (default)> = [0. 0. 0. 0.]
#                                       tax_unit_taxable_social_security<2023, (default)> = [0.]
#                                         tax_unit_social_security<2023, (default)> = [0.]
#                                           social_security<2023, (default)> = [0. 0. 0. 0.]
#                                         taxable_ss_magi<2023, (default)> = [80000.]
#                                           is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                                           employment_income<2023, (default)> = [45000. 35000.     0.     0.]
#                                           self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                           partnership_s_corp_income<2023, (default)> = [0. 0. 0. 0.]
#                                           farm_income<2023, (default)> = [0. 0. 0. 0.]
#                                           farm_rent_income<2023, (default)> = [0. 0. 0. 0.]
#                                           capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                                           taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#                                           rental_income<2023, (default)> = [0. 0. 0. 0.]
#                                           dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                                           taxable_pension_income<2023, (default)> = [0. 0. 0. 0.]
#                                           debt_relief<2023, (default)> = [0. 0. 0. 0.]
#                                           illicit_income<2023, (default)> = [0. 0. 0. 0.]
#                                           unemployment_compensation<2023, (default)> = [0. 0. 0. 0.]
#                                           tax_exempt_interest_income<2023, (default)> = [0. 0. 0. 0.]
#                                           loss_ald<2023, (default)> = [0.]
#                                             filing_status<2023, (default)> = ['JOINT']
#                                               is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                                               tax_unit_dependents<2023, (default)> = [2]
#                                                 is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                                             self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                             maximum_capital_loss<2023, (default)> = [0.]
#                                               tax_unit_capital_loss<2023, (default)> = [0.]
#                                                 capital_loss<2023, (default)> = [0. 0. 0. 0.]
#                                                   capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                                               filing_status<2023, (default)> = ['JOINT']
#                                           self_employment_tax_ald<2023, (default)> = [0.]
#                                             self_employment_tax_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employment_tax<2023, (default)> = [0. 0. 0. 0.]
#                                                 self_employment_social_security_tax<2023, (default)> = [0. 0. 0. 0.]
#                                                   social_security_taxable_self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                                     taxable_self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                                       sey<2023, (default)> = [0. 0. 0. 0.]
#                                                         self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                                         farm_income<2023, (default)> = [0. 0. 0. 0.]
#                                                         k1bx14<2023, (default)> = [0. 0. 0. 0.]
#                                                     taxable_earnings_for_social_security<2023, (default)> = [45000. 35000.     0.     0.]
#                                                       payroll_tax_gross_wages<2023, (default)> = [45000. 35000.     0.     0.]
#                                                         employment_income<2023, (default)> = [45000. 35000.     0.     0.]
#                                                 self_employment_medicare_tax<2023, (default)> = [0. 0. 0. 0.]
#                                                   taxable_self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                           early_withdrawal_penalty<2023, (default)> = [0. 0. 0. 0.]
#                                           alimony_income<2023, (default)> = [0. 0. 0. 0.]
#                                           educator_expense<2023, (default)> = [0. 0. 0. 0.]
#                                           health_savings_account_ald<2023, (default)> = [0.]
#                                           self_employed_health_insurance_ald<2023, (default)> = [0.]
#                                             self_employed_health_insurance_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employed_health_insurance_premiums<2023, (default)> = [0. 0. 0. 0.]
#                                                 is_self_employed<2023, (default)> = [False False False False]
#                                                 health_insurance_premiums<2023, (default)> = [0. 0. 0. 0.]
#                                           self_employed_pension_contribution_ald<2023, (default)> = [0.]
#                                             self_employed_pension_contribution_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employed_pension_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                           ira_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                           sep_simple_qualified_plan_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                         filing_status<2023, (default)> = ['JOINT']
#                                       tax_unit_social_security<2023, (default)> = [0.]
#                                       social_security<2023, (default)> = [0. 0. 0. 0.]
#                                       is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                                       is_tax_unit_head<2023, (default)> = [ True False False False]
#                                     illicit_income<2023, (default)> = [0. 0. 0. 0.]
#                                     loss_ald<2023, (default)> = [0.]
#                                     self_employment_tax_ald<2023, (default)> = [0.]
#                                     student_loan_interest<2023, (default)> = [0. 0. 0. 0.]
#                                     early_withdrawal_penalty<2023, (default)> = [0. 0. 0. 0.]
#                                     alimony_income<2023, (default)> = [0. 0. 0. 0.]
#                                     educator_expense<2023, (default)> = [0. 0. 0. 0.]
#                                     health_savings_account_ald<2023, (default)> = [0.]
#                                     self_employed_health_insurance_ald<2023, (default)> = [0.]
#                                     self_employed_pension_contribution_ald<2023, (default)> = [0.]
#                                     ira_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                     sep_simple_qualified_plan_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                     qualified_adoption_assistance_expense<2023, (default)> = [0. 0. 0. 0.]
#                                     us_bonds_for_higher_ed<2023, (default)> = [0. 0. 0. 0.]
#                                     specified_possession_income<2023, (default)> = [0.]
#                                     puerto_rico_income<2023, (default)> = [0.]
#                                   filing_status<2023, (default)> = ['JOINT']
#                               taxable_social_security<2023, (default)> = [0. 0. 0. 0.]
#                               illicit_income<2023, (default)> = [0. 0. 0. 0.]
#                             above_the_line_deductions<2023, (default)> = [0.]
#                               loss_ald<2023, (default)> = [0.]
#                               self_employment_tax_ald<2023, (default)> = [0.]
#                               student_loan_interest<2023, (default)> = [0. 0. 0. 0.]
#                               early_withdrawal_penalty<2023, (default)> = [0. 0. 0. 0.]
#                               alimony_income<2023, (default)> = [0. 0. 0. 0.]
#                               educator_expense<2023, (default)> = [0. 0. 0. 0.]
#                               health_savings_account_ald<2023, (default)> = [0.]
#                               self_employed_health_insurance_ald<2023, (default)> = [0.]
#                               self_employed_pension_contribution_ald<2023, (default)> = [0.]
#                               ira_contributions<2023, (default)> = [0. 0. 0. 0.]
#                               sep_simple_qualified_plan_contributions<2023, (default)> = [0. 0. 0. 0.]
#                               qualified_adoption_assistance_expense<2023, (default)> = [0. 0. 0. 0.]
#                               us_bonds_for_higher_ed<2023, (default)> = [0. 0. 0. 0.]
#                               specified_possession_income<2023, (default)> = [0.]
#                               puerto_rico_income<2023, (default)> = [0.]
#                           foreign_earned_income_exclusion<2023, (default)> = [0.]
#                           student_loan_interest<2023, (default)> = [0. 0. 0. 0.]
#                           tax_exempt_social_security<2023, (default)> = [0.]
#                             tax_unit_social_security<2023, (default)> = [0.]
#                             tax_unit_taxable_social_security<2023, (default)> = [0.]
#                         tax_unit_fpg<2023, (default)> = [30000.]
#                           tax_unit_size<2023, (default)> = [4]
#                           state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#                     state_code_str<2023, (default)> = ['UT']
#                   is_infant_for_medicaid_nfc<2023, (default)> = [False False False False]
#                     age<2023, (default)> = [38. 35. 10. 10.]
#                 is_young_child_for_medicaid<2023, (default)> = [False False False False]
#                   is_young_child_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [2.6666667 2.6666667 2.6666667 2.6666667]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_young_child_for_medicaid_nfc<2023, (default)> = [False False False False]
#                     age<2023, (default)> = [38. 35. 10. 10.]
#                 is_older_child_for_medicaid<2023, (default)> = [False False False False]
#                   age<2023, (default)> = [38. 35. 10. 10.]
#                   medicaid_income_level<2023, (default)> = [2.6666667 2.6666667 2.6666667 2.6666667]
#                   state_code_str<2023, (default)> = ['UT']
#                 is_young_adult_for_medicaid<2023, (default)> = [False False False False]
#                   is_young_adult_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [2.6666667 2.6666667 2.6666667 2.6666667]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_young_adult_for_medicaid_nfc<2023, (default)> = [False False False False]
#                     age<2023, (default)> = [38. 35. 10. 10.]
#                 is_adult_for_medicaid<2023, (default)> = [False False False False]
#                   is_adult_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [2.6666667 2.6666667 2.6666667 2.6666667]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_adult_for_medicaid_nfc<2023, (default)> = [ True  True False False]
#                     age<2023, (default)> = [38. 35. 10. 10.]
#                 is_parent_for_medicaid<2023, (default)> = [False False False False]
#                   is_parent_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [2.6666667 2.6666667 2.6666667 2.6666667]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_parent_for_medicaid_nfc<2023, (default)> = [ True  True False False]
#                     is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                     tax_unit_count_dependents<2023, (default)> = [2]
#                       is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                 is_pregnant_for_medicaid<2023, (default)> = [False False False False]
#                   is_pregnant_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [2.6666667 2.6666667 2.6666667 2.6666667]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_pregnant_for_medicaid_nfc<2023, (default)> = [False False False False]
#                     is_pregnant<2023, (default)> = [False False False False]
#                     count_days_postpartum<2023, (default)> = [inf inf inf inf]
#                       under_60_days_postpartum<2023, (default)> = [False False False False]
#                       under_12_months_postpartum<2023, (default)> = [False False False False]
#                     state_code_str<2023, (default)> = ['UT']
#                 is_ssi_recipient_for_medicaid<2023, (default)> = [False False False False]
#                   state_code_str<2023, (default)> = ['UT']
#                   ssi<2023, (default)> = [0. 0. 0. 0.]
#             medicaid_benefit_value<2023, (default)> = [9966.585 9966.585 9966.585 9966.585]
#               state_code_str<2023, (default)> = ['UT']
#           is_pregnant<2023, (default)> = [False False False False]
#           wic_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#             is_pregnant<2023, (default)> = [False False False False]
#             is_mother<2023, (default)> = [False False False False]
#               is_female<2023, (default)> = [False False False False]
#               own_children_in_household<2023, (default)> = [0 0 0 0]
#               is_breastfeeding<2023, (default)> = [False False False False]
#             is_breastfeeding<2023, (default)> = [False False False False]
#             age<2023, (default)> = [38. 35. 10. 10.]
#         wic_category_str<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#           wic_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#         is_wic_at_nutritional_risk<2023, (default)> = [False False False False]
#           receives_wic<2023, (default)> = [False False False False]
#           meets_wic_income_test<2023, (default)> = [False]
#           meets_wic_categorical_eligibility<2023, (default)> = [False False False False]
#           wic_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#         would_claim_wic<2023, (default)> = [ True  True  True  True]
#       free_school_meals<2023, (default)> = [0.]
#         school_meal_tier<2023, (default)> = ['PAID']
#           school_meal_fpg_ratio<2023, (default)> = [2.6666667]
#             school_meal_countable_income<2023, (default)> = [80000.]
#             spm_unit_fpg<2023, (default)> = [30000.]
#           meets_school_meal_categorical_eligibility<2023, (default)> = [False]
#             snap<2023, (default)> = [0.]
#             tanf<2023, (default)> = [0.]
#             fdpir<2023, (default)> = [0.]
#         school_meal_net_subsidy<2023, (default)> = [0.]
#           school_meal_daily_subsidy<2023, (default)> = [0.72]
#             state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#             school_meal_tier<2023, (default)> = ['PAID']
#           school_meal_paid_daily_subsidy<2023, (default)> = [0.72]
#             state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#           is_in_k12_school<2023, (default)> = [False False  True  True]
#       reduced_price_school_meals<2023, (default)> = [0.]
#         school_meal_tier<2023, (default)> = ['PAID']
#         school_meal_net_subsidy<2023, (default)> = [0.]
#       lifeline<2023, (default)> = [0.]
#         is_rural<2023, (default)> = [False]
#         is_on_tribal_land<2023, (default)> = [False]
#         phone_cost<2023, (default)> = [1500.]
#         broadband_cost<2023, (default)> = [900.]
#         is_lifeline_eligible<2023, (default)> = [False]
#           medicaid<2023, (default)> = [0. 0. 0. 0.]
#           snap<2023, (default)> = [0.]
#           ssi<2023, (default)> = [0. 0. 0. 0.]
#           fcc_fpg_ratio<2023, (default)> = [2.6666667]
#             irs_gross_income<2023, (default)> = [45000. 35000.     0.     0.]
#             spm_unit_fpg<2023, (default)> = [30000.]
#       acp<2023, (default)> = [0.]
#         is_acp_eligible<2023, (default)> = [False]
#           lifeline<2023, (default)> = [0.]
#           free_school_meals<2023, (default)> = [0.]
#           reduced_price_school_meals<2023, (default)> = [0.]
#           pell_grant<2023, (default)> = [0.]
#           wic<2023, (default)> = [0. 0. 0. 0.]
#           medicaid<2023, (default)> = [0. 0. 0. 0.]
#           snap<2023, (default)> = [0.]
#           ssi<2023, (default)> = [0. 0. 0. 0.]
#           fcc_fpg_ratio<2023, (default)> = [2.6666667]
#           ebb<2023, (default)> = [0.]
#             is_ebb_eligible<2023, (default)> = [False]
#               is_lifeline_eligible<2023, (default)> = [False]
#               free_school_meals<2023, (default)> = [0.]
#               reduced_price_school_meals<2023, (default)> = [0.]
#               pell_grant<2023, (default)> = [0.]
#               experienced_covid_income_loss<2023, (default)> = [False]
#               enrolled_in_ebb<2023, (default)> = [False]
#             broadband_cost_after_lifeline<2023, (default)> = [900.]
#               broadband_cost<2023, (default)> = [900.]
#               lifeline<2023, (default)> = [0.]
#             is_on_tribal_land<2023, (default)> = [False]
#         broadband_cost_after_lifeline<2023, (default)> = [900.]
#         is_on_tribal_land<2023, (default)> = [False]
#       ebb<2023, (default)> = [0.]
#       tanf<2023, (default)> = [0.]
#       high_efficiency_electric_home_rebate<2023, (default)> = [0.]
#         capped_electric_heat_pump_clothes_dryer_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#             tax_unit_income_ami_ratio<2023, (default)> = [0.]
#           electric_heat_pump_clothes_dryer_expenditures<2023, (default)> = [0.]
#         capped_electric_load_service_center_upgrade_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           electric_load_service_center_upgrade_expenditures<2023, (default)> = [0.]
#         capped_electric_stove_cooktop_range_or_oven_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           electric_stove_cooktop_range_or_oven_expenditures<2023, (default)> = [0.]
#         capped_electric_wiring_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           electric_wiring_expenditures<2023, (default)> = [0.]
#         capped_heat_pump_water_heater_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           heat_pump_water_heater_expenditures<2023, (default)> = [0.]
#         capped_heat_pump_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           heat_pump_expenditures<2023, (default)> = [0.]
#         capped_insulation_air_sealing_ventilation_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           energy_efficient_insulation_expenditures<2023, (default)> = [0.]
#           air_sealing_ventilation_expenditures<2023, (default)> = [0.]
#       residential_efficiency_electrification_rebate<2023, (default)> = [0.]
#         residential_efficiency_electrification_retrofit_expenditures<2023, (default)> = [0.]
#         residential_efficiency_electrification_retrofit_energy_savings<2023, (default)> = [0.]
#         current_home_energy_use<2023, (default)> = [0.]
#         household_income_ami_ratio<2023, (default)> = [0.]
#         average_home_energy_use_in_state<2023, (default)> = [0.]
#       basic_income<2023, (default)> = [0.]
#         basic_income_eligible<2023, (default)> = [ True]
#         basic_income_before_phase_out<2023, (default)> = [0.]
#           tax_unit_size<2023, (default)> = [4]
#           age<2023, (default)> = [38. 35. 10. 10.]
#           tax_unit_fpg<2023, (default)> = [30000.]
#         basic_income_phase_out<2023, (default)> = [0.]
#           basic_income_before_phase_out<2023, (default)> = [0.]
#           adjusted_gross_income<2023, (default)> = [80000.]
#           filing_status<2023, (default)> = ['JOINT']
#       spm_unit_capped_housing_subsidy<2023, (default)> = [0.]
#         spm_unit_capped_housing_subsidy_reported<2023, (default)> = [0.]
#     household_refundable_tax_credits<2023, (default)> = [0.]
#       income_tax_refundable_credits<2023, (default)> = [0.]
#         eitc<2023, (default)> = [0.]
#           earned_income_tax_credit<2023, (default)> = [0.]
#             eitc_eligible<2023, (default)> = [ True]
#               is_child<2023, (default)> = [False False  True  True]
#               age<2023, (default)> = [38. 35. 10. 10.]
#               tax_exempt_interest_income<2023, (default)> = [0. 0. 0. 0.]
#               taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#               dividend_income<2023, (default)> = [0. 0. 0. 0.]
#               c01000<2023, (default)> = [0.]
#                 sep<2023, (default)> = [1]
#                 c23650<2023, (default)> = [0.]
#                   long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   short_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#               tax_unit_rental_income<2023, (default)> = [0.]
#                 rental_income<2023, (default)> = [0. 0. 0. 0.]
#               tax_unit_partnership_s_corp_income<2023, (default)> = [0.]
# ...
#                         blind_head<2023, (default)> = [False]
#                           is_blind<2023, (default)> = [False False False False]
#                           is_tax_unit_head<2023, (default)> = [ True False False False]
#                         blind_spouse<2023, (default)> = [False]
#                           is_blind<2023, (default)> = [False False False False]
#                           is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                         age_head<2023, (default)> = [38]
#                         age_spouse<2023, (default)> = [35]
#                 taxable_income_deductions_if_itemizing<2023, (default)> = [8637.512]
#                   charitable_deduction<2023, (default)> = [6000.]
#                   interest_deduction<2023, (default)> = [0.]
#                   salt_deduction<2023, (default)> = [2637.512]
#                     state_and_local_sales_or_income_tax<2023, (default)> = [2637.512]
#                       state_income_tax<2023, (default)> = [2637.512]
#                         ma_income_tax<2023, (default)> = [0.]
#                           MA<2023, (default)> = [False]
#                         md_income_tax<2023, (default)> = [0.]
#                           MD<2023, (default)> = [False]
#                         ny_income_tax<2023, (default)> = [0.]
#                           NY<2023, (default)> = [False]
#                         or_income_tax<2023, (default)> = [0.]
#                           OR<2023, (default)> = [False]
#                         pa_income_tax<2023, (default)> = [0.]
#                           PA<2023, (default)> = [False]
#                             state_code_str<2023, (default)> = ['UT']
#                         wa_income_tax<2023, (default)> = [0.]
#                           WA<2023, (default)> = [False]
#                         ut_income_tax<2023, (default)> = [2637.512]
#                           UT<2023, (default)> = [ True]
#                           ut_income_tax_before_refundable_credits<2023, (default)> = [2637.512]
#                             ut_income_tax_after_credits<2023, (default)> = [2637.512]
#                               ut_income_tax_before_credits<2023, (default)> = [3880.]
#                                 UT<2023, (default)> = [ True]
#                                 ut_taxable_income<2023, (default)> = [80000.]
#                                   UT<2023, (default)> = [ True]
#                                   ut_total_income<2023, (default)> = [80000.]
#                                     UT<2023, (default)> = [ True]
#                                     adjusted_gross_income<2023, (default)> = [80000.]
#                                     ut_additions_to_income<2023, (default)> = [0.]
#                                       UT<2023, (default)> = [ True]
#                                   salt_refund_last_year<2023, (default)> = [0.]
#                                   ut_subtractions_from_income<2023, (default)> = [0.]
#                                     UT<2023, (default)> = [ True]
#                               ut_taxpayer_credit<2023, (default)> = [1242.488]
#                                 UT<2023, (default)> = [ True]
#                                 ut_taxpayer_credit_max<2023, (default)> = [1878.24]
#                                   UT<2023, (default)> = [ True]
#                                   tax_unit_count_dependents<2023, (default)> = [2]
#                                   tax_unit_itemizes<2023, (default)> = [False]
#                                   standard_deduction<2023, (default)> = [27700.]
#                                   charitable_deduction<2023, (default)> = [6000.]
#                                   interest_deduction<2023, (default)> = [0.]
#                                   medical_expense_deduction<2023, (default)> = [0.]
#                                   casualty_loss_deduction<2023, (default)> = [0.]
#                                 ut_taxpayer_credit_reduction<2023, (default)> = [635.752]
#                                   UT<2023, (default)> = [ True]
#                                   filing_status<2023, (default)> = ['JOINT']
#                                   ut_taxable_income<2023, (default)> = [80000.]
#                             ut_apportionable_nonrefundable_credits<2023, (default)> = [0.]
#                               UT<2023, (default)> = [ True]
#                             ut_nonapportionable_nonrefundable_credits<2023, (default)> = [0.]
#                               UT<2023, (default)> = [ True]
#                             ut_recapture_low_inc_housing_credit<2023, (default)> = [0.]
#                               UT<2023, (default)> = [ True]
#                           ut_refundable_credits<2023, (default)> = [0.]
#                       local_income_tax<2023, (default)> = [0.]
#                       state_sales_tax<2023, (default)> = [0.]
#                       local_sales_tax<2023, (default)> = [0.]
#                     real_estate_taxes<2023, (default)> = [0. 0. 0. 0.]
#                     filing_status<2023, (default)> = ['JOINT']
#                   medical_expense_deduction<2023, (default)> = [0.]
#                   casualty_loss_deduction<2023, (default)> = [0.]
#                   qualified_business_income_deduction<2023, (default)> = [0.]
#                     qbid_amount<2023, (default)> = [0. 0. 0. 0.]
#                       qualified_business_income<2023, (default)> = [0. 0. 0. 0.]
#                         self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                         partnership_s_corp_income<2023, (default)> = [0. 0. 0. 0.]
#                         farm_income<2023, (default)> = [0. 0. 0. 0.]
#                         farm_rent_income<2023, (default)> = [0. 0. 0. 0.]
#                         self_employment_tax_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                         self_employed_health_insurance_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                         self_employed_pension_contribution_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                         business_is_qualified<2023, (default)> = [False False False False]
#                       w2_wages_from_qualified_business<2023, (default)> = [0. 0. 0. 0.]
#                       unadjusted_basis_qualified_property<2023, (default)> = [0. 0. 0. 0.]
#                       taxable_income_less_qbid<2023, (default)> = [52300.]
#                         adjusted_gross_income<2023, (default)> = [80000.]
#                         charitable_deduction<2023, (default)> = [6000.]
#                         interest_deduction<2023, (default)> = [0.]
#                         salt_deduction<2023, (default)> = [2637.512]
#                         medical_expense_deduction<2023, (default)> = [0.]
#                         casualty_loss_deduction<2023, (default)> = [0.]
#                         standard_deduction<2023, (default)> = [27700.]
#                       filing_status<2023, (default)> = ['JOINT']
#                       business_is_sstb<2023, (default)> = [False False False False]
#                     taxable_income_less_qbid<2023, (default)> = [52300.]
#                     adjusted_net_capital_gain<2023, (default)> = [0.]
#                       net_capital_gain<2023, (default)> = [0.]
#                         net_long_term_capital_gain<2023, (default)> = [0.]
#                           long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                           long_term_capital_losses<2023, (default)> = [0. 0. 0. 0.]
#                         net_short_term_capital_loss<2023, (default)> = [0.]
#                           short_term_capital_losses<2023, (default)> = [0. 0. 0. 0.]
#                           short_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                         qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                       qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                       unrecaptured_section_1250_gain<2023, (default)> = [0.]
#                       capital_gains_28_percent_rate_gain<2023, (default)> = [0.]
#                         long_term_capital_gains_on_collectibles<2023, (default)> = [0. 0. 0. 0.]
#                         long_term_capital_gains_on_small_business_stock<2023, (default)> = [0. 0. 0. 0.]
#                 taxable_income_deductions_if_not_itemizing<2023, (default)> = [27700.]
#                   standard_deduction<2023, (default)> = [27700.]
#                   qualified_business_income_deduction<2023, (default)> = [0.]
#             capital_gains_excluded_from_taxable_income<2023, (default)> = [0.]
#               net_capital_gain<2023, (default)> = [0.]
#               adjusted_net_capital_gain<2023, (default)> = [0.]
#               taxable_income<2023, (default)> = [52300.]
#               filing_status<2023, (default)> = ['JOINT']
#             filing_status<2023, (default)> = ['JOINT']
#           capital_gains_tax<2023, (default)> = [0.]
#             net_capital_gain<2023, (default)> = [0.]
#             taxable_income<2023, (default)> = [52300.]
#             adjusted_net_capital_gain<2023, (default)> = [0.]
#             capital_gains_excluded_from_taxable_income<2023, (default)> = [0.]
#             filing_status<2023, (default)> = ['JOINT']
#             unrecaptured_section_1250_gain<2023, (default)> = [0.]
#             qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#             capital_gains_28_percent_rate_gain<2023, (default)> = [0.]
#           alternative_minimum_tax<2023, (default)> = [0.]
#             c09600<2023, (default)> = [0.]
#               c62100<2023, (default)> = [80000.]
#                 amt_income<2023, (default)> = [80000.]
#                   taxable_income<2023, (default)> = [52300.]
#                   tax_unit_itemizes<2023, (default)> = [False]
#                   standard_deduction<2023, (default)> = [27700.]
#                   salt_deduction<2023, (default)> = [2637.512]
#                   filing_status<2023, (default)> = ['JOINT']
#               filing_status<2023, (default)> = ['JOINT']
#               age_head<2023, (default)> = [38]
#               age_spouse<2023, (default)> = [35]
#               filer_earned<2023, (default)> = [80000.]
#               sep<2023, (default)> = [1]
#               dwks10<2023, (default)> = [0.]
#                 dwks6<2023, (default)> = [0.]
#                   qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                   investment_income_form_4952<2023, (default)> = [0.]
#                 dwks9<2023, (default)> = [0.]
#                   long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                   c23650<2023, (default)> = [0.]
#                   non_sch_d_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   investment_income_form_4952<2023, (default)> = [0.]
#                 long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                 qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                 c23650<2023, (default)> = [0.]
#                 non_sch_d_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                 hasqdivltcg<2023, (default)> = [False]
#                   c01000<2023, (default)> = [0.]
#                   c23650<2023, (default)> = [0.]
#                   long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   non_sch_d_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#               dwks13<2023, (default)> = [0.]
#                 unrecaptured_section_1250_gain<2023, (default)> = [0.]
#                 capital_gains_28_percent_rate_gain<2023, (default)> = [0.]
#                 dwks9<2023, (default)> = [0.]
#                 dwks10<2023, (default)> = [0.]
#                 hasqdivltcg<2023, (default)> = [False]
#               dwks14<2023, (default)> = [0.]
#                 taxable_income<2023, (default)> = [52300.]
#                 dwks13<2023, (default)> = [0.]
#                 hasqdivltcg<2023, (default)> = [False]
#               dwks19<2023, (default)> = [0.]
#                 dwks14<2023, (default)> = [0.]
#                 filing_status<2023, (default)> = ['JOINT']
#                 taxable_income<2023, (default)> = [52300.]
#                 dwks10<2023, (default)> = [0.]
#                 hasqdivltcg<2023, (default)> = [False]
#               unrecaptured_section_1250_gain<2023, (default)> = [0.]
#               sep<2023, (default)> = [1]
#               foreign_tax_credit<2023, (default)> = [0.]
#               amt_form_completed<2023, (default)> = [False]
#               foreign_tax_credit<2023, (default)> = [0.]
#               taxbc<2023, (default)> = [5836.]
#                 regular_tax_before_credits<2023, (default)> = [5836.]
#                   filing_status<2023, (default)> = ['JOINT']
#                   taxable_income<2023, (default)> = [52300.]
#                   dwks14<2023, (default)> = [0.]
#                   dwks13<2023, (default)> = [0.]
#                   dwks19<2023, (default)> = [0.]
#                   dwks9<2023, (default)> = [0.]
#                   unrecaptured_section_1250_gain<2023, (default)> = [0.]
#                   dwks10<2023, (default)> = [0.]
#                   income_tax_main_rates<2023, (default)> = [5836.]
#                   hasqdivltcg<2023, (default)> = [False]
#               c05700<2023, (default)> = [0.]
#         net_investment_income_tax<2023, (default)> = [0.]
#           taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#           dividend_income<2023, (default)> = [0. 0. 0. 0.]
#           c01000<2023, (default)> = [0.]
#           rental_income<2023, (default)> = [0. 0. 0. 0.]
#           filing_status<2023, (default)> = ['JOINT']
#           adjusted_gross_income<2023, (default)> = [80000.]
#         recapture_of_investment_credit<2023, (default)> = [0.]
#         unreported_payroll_tax<2023, (default)> = [0.]
#         qualified_retirement_penalty<2023, (default)> = [0.]
#         income_tax_capped_non_refundable_credits<2023, (default)> = [4200.]
#           income_tax_non_refundable_credits<2023, (default)> = [4200.]
#             cdcc<2023, (default)> = [200.]
#             elderly_disabled_credit<2023, (default)> = [0.]
#             non_refundable_ctc<2023, (default)> = [4000.]
#               ctc<2023, (default)> = [4000.]
#               refundable_ctc<2023, (default)> = [0.]
#             non_refundable_american_opportunity_credit<2023, (default)> = [0.]
#             lifetime_learning_credit<2023, (default)> = [0.]
#             retirement_savings_credit<2023, (default)> = [0.]
#             residential_clean_energy_credit<2023, (default)> = [0.]
#             energy_efficient_home_improvement_credit<2023, (default)> = [0.]
#             new_clean_vehicle_credit<2023, (default)> = [0.]
#             used_clean_vehicle_credit<2023, (default)> = [0.]
#           income_tax_unavailable_non_refundable_credits<2023, (default)> = [0.]
#             income_tax_before_credits<2023, (default)> = [5836.]
#             income_tax_non_refundable_credits<2023, (default)> = [4200.]
#             income_tax_non_refundable_credits<2023, (default)> = [4200.]
#       ma_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         MA<2023, (default)> = [False]
#       md_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         MD<2023, (default)> = [False]
#       ny_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         NY<2023, (default)> = [False]
#       or_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         or_income_tax_before_credits<2023, (default)> = [0.]
#           OR<2023, (default)> = [False]
#         or_non_refundable_credits<2023, (default)> = [0.]
#           or_exemption_credit<2023, (default)> = [0.]
#             OR<2023, (default)> = [False]
#       pa_income_tax<2023, (default)> = [0.]
#       ut_income_tax_before_refundable_credits<2023, (default)> = [2637.512]
#       wa_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         WA<2023, (default)> = [False]
#       flat_tax<2023, (default)> = [0.]
#         positive_agi<2023, (default)> = [80000.]

# %% [markdown]
# #### 3.2.3. Baseline simulation for the high income household

# %%
simulation_b_h = Simulation(
    reform=reform_b,
    situation=situation_high,
)

simulation_b_h.trace = True
simulation_b_h.calculate("household_net_income", 2023)
simulation_b_h.tracer.print_computation_log()
# Out:
#   household_net_income<2023, (default)> = [150505.48]
#     household_market_income<2023, (default)> = [200000.]
#       employment_income<2023, (default)> = [100000. 100000.      0.      0.]
#       self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#       pension_income<2023, (default)> = [0. 0. 0. 0.]
#         tax_exempt_pension_income<2023, (default)> = [0. 0. 0. 0.]
#         taxable_pension_income<2023, (default)> = [0. 0. 0. 0.]
#       dividend_income<2023, (default)> = [0. 0. 0. 0.]
#         qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#         non_qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#       interest_income<2023, (default)> = [0. 0. 0. 0.]
#         tax_exempt_interest_income<2023, (default)> = [0. 0. 0. 0.]
#         taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#       gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#       capital_gains<2023, (default)> = [0. 0. 0. 0.]
#         short_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#         long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#       rental_income<2023, (default)> = [0. 0. 0. 0.]
#       illicit_income<2023, (default)> = [0. 0. 0. 0.]
#       farm_income<2023, (default)> = [0. 0. 0. 0.]
#     household_benefits<2023, (default)> = [0.]
#       social_security<2023, (default)> = [0. 0. 0. 0.]
#         social_security_dependents<2023, (default)> = [0. 0. 0. 0.]
#         social_security_disability<2023, (default)> = [0. 0. 0. 0.]
#         social_security_retirement<2023, (default)> = [0. 0. 0. 0.]
#         social_security_survivors<2023, (default)> = [0. 0. 0. 0.]
#       ssi<2023, (default)> = [0. 0. 0. 0.]
#         uncapped_ssi<2023, (default)> = [0. 0. 0. 0.]
#           ssi_amount_if_eligible<2023, (default)> = [16452. 10968. 10968. 10968.]
#             ssi_claim_is_joint<2023, (default)> = [ True False False False]
#               is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                 is_ssi_aged<2023, (default)> = [False False False False]
#                   age<2023, (default)> = [38. 35. 10. 10.]
#                 is_blind<2023, (default)> = [False False False False]
#                 is_ssi_disabled<2023, (default)> = [False False False False]
#                   is_ssi_aged<2023, (default)> = [False False False False]
#                   is_blind<2023, (default)> = [False False False False]
#                   ssi_reported<2023, (default)> = [0. 0. 0. 0.]
#               ssi_income_deemed_from_ineligible_spouse<2023, (default)> = [50000.     0.     0.     0.]
#                 ssi_earned_income<2023, (default)> = [100000. 100000.      0.      0.]
#                   employment_income<2023, (default)> = [100000. 100000.      0.      0.]
#                   self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                 ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#                   dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                   interest_income<2023, (default)> = [0. 0. 0. 0.]
#                   gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#                   social_security<2023, (default)> = [0. 0. 0. 0.]
#                   alimony_income<2023, (default)> = [0. 0. 0. 0.]
#                   pension_income<2023, (default)> = [0. 0. 0. 0.]
#                   unemployment_compensation<2023, (default)> = [0. 0. 0. 0.]
#                 ssi_earned_income_deemed_from_ineligible_spouse<2023, (default)> = [100000.      0.      0.      0.]
#                   is_ssi_ineligible_spouse<2023, (default)> = [False  True False False]
#                     is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                       is_child<2023, (default)> = [False False  True  True]
#                         age<2023, (default)> = [38. 35. 10. 10.]
#                       is_tax_unit_head<2023, (default)> = [ True False False False]
#                         is_child<2023, (default)> = [False False  True  True]
#                         age<2023, (default)> = [38. 35. 10. 10.]
#                       age<2023, (default)> = [38. 35. 10. 10.]
#                     is_ssi_eligible_spouse<2023, (default)> = [False False False False]
#                       is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                       is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                   ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#                   ssi_earned_income<2023, (default)> = [100000. 100000.      0.      0.]
#                   ssi_ineligible_child_allocation<2023, (default)> = [   0.    0. 5484. 5484.]
#                     ssi_earned_income<2023, (default)> = [100000. 100000.      0.      0.]
#                     ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#                     is_ssi_ineligible_child<2023, (default)> = [False False  True  True]
#                       is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                       is_child<2023, (default)> = [False False  True  True]
#                   is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                 ssi_unearned_income_deemed_from_ineligible_spouse<2023, (default)> = [0. 0. 0. 0.]
#                   is_ssi_ineligible_spouse<2023, (default)> = [False  True False False]
#                   ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#                   ssi_ineligible_child_allocation<2023, (default)> = [   0.    0. 5484. 5484.]
#                 is_ssi_ineligible_child<2023, (default)> = [False False  True  True]
#           meets_ssi_resource_test<2023, (default)> = [ True  True  True  True]
#             ssi_claim_is_joint<2023, (default)> = [ True False False False]
#             ssi_countable_resources<2023, (default)> = [0. 0. 0. 0.]
#           is_ssi_eligible_individual<2023, (default)> = [False False False False]
#             is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#             is_ssi_eligible_spouse<2023, (default)> = [False False False False]
#           ssi_countable_income<2023, (default)> = [0. 0. 0. 0.]
#             ssi_earned_income<2023, (default)> = [100000. 100000.      0.      0.]
#             ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#             ssi_unearned_income_deemed_from_ineligible_parent<2023, (default)> = [0. 0. 0. 0.]
#               is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#               is_child<2023, (default)> = [False False  True  True]
#               is_ssi_ineligible_parent<2023, (default)> = [False False False False]
#                 is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                 is_child<2023, (default)> = [False False  True  True]
#               ssi_earned_income<2023, (default)> = [100000. 100000.      0.      0.]
#               ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#               ssi_ineligible_child_allocation<2023, (default)> = [   0.    0. 5484. 5484.]
#               ssi_ineligible_parent_allocation<2023, (default)> = [0. 0. 0. 0.]
#                 is_ssi_ineligible_parent<2023, (default)> = [False False False False]
#             ssi_income_deemed_from_ineligible_spouse<2023, (default)> = [50000.     0.     0.     0.]
#             is_ssi_eligible_individual<2023, (default)> = [False False False False]
#       state_supplement<2023, (default)> = [0. 0. 0. 0.]
#         uncapped_ssi<2023, (default)> = [0. 0. 0. 0.]
#         maximum_state_supplement<2023, (default)> = [0. 0. 0. 0.]
#           is_ssi_eligible_individual<2023, (default)> = [False False False False]
#           state_code_str<2023, (default)> = ['UT']
#             state_code<2023, (default)> = ['UT']
#               state_name<2023, (default)> = ['UT']
#           state_living_arrangement<2023, (default)> = ['FULL_COST']
#           is_blind<2023, (default)> = [False False False False]
#           is_ssi_aged<2023, (default)> = [False False False False]
#           is_ssi_disabled<2023, (default)> = [False False False False]
#           ssi_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#           ssi_claim_is_joint<2023, (default)> = [ True False False False]
#         is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#         meets_ssi_resource_test<2023, (default)> = [ True  True  True  True]
#         ssi_claim_is_joint<2023, (default)> = [ True False False False]
#       ca_cvrp<2023, (default)> = [0. 0. 0. 0.]
#         CA<2023, (default)> = [False]
#           state_code_str<2023, (default)> = ['UT']
#       snap<2023, (default)> = [0.]
#         snap_normal_allotment<2023, (default)> = [0.]
#           is_snap_eligible<2023, (default)> = [False]
#             meets_snap_net_income_test<2023, (default)> = [False]
#               snap_net_income_fpg_ratio<2023, (default)> = [5.2043333]
#                 snap_net_income<2023, (default)> = [156130.]
#                   snap_gross_income<2023, (default)> = [200000.]
#                     snap_earned_income<2023, (default)> = [200000.]
#                       employment_income<2023, (default)> = [100000. 100000.      0.      0.]
#                       self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                     snap_unearned_income<2023, (default)> = [0.]
#                       dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                       interest_income<2023, (default)> = [0. 0. 0. 0.]
#                       gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#                       social_security<2023, (default)> = [0. 0. 0. 0.]
#                       ssi<2023, (default)> = [0. 0. 0. 0.]
#                   snap_deductions<2023, (default)> = [43870.]
#                     snap_standard_deduction<2023, (default)> = [2316.]
#                       state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#                         state_group<2023, (default)> = ['CONTIGUOUS_US']
#                           state_code<2023, (default)> = ['UT']
#                       spm_unit_size<2023, (default)> = [4]
#                     snap_earned_income_deduction<2023, (default)> = [40000.]
#                       snap_earned_income<2023, (default)> = [200000.]
#                     snap_dependent_care_deduction<2023, (default)> = [1500.]
#                       childcare_expenses<2023, (default)> = [1500.]
#                     snap_child_support_deduction<2023, (default)> = [0.]
#                       child_support_expense<2023, (default)> = [0. 0. 0. 0.]
#                       state_code_str<2023, (default)> = ['UT']
#                     snap_excess_medical_expense_deduction<2023, (default)> = [0.]
#                       is_usda_elderly<2023, (default)> = [False False False False]
#                         age<2023, (default)> = [38. 35. 10. 10.]
#                       is_usda_disabled<2023, (default)> = [False False False False]
#                         is_ssi_disabled<2023, (default)> = [False False False False]
#                         social_security_disability<2023, (default)> = [0. 0. 0. 0.]
#                         is_permanently_disabled_veteran<2023, (default)> = [False False False False]
#                         is_surviving_spouse_of_disabled_veteran<2023, (default)> = [False False False False]
#                         is_surviving_child_of_disabled_veteran<2023, (default)> = [False False False False]
#                       medical_out_of_pocket_expenses<2023, (default)> = [4000.    0.    0.    0.]
#                       state_code_str<2023, (default)> = ['UT']
#                     snap_excess_shelter_expense_deduction<2023, (default)> = [54.]
#                       snap_net_income_pre_shelter<2023, (default)> = [156184.]
#                         snap_gross_income<2023, (default)> = [200000.]
#                         snap_standard_deduction<2023, (default)> = [2316.]
#                         snap_earned_income_deduction<2023, (default)> = [40000.]
#                         snap_dependent_care_deduction<2023, (default)> = [1500.]
#                         snap_child_support_deduction<2023, (default)> = [0.]
#                         snap_excess_medical_expense_deduction<2023, (default)> = [0.]
#                       housing_cost<2023, (default)> = [36000.]
#                       snap_region_str<2023, (default)> = ['CONTIGUOUS_US']
#                         snap_region<2023, (default)> = ['CONTIGUOUS_US']
#                           state_group<2023, (default)> = ['CONTIGUOUS_US']
#                       has_usda_elderly_disabled<2023, (default)> = [False]
#                         is_usda_elderly<2023, (default)> = [False False False False]
#                         is_usda_disabled<2023, (default)> = [False False False False]
#                       snap_utility_allowance<2023, (default)> = [54.]
#                         snap_utility_allowance_type<2023, (default)> = ['IUA']
#                           count_distinct_utility_expenses<2023, (default)> = [1]
#                             heating_cooling_expense<2023, (default)> = [0.]
#                             electricity_expense<2023, (default)> = [0.]
#                             gas_expense<2023, (default)> = [0.]
#                             phone_expense<2023, (default)> = [2400.]
#                               phone_cost<2023, (default)> = [2400.]
#                             trash_expense<2023, (default)> = [0.]
#                             water_expense<2023, (default)> = [0.]
#                             sewage_expense<2023, (default)> = [0.]
#                           snap_utility_region_str<2023, (default)> = ['UT']
#                             snap_utility_region<2023, (default)> = ['UT']
#                               state_code<2023, (default)> = ['UT']
#                           has_heating_cooling_expense<2023, (default)> = [False]
#                             heating_cooling_expense<2023, (default)> = [0.]
#                         snap_utility_region_str<2023, (default)> = ['UT']
#                       state_code_str<2023, (default)> = ['UT']
#                       is_homeless<2023, (default)> = [False]
#                 spm_unit_fpg<2023, (default)> = [30000.]
#                   spm_unit_size<2023, (default)> = [4]
#                   state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#             meets_snap_gross_income_test<2023, (default)> = [False]
#               snap_gross_income_fpg_ratio<2023, (default)> = [6.6666665]
#                 snap_gross_income<2023, (default)> = [200000.]
#                 spm_unit_fpg<2023, (default)> = [30000.]
#               has_usda_elderly_disabled<2023, (default)> = [False]
#             meets_snap_asset_test<2023, (default)> = [ True]
#               has_usda_elderly_disabled<2023, (default)> = [False]
#               snap_assets<2023, (default)> = [0.]
#             meets_snap_categorical_eligibility<2023, (default)> = [False]
#               ssi<2023, (default)> = [0. 0. 0. 0.]
#               is_tanf_non_cash_eligible<2023, (default)> = [False]
#                 meets_tanf_non_cash_gross_income_test<2023, (default)> = [False]
#                   state_code_str<2023, (default)> = ['UT']
#                   snap_gross_income_fpg_ratio<2023, (default)> = [6.6666665]
#                 meets_tanf_non_cash_net_income_test<2023, (default)> = [ True]
#                   state_code_str<2023, (default)> = ['UT']
#                   is_tanf_non_cash_hheod<2023, (default)> = [False]
#                     state_code_str<2023, (default)> = ['UT']
#                     has_all_usda_elderly_disabled<2023, (default)> = [False]
#                       is_usda_elderly<2023, (default)> = [False False False False]
#                       is_usda_disabled<2023, (default)> = [False False False False]
#                     has_usda_elderly_disabled<2023, (default)> = [False]
#                   snap_net_income_fpg_ratio<2023, (default)> = [5.2043333]
#                 meets_tanf_non_cash_asset_test<2023, (default)> = [False]
#                   snap_assets<2023, (default)> = [0.]
#                   state_code_str<2023, (default)> = ['UT']
#           snap_expected_contribution<2023, (default)> = [46839.]
#             snap_net_income<2023, (default)> = [156130.]
#           snap_max_allotment<2023, (default)> = [11268.]
#             snap_region_str<2023, (default)> = ['CONTIGUOUS_US']
#             spm_unit_size<2023, (default)> = [4]
#             spm_unit_size<2023, (default)> = [4]
#           snap_min_allotment<2023, (default)> = [0.]
#             snap_region_str<2023, (default)> = ['CONTIGUOUS_US']
#             spm_unit_size<2023, (default)> = [4]
#         snap_emergency_allotment<2023, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-01, (default)> = [0.]
#             is_snap_eligible<2023, (default)> = [False]
#             snap_max_allotment<2023, (default)> = [11268.]
#             snap_normal_allotment<2023, (default)> = [0.]
#             state_code<2023, (default)> = ['UT']
#           snap_emergency_allotment_monthly<2023-02, (default)> = [0.]
#             is_snap_eligible<2023, (default)> = [False]
#             snap_max_allotment<2023, (default)> = [11268.]
#             snap_normal_allotment<2023, (default)> = [0.]
#             state_code<2023, (default)> = ['UT']
#           snap_emergency_allotment_monthly<2023-03, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-04, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-05, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-06, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-07, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-08, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-09, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-10, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-11, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-12, (default)> = [0.]
#       wic<2023, (default)> = [0. 0. 0. 0.]
#         meets_wic_income_test<2023, (default)> = [False]
#           school_meal_countable_income<2023, (default)> = [200000.]
#             employment_income<2023, (default)> = [100000. 100000.      0.      0.]
#             self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#             dividend_income<2023, (default)> = [0. 0. 0. 0.]
#             interest_income<2023, (default)> = [0. 0. 0. 0.]
#             gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#             social_security<2023, (default)> = [0. 0. 0. 0.]
#             ssi<2023, (default)> = [0. 0. 0. 0.]
#           wic_fpg<2023, (default)> = [30000.]
#             is_pregnant<2023, (default)> = [False False False False]
#             spm_unit_fpg<2023, (default)> = [30000.]
#             state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#         meets_wic_categorical_eligibility<2023, (default)> = [False False False False]
#           snap<2023, (default)> = [0.]
#           tanf<2023, (default)> = [0.]
#             tanf_reported<2023, (default)> = [0. 0. 0. 0.]
#             is_tanf_eligible<2023, (default)> = [False]
#               is_person_demographic_tanf_eligible<2023, (default)> = [False False  True  True]
#                 is_child<2023, (default)> = [False False  True  True]
#                 age<2023, (default)> = [38. 35. 10. 10.]
#                 is_full_time_student<2023, (default)> = [False False  True  True]
#                   is_full_time_college_student<2023, (default)> = [False False False False]
#                   is_in_k12_school<2023, (default)> = [False False  True  True]
#                     age<2023, (default)> = [38. 35. 10. 10.]
#                 is_pregnant<2023, (default)> = [False False False False]
#               is_tanf_enrolled<2023, (default)> = [False]
#               is_tanf_continuous_eligible<2023, (default)> = [False]
#                 tanf_gross_earned_income<2023, (default)> = [200000.]
#                   employment_income<2023, (default)> = [100000. 100000.      0.      0.]
#                   self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                 tanf_gross_unearned_income<2023, (default)> = [0.]
#                   dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                   interest_income<2023, (default)> = [0. 0. 0. 0.]
#                   gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#                   social_security<2023, (default)> = [0. 0. 0. 0.]
#                   ssi<2023, (default)> = [0. 0. 0. 0.]
#                 tanf_max_amount<2023, (default)> = [0.]
#                   spm_unit_size<2023, (default)> = [4]
#                   state_code_str<2023, (default)> = ['UT']
#               is_tanf_initial_eligible<2023, (default)> = [False]
#                 tanf_initial_employment_deduction<2023, (default)> = [0.]
#                   spm_unit_size<2023, (default)> = [4]
#                   state_code_str<2023, (default)> = ['UT']
#                   market_income<2023, (default)> = [100000. 100000.      0.      0.]
#                     employment_income<2023, (default)> = [100000. 100000.      0.      0.]
#                     self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                     pension_income<2023, (default)> = [0. 0. 0. 0.]
#                     dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                     interest_income<2023, (default)> = [0. 0. 0. 0.]
#                     gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#                     capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                     rental_income<2023, (default)> = [0. 0. 0. 0.]
#                     illicit_income<2023, (default)> = [0. 0. 0. 0.]
#                     farm_income<2023, (default)> = [0. 0. 0. 0.]
#                 tanf_gross_earned_income<2023, (default)> = [200000.]
#                 tanf_gross_unearned_income<2023, (default)> = [0.]
#                 tanf_max_amount<2023, (default)> = [0.]
#             tanf_amount_if_eligible<2023, (default)> = [0.]
#               tanf_max_amount<2023, (default)> = [0.]
#               tanf_countable_income<2023, (default)> = [200000.]
#                 state_code_str<2023, (default)> = ['UT']
#                 tanf_gross_unearned_income<2023, (default)> = [0.]
#                 tanf_gross_earned_income<2023, (default)> = [200000.]
#           medicaid<2023, (default)> = [0. 0. 0. 0.]
#             is_medicaid_eligible<2023, (default)> = [False False False False]
#               medicaid_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#                 is_infant_for_medicaid<2023, (default)> = [False False False False]
#                   is_infant_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [6.6666665 6.6666665 6.6666665 6.6666665]
#                       tax_unit_medicaid_income_level<2023, (default)> = [6.6666665]
#                         medicaid_income<2023, (default)> = [200000.]
#                           adjusted_gross_income<2023, (default)> = [200000.]
#                             irs_gross_income<2023, (default)> = [100000. 100000.      0.      0.]
#                               is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                               employment_income<2023, (default)> = [100000. 100000.      0.      0.]
#                               self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                               partnership_s_corp_income<2023, (default)> = [0. 0. 0. 0.]
#                               farm_income<2023, (default)> = [0. 0. 0. 0.]
#                               farm_rent_income<2023, (default)> = [0. 0. 0. 0.]
#                               capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                               taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#                               rental_income<2023, (default)> = [0. 0. 0. 0.]
#                               dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                               taxable_pension_income<2023, (default)> = [0. 0. 0. 0.]
#                               debt_relief<2023, (default)> = [0. 0. 0. 0.]
#                               taxable_unemployment_compensation<2023, (default)> = [0. 0. 0. 0.]
#                                 is_tax_unit_head<2023, (default)> = [ True False False False]
#                                 tax_unit_taxable_unemployment_compensation<2023, (default)> = [0.]
#                                   tax_unit_unemployment_compensation<2023, (default)> = [0.]
#                                     unemployment_compensation<2023, (default)> = [0. 0. 0. 0.]
#                                   taxable_uc_agi<2023, (default)> = [200000.]
#                                     is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                                     employment_income<2023, (default)> = [100000. 100000.      0.      0.]
#                                     self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                     partnership_s_corp_income<2023, (default)> = [0. 0. 0. 0.]
#                                     farm_income<2023, (default)> = [0. 0. 0. 0.]
#                                     farm_rent_income<2023, (default)> = [0. 0. 0. 0.]
#                                     capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                                     taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#                                     rental_income<2023, (default)> = [0. 0. 0. 0.]
#                                     dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                                     taxable_pension_income<2023, (default)> = [0. 0. 0. 0.]
#                                     debt_relief<2023, (default)> = [0. 0. 0. 0.]
#                                     taxable_social_security<2023, (default)> = [0. 0. 0. 0.]
#                                       tax_unit_taxable_social_security<2023, (default)> = [0.]
#                                         tax_unit_social_security<2023, (default)> = [0.]
#                                           social_security<2023, (default)> = [0. 0. 0. 0.]
#                                         taxable_ss_magi<2023, (default)> = [200000.]
#                                           is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                                           employment_income<2023, (default)> = [100000. 100000.      0.      0.]
#                                           self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                           partnership_s_corp_income<2023, (default)> = [0. 0. 0. 0.]
#                                           farm_income<2023, (default)> = [0. 0. 0. 0.]
#                                           farm_rent_income<2023, (default)> = [0. 0. 0. 0.]
#                                           capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                                           taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#                                           rental_income<2023, (default)> = [0. 0. 0. 0.]
#                                           dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                                           taxable_pension_income<2023, (default)> = [0. 0. 0. 0.]
#                                           debt_relief<2023, (default)> = [0. 0. 0. 0.]
#                                           illicit_income<2023, (default)> = [0. 0. 0. 0.]
#                                           unemployment_compensation<2023, (default)> = [0. 0. 0. 0.]
#                                           tax_exempt_interest_income<2023, (default)> = [0. 0. 0. 0.]
#                                           loss_ald<2023, (default)> = [0.]
#                                             filing_status<2023, (default)> = ['JOINT']
#                                               is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                                               tax_unit_dependents<2023, (default)> = [2]
#                                                 is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                                             self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                             maximum_capital_loss<2023, (default)> = [0.]
#                                               tax_unit_capital_loss<2023, (default)> = [0.]
#                                                 capital_loss<2023, (default)> = [0. 0. 0. 0.]
#                                                   capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                                               filing_status<2023, (default)> = ['JOINT']
#                                           self_employment_tax_ald<2023, (default)> = [0.]
#                                             self_employment_tax_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employment_tax<2023, (default)> = [0. 0. 0. 0.]
#                                                 self_employment_social_security_tax<2023, (default)> = [0. 0. 0. 0.]
#                                                   social_security_taxable_self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                                     taxable_self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                                       sey<2023, (default)> = [0. 0. 0. 0.]
#                                                         self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                                         farm_income<2023, (default)> = [0. 0. 0. 0.]
#                                                         k1bx14<2023, (default)> = [0. 0. 0. 0.]
#                                                     taxable_earnings_for_social_security<2023, (default)> = [100000. 100000.      0.      0.]
#                                                       payroll_tax_gross_wages<2023, (default)> = [100000. 100000.      0.      0.]
#                                                         employment_income<2023, (default)> = [100000. 100000.      0.      0.]
#                                                 self_employment_medicare_tax<2023, (default)> = [0. 0. 0. 0.]
#                                                   taxable_self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                           early_withdrawal_penalty<2023, (default)> = [0. 0. 0. 0.]
#                                           alimony_income<2023, (default)> = [0. 0. 0. 0.]
#                                           educator_expense<2023, (default)> = [0. 0. 0. 0.]
#                                           health_savings_account_ald<2023, (default)> = [0.]
#                                           self_employed_health_insurance_ald<2023, (default)> = [0.]
#                                             self_employed_health_insurance_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employed_health_insurance_premiums<2023, (default)> = [0. 0. 0. 0.]
#                                                 is_self_employed<2023, (default)> = [False False False False]
#                                                 health_insurance_premiums<2023, (default)> = [0. 0. 0. 0.]
#                                           self_employed_pension_contribution_ald<2023, (default)> = [0.]
#                                             self_employed_pension_contribution_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employed_pension_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                           ira_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                           sep_simple_qualified_plan_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                         filing_status<2023, (default)> = ['JOINT']
#                                       tax_unit_social_security<2023, (default)> = [0.]
#                                       social_security<2023, (default)> = [0. 0. 0. 0.]
#                                       is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                                       is_tax_unit_head<2023, (default)> = [ True False False False]
#                                     illicit_income<2023, (default)> = [0. 0. 0. 0.]
#                                     loss_ald<2023, (default)> = [0.]
#                                     self_employment_tax_ald<2023, (default)> = [0.]
#                                     student_loan_interest<2023, (default)> = [0. 0. 0. 0.]
#                                     early_withdrawal_penalty<2023, (default)> = [0. 0. 0. 0.]
#                                     alimony_income<2023, (default)> = [0. 0. 0. 0.]
#                                     educator_expense<2023, (default)> = [0. 0. 0. 0.]
#                                     health_savings_account_ald<2023, (default)> = [0.]
#                                     self_employed_health_insurance_ald<2023, (default)> = [0.]
#                                     self_employed_pension_contribution_ald<2023, (default)> = [0.]
#                                     ira_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                     sep_simple_qualified_plan_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                     qualified_adoption_assistance_expense<2023, (default)> = [0. 0. 0. 0.]
#                                     us_bonds_for_higher_ed<2023, (default)> = [0. 0. 0. 0.]
#                                     specified_possession_income<2023, (default)> = [0.]
#                                     puerto_rico_income<2023, (default)> = [0.]
#                                   filing_status<2023, (default)> = ['JOINT']
#                               taxable_social_security<2023, (default)> = [0. 0. 0. 0.]
#                               illicit_income<2023, (default)> = [0. 0. 0. 0.]
#                             above_the_line_deductions<2023, (default)> = [0.]
#                               loss_ald<2023, (default)> = [0.]
#                               self_employment_tax_ald<2023, (default)> = [0.]
#                               student_loan_interest<2023, (default)> = [0. 0. 0. 0.]
#                               early_withdrawal_penalty<2023, (default)> = [0. 0. 0. 0.]
#                               alimony_income<2023, (default)> = [0. 0. 0. 0.]
#                               educator_expense<2023, (default)> = [0. 0. 0. 0.]
#                               health_savings_account_ald<2023, (default)> = [0.]
#                               self_employed_health_insurance_ald<2023, (default)> = [0.]
#                               self_employed_pension_contribution_ald<2023, (default)> = [0.]
#                               ira_contributions<2023, (default)> = [0. 0. 0. 0.]
#                               sep_simple_qualified_plan_contributions<2023, (default)> = [0. 0. 0. 0.]
#                               qualified_adoption_assistance_expense<2023, (default)> = [0. 0. 0. 0.]
#                               us_bonds_for_higher_ed<2023, (default)> = [0. 0. 0. 0.]
#                               specified_possession_income<2023, (default)> = [0.]
#                               puerto_rico_income<2023, (default)> = [0.]
#                           foreign_earned_income_exclusion<2023, (default)> = [0.]
#                           student_loan_interest<2023, (default)> = [0. 0. 0. 0.]
#                           tax_exempt_social_security<2023, (default)> = [0.]
#                             tax_unit_social_security<2023, (default)> = [0.]
#                             tax_unit_taxable_social_security<2023, (default)> = [0.]
#                         tax_unit_fpg<2023, (default)> = [30000.]
#                           tax_unit_size<2023, (default)> = [4]
#                           state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#                     state_code_str<2023, (default)> = ['UT']
#                   is_infant_for_medicaid_nfc<2023, (default)> = [False False False False]
#                     age<2023, (default)> = [38. 35. 10. 10.]
#                 is_young_child_for_medicaid<2023, (default)> = [False False False False]
#                   is_young_child_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [6.6666665 6.6666665 6.6666665 6.6666665]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_young_child_for_medicaid_nfc<2023, (default)> = [False False False False]
#                     age<2023, (default)> = [38. 35. 10. 10.]
#                 is_older_child_for_medicaid<2023, (default)> = [False False False False]
#                   age<2023, (default)> = [38. 35. 10. 10.]
#                   medicaid_income_level<2023, (default)> = [6.6666665 6.6666665 6.6666665 6.6666665]
#                   state_code_str<2023, (default)> = ['UT']
#                 is_young_adult_for_medicaid<2023, (default)> = [False False False False]
#                   is_young_adult_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [6.6666665 6.6666665 6.6666665 6.6666665]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_young_adult_for_medicaid_nfc<2023, (default)> = [False False False False]
#                     age<2023, (default)> = [38. 35. 10. 10.]
#                 is_adult_for_medicaid<2023, (default)> = [False False False False]
#                   is_adult_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [6.6666665 6.6666665 6.6666665 6.6666665]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_adult_for_medicaid_nfc<2023, (default)> = [ True  True False False]
#                     age<2023, (default)> = [38. 35. 10. 10.]
#                 is_parent_for_medicaid<2023, (default)> = [False False False False]
#                   is_parent_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [6.6666665 6.6666665 6.6666665 6.6666665]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_parent_for_medicaid_nfc<2023, (default)> = [ True  True False False]
#                     is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                     tax_unit_count_dependents<2023, (default)> = [2]
#                       is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                 is_pregnant_for_medicaid<2023, (default)> = [False False False False]
#                   is_pregnant_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [6.6666665 6.6666665 6.6666665 6.6666665]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_pregnant_for_medicaid_nfc<2023, (default)> = [False False False False]
#                     is_pregnant<2023, (default)> = [False False False False]
#                     count_days_postpartum<2023, (default)> = [inf inf inf inf]
#                       under_60_days_postpartum<2023, (default)> = [False False False False]
#                       under_12_months_postpartum<2023, (default)> = [False False False False]
#                     state_code_str<2023, (default)> = ['UT']
#                 is_ssi_recipient_for_medicaid<2023, (default)> = [False False False False]
#                   state_code_str<2023, (default)> = ['UT']
#                   ssi<2023, (default)> = [0. 0. 0. 0.]
#             medicaid_benefit_value<2023, (default)> = [9966.585 9966.585 9966.585 9966.585]
#               state_code_str<2023, (default)> = ['UT']
#           is_pregnant<2023, (default)> = [False False False False]
#           wic_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#             is_pregnant<2023, (default)> = [False False False False]
#             is_mother<2023, (default)> = [False False False False]
#               is_female<2023, (default)> = [False False False False]
#               own_children_in_household<2023, (default)> = [0 0 0 0]
#               is_breastfeeding<2023, (default)> = [False False False False]
#             is_breastfeeding<2023, (default)> = [False False False False]
#             age<2023, (default)> = [38. 35. 10. 10.]
#         wic_category_str<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#           wic_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#         is_wic_at_nutritional_risk<2023, (default)> = [False False False False]
#           receives_wic<2023, (default)> = [False False False False]
#           meets_wic_income_test<2023, (default)> = [False]
#           meets_wic_categorical_eligibility<2023, (default)> = [False False False False]
#           wic_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#         would_claim_wic<2023, (default)> = [ True  True  True  True]
#       free_school_meals<2023, (default)> = [0.]
#         school_meal_tier<2023, (default)> = ['PAID']
#           school_meal_fpg_ratio<2023, (default)> = [6.6666665]
#             school_meal_countable_income<2023, (default)> = [200000.]
#             spm_unit_fpg<2023, (default)> = [30000.]
#           meets_school_meal_categorical_eligibility<2023, (default)> = [False]
#             snap<2023, (default)> = [0.]
#             tanf<2023, (default)> = [0.]
#             fdpir<2023, (default)> = [0.]
#         school_meal_net_subsidy<2023, (default)> = [0.]
#           school_meal_daily_subsidy<2023, (default)> = [0.72]
#             state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#             school_meal_tier<2023, (default)> = ['PAID']
#           school_meal_paid_daily_subsidy<2023, (default)> = [0.72]
#             state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#           is_in_k12_school<2023, (default)> = [False False  True  True]
#       reduced_price_school_meals<2023, (default)> = [0.]
#         school_meal_tier<2023, (default)> = ['PAID']
#         school_meal_net_subsidy<2023, (default)> = [0.]
#       lifeline<2023, (default)> = [0.]
#         is_rural<2023, (default)> = [False]
#         is_on_tribal_land<2023, (default)> = [False]
#         phone_cost<2023, (default)> = [2400.]
#         broadband_cost<2023, (default)> = [1200.]
#         is_lifeline_eligible<2023, (default)> = [False]
#           medicaid<2023, (default)> = [0. 0. 0. 0.]
#           snap<2023, (default)> = [0.]
#           ssi<2023, (default)> = [0. 0. 0. 0.]
#           fcc_fpg_ratio<2023, (default)> = [6.6666665]
#             irs_gross_income<2023, (default)> = [100000. 100000.      0.      0.]
#             spm_unit_fpg<2023, (default)> = [30000.]
#       acp<2023, (default)> = [0.]
#         is_acp_eligible<2023, (default)> = [False]
#           lifeline<2023, (default)> = [0.]
#           free_school_meals<2023, (default)> = [0.]
#           reduced_price_school_meals<2023, (default)> = [0.]
#           pell_grant<2023, (default)> = [0.]
#           wic<2023, (default)> = [0. 0. 0. 0.]
#           medicaid<2023, (default)> = [0. 0. 0. 0.]
#           snap<2023, (default)> = [0.]
#           ssi<2023, (default)> = [0. 0. 0. 0.]
#           fcc_fpg_ratio<2023, (default)> = [6.6666665]
#           ebb<2023, (default)> = [0.]
#             is_ebb_eligible<2023, (default)> = [False]
#               is_lifeline_eligible<2023, (default)> = [False]
#               free_school_meals<2023, (default)> = [0.]
#               reduced_price_school_meals<2023, (default)> = [0.]
#               pell_grant<2023, (default)> = [0.]
#               experienced_covid_income_loss<2023, (default)> = [False]
#               enrolled_in_ebb<2023, (default)> = [False]
#             broadband_cost_after_lifeline<2023, (default)> = [1200.]
#               broadband_cost<2023, (default)> = [1200.]
#               lifeline<2023, (default)> = [0.]
#             is_on_tribal_land<2023, (default)> = [False]
#         broadband_cost_after_lifeline<2023, (default)> = [1200.]
#         is_on_tribal_land<2023, (default)> = [False]
#       ebb<2023, (default)> = [0.]
#       tanf<2023, (default)> = [0.]
#       high_efficiency_electric_home_rebate<2023, (default)> = [0.]
#         capped_electric_heat_pump_clothes_dryer_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#             tax_unit_income_ami_ratio<2023, (default)> = [0.]
#           electric_heat_pump_clothes_dryer_expenditures<2023, (default)> = [0.]
#         capped_electric_load_service_center_upgrade_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           electric_load_service_center_upgrade_expenditures<2023, (default)> = [0.]
#         capped_electric_stove_cooktop_range_or_oven_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           electric_stove_cooktop_range_or_oven_expenditures<2023, (default)> = [0.]
#         capped_electric_wiring_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           electric_wiring_expenditures<2023, (default)> = [0.]
#         capped_heat_pump_water_heater_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           heat_pump_water_heater_expenditures<2023, (default)> = [0.]
#         capped_heat_pump_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           heat_pump_expenditures<2023, (default)> = [0.]
#         capped_insulation_air_sealing_ventilation_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           energy_efficient_insulation_expenditures<2023, (default)> = [0.]
#           air_sealing_ventilation_expenditures<2023, (default)> = [0.]
#       residential_efficiency_electrification_rebate<2023, (default)> = [0.]
#         residential_efficiency_electrification_retrofit_expenditures<2023, (default)> = [0.]
#         residential_efficiency_electrification_retrofit_energy_savings<2023, (default)> = [0.]
#         current_home_energy_use<2023, (default)> = [0.]
#         household_income_ami_ratio<2023, (default)> = [0.]
#         average_home_energy_use_in_state<2023, (default)> = [0.]
#       basic_income<2023, (default)> = [0.]
#         basic_income_eligible<2023, (default)> = [ True]
#         basic_income_before_phase_out<2023, (default)> = [0.]
#           tax_unit_size<2023, (default)> = [4]
#           age<2023, (default)> = [38. 35. 10. 10.]
#           tax_unit_fpg<2023, (default)> = [30000.]
#         basic_income_phase_out<2023, (default)> = [0.]
#           basic_income_before_phase_out<2023, (default)> = [0.]
#           adjusted_gross_income<2023, (default)> = [200000.]
#           filing_status<2023, (default)> = ['JOINT']
#       spm_unit_capped_housing_subsidy<2023, (default)> = [0.]
#         spm_unit_capped_housing_subsidy_reported<2023, (default)> = [0.]
#     household_refundable_tax_credits<2023, (default)> = [0.]
#       income_tax_refundable_credits<2023, (default)> = [0.]
#         eitc<2023, (default)> = [0.]
#           earned_income_tax_credit<2023, (default)> = [0.]
#             eitc_eligible<2023, (default)> = [ True]
#               is_child<2023, (default)> = [False False  True  True]
#               age<2023, (default)> = [38. 35. 10. 10.]
#               tax_exempt_interest_income<2023, (default)> = [0. 0. 0. 0.]
#               taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#               dividend_income<2023, (default)> = [0. 0. 0. 0.]
#               c01000<2023, (default)> = [0.]
#                 sep<2023, (default)> = [1]
#                 c23650<2023, (default)> = [0.]
#                   long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   short_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#               tax_unit_rental_income<2023, (default)> = [0.]
#                 rental_income<2023, (default)> = [0. 0. 0. 0.]
# ...
#                               income_tax_unavailable_non_refundable_credits<2023, (not_itemizing)> = [0.]
#                                 income_tax_before_credits<2023, (not_itemizing)> = [28521.]
#                                 income_tax_non_refundable_credits<2023, (not_itemizing)> = [4300.]
#                                 income_tax_non_refundable_credits<2023, (not_itemizing)> = [4300.]
#                           income_tax_refundable_credits<2023, (not_itemizing)> = [0.]
#                       state_income_tax<2023, (not_itemizing)> = [10017.512]
#                 taxable_income_deductions_if_itemizing<2023, (default)> = [30000.]
#                   charitable_deduction<2023, (default)> = [20000.]
#                   interest_deduction<2023, (default)> = [0.]
#                   salt_deduction<2023, (default)> = [10000.]
#                     state_and_local_sales_or_income_tax<2023, (default)> = [10479.512]
#                       state_income_tax<2023, (default)> = [10479.512]
#                         ma_income_tax<2023, (default)> = [0.]
#                           MA<2023, (default)> = [False]
#                         md_income_tax<2023, (default)> = [0.]
#                           MD<2023, (default)> = [False]
#                         ny_income_tax<2023, (default)> = [0.]
#                           NY<2023, (default)> = [False]
#                         or_income_tax<2023, (default)> = [0.]
#                           OR<2023, (default)> = [False]
#                         pa_income_tax<2023, (default)> = [0.]
#                           PA<2023, (default)> = [False]
#                             state_code_str<2023, (default)> = ['UT']
#                         wa_income_tax<2023, (default)> = [0.]
#                           WA<2023, (default)> = [False]
#                         ut_income_tax<2023, (default)> = [10479.512]
#                           UT<2023, (default)> = [ True]
#                           ut_income_tax_before_refundable_credits<2023, (default)> = [10479.512]
#                             ut_income_tax_after_credits<2023, (default)> = [10479.512]
#                               ut_income_tax_before_credits<2023, (default)> = [9700.]
#                                 UT<2023, (default)> = [ True]
#                                 ut_taxable_income<2023, (default)> = [200000.]
#                                   UT<2023, (default)> = [ True]
#                                   ut_total_income<2023, (default)> = [200000.]
#                                     UT<2023, (default)> = [ True]
#                                     adjusted_gross_income<2023, (default)> = [200000.]
#                                     ut_additions_to_income<2023, (default)> = [0.]
#                                       UT<2023, (default)> = [ True]
#                                   salt_refund_last_year<2023, (default)> = [0.]
#                                   ut_subtractions_from_income<2023, (default)> = [0.]
#                                     UT<2023, (default)> = [ True]
#                               ut_taxpayer_credit<2023, (default)> = [-779.51196]
#                                 UT<2023, (default)> = [ True]
#                                 ut_taxpayer_credit_max<2023, (default)> = [1416.24]
#                                   UT<2023, (default)> = [ True]
#                                   tax_unit_count_dependents<2023, (default)> = [2]
#                                   tax_unit_itemizes<2023, (default)> = [ True]
#                                   standard_deduction<2023, (default)> = [27700.]
#                                   charitable_deduction<2023, (default)> = [20000.]
#                                   interest_deduction<2023, (default)> = [0.]
#                                   medical_expense_deduction<2023, (default)> = [0.]
#                                   casualty_loss_deduction<2023, (default)> = [0.]
#                                 ut_taxpayer_credit_reduction<2023, (default)> = [2195.752]
#                                   UT<2023, (default)> = [ True]
#                                   filing_status<2023, (default)> = ['JOINT']
#                                   ut_taxable_income<2023, (default)> = [200000.]
#                             ut_apportionable_nonrefundable_credits<2023, (default)> = [0.]
#                               UT<2023, (default)> = [ True]
#                             ut_nonapportionable_nonrefundable_credits<2023, (default)> = [0.]
#                               UT<2023, (default)> = [ True]
#                             ut_recapture_low_inc_housing_credit<2023, (default)> = [0.]
#                               UT<2023, (default)> = [ True]
#                           ut_refundable_credits<2023, (default)> = [0.]
#                       local_income_tax<2023, (default)> = [0.]
#                       state_sales_tax<2023, (default)> = [0.]
#                       local_sales_tax<2023, (default)> = [0.]
#                     real_estate_taxes<2023, (default)> = [0. 0. 0. 0.]
#                     filing_status<2023, (default)> = ['JOINT']
#                   medical_expense_deduction<2023, (default)> = [0.]
#                   casualty_loss_deduction<2023, (default)> = [0.]
#                   qualified_business_income_deduction<2023, (default)> = [0.]
#                     qbid_amount<2023, (default)> = [0. 0. 0. 0.]
#                       qualified_business_income<2023, (default)> = [0. 0. 0. 0.]
#                         self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                         partnership_s_corp_income<2023, (default)> = [0. 0. 0. 0.]
#                         farm_income<2023, (default)> = [0. 0. 0. 0.]
#                         farm_rent_income<2023, (default)> = [0. 0. 0. 0.]
#                         self_employment_tax_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                         self_employed_health_insurance_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                         self_employed_pension_contribution_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                         business_is_qualified<2023, (default)> = [False False False False]
#                       w2_wages_from_qualified_business<2023, (default)> = [0. 0. 0. 0.]
#                       unadjusted_basis_qualified_property<2023, (default)> = [0. 0. 0. 0.]
#                       taxable_income_less_qbid<2023, (default)> = [170000.]
#                         adjusted_gross_income<2023, (default)> = [200000.]
#                         charitable_deduction<2023, (default)> = [20000.]
#                         interest_deduction<2023, (default)> = [0.]
#                         salt_deduction<2023, (default)> = [10000.]
#                         medical_expense_deduction<2023, (default)> = [0.]
#                         casualty_loss_deduction<2023, (default)> = [0.]
#                         standard_deduction<2023, (default)> = [27700.]
#                       filing_status<2023, (default)> = ['JOINT']
#                       business_is_sstb<2023, (default)> = [False False False False]
#                     taxable_income_less_qbid<2023, (default)> = [170000.]
#                     adjusted_net_capital_gain<2023, (default)> = [0.]
#                       net_capital_gain<2023, (default)> = [0.]
#                         net_long_term_capital_gain<2023, (default)> = [0.]
#                           long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                           long_term_capital_losses<2023, (default)> = [0. 0. 0. 0.]
#                         net_short_term_capital_loss<2023, (default)> = [0.]
#                           short_term_capital_losses<2023, (default)> = [0. 0. 0. 0.]
#                           short_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                         qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                       qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                       unrecaptured_section_1250_gain<2023, (default)> = [0.]
#                       capital_gains_28_percent_rate_gain<2023, (default)> = [0.]
#                         long_term_capital_gains_on_collectibles<2023, (default)> = [0. 0. 0. 0.]
#                         long_term_capital_gains_on_small_business_stock<2023, (default)> = [0. 0. 0. 0.]
#                 taxable_income_deductions_if_not_itemizing<2023, (default)> = [27700.]
#                   standard_deduction<2023, (default)> = [27700.]
#                   qualified_business_income_deduction<2023, (default)> = [0.]
#             capital_gains_excluded_from_taxable_income<2023, (default)> = [0.]
#               net_capital_gain<2023, (default)> = [0.]
#               adjusted_net_capital_gain<2023, (default)> = [0.]
#               taxable_income<2023, (default)> = [170000.]
#               filing_status<2023, (default)> = ['JOINT']
#             filing_status<2023, (default)> = ['JOINT']
#           capital_gains_tax<2023, (default)> = [0.]
#             net_capital_gain<2023, (default)> = [0.]
#             taxable_income<2023, (default)> = [170000.]
#             adjusted_net_capital_gain<2023, (default)> = [0.]
#             capital_gains_excluded_from_taxable_income<2023, (default)> = [0.]
#             filing_status<2023, (default)> = ['JOINT']
#             unrecaptured_section_1250_gain<2023, (default)> = [0.]
#             qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#             capital_gains_28_percent_rate_gain<2023, (default)> = [0.]
#           alternative_minimum_tax<2023, (default)> = [0.]
#             c09600<2023, (default)> = [0.]
#               c62100<2023, (default)> = [180000.]
#                 amt_income<2023, (default)> = [180000.]
#                   taxable_income<2023, (default)> = [170000.]
#                   tax_unit_itemizes<2023, (default)> = [ True]
#                   standard_deduction<2023, (default)> = [27700.]
#                   salt_deduction<2023, (default)> = [10000.]
#                   filing_status<2023, (default)> = ['JOINT']
#               filing_status<2023, (default)> = ['JOINT']
#               age_head<2023, (default)> = [38]
#               age_spouse<2023, (default)> = [35]
#               filer_earned<2023, (default)> = [200000.]
#               sep<2023, (default)> = [1]
#               dwks10<2023, (default)> = [0.]
#                 dwks6<2023, (default)> = [0.]
#                   qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                   investment_income_form_4952<2023, (default)> = [0.]
#                 dwks9<2023, (default)> = [0.]
#                   long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                   c23650<2023, (default)> = [0.]
#                   non_sch_d_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   investment_income_form_4952<2023, (default)> = [0.]
#                 long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                 qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                 c23650<2023, (default)> = [0.]
#                 non_sch_d_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                 hasqdivltcg<2023, (default)> = [False]
#                   c01000<2023, (default)> = [0.]
#                   c23650<2023, (default)> = [0.]
#                   long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   non_sch_d_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#               dwks13<2023, (default)> = [0.]
#                 unrecaptured_section_1250_gain<2023, (default)> = [0.]
#                 capital_gains_28_percent_rate_gain<2023, (default)> = [0.]
#                 dwks9<2023, (default)> = [0.]
#                 dwks10<2023, (default)> = [0.]
#                 hasqdivltcg<2023, (default)> = [False]
#               dwks14<2023, (default)> = [0.]
#                 taxable_income<2023, (default)> = [170000.]
#                 dwks13<2023, (default)> = [0.]
#                 hasqdivltcg<2023, (default)> = [False]
#               dwks19<2023, (default)> = [0.]
#                 dwks14<2023, (default)> = [0.]
#                 filing_status<2023, (default)> = ['JOINT']
#                 taxable_income<2023, (default)> = [170000.]
#                 dwks10<2023, (default)> = [0.]
#                 hasqdivltcg<2023, (default)> = [False]
#               unrecaptured_section_1250_gain<2023, (default)> = [0.]
#               sep<2023, (default)> = [1]
#               foreign_tax_credit<2023, (default)> = [0.]
#               amt_form_completed<2023, (default)> = [False]
#               foreign_tax_credit<2023, (default)> = [0.]
#               taxbc<2023, (default)> = [28015.]
#                 regular_tax_before_credits<2023, (default)> = [28015.]
#                   filing_status<2023, (default)> = ['JOINT']
#                   taxable_income<2023, (default)> = [170000.]
#                   dwks14<2023, (default)> = [0.]
#                   dwks13<2023, (default)> = [0.]
#                   dwks19<2023, (default)> = [0.]
#                   dwks9<2023, (default)> = [0.]
#                   unrecaptured_section_1250_gain<2023, (default)> = [0.]
#                   dwks10<2023, (default)> = [0.]
#                   income_tax_main_rates<2023, (default)> = [28015.]
#                   hasqdivltcg<2023, (default)> = [False]
#               c05700<2023, (default)> = [0.]
#         net_investment_income_tax<2023, (default)> = [0.]
#           taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#           dividend_income<2023, (default)> = [0. 0. 0. 0.]
#           c01000<2023, (default)> = [0.]
#           rental_income<2023, (default)> = [0. 0. 0. 0.]
#           filing_status<2023, (default)> = ['JOINT']
#           adjusted_gross_income<2023, (default)> = [200000.]
#         recapture_of_investment_credit<2023, (default)> = [0.]
#         unreported_payroll_tax<2023, (default)> = [0.]
#         qualified_retirement_penalty<2023, (default)> = [0.]
#         income_tax_capped_non_refundable_credits<2023, (default)> = [4300.]
#           income_tax_non_refundable_credits<2023, (default)> = [4300.]
#             cdcc<2023, (default)> = [300.]
#             elderly_disabled_credit<2023, (default)> = [0.]
#             non_refundable_ctc<2023, (default)> = [4000.]
#               ctc<2023, (default)> = [4000.]
#               refundable_ctc<2023, (default)> = [0.]
#             non_refundable_american_opportunity_credit<2023, (default)> = [0.]
#             lifetime_learning_credit<2023, (default)> = [0.]
#             retirement_savings_credit<2023, (default)> = [0.]
#             residential_clean_energy_credit<2023, (default)> = [0.]
#             energy_efficient_home_improvement_credit<2023, (default)> = [0.]
#             new_clean_vehicle_credit<2023, (default)> = [0.]
#             used_clean_vehicle_credit<2023, (default)> = [0.]
#           income_tax_unavailable_non_refundable_credits<2023, (default)> = [0.]
#             income_tax_before_credits<2023, (default)> = [28015.]
#             income_tax_non_refundable_credits<2023, (default)> = [4300.]
#             income_tax_non_refundable_credits<2023, (default)> = [4300.]
#       ma_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         MA<2023, (default)> = [False]
#       md_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         MD<2023, (default)> = [False]
#       ny_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         NY<2023, (default)> = [False]
#       or_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         or_income_tax_before_credits<2023, (default)> = [0.]
#           OR<2023, (default)> = [False]
#         or_non_refundable_credits<2023, (default)> = [0.]
#           or_exemption_credit<2023, (default)> = [0.]
#             OR<2023, (default)> = [False]
#       pa_income_tax<2023, (default)> = [0.]
#       ut_income_tax_before_refundable_credits<2023, (default)> = [10479.512]
#       wa_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         WA<2023, (default)> = [False]
#       flat_tax<2023, (default)> = [0.]
#         positive_agi<2023, (default)> = [200000.]

# %% [markdown]
# ### 3.3. Effects on three household types of rate cut to 4.65%

# %% [markdown]
# #### 3.3.1. Effect of rate cut to 4.65% on low income household

# %%
def modify_parameters_1(parameters):
    parameters.gov.states.ut.tax.income.rate.update(
        start=instant("2022-01-01"),
        stop=instant("2028-12-31"),
        value=0.0465
    )
    return parameters

class reform_1(Reform):
    def apply(self):
        self.modify_parameters(modify_parameters_1)

simulation_1_l = Simulation(
    reform=reform_1,
    situation=situation_low,
)

simulation_1_l.trace = True
simulation_1_l.calculate("household_net_income", 2023)
simulation_1_l.tracer.print_computation_log()
# Out:
#   household_net_income<2023, (default)> = [42138.2]
#     household_market_income<2023, (default)> = [25000.]
#       employment_income<2023, (default)> = [25000.     0.     0.     0.]
#       self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#       pension_income<2023, (default)> = [0. 0. 0. 0.]
#         tax_exempt_pension_income<2023, (default)> = [0. 0. 0. 0.]
#         taxable_pension_income<2023, (default)> = [0. 0. 0. 0.]
#       dividend_income<2023, (default)> = [0. 0. 0. 0.]
#         qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#         non_qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#       interest_income<2023, (default)> = [0. 0. 0. 0.]
#         tax_exempt_interest_income<2023, (default)> = [0. 0. 0. 0.]
#         taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#       gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#       capital_gains<2023, (default)> = [0. 0. 0. 0.]
#         short_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#         long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#       rental_income<2023, (default)> = [0. 0. 0. 0.]
#       illicit_income<2023, (default)> = [0. 0. 0. 0.]
#       farm_income<2023, (default)> = [0. 0. 0. 0.]
#     household_benefits<2023, (default)> = [9246.7]
#       social_security<2023, (default)> = [0. 0. 0. 0.]
#         social_security_dependents<2023, (default)> = [0. 0. 0. 0.]
#         social_security_disability<2023, (default)> = [0. 0. 0. 0.]
#         social_security_retirement<2023, (default)> = [0. 0. 0. 0.]
#         social_security_survivors<2023, (default)> = [0. 0. 0. 0.]
#       ssi<2023, (default)> = [0. 0. 0. 0.]
#         uncapped_ssi<2023, (default)> = [0. 0. 0. 0.]
#           ssi_amount_if_eligible<2023, (default)> = [10968. 10968. 10968. 10968.]
#             ssi_claim_is_joint<2023, (default)> = [False False False False]
#               is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                 is_ssi_aged<2023, (default)> = [False False False False]
#                   age<2023, (default)> = [38. 35. 10.  6.]
#                 is_blind<2023, (default)> = [False False False False]
#                 is_ssi_disabled<2023, (default)> = [False False False False]
#                   is_ssi_aged<2023, (default)> = [False False False False]
#                   is_blind<2023, (default)> = [False False False False]
#                   ssi_reported<2023, (default)> = [0. 0. 0. 0.]
#               ssi_income_deemed_from_ineligible_spouse<2023, (default)> = [0. 0. 0. 0.]
#                 ssi_earned_income<2023, (default)> = [25000.     0.     0.     0.]
#                   employment_income<2023, (default)> = [25000.     0.     0.     0.]
#                   self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                 ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#                   dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                   interest_income<2023, (default)> = [0. 0. 0. 0.]
#                   gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#                   social_security<2023, (default)> = [0. 0. 0. 0.]
#                   alimony_income<2023, (default)> = [0. 0. 0. 0.]
#                   pension_income<2023, (default)> = [0. 0. 0. 0.]
#                   unemployment_compensation<2023, (default)> = [0. 0. 0. 0.]
#                 ssi_earned_income_deemed_from_ineligible_spouse<2023, (default)> = [0. 0. 0. 0.]
#                   is_ssi_ineligible_spouse<2023, (default)> = [False  True False False]
#                     is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                       is_child<2023, (default)> = [False False  True  True]
#                         age<2023, (default)> = [38. 35. 10.  6.]
#                       is_tax_unit_head<2023, (default)> = [ True False False False]
#                         is_child<2023, (default)> = [False False  True  True]
#                         age<2023, (default)> = [38. 35. 10.  6.]
#                       age<2023, (default)> = [38. 35. 10.  6.]
#                     is_ssi_eligible_spouse<2023, (default)> = [False False False False]
#                       is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                       is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                   ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#                   ssi_earned_income<2023, (default)> = [25000.     0.     0.     0.]
#                   ssi_ineligible_child_allocation<2023, (default)> = [   0.    0. 5484. 5484.]
#                     ssi_earned_income<2023, (default)> = [25000.     0.     0.     0.]
#                     ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#                     is_ssi_ineligible_child<2023, (default)> = [False False  True  True]
#                       is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                       is_child<2023, (default)> = [False False  True  True]
#                   is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                 ssi_unearned_income_deemed_from_ineligible_spouse<2023, (default)> = [0. 0. 0. 0.]
#                   is_ssi_ineligible_spouse<2023, (default)> = [False  True False False]
#                   ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#                   ssi_ineligible_child_allocation<2023, (default)> = [   0.    0. 5484. 5484.]
#                 is_ssi_ineligible_child<2023, (default)> = [False False  True  True]
#           meets_ssi_resource_test<2023, (default)> = [ True  True  True  True]
#             ssi_claim_is_joint<2023, (default)> = [False False False False]
#             ssi_countable_resources<2023, (default)> = [0. 0. 0. 0.]
#           is_ssi_eligible_individual<2023, (default)> = [False False False False]
#             is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#             is_ssi_eligible_spouse<2023, (default)> = [False False False False]
#           ssi_countable_income<2023, (default)> = [0. 0. 0. 0.]
#             ssi_earned_income<2023, (default)> = [25000.     0.     0.     0.]
#             ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#             ssi_unearned_income_deemed_from_ineligible_parent<2023, (default)> = [0. 0. 0. 0.]
#               is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#               is_child<2023, (default)> = [False False  True  True]
#               is_ssi_ineligible_parent<2023, (default)> = [False False False False]
#                 is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                 is_child<2023, (default)> = [False False  True  True]
#               ssi_earned_income<2023, (default)> = [25000.     0.     0.     0.]
#               ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#               ssi_ineligible_child_allocation<2023, (default)> = [   0.    0. 5484. 5484.]
#               ssi_ineligible_parent_allocation<2023, (default)> = [0. 0. 0. 0.]
#                 is_ssi_ineligible_parent<2023, (default)> = [False False False False]
#             ssi_income_deemed_from_ineligible_spouse<2023, (default)> = [0. 0. 0. 0.]
#             is_ssi_eligible_individual<2023, (default)> = [False False False False]
#       state_supplement<2023, (default)> = [0. 0. 0. 0.]
#         uncapped_ssi<2023, (default)> = [0. 0. 0. 0.]
#         maximum_state_supplement<2023, (default)> = [0. 0. 0. 0.]
#           is_ssi_eligible_individual<2023, (default)> = [False False False False]
#           state_code_str<2023, (default)> = ['UT']
#             state_code<2023, (default)> = ['UT']
#               state_name<2023, (default)> = ['UT']
#           state_living_arrangement<2023, (default)> = ['FULL_COST']
#           is_blind<2023, (default)> = [False False False False]
#           is_ssi_aged<2023, (default)> = [False False False False]
#           is_ssi_disabled<2023, (default)> = [False False False False]
#           ssi_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#           ssi_claim_is_joint<2023, (default)> = [False False False False]
#         is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#         meets_ssi_resource_test<2023, (default)> = [ True  True  True  True]
#         ssi_claim_is_joint<2023, (default)> = [False False False False]
#       ca_cvrp<2023, (default)> = [0. 0. 0. 0.]
#         CA<2023, (default)> = [False]
#           state_code_str<2023, (default)> = ['UT']
#       snap<2023, (default)> = [6860.5]
#         snap_normal_allotment<2023, (default)> = [5979.]
#           is_snap_eligible<2023, (default)> = [ True]
#             meets_snap_net_income_test<2023, (default)> = [ True]
#               snap_net_income_fpg_ratio<2023, (default)> = [0.5876667]
#                 snap_net_income<2023, (default)> = [17630.]
#                   snap_gross_income<2023, (default)> = [25000.]
#                     snap_earned_income<2023, (default)> = [25000.]
#                       employment_income<2023, (default)> = [25000.     0.     0.     0.]
#                       self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                     snap_unearned_income<2023, (default)> = [0.]
#                       dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                       interest_income<2023, (default)> = [0. 0. 0. 0.]
#                       gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#                       social_security<2023, (default)> = [0. 0. 0. 0.]
#                       ssi<2023, (default)> = [0. 0. 0. 0.]
#                   snap_deductions<2023, (default)> = [7370.]
#                     snap_standard_deduction<2023, (default)> = [2316.]
#                       state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#                         state_group<2023, (default)> = ['CONTIGUOUS_US']
#                           state_code<2023, (default)> = ['UT']
#                       spm_unit_size<2023, (default)> = [4]
#                     snap_earned_income_deduction<2023, (default)> = [5000.]
#                       snap_earned_income<2023, (default)> = [25000.]
#                     snap_dependent_care_deduction<2023, (default)> = [0.]
#                       childcare_expenses<2023, (default)> = [0.]
#                     snap_child_support_deduction<2023, (default)> = [0.]
#                       child_support_expense<2023, (default)> = [0. 0. 0. 0.]
#                       state_code_str<2023, (default)> = ['UT']
#                     snap_excess_medical_expense_deduction<2023, (default)> = [0.]
#                       is_usda_elderly<2023, (default)> = [False False False False]
#                         age<2023, (default)> = [38. 35. 10.  6.]
#                       is_usda_disabled<2023, (default)> = [False False False False]
#                         is_ssi_disabled<2023, (default)> = [False False False False]
#                         social_security_disability<2023, (default)> = [0. 0. 0. 0.]
#                         is_permanently_disabled_veteran<2023, (default)> = [False False False False]
#                         is_surviving_spouse_of_disabled_veteran<2023, (default)> = [False False False False]
#                         is_surviving_child_of_disabled_veteran<2023, (default)> = [False False False False]
#                       medical_out_of_pocket_expenses<2023, (default)> = [200.   0.   0.   0.]
#                       state_code_str<2023, (default)> = ['UT']
#                     snap_excess_shelter_expense_deduction<2023, (default)> = [54.]
#                       snap_net_income_pre_shelter<2023, (default)> = [17684.]
#                         snap_gross_income<2023, (default)> = [25000.]
#                         snap_standard_deduction<2023, (default)> = [2316.]
#                         snap_earned_income_deduction<2023, (default)> = [5000.]
#                         snap_dependent_care_deduction<2023, (default)> = [0.]
#                         snap_child_support_deduction<2023, (default)> = [0.]
#                         snap_excess_medical_expense_deduction<2023, (default)> = [0.]
#                       housing_cost<2023, (default)> = [8000.]
#                       snap_region_str<2023, (default)> = ['CONTIGUOUS_US']
#                         snap_region<2023, (default)> = ['CONTIGUOUS_US']
#                           state_group<2023, (default)> = ['CONTIGUOUS_US']
#                       has_usda_elderly_disabled<2023, (default)> = [False]
#                         is_usda_elderly<2023, (default)> = [False False False False]
#                         is_usda_disabled<2023, (default)> = [False False False False]
#                       snap_utility_allowance<2023, (default)> = [54.]
#                         snap_utility_allowance_type<2023, (default)> = ['IUA']
#                           count_distinct_utility_expenses<2023, (default)> = [1]
#                             heating_cooling_expense<2023, (default)> = [0.]
#                             electricity_expense<2023, (default)> = [0.]
#                             gas_expense<2023, (default)> = [0.]
#                             phone_expense<2023, (default)> = [700.]
#                               phone_cost<2023, (default)> = [700.]
#                             trash_expense<2023, (default)> = [0.]
#                             water_expense<2023, (default)> = [0.]
#                             sewage_expense<2023, (default)> = [0.]
#                           snap_utility_region_str<2023, (default)> = ['UT']
#                             snap_utility_region<2023, (default)> = ['UT']
#                               state_code<2023, (default)> = ['UT']
#                           has_heating_cooling_expense<2023, (default)> = [False]
#                             heating_cooling_expense<2023, (default)> = [0.]
#                         snap_utility_region_str<2023, (default)> = ['UT']
#                       state_code_str<2023, (default)> = ['UT']
#                       is_homeless<2023, (default)> = [False]
#                 spm_unit_fpg<2023, (default)> = [30000.]
#                   spm_unit_size<2023, (default)> = [4]
#                   state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#             meets_snap_gross_income_test<2023, (default)> = [ True]
#               snap_gross_income_fpg_ratio<2023, (default)> = [0.8333333]
#                 snap_gross_income<2023, (default)> = [25000.]
#                 spm_unit_fpg<2023, (default)> = [30000.]
#               has_usda_elderly_disabled<2023, (default)> = [False]
#             meets_snap_asset_test<2023, (default)> = [ True]
#               has_usda_elderly_disabled<2023, (default)> = [False]
#               snap_assets<2023, (default)> = [0.]
#             meets_snap_categorical_eligibility<2023, (default)> = [False]
#               ssi<2023, (default)> = [0. 0. 0. 0.]
#               is_tanf_non_cash_eligible<2023, (default)> = [False]
#                 meets_tanf_non_cash_gross_income_test<2023, (default)> = [False]
#                   state_code_str<2023, (default)> = ['UT']
#                   snap_gross_income_fpg_ratio<2023, (default)> = [0.8333333]
#                 meets_tanf_non_cash_net_income_test<2023, (default)> = [ True]
#                   state_code_str<2023, (default)> = ['UT']
#                   is_tanf_non_cash_hheod<2023, (default)> = [False]
#                     state_code_str<2023, (default)> = ['UT']
#                     has_all_usda_elderly_disabled<2023, (default)> = [False]
#                       is_usda_elderly<2023, (default)> = [False False False False]
#                       is_usda_disabled<2023, (default)> = [False False False False]
#                     has_usda_elderly_disabled<2023, (default)> = [False]
#                   snap_net_income_fpg_ratio<2023, (default)> = [0.5876667]
#                 meets_tanf_non_cash_asset_test<2023, (default)> = [False]
#                   snap_assets<2023, (default)> = [0.]
#                   state_code_str<2023, (default)> = ['UT']
#           snap_expected_contribution<2023, (default)> = [5289.]
#             snap_net_income<2023, (default)> = [17630.]
#           snap_max_allotment<2023, (default)> = [11268.]
#             snap_region_str<2023, (default)> = ['CONTIGUOUS_US']
#             spm_unit_size<2023, (default)> = [4]
#             spm_unit_size<2023, (default)> = [4]
#           snap_min_allotment<2023, (default)> = [0.]
#             snap_region_str<2023, (default)> = ['CONTIGUOUS_US']
#             spm_unit_size<2023, (default)> = [4]
#         snap_emergency_allotment<2023, (default)> = [881.5]
#           snap_emergency_allotment_monthly<2023-01, (default)> = [440.75]
#             is_snap_eligible<2023, (default)> = [ True]
#             snap_max_allotment<2023, (default)> = [11268.]
#             snap_normal_allotment<2023, (default)> = [5979.]
#             state_code<2023, (default)> = ['UT']
#           snap_emergency_allotment_monthly<2023-02, (default)> = [440.75]
#             is_snap_eligible<2023, (default)> = [ True]
#             snap_max_allotment<2023, (default)> = [11268.]
#             snap_normal_allotment<2023, (default)> = [5979.]
#             state_code<2023, (default)> = ['UT']
#           snap_emergency_allotment_monthly<2023-03, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-04, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-05, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-06, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-07, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-08, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-09, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-10, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-11, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-12, (default)> = [0.]
#       wic<2023, (default)> = [0. 0. 0. 0.]
#         meets_wic_income_test<2023, (default)> = [ True]
#           school_meal_countable_income<2023, (default)> = [25000.]
#             employment_income<2023, (default)> = [25000.     0.     0.     0.]
#             self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#             dividend_income<2023, (default)> = [0. 0. 0. 0.]
#             interest_income<2023, (default)> = [0. 0. 0. 0.]
#             gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#             social_security<2023, (default)> = [0. 0. 0. 0.]
#             ssi<2023, (default)> = [0. 0. 0. 0.]
#           wic_fpg<2023, (default)> = [30000.]
#             is_pregnant<2023, (default)> = [False False False False]
#             spm_unit_fpg<2023, (default)> = [30000.]
#             state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#         meets_wic_categorical_eligibility<2023, (default)> = [ True  True  True  True]
#           snap<2023, (default)> = [6860.5]
#           tanf<2023, (default)> = [0.]
#             tanf_reported<2023, (default)> = [0. 0. 0. 0.]
#             is_tanf_eligible<2023, (default)> = [False]
#               is_person_demographic_tanf_eligible<2023, (default)> = [False False  True  True]
#                 is_child<2023, (default)> = [False False  True  True]
#                 age<2023, (default)> = [38. 35. 10.  6.]
#                 is_full_time_student<2023, (default)> = [False False  True  True]
#                   is_full_time_college_student<2023, (default)> = [False False False False]
#                   is_in_k12_school<2023, (default)> = [False False  True  True]
#                     age<2023, (default)> = [38. 35. 10.  6.]
#                 is_pregnant<2023, (default)> = [False False False False]
#               is_tanf_enrolled<2023, (default)> = [False]
#               is_tanf_continuous_eligible<2023, (default)> = [False]
#                 tanf_gross_earned_income<2023, (default)> = [25000.]
#                   employment_income<2023, (default)> = [25000.     0.     0.     0.]
#                   self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                 tanf_gross_unearned_income<2023, (default)> = [0.]
#                   dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                   interest_income<2023, (default)> = [0. 0. 0. 0.]
#                   gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#                   social_security<2023, (default)> = [0. 0. 0. 0.]
#                   ssi<2023, (default)> = [0. 0. 0. 0.]
#                 tanf_max_amount<2023, (default)> = [0.]
#                   spm_unit_size<2023, (default)> = [4]
#                   state_code_str<2023, (default)> = ['UT']
#               is_tanf_initial_eligible<2023, (default)> = [False]
#                 tanf_initial_employment_deduction<2023, (default)> = [0.]
#                   spm_unit_size<2023, (default)> = [4]
#                   state_code_str<2023, (default)> = ['UT']
#                   market_income<2023, (default)> = [25000.     0.     0.     0.]
#                     employment_income<2023, (default)> = [25000.     0.     0.     0.]
#                     self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                     pension_income<2023, (default)> = [0. 0. 0. 0.]
#                     dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                     interest_income<2023, (default)> = [0. 0. 0. 0.]
#                     gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#                     capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                     rental_income<2023, (default)> = [0. 0. 0. 0.]
#                     illicit_income<2023, (default)> = [0. 0. 0. 0.]
#                     farm_income<2023, (default)> = [0. 0. 0. 0.]
#                 tanf_gross_earned_income<2023, (default)> = [25000.]
#                 tanf_gross_unearned_income<2023, (default)> = [0.]
#                 tanf_max_amount<2023, (default)> = [0.]
#             tanf_amount_if_eligible<2023, (default)> = [0.]
#               tanf_max_amount<2023, (default)> = [0.]
#               tanf_countable_income<2023, (default)> = [25000.]
#                 state_code_str<2023, (default)> = ['UT']
#                 tanf_gross_unearned_income<2023, (default)> = [0.]
#                 tanf_gross_earned_income<2023, (default)> = [25000.]
#           medicaid<2023, (default)> = [9966.585 9966.585 9966.585 9966.585]
#             is_medicaid_eligible<2023, (default)> = [ True  True  True  True]
#               medicaid_category<2023, (default)> = ['ADULT' 'ADULT' 'OLDER_CHILD' 'OLDER_CHILD']
#                 is_infant_for_medicaid<2023, (default)> = [False False False False]
#                   is_infant_for_medicaid_fc<2023, (default)> = [ True  True  True  True]
#                     medicaid_income_level<2023, (default)> = [0.8333333 0.8333333 0.8333333 0.8333333]
#                       tax_unit_medicaid_income_level<2023, (default)> = [0.8333333]
#                         medicaid_income<2023, (default)> = [25000.]
#                           adjusted_gross_income<2023, (default)> = [25000.]
#                             irs_gross_income<2023, (default)> = [25000.     0.     0.     0.]
#                               is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                               employment_income<2023, (default)> = [25000.     0.     0.     0.]
#                               self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                               partnership_s_corp_income<2023, (default)> = [0. 0. 0. 0.]
#                               farm_income<2023, (default)> = [0. 0. 0. 0.]
#                               farm_rent_income<2023, (default)> = [0. 0. 0. 0.]
#                               capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                               taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#                               rental_income<2023, (default)> = [0. 0. 0. 0.]
#                               dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                               taxable_pension_income<2023, (default)> = [0. 0. 0. 0.]
#                               debt_relief<2023, (default)> = [0. 0. 0. 0.]
#                               taxable_unemployment_compensation<2023, (default)> = [0. 0. 0. 0.]
#                                 is_tax_unit_head<2023, (default)> = [ True False False False]
#                                 tax_unit_taxable_unemployment_compensation<2023, (default)> = [0.]
#                                   tax_unit_unemployment_compensation<2023, (default)> = [0.]
#                                     unemployment_compensation<2023, (default)> = [0. 0. 0. 0.]
#                                   taxable_uc_agi<2023, (default)> = [25000.]
#                                     is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                                     employment_income<2023, (default)> = [25000.     0.     0.     0.]
#                                     self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                     partnership_s_corp_income<2023, (default)> = [0. 0. 0. 0.]
#                                     farm_income<2023, (default)> = [0. 0. 0. 0.]
#                                     farm_rent_income<2023, (default)> = [0. 0. 0. 0.]
#                                     capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                                     taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#                                     rental_income<2023, (default)> = [0. 0. 0. 0.]
#                                     dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                                     taxable_pension_income<2023, (default)> = [0. 0. 0. 0.]
#                                     debt_relief<2023, (default)> = [0. 0. 0. 0.]
#                                     taxable_social_security<2023, (default)> = [0. 0. 0. 0.]
#                                       tax_unit_taxable_social_security<2023, (default)> = [0.]
#                                         tax_unit_social_security<2023, (default)> = [0.]
#                                           social_security<2023, (default)> = [0. 0. 0. 0.]
#                                         taxable_ss_magi<2023, (default)> = [25000.]
#                                           is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                                           employment_income<2023, (default)> = [25000.     0.     0.     0.]
#                                           self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                           partnership_s_corp_income<2023, (default)> = [0. 0. 0. 0.]
#                                           farm_income<2023, (default)> = [0. 0. 0. 0.]
#                                           farm_rent_income<2023, (default)> = [0. 0. 0. 0.]
#                                           capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                                           taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#                                           rental_income<2023, (default)> = [0. 0. 0. 0.]
#                                           dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                                           taxable_pension_income<2023, (default)> = [0. 0. 0. 0.]
#                                           debt_relief<2023, (default)> = [0. 0. 0. 0.]
#                                           illicit_income<2023, (default)> = [0. 0. 0. 0.]
#                                           unemployment_compensation<2023, (default)> = [0. 0. 0. 0.]
#                                           tax_exempt_interest_income<2023, (default)> = [0. 0. 0. 0.]
#                                           loss_ald<2023, (default)> = [0.]
#                                             filing_status<2023, (default)> = ['JOINT']
#                                               is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                                               tax_unit_dependents<2023, (default)> = [2]
#                                                 is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                                             self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                             maximum_capital_loss<2023, (default)> = [0.]
#                                               tax_unit_capital_loss<2023, (default)> = [0.]
#                                                 capital_loss<2023, (default)> = [0. 0. 0. 0.]
#                                                   capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                                               filing_status<2023, (default)> = ['JOINT']
#                                           self_employment_tax_ald<2023, (default)> = [0.]
#                                             self_employment_tax_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employment_tax<2023, (default)> = [0. 0. 0. 0.]
#                                                 self_employment_social_security_tax<2023, (default)> = [0. 0. 0. 0.]
#                                                   social_security_taxable_self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                                     taxable_self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                                       sey<2023, (default)> = [0. 0. 0. 0.]
#                                                         self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                                         farm_income<2023, (default)> = [0. 0. 0. 0.]
#                                                         k1bx14<2023, (default)> = [0. 0. 0. 0.]
#                                                     taxable_earnings_for_social_security<2023, (default)> = [25000.     0.     0.     0.]
#                                                       payroll_tax_gross_wages<2023, (default)> = [25000.     0.     0.     0.]
#                                                         employment_income<2023, (default)> = [25000.     0.     0.     0.]
#                                                 self_employment_medicare_tax<2023, (default)> = [0. 0. 0. 0.]
#                                                   taxable_self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                           early_withdrawal_penalty<2023, (default)> = [0. 0. 0. 0.]
#                                           alimony_income<2023, (default)> = [0. 0. 0. 0.]
#                                           educator_expense<2023, (default)> = [0. 0. 0. 0.]
#                                           health_savings_account_ald<2023, (default)> = [0.]
#                                           self_employed_health_insurance_ald<2023, (default)> = [0.]
#                                             self_employed_health_insurance_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employed_health_insurance_premiums<2023, (default)> = [0. 0. 0. 0.]
#                                                 is_self_employed<2023, (default)> = [False False False False]
#                                                 health_insurance_premiums<2023, (default)> = [0. 0. 0. 0.]
#                                           self_employed_pension_contribution_ald<2023, (default)> = [0.]
#                                             self_employed_pension_contribution_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employed_pension_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                           ira_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                           sep_simple_qualified_plan_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                         filing_status<2023, (default)> = ['JOINT']
#                                       tax_unit_social_security<2023, (default)> = [0.]
#                                       social_security<2023, (default)> = [0. 0. 0. 0.]
#                                       is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                                       is_tax_unit_head<2023, (default)> = [ True False False False]
#                                     illicit_income<2023, (default)> = [0. 0. 0. 0.]
#                                     loss_ald<2023, (default)> = [0.]
#                                     self_employment_tax_ald<2023, (default)> = [0.]
#                                     student_loan_interest<2023, (default)> = [0. 0. 0. 0.]
#                                     early_withdrawal_penalty<2023, (default)> = [0. 0. 0. 0.]
#                                     alimony_income<2023, (default)> = [0. 0. 0. 0.]
#                                     educator_expense<2023, (default)> = [0. 0. 0. 0.]
#                                     health_savings_account_ald<2023, (default)> = [0.]
#                                     self_employed_health_insurance_ald<2023, (default)> = [0.]
#                                     self_employed_pension_contribution_ald<2023, (default)> = [0.]
#                                     ira_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                     sep_simple_qualified_plan_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                     qualified_adoption_assistance_expense<2023, (default)> = [0. 0. 0. 0.]
#                                     us_bonds_for_higher_ed<2023, (default)> = [0. 0. 0. 0.]
#                                     specified_possession_income<2023, (default)> = [0.]
#                                     puerto_rico_income<2023, (default)> = [0.]
#                                   filing_status<2023, (default)> = ['JOINT']
#                               taxable_social_security<2023, (default)> = [0. 0. 0. 0.]
#                               illicit_income<2023, (default)> = [0. 0. 0. 0.]
#                             above_the_line_deductions<2023, (default)> = [0.]
#                               loss_ald<2023, (default)> = [0.]
#                               self_employment_tax_ald<2023, (default)> = [0.]
#                               student_loan_interest<2023, (default)> = [0. 0. 0. 0.]
#                               early_withdrawal_penalty<2023, (default)> = [0. 0. 0. 0.]
#                               alimony_income<2023, (default)> = [0. 0. 0. 0.]
#                               educator_expense<2023, (default)> = [0. 0. 0. 0.]
#                               health_savings_account_ald<2023, (default)> = [0.]
#                               self_employed_health_insurance_ald<2023, (default)> = [0.]
#                               self_employed_pension_contribution_ald<2023, (default)> = [0.]
#                               ira_contributions<2023, (default)> = [0. 0. 0. 0.]
#                               sep_simple_qualified_plan_contributions<2023, (default)> = [0. 0. 0. 0.]
#                               qualified_adoption_assistance_expense<2023, (default)> = [0. 0. 0. 0.]
#                               us_bonds_for_higher_ed<2023, (default)> = [0. 0. 0. 0.]
#                               specified_possession_income<2023, (default)> = [0.]
#                               puerto_rico_income<2023, (default)> = [0.]
#                           foreign_earned_income_exclusion<2023, (default)> = [0.]
#                           student_loan_interest<2023, (default)> = [0. 0. 0. 0.]
#                           tax_exempt_social_security<2023, (default)> = [0.]
#                             tax_unit_social_security<2023, (default)> = [0.]
#                             tax_unit_taxable_social_security<2023, (default)> = [0.]
#                         tax_unit_fpg<2023, (default)> = [30000.]
#                           tax_unit_size<2023, (default)> = [4]
#                           state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#                     state_code_str<2023, (default)> = ['UT']
#                   is_infant_for_medicaid_nfc<2023, (default)> = [False False False False]
#                     age<2023, (default)> = [38. 35. 10.  6.]
#                 is_young_child_for_medicaid<2023, (default)> = [False False False False]
#                   is_young_child_for_medicaid_fc<2023, (default)> = [ True  True  True  True]
#                     medicaid_income_level<2023, (default)> = [0.8333333 0.8333333 0.8333333 0.8333333]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_young_child_for_medicaid_nfc<2023, (default)> = [False False False False]
#                     age<2023, (default)> = [38. 35. 10.  6.]
#                 is_older_child_for_medicaid<2023, (default)> = [False False  True  True]
#                   age<2023, (default)> = [38. 35. 10.  6.]
#                   medicaid_income_level<2023, (default)> = [0.8333333 0.8333333 0.8333333 0.8333333]
#                   state_code_str<2023, (default)> = ['UT']
#                 is_young_adult_for_medicaid<2023, (default)> = [False False False False]
#                   is_young_adult_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [0.8333333 0.8333333 0.8333333 0.8333333]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_young_adult_for_medicaid_nfc<2023, (default)> = [False False False False]
#                     age<2023, (default)> = [38. 35. 10.  6.]
#                 is_adult_for_medicaid<2023, (default)> = [ True  True False False]
#                   is_adult_for_medicaid_fc<2023, (default)> = [ True  True  True  True]
#                     medicaid_income_level<2023, (default)> = [0.8333333 0.8333333 0.8333333 0.8333333]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_adult_for_medicaid_nfc<2023, (default)> = [ True  True False False]
#                     age<2023, (default)> = [38. 35. 10.  6.]
#                 is_parent_for_medicaid<2023, (default)> = [False False False False]
#                   is_parent_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [0.8333333 0.8333333 0.8333333 0.8333333]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_parent_for_medicaid_nfc<2023, (default)> = [ True  True False False]
#                     is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                     tax_unit_count_dependents<2023, (default)> = [2]
#                       is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                 is_pregnant_for_medicaid<2023, (default)> = [False False False False]
#                   is_pregnant_for_medicaid_fc<2023, (default)> = [ True  True  True  True]
#                     medicaid_income_level<2023, (default)> = [0.8333333 0.8333333 0.8333333 0.8333333]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_pregnant_for_medicaid_nfc<2023, (default)> = [False False False False]
#                     is_pregnant<2023, (default)> = [False False False False]
#                     count_days_postpartum<2023, (default)> = [inf inf inf inf]
#                       under_60_days_postpartum<2023, (default)> = [False False False False]
#                       under_12_months_postpartum<2023, (default)> = [False False False False]
#                     state_code_str<2023, (default)> = ['UT']
#                 is_ssi_recipient_for_medicaid<2023, (default)> = [False False False False]
#                   state_code_str<2023, (default)> = ['UT']
#                   ssi<2023, (default)> = [0. 0. 0. 0.]
#             medicaid_benefit_value<2023, (default)> = [9966.585 9966.585 9966.585 9966.585]
#               state_code_str<2023, (default)> = ['UT']
#           is_pregnant<2023, (default)> = [False False False False]
#           wic_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#             is_pregnant<2023, (default)> = [False False False False]
#             is_mother<2023, (default)> = [False False False False]
#               is_female<2023, (default)> = [False False False False]
#               own_children_in_household<2023, (default)> = [0 0 0 0]
#               is_breastfeeding<2023, (default)> = [False False False False]
#             is_breastfeeding<2023, (default)> = [False False False False]
#             age<2023, (default)> = [38. 35. 10.  6.]
#         wic_category_str<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#           wic_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#         is_wic_at_nutritional_risk<2023, (default)> = [False False False False]
#           receives_wic<2023, (default)> = [False False False False]
#           meets_wic_income_test<2023, (default)> = [ True]
#           meets_wic_categorical_eligibility<2023, (default)> = [ True  True  True  True]
#           wic_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#         would_claim_wic<2023, (default)> = [ True  True  True  True]
#       free_school_meals<2023, (default)> = [1915.2]
#         school_meal_tier<2023, (default)> = ['FREE']
#           school_meal_fpg_ratio<2023, (default)> = [0.8333333]
#             school_meal_countable_income<2023, (default)> = [25000.]
#             spm_unit_fpg<2023, (default)> = [30000.]
#           meets_school_meal_categorical_eligibility<2023, (default)> = [ True]
#             snap<2023, (default)> = [6860.5]
#             tanf<2023, (default)> = [0.]
#             fdpir<2023, (default)> = [0.]
#         school_meal_net_subsidy<2023, (default)> = [1915.2]
#           school_meal_daily_subsidy<2023, (default)> = [6.04]
#             state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#             school_meal_tier<2023, (default)> = ['FREE']
#           school_meal_paid_daily_subsidy<2023, (default)> = [0.72]
#             state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#           is_in_k12_school<2023, (default)> = [False False  True  True]
#       reduced_price_school_meals<2023, (default)> = [0.]
#         school_meal_tier<2023, (default)> = ['FREE']
#         school_meal_net_subsidy<2023, (default)> = [1915.2]
#       lifeline<2023, (default)> = [111.]
#         is_rural<2023, (default)> = [False]
#         is_on_tribal_land<2023, (default)> = [False]
#         phone_cost<2023, (default)> = [700.]
#         broadband_cost<2023, (default)> = [600.]
#         is_lifeline_eligible<2023, (default)> = [ True]
#           medicaid<2023, (default)> = [9966.585 9966.585 9966.585 9966.585]
#           snap<2023, (default)> = [6860.5]
#           ssi<2023, (default)> = [0. 0. 0. 0.]
#           fcc_fpg_ratio<2023, (default)> = [0.8333333]
#             irs_gross_income<2023, (default)> = [25000.     0.     0.     0.]
#             spm_unit_fpg<2023, (default)> = [30000.]
#       acp<2023, (default)> = [360.]
#         is_acp_eligible<2023, (default)> = [ True]
#           lifeline<2023, (default)> = [111.]
#           free_school_meals<2023, (default)> = [1915.2]
#           reduced_price_school_meals<2023, (default)> = [0.]
#           pell_grant<2023, (default)> = [0.]
#           wic<2023, (default)> = [0. 0. 0. 0.]
#           medicaid<2023, (default)> = [9966.585 9966.585 9966.585 9966.585]
#           snap<2023, (default)> = [6860.5]
#           ssi<2023, (default)> = [0. 0. 0. 0.]
#           fcc_fpg_ratio<2023, (default)> = [0.8333333]
#           ebb<2023, (default)> = [0.]
#             is_ebb_eligible<2023, (default)> = [False]
#               is_lifeline_eligible<2023, (default)> = [ True]
#               free_school_meals<2023, (default)> = [1915.2]
#               reduced_price_school_meals<2023, (default)> = [0.]
#               pell_grant<2023, (default)> = [0.]
#               experienced_covid_income_loss<2023, (default)> = [False]
#               enrolled_in_ebb<2023, (default)> = [False]
#             broadband_cost_after_lifeline<2023, (default)> = [489.]
#               broadband_cost<2023, (default)> = [600.]
#               lifeline<2023, (default)> = [111.]
#             is_on_tribal_land<2023, (default)> = [False]
#         broadband_cost_after_lifeline<2023, (default)> = [489.]
#         is_on_tribal_land<2023, (default)> = [False]
#       ebb<2023, (default)> = [0.]
#       tanf<2023, (default)> = [0.]
#       high_efficiency_electric_home_rebate<2023, (default)> = [0.]
#         capped_electric_heat_pump_clothes_dryer_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#             tax_unit_income_ami_ratio<2023, (default)> = [0.]
#           electric_heat_pump_clothes_dryer_expenditures<2023, (default)> = [0.]
#         capped_electric_load_service_center_upgrade_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           electric_load_service_center_upgrade_expenditures<2023, (default)> = [0.]
#         capped_electric_stove_cooktop_range_or_oven_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           electric_stove_cooktop_range_or_oven_expenditures<2023, (default)> = [0.]
#         capped_electric_wiring_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           electric_wiring_expenditures<2023, (default)> = [0.]
#         capped_heat_pump_water_heater_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           heat_pump_water_heater_expenditures<2023, (default)> = [0.]
#         capped_heat_pump_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           heat_pump_expenditures<2023, (default)> = [0.]
#         capped_insulation_air_sealing_ventilation_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           energy_efficient_insulation_expenditures<2023, (default)> = [0.]
#           air_sealing_ventilation_expenditures<2023, (default)> = [0.]
#       residential_efficiency_electrification_rebate<2023, (default)> = [0.]
#         residential_efficiency_electrification_retrofit_expenditures<2023, (default)> = [0.]
#         residential_efficiency_electrification_retrofit_energy_savings<2023, (default)> = [0.]
#         current_home_energy_use<2023, (default)> = [0.]
#         household_income_ami_ratio<2023, (default)> = [0.]
#         average_home_energy_use_in_state<2023, (default)> = [0.]
#       basic_income<2023, (default)> = [0.]
#         basic_income_eligible<2023, (default)> = [ True]
#         basic_income_before_phase_out<2023, (default)> = [0.]
#           tax_unit_size<2023, (default)> = [4]
#           age<2023, (default)> = [38. 35. 10.  6.]
#           tax_unit_fpg<2023, (default)> = [30000.]
#         basic_income_phase_out<2023, (default)> = [0.]
#           basic_income_before_phase_out<2023, (default)> = [0.]
#           adjusted_gross_income<2023, (default)> = [25000.]
#           filing_status<2023, (default)> = ['JOINT']
#       spm_unit_capped_housing_subsidy<2023, (default)> = [0.]
#         spm_unit_capped_housing_subsidy_reported<2023, (default)> = [0.]
#     household_refundable_tax_credits<2023, (default)> = [9804.]
#       income_tax_refundable_credits<2023, (default)> = [9804.]
#         eitc<2023, (default)> = [6604.]
#           earned_income_tax_credit<2023, (default)> = [6604.]
#             eitc_eligible<2023, (default)> = [ True]
#               is_child<2023, (default)> = [False False  True  True]
#               age<2023, (default)> = [38. 35. 10.  6.]
#               tax_exempt_interest_income<2023, (default)> = [0. 0. 0. 0.]
#               taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#               dividend_income<2023, (default)> = [0. 0. 0. 0.]
#               c01000<2023, (default)> = [0.]
#                 sep<2023, (default)> = [1]
#                 c23650<2023, (default)> = [0.]
#                   long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   short_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#               tax_unit_rental_income<2023, (default)> = [0.]
#                 rental_income<2023, (default)> = [0. 0. 0. 0.]
# ...
#                       filing_status<2023, (default)> = ['JOINT']
#                       aged_blind_count<2023, (default)> = [0]
#                         blind_head<2023, (default)> = [False]
#                           is_blind<2023, (default)> = [False False False False]
#                           is_tax_unit_head<2023, (default)> = [ True False False False]
#                         blind_spouse<2023, (default)> = [False]
#                           is_blind<2023, (default)> = [False False False False]
#                           is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                         age_head<2023, (default)> = [38]
#                         age_spouse<2023, (default)> = [35]
#                 taxable_income_deductions_if_itemizing<2023, (default)> = [0.]
#                   charitable_deduction<2023, (default)> = [0.]
#                   interest_deduction<2023, (default)> = [0.]
#                   salt_deduction<2023, (default)> = [0.]
#                     state_and_local_sales_or_income_tax<2023, (default)> = [0.]
#                       state_income_tax<2023, (default)> = [0.]
#                         ma_income_tax<2023, (default)> = [0.]
#                           MA<2023, (default)> = [False]
#                         md_income_tax<2023, (default)> = [0.]
#                           MD<2023, (default)> = [False]
#                         ny_income_tax<2023, (default)> = [0.]
#                           NY<2023, (default)> = [False]
#                         or_income_tax<2023, (default)> = [0.]
#                           OR<2023, (default)> = [False]
#                         pa_income_tax<2023, (default)> = [0.]
#                           PA<2023, (default)> = [False]
#                             state_code_str<2023, (default)> = ['UT']
#                         wa_income_tax<2023, (default)> = [0.]
#                           WA<2023, (default)> = [False]
#                         ut_income_tax<2023, (default)> = [0.]
#                           UT<2023, (default)> = [ True]
#                           ut_income_tax_before_refundable_credits<2023, (default)> = [0.]
#                             ut_income_tax_after_credits<2023, (default)> = [0.]
#                               ut_income_tax_before_credits<2023, (default)> = [1162.5]
#                                 UT<2023, (default)> = [ True]
#                                 ut_taxable_income<2023, (default)> = [25000.]
#                                   UT<2023, (default)> = [ True]
#                                   ut_total_income<2023, (default)> = [25000.]
#                                     UT<2023, (default)> = [ True]
#                                     adjusted_gross_income<2023, (default)> = [25000.]
#                                     ut_additions_to_income<2023, (default)> = [0.]
#                                       UT<2023, (default)> = [ True]
#                                   salt_refund_last_year<2023, (default)> = [0.]
#                                   ut_subtractions_from_income<2023, (default)> = [0.]
#                                     UT<2023, (default)> = [ True]
#                               ut_taxpayer_credit<2023, (default)> = [1878.24]
#                                 UT<2023, (default)> = [ True]
#                                 ut_taxpayer_credit_max<2023, (default)> = [1878.24]
#                                   UT<2023, (default)> = [ True]
#                                   tax_unit_count_dependents<2023, (default)> = [2]
#                                   tax_unit_itemizes<2023, (default)> = [False]
#                                   standard_deduction<2023, (default)> = [27700.]
#                                   charitable_deduction<2023, (default)> = [0.]
#                                   interest_deduction<2023, (default)> = [0.]
#                                   medical_expense_deduction<2023, (default)> = [0.]
#                                   casualty_loss_deduction<2023, (default)> = [0.]
#                                 ut_taxpayer_credit_reduction<2023, (default)> = [0.]
#                                   UT<2023, (default)> = [ True]
#                                   filing_status<2023, (default)> = ['JOINT']
#                                   ut_taxable_income<2023, (default)> = [25000.]
#                             ut_apportionable_nonrefundable_credits<2023, (default)> = [0.]
#                               UT<2023, (default)> = [ True]
#                             ut_nonapportionable_nonrefundable_credits<2023, (default)> = [0.]
#                               UT<2023, (default)> = [ True]
#                             ut_recapture_low_inc_housing_credit<2023, (default)> = [0.]
#                               UT<2023, (default)> = [ True]
#                           ut_refundable_credits<2023, (default)> = [0.]
#                       local_income_tax<2023, (default)> = [0.]
#                       state_sales_tax<2023, (default)> = [0.]
#                       local_sales_tax<2023, (default)> = [0.]
#                     real_estate_taxes<2023, (default)> = [0. 0. 0. 0.]
#                     filing_status<2023, (default)> = ['JOINT']
#                   medical_expense_deduction<2023, (default)> = [0.]
#                   casualty_loss_deduction<2023, (default)> = [0.]
#                   qualified_business_income_deduction<2023, (default)> = [0.]
#                     qbid_amount<2023, (default)> = [0. 0. 0. 0.]
#                       qualified_business_income<2023, (default)> = [0. 0. 0. 0.]
#                         self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                         partnership_s_corp_income<2023, (default)> = [0. 0. 0. 0.]
#                         farm_income<2023, (default)> = [0. 0. 0. 0.]
#                         farm_rent_income<2023, (default)> = [0. 0. 0. 0.]
#                         self_employment_tax_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                         self_employed_health_insurance_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                         self_employed_pension_contribution_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                         business_is_qualified<2023, (default)> = [False False False False]
#                       w2_wages_from_qualified_business<2023, (default)> = [0. 0. 0. 0.]
#                       unadjusted_basis_qualified_property<2023, (default)> = [0. 0. 0. 0.]
#                       taxable_income_less_qbid<2023, (default)> = [0.]
#                         adjusted_gross_income<2023, (default)> = [25000.]
#                         charitable_deduction<2023, (default)> = [0.]
#                         interest_deduction<2023, (default)> = [0.]
#                         salt_deduction<2023, (default)> = [0.]
#                         medical_expense_deduction<2023, (default)> = [0.]
#                         casualty_loss_deduction<2023, (default)> = [0.]
#                         standard_deduction<2023, (default)> = [27700.]
#                       filing_status<2023, (default)> = ['JOINT']
#                       business_is_sstb<2023, (default)> = [False False False False]
#                     taxable_income_less_qbid<2023, (default)> = [0.]
#                     adjusted_net_capital_gain<2023, (default)> = [0.]
#                       net_capital_gain<2023, (default)> = [0.]
#                         net_long_term_capital_gain<2023, (default)> = [0.]
#                           long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                           long_term_capital_losses<2023, (default)> = [0. 0. 0. 0.]
#                         net_short_term_capital_loss<2023, (default)> = [0.]
#                           short_term_capital_losses<2023, (default)> = [0. 0. 0. 0.]
#                           short_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                         qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                       qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                       unrecaptured_section_1250_gain<2023, (default)> = [0.]
#                       capital_gains_28_percent_rate_gain<2023, (default)> = [0.]
#                         long_term_capital_gains_on_collectibles<2023, (default)> = [0. 0. 0. 0.]
#                         long_term_capital_gains_on_small_business_stock<2023, (default)> = [0. 0. 0. 0.]
#                 taxable_income_deductions_if_not_itemizing<2023, (default)> = [27700.]
#                   standard_deduction<2023, (default)> = [27700.]
#                   qualified_business_income_deduction<2023, (default)> = [0.]
#             capital_gains_excluded_from_taxable_income<2023, (default)> = [0.]
#               net_capital_gain<2023, (default)> = [0.]
#               adjusted_net_capital_gain<2023, (default)> = [0.]
#               taxable_income<2023, (default)> = [0.]
#               filing_status<2023, (default)> = ['JOINT']
#             filing_status<2023, (default)> = ['JOINT']
#           capital_gains_tax<2023, (default)> = [0.]
#             net_capital_gain<2023, (default)> = [0.]
#             taxable_income<2023, (default)> = [0.]
#             adjusted_net_capital_gain<2023, (default)> = [0.]
#             capital_gains_excluded_from_taxable_income<2023, (default)> = [0.]
#             filing_status<2023, (default)> = ['JOINT']
#             unrecaptured_section_1250_gain<2023, (default)> = [0.]
#             qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#             capital_gains_28_percent_rate_gain<2023, (default)> = [0.]
#           alternative_minimum_tax<2023, (default)> = [0.]
#             c09600<2023, (default)> = [0.]
#               c62100<2023, (default)> = [27700.]
#                 amt_income<2023, (default)> = [27700.]
#                   taxable_income<2023, (default)> = [0.]
#                   tax_unit_itemizes<2023, (default)> = [False]
#                   standard_deduction<2023, (default)> = [27700.]
#                   salt_deduction<2023, (default)> = [0.]
#                   filing_status<2023, (default)> = ['JOINT']
#               filing_status<2023, (default)> = ['JOINT']
#               age_head<2023, (default)> = [38]
#               age_spouse<2023, (default)> = [35]
#               filer_earned<2023, (default)> = [25000.]
#               sep<2023, (default)> = [1]
#               dwks10<2023, (default)> = [0.]
#                 dwks6<2023, (default)> = [0.]
#                   qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                   investment_income_form_4952<2023, (default)> = [0.]
#                 dwks9<2023, (default)> = [0.]
#                   long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                   c23650<2023, (default)> = [0.]
#                   non_sch_d_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   investment_income_form_4952<2023, (default)> = [0.]
#                 long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                 qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                 c23650<2023, (default)> = [0.]
#                 non_sch_d_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                 hasqdivltcg<2023, (default)> = [False]
#                   c01000<2023, (default)> = [0.]
#                   c23650<2023, (default)> = [0.]
#                   long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   non_sch_d_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#               dwks13<2023, (default)> = [0.]
#                 unrecaptured_section_1250_gain<2023, (default)> = [0.]
#                 capital_gains_28_percent_rate_gain<2023, (default)> = [0.]
#                 dwks9<2023, (default)> = [0.]
#                 dwks10<2023, (default)> = [0.]
#                 hasqdivltcg<2023, (default)> = [False]
#               dwks14<2023, (default)> = [0.]
#                 taxable_income<2023, (default)> = [0.]
#                 dwks13<2023, (default)> = [0.]
#                 hasqdivltcg<2023, (default)> = [False]
#               dwks19<2023, (default)> = [0.]
#                 dwks14<2023, (default)> = [0.]
#                 filing_status<2023, (default)> = ['JOINT']
#                 taxable_income<2023, (default)> = [0.]
#                 dwks10<2023, (default)> = [0.]
#                 hasqdivltcg<2023, (default)> = [False]
#               unrecaptured_section_1250_gain<2023, (default)> = [0.]
#               sep<2023, (default)> = [1]
#               foreign_tax_credit<2023, (default)> = [0.]
#               amt_form_completed<2023, (default)> = [False]
#               foreign_tax_credit<2023, (default)> = [0.]
#               taxbc<2023, (default)> = [0.]
#                 regular_tax_before_credits<2023, (default)> = [0.]
#                   filing_status<2023, (default)> = ['JOINT']
#                   taxable_income<2023, (default)> = [0.]
#                   dwks14<2023, (default)> = [0.]
#                   dwks13<2023, (default)> = [0.]
#                   dwks19<2023, (default)> = [0.]
#                   dwks9<2023, (default)> = [0.]
#                   unrecaptured_section_1250_gain<2023, (default)> = [0.]
#                   dwks10<2023, (default)> = [0.]
#                   income_tax_main_rates<2023, (default)> = [0.]
#                   hasqdivltcg<2023, (default)> = [False]
#               c05700<2023, (default)> = [0.]
#         net_investment_income_tax<2023, (default)> = [0.]
#           taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#           dividend_income<2023, (default)> = [0. 0. 0. 0.]
#           c01000<2023, (default)> = [0.]
#           rental_income<2023, (default)> = [0. 0. 0. 0.]
#           filing_status<2023, (default)> = ['JOINT']
#           adjusted_gross_income<2023, (default)> = [25000.]
#         recapture_of_investment_credit<2023, (default)> = [0.]
#         unreported_payroll_tax<2023, (default)> = [0.]
#         qualified_retirement_penalty<2023, (default)> = [0.]
#         income_tax_capped_non_refundable_credits<2023, (default)> = [0.]
#           income_tax_non_refundable_credits<2023, (default)> = [800.]
#             cdcc<2023, (default)> = [0.]
#             elderly_disabled_credit<2023, (default)> = [0.]
#             non_refundable_ctc<2023, (default)> = [800.]
#               ctc<2023, (default)> = [4000.]
#               refundable_ctc<2023, (default)> = [3200.]
#             non_refundable_american_opportunity_credit<2023, (default)> = [0.]
#             lifetime_learning_credit<2023, (default)> = [0.]
#             retirement_savings_credit<2023, (default)> = [0.]
#             residential_clean_energy_credit<2023, (default)> = [0.]
#             energy_efficient_home_improvement_credit<2023, (default)> = [0.]
#             new_clean_vehicle_credit<2023, (default)> = [0.]
#             used_clean_vehicle_credit<2023, (default)> = [0.]
#           income_tax_unavailable_non_refundable_credits<2023, (default)> = [800.]
#             income_tax_before_credits<2023, (default)> = [0.]
#             income_tax_non_refundable_credits<2023, (default)> = [800.]
#             income_tax_non_refundable_credits<2023, (default)> = [800.]
#       ma_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         MA<2023, (default)> = [False]
#       md_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         MD<2023, (default)> = [False]
#       ny_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         NY<2023, (default)> = [False]
#       or_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         or_income_tax_before_credits<2023, (default)> = [0.]
#           OR<2023, (default)> = [False]
#         or_non_refundable_credits<2023, (default)> = [0.]
#           or_exemption_credit<2023, (default)> = [0.]
#             OR<2023, (default)> = [False]
#       pa_income_tax<2023, (default)> = [0.]
#       ut_income_tax_before_refundable_credits<2023, (default)> = [0.]
#       wa_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         WA<2023, (default)> = [False]
#       flat_tax<2023, (default)> = [0.]
#         positive_agi<2023, (default)> = [25000.]

# %% [markdown]
# #### 3.3.2. Effect of rate cut to 4.65% on middle income household

# %%
simulation_1_m = Simulation(
    reform=reform_1,
    situation=situation_mid,
)

simulation_1_m.trace = True
simulation_1_m.calculate("household_net_income", 2023)
simulation_1_m.tracer.print_computation_log()
# Out:
#   household_net_income<2023, (default)> = [69766.484]
#     household_market_income<2023, (default)> = [80000.]
#       employment_income<2023, (default)> = [45000. 35000.     0.     0.]
#       self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#       pension_income<2023, (default)> = [0. 0. 0. 0.]
#         tax_exempt_pension_income<2023, (default)> = [0. 0. 0. 0.]
#         taxable_pension_income<2023, (default)> = [0. 0. 0. 0.]
#       dividend_income<2023, (default)> = [0. 0. 0. 0.]
#         qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#         non_qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#       interest_income<2023, (default)> = [0. 0. 0. 0.]
#         tax_exempt_interest_income<2023, (default)> = [0. 0. 0. 0.]
#         taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#       gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#       capital_gains<2023, (default)> = [0. 0. 0. 0.]
#         short_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#         long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#       rental_income<2023, (default)> = [0. 0. 0. 0.]
#       illicit_income<2023, (default)> = [0. 0. 0. 0.]
#       farm_income<2023, (default)> = [0. 0. 0. 0.]
#     household_benefits<2023, (default)> = [0.]
#       social_security<2023, (default)> = [0. 0. 0. 0.]
#         social_security_dependents<2023, (default)> = [0. 0. 0. 0.]
#         social_security_disability<2023, (default)> = [0. 0. 0. 0.]
#         social_security_retirement<2023, (default)> = [0. 0. 0. 0.]
#         social_security_survivors<2023, (default)> = [0. 0. 0. 0.]
#       ssi<2023, (default)> = [0. 0. 0. 0.]
#         uncapped_ssi<2023, (default)> = [0. 0. 0. 0.]
#           ssi_amount_if_eligible<2023, (default)> = [16452. 10968. 10968. 10968.]
#             ssi_claim_is_joint<2023, (default)> = [ True False False False]
#               is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                 is_ssi_aged<2023, (default)> = [False False False False]
#                   age<2023, (default)> = [38. 35. 10. 10.]
#                 is_blind<2023, (default)> = [False False False False]
#                 is_ssi_disabled<2023, (default)> = [False False False False]
#                   is_ssi_aged<2023, (default)> = [False False False False]
#                   is_blind<2023, (default)> = [False False False False]
#                   ssi_reported<2023, (default)> = [0. 0. 0. 0.]
#               ssi_income_deemed_from_ineligible_spouse<2023, (default)> = [17500.     0.     0.     0.]
#                 ssi_earned_income<2023, (default)> = [45000. 35000.     0.     0.]
#                   employment_income<2023, (default)> = [45000. 35000.     0.     0.]
#                   self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                 ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#                   dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                   interest_income<2023, (default)> = [0. 0. 0. 0.]
#                   gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#                   social_security<2023, (default)> = [0. 0. 0. 0.]
#                   alimony_income<2023, (default)> = [0. 0. 0. 0.]
#                   pension_income<2023, (default)> = [0. 0. 0. 0.]
#                   unemployment_compensation<2023, (default)> = [0. 0. 0. 0.]
#                 ssi_earned_income_deemed_from_ineligible_spouse<2023, (default)> = [35000.     0.     0.     0.]
#                   is_ssi_ineligible_spouse<2023, (default)> = [False  True False False]
#                     is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                       is_child<2023, (default)> = [False False  True  True]
#                         age<2023, (default)> = [38. 35. 10. 10.]
#                       is_tax_unit_head<2023, (default)> = [ True False False False]
#                         is_child<2023, (default)> = [False False  True  True]
#                         age<2023, (default)> = [38. 35. 10. 10.]
#                       age<2023, (default)> = [38. 35. 10. 10.]
#                     is_ssi_eligible_spouse<2023, (default)> = [False False False False]
#                       is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                       is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                   ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#                   ssi_earned_income<2023, (default)> = [45000. 35000.     0.     0.]
#                   ssi_ineligible_child_allocation<2023, (default)> = [   0.    0. 5484. 5484.]
#                     ssi_earned_income<2023, (default)> = [45000. 35000.     0.     0.]
#                     ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#                     is_ssi_ineligible_child<2023, (default)> = [False False  True  True]
#                       is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                       is_child<2023, (default)> = [False False  True  True]
#                   is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                 ssi_unearned_income_deemed_from_ineligible_spouse<2023, (default)> = [0. 0. 0. 0.]
#                   is_ssi_ineligible_spouse<2023, (default)> = [False  True False False]
#                   ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#                   ssi_ineligible_child_allocation<2023, (default)> = [   0.    0. 5484. 5484.]
#                 is_ssi_ineligible_child<2023, (default)> = [False False  True  True]
#           meets_ssi_resource_test<2023, (default)> = [ True  True  True  True]
#             ssi_claim_is_joint<2023, (default)> = [ True False False False]
#             ssi_countable_resources<2023, (default)> = [0. 0. 0. 0.]
#           is_ssi_eligible_individual<2023, (default)> = [False False False False]
#             is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#             is_ssi_eligible_spouse<2023, (default)> = [False False False False]
#           ssi_countable_income<2023, (default)> = [0. 0. 0. 0.]
#             ssi_earned_income<2023, (default)> = [45000. 35000.     0.     0.]
#             ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#             ssi_unearned_income_deemed_from_ineligible_parent<2023, (default)> = [0. 0. 0. 0.]
#               is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#               is_child<2023, (default)> = [False False  True  True]
#               is_ssi_ineligible_parent<2023, (default)> = [False False False False]
#                 is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                 is_child<2023, (default)> = [False False  True  True]
#               ssi_earned_income<2023, (default)> = [45000. 35000.     0.     0.]
#               ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#               ssi_ineligible_child_allocation<2023, (default)> = [   0.    0. 5484. 5484.]
#               ssi_ineligible_parent_allocation<2023, (default)> = [0. 0. 0. 0.]
#                 is_ssi_ineligible_parent<2023, (default)> = [False False False False]
#             ssi_income_deemed_from_ineligible_spouse<2023, (default)> = [17500.     0.     0.     0.]
#             is_ssi_eligible_individual<2023, (default)> = [False False False False]
#       state_supplement<2023, (default)> = [0. 0. 0. 0.]
#         uncapped_ssi<2023, (default)> = [0. 0. 0. 0.]
#         maximum_state_supplement<2023, (default)> = [0. 0. 0. 0.]
#           is_ssi_eligible_individual<2023, (default)> = [False False False False]
#           state_code_str<2023, (default)> = ['UT']
#             state_code<2023, (default)> = ['UT']
#               state_name<2023, (default)> = ['UT']
#           state_living_arrangement<2023, (default)> = ['FULL_COST']
#           is_blind<2023, (default)> = [False False False False]
#           is_ssi_aged<2023, (default)> = [False False False False]
#           is_ssi_disabled<2023, (default)> = [False False False False]
#           ssi_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#           ssi_claim_is_joint<2023, (default)> = [ True False False False]
#         is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#         meets_ssi_resource_test<2023, (default)> = [ True  True  True  True]
#         ssi_claim_is_joint<2023, (default)> = [ True False False False]
#       ca_cvrp<2023, (default)> = [0. 0. 0. 0.]
#         CA<2023, (default)> = [False]
#           state_code_str<2023, (default)> = ['UT']
#       snap<2023, (default)> = [0.]
#         snap_normal_allotment<2023, (default)> = [0.]
#           is_snap_eligible<2023, (default)> = [False]
#             meets_snap_net_income_test<2023, (default)> = [False]
#               snap_net_income_fpg_ratio<2023, (default)> = [2.021]
#                 snap_net_income<2023, (default)> = [60630.]
#                   snap_gross_income<2023, (default)> = [80000.]
#                     snap_earned_income<2023, (default)> = [80000.]
#                       employment_income<2023, (default)> = [45000. 35000.     0.     0.]
#                       self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                     snap_unearned_income<2023, (default)> = [0.]
#                       dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                       interest_income<2023, (default)> = [0. 0. 0. 0.]
#                       gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#                       social_security<2023, (default)> = [0. 0. 0. 0.]
#                       ssi<2023, (default)> = [0. 0. 0. 0.]
#                   snap_deductions<2023, (default)> = [19370.]
#                     snap_standard_deduction<2023, (default)> = [2316.]
#                       state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#                         state_group<2023, (default)> = ['CONTIGUOUS_US']
#                           state_code<2023, (default)> = ['UT']
#                       spm_unit_size<2023, (default)> = [4]
#                     snap_earned_income_deduction<2023, (default)> = [16000.]
#                       snap_earned_income<2023, (default)> = [80000.]
#                     snap_dependent_care_deduction<2023, (default)> = [1000.]
#                       childcare_expenses<2023, (default)> = [1000.]
#                     snap_child_support_deduction<2023, (default)> = [0.]
#                       child_support_expense<2023, (default)> = [0. 0. 0. 0.]
#                       state_code_str<2023, (default)> = ['UT']
#                     snap_excess_medical_expense_deduction<2023, (default)> = [0.]
#                       is_usda_elderly<2023, (default)> = [False False False False]
#                         age<2023, (default)> = [38. 35. 10. 10.]
#                       is_usda_disabled<2023, (default)> = [False False False False]
#                         is_ssi_disabled<2023, (default)> = [False False False False]
#                         social_security_disability<2023, (default)> = [0. 0. 0. 0.]
#                         is_permanently_disabled_veteran<2023, (default)> = [False False False False]
#                         is_surviving_spouse_of_disabled_veteran<2023, (default)> = [False False False False]
#                         is_surviving_child_of_disabled_veteran<2023, (default)> = [False False False False]
#                       medical_out_of_pocket_expenses<2023, (default)> = [2000.    0.    0.    0.]
#                       state_code_str<2023, (default)> = ['UT']
#                     snap_excess_shelter_expense_deduction<2023, (default)> = [54.]
#                       snap_net_income_pre_shelter<2023, (default)> = [60684.]
#                         snap_gross_income<2023, (default)> = [80000.]
#                         snap_standard_deduction<2023, (default)> = [2316.]
#                         snap_earned_income_deduction<2023, (default)> = [16000.]
#                         snap_dependent_care_deduction<2023, (default)> = [1000.]
#                         snap_child_support_deduction<2023, (default)> = [0.]
#                         snap_excess_medical_expense_deduction<2023, (default)> = [0.]
#                       housing_cost<2023, (default)> = [20000.]
#                       snap_region_str<2023, (default)> = ['CONTIGUOUS_US']
#                         snap_region<2023, (default)> = ['CONTIGUOUS_US']
#                           state_group<2023, (default)> = ['CONTIGUOUS_US']
#                       has_usda_elderly_disabled<2023, (default)> = [False]
#                         is_usda_elderly<2023, (default)> = [False False False False]
#                         is_usda_disabled<2023, (default)> = [False False False False]
#                       snap_utility_allowance<2023, (default)> = [54.]
#                         snap_utility_allowance_type<2023, (default)> = ['IUA']
#                           count_distinct_utility_expenses<2023, (default)> = [1]
#                             heating_cooling_expense<2023, (default)> = [0.]
#                             electricity_expense<2023, (default)> = [0.]
#                             gas_expense<2023, (default)> = [0.]
#                             phone_expense<2023, (default)> = [1500.]
#                               phone_cost<2023, (default)> = [1500.]
#                             trash_expense<2023, (default)> = [0.]
#                             water_expense<2023, (default)> = [0.]
#                             sewage_expense<2023, (default)> = [0.]
#                           snap_utility_region_str<2023, (default)> = ['UT']
#                             snap_utility_region<2023, (default)> = ['UT']
#                               state_code<2023, (default)> = ['UT']
#                           has_heating_cooling_expense<2023, (default)> = [False]
#                             heating_cooling_expense<2023, (default)> = [0.]
#                         snap_utility_region_str<2023, (default)> = ['UT']
#                       state_code_str<2023, (default)> = ['UT']
#                       is_homeless<2023, (default)> = [False]
#                 spm_unit_fpg<2023, (default)> = [30000.]
#                   spm_unit_size<2023, (default)> = [4]
#                   state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#             meets_snap_gross_income_test<2023, (default)> = [False]
#               snap_gross_income_fpg_ratio<2023, (default)> = [2.6666667]
#                 snap_gross_income<2023, (default)> = [80000.]
#                 spm_unit_fpg<2023, (default)> = [30000.]
#               has_usda_elderly_disabled<2023, (default)> = [False]
#             meets_snap_asset_test<2023, (default)> = [ True]
#               has_usda_elderly_disabled<2023, (default)> = [False]
#               snap_assets<2023, (default)> = [0.]
#             meets_snap_categorical_eligibility<2023, (default)> = [False]
#               ssi<2023, (default)> = [0. 0. 0. 0.]
#               is_tanf_non_cash_eligible<2023, (default)> = [False]
#                 meets_tanf_non_cash_gross_income_test<2023, (default)> = [False]
#                   state_code_str<2023, (default)> = ['UT']
#                   snap_gross_income_fpg_ratio<2023, (default)> = [2.6666667]
#                 meets_tanf_non_cash_net_income_test<2023, (default)> = [ True]
#                   state_code_str<2023, (default)> = ['UT']
#                   is_tanf_non_cash_hheod<2023, (default)> = [False]
#                     state_code_str<2023, (default)> = ['UT']
#                     has_all_usda_elderly_disabled<2023, (default)> = [False]
#                       is_usda_elderly<2023, (default)> = [False False False False]
#                       is_usda_disabled<2023, (default)> = [False False False False]
#                     has_usda_elderly_disabled<2023, (default)> = [False]
#                   snap_net_income_fpg_ratio<2023, (default)> = [2.021]
#                 meets_tanf_non_cash_asset_test<2023, (default)> = [False]
#                   snap_assets<2023, (default)> = [0.]
#                   state_code_str<2023, (default)> = ['UT']
#           snap_expected_contribution<2023, (default)> = [18189.]
#             snap_net_income<2023, (default)> = [60630.]
#           snap_max_allotment<2023, (default)> = [11268.]
#             snap_region_str<2023, (default)> = ['CONTIGUOUS_US']
#             spm_unit_size<2023, (default)> = [4]
#             spm_unit_size<2023, (default)> = [4]
#           snap_min_allotment<2023, (default)> = [0.]
#             snap_region_str<2023, (default)> = ['CONTIGUOUS_US']
#             spm_unit_size<2023, (default)> = [4]
#         snap_emergency_allotment<2023, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-01, (default)> = [0.]
#             is_snap_eligible<2023, (default)> = [False]
#             snap_max_allotment<2023, (default)> = [11268.]
#             snap_normal_allotment<2023, (default)> = [0.]
#             state_code<2023, (default)> = ['UT']
#           snap_emergency_allotment_monthly<2023-02, (default)> = [0.]
#             is_snap_eligible<2023, (default)> = [False]
#             snap_max_allotment<2023, (default)> = [11268.]
#             snap_normal_allotment<2023, (default)> = [0.]
#             state_code<2023, (default)> = ['UT']
#           snap_emergency_allotment_monthly<2023-03, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-04, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-05, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-06, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-07, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-08, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-09, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-10, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-11, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-12, (default)> = [0.]
#       wic<2023, (default)> = [0. 0. 0. 0.]
#         meets_wic_income_test<2023, (default)> = [False]
#           school_meal_countable_income<2023, (default)> = [80000.]
#             employment_income<2023, (default)> = [45000. 35000.     0.     0.]
#             self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#             dividend_income<2023, (default)> = [0. 0. 0. 0.]
#             interest_income<2023, (default)> = [0. 0. 0. 0.]
#             gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#             social_security<2023, (default)> = [0. 0. 0. 0.]
#             ssi<2023, (default)> = [0. 0. 0. 0.]
#           wic_fpg<2023, (default)> = [30000.]
#             is_pregnant<2023, (default)> = [False False False False]
#             spm_unit_fpg<2023, (default)> = [30000.]
#             state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#         meets_wic_categorical_eligibility<2023, (default)> = [False False False False]
#           snap<2023, (default)> = [0.]
#           tanf<2023, (default)> = [0.]
#             tanf_reported<2023, (default)> = [0. 0. 0. 0.]
#             is_tanf_eligible<2023, (default)> = [False]
#               is_person_demographic_tanf_eligible<2023, (default)> = [False False  True  True]
#                 is_child<2023, (default)> = [False False  True  True]
#                 age<2023, (default)> = [38. 35. 10. 10.]
#                 is_full_time_student<2023, (default)> = [False False  True  True]
#                   is_full_time_college_student<2023, (default)> = [False False False False]
#                   is_in_k12_school<2023, (default)> = [False False  True  True]
#                     age<2023, (default)> = [38. 35. 10. 10.]
#                 is_pregnant<2023, (default)> = [False False False False]
#               is_tanf_enrolled<2023, (default)> = [False]
#               is_tanf_continuous_eligible<2023, (default)> = [False]
#                 tanf_gross_earned_income<2023, (default)> = [80000.]
#                   employment_income<2023, (default)> = [45000. 35000.     0.     0.]
#                   self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                 tanf_gross_unearned_income<2023, (default)> = [0.]
#                   dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                   interest_income<2023, (default)> = [0. 0. 0. 0.]
#                   gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#                   social_security<2023, (default)> = [0. 0. 0. 0.]
#                   ssi<2023, (default)> = [0. 0. 0. 0.]
#                 tanf_max_amount<2023, (default)> = [0.]
#                   spm_unit_size<2023, (default)> = [4]
#                   state_code_str<2023, (default)> = ['UT']
#               is_tanf_initial_eligible<2023, (default)> = [False]
#                 tanf_initial_employment_deduction<2023, (default)> = [0.]
#                   spm_unit_size<2023, (default)> = [4]
#                   state_code_str<2023, (default)> = ['UT']
#                   market_income<2023, (default)> = [45000. 35000.     0.     0.]
#                     employment_income<2023, (default)> = [45000. 35000.     0.     0.]
#                     self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                     pension_income<2023, (default)> = [0. 0. 0. 0.]
#                     dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                     interest_income<2023, (default)> = [0. 0. 0. 0.]
#                     gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#                     capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                     rental_income<2023, (default)> = [0. 0. 0. 0.]
#                     illicit_income<2023, (default)> = [0. 0. 0. 0.]
#                     farm_income<2023, (default)> = [0. 0. 0. 0.]
#                 tanf_gross_earned_income<2023, (default)> = [80000.]
#                 tanf_gross_unearned_income<2023, (default)> = [0.]
#                 tanf_max_amount<2023, (default)> = [0.]
#             tanf_amount_if_eligible<2023, (default)> = [0.]
#               tanf_max_amount<2023, (default)> = [0.]
#               tanf_countable_income<2023, (default)> = [80000.]
#                 state_code_str<2023, (default)> = ['UT']
#                 tanf_gross_unearned_income<2023, (default)> = [0.]
#                 tanf_gross_earned_income<2023, (default)> = [80000.]
#           medicaid<2023, (default)> = [0. 0. 0. 0.]
#             is_medicaid_eligible<2023, (default)> = [False False False False]
#               medicaid_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#                 is_infant_for_medicaid<2023, (default)> = [False False False False]
#                   is_infant_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [2.6666667 2.6666667 2.6666667 2.6666667]
#                       tax_unit_medicaid_income_level<2023, (default)> = [2.6666667]
#                         medicaid_income<2023, (default)> = [80000.]
#                           adjusted_gross_income<2023, (default)> = [80000.]
#                             irs_gross_income<2023, (default)> = [45000. 35000.     0.     0.]
#                               is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                               employment_income<2023, (default)> = [45000. 35000.     0.     0.]
#                               self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                               partnership_s_corp_income<2023, (default)> = [0. 0. 0. 0.]
#                               farm_income<2023, (default)> = [0. 0. 0. 0.]
#                               farm_rent_income<2023, (default)> = [0. 0. 0. 0.]
#                               capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                               taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#                               rental_income<2023, (default)> = [0. 0. 0. 0.]
#                               dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                               taxable_pension_income<2023, (default)> = [0. 0. 0. 0.]
#                               debt_relief<2023, (default)> = [0. 0. 0. 0.]
#                               taxable_unemployment_compensation<2023, (default)> = [0. 0. 0. 0.]
#                                 is_tax_unit_head<2023, (default)> = [ True False False False]
#                                 tax_unit_taxable_unemployment_compensation<2023, (default)> = [0.]
#                                   tax_unit_unemployment_compensation<2023, (default)> = [0.]
#                                     unemployment_compensation<2023, (default)> = [0. 0. 0. 0.]
#                                   taxable_uc_agi<2023, (default)> = [80000.]
#                                     is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                                     employment_income<2023, (default)> = [45000. 35000.     0.     0.]
#                                     self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                     partnership_s_corp_income<2023, (default)> = [0. 0. 0. 0.]
#                                     farm_income<2023, (default)> = [0. 0. 0. 0.]
#                                     farm_rent_income<2023, (default)> = [0. 0. 0. 0.]
#                                     capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                                     taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#                                     rental_income<2023, (default)> = [0. 0. 0. 0.]
#                                     dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                                     taxable_pension_income<2023, (default)> = [0. 0. 0. 0.]
#                                     debt_relief<2023, (default)> = [0. 0. 0. 0.]
#                                     taxable_social_security<2023, (default)> = [0. 0. 0. 0.]
#                                       tax_unit_taxable_social_security<2023, (default)> = [0.]
#                                         tax_unit_social_security<2023, (default)> = [0.]
#                                           social_security<2023, (default)> = [0. 0. 0. 0.]
#                                         taxable_ss_magi<2023, (default)> = [80000.]
#                                           is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                                           employment_income<2023, (default)> = [45000. 35000.     0.     0.]
#                                           self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                           partnership_s_corp_income<2023, (default)> = [0. 0. 0. 0.]
#                                           farm_income<2023, (default)> = [0. 0. 0. 0.]
#                                           farm_rent_income<2023, (default)> = [0. 0. 0. 0.]
#                                           capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                                           taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#                                           rental_income<2023, (default)> = [0. 0. 0. 0.]
#                                           dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                                           taxable_pension_income<2023, (default)> = [0. 0. 0. 0.]
#                                           debt_relief<2023, (default)> = [0. 0. 0. 0.]
#                                           illicit_income<2023, (default)> = [0. 0. 0. 0.]
#                                           unemployment_compensation<2023, (default)> = [0. 0. 0. 0.]
#                                           tax_exempt_interest_income<2023, (default)> = [0. 0. 0. 0.]
#                                           loss_ald<2023, (default)> = [0.]
#                                             filing_status<2023, (default)> = ['JOINT']
#                                               is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                                               tax_unit_dependents<2023, (default)> = [2]
#                                                 is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                                             self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                             maximum_capital_loss<2023, (default)> = [0.]
#                                               tax_unit_capital_loss<2023, (default)> = [0.]
#                                                 capital_loss<2023, (default)> = [0. 0. 0. 0.]
#                                                   capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                                               filing_status<2023, (default)> = ['JOINT']
#                                           self_employment_tax_ald<2023, (default)> = [0.]
#                                             self_employment_tax_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employment_tax<2023, (default)> = [0. 0. 0. 0.]
#                                                 self_employment_social_security_tax<2023, (default)> = [0. 0. 0. 0.]
#                                                   social_security_taxable_self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                                     taxable_self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                                       sey<2023, (default)> = [0. 0. 0. 0.]
#                                                         self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                                         farm_income<2023, (default)> = [0. 0. 0. 0.]
#                                                         k1bx14<2023, (default)> = [0. 0. 0. 0.]
#                                                     taxable_earnings_for_social_security<2023, (default)> = [45000. 35000.     0.     0.]
#                                                       payroll_tax_gross_wages<2023, (default)> = [45000. 35000.     0.     0.]
#                                                         employment_income<2023, (default)> = [45000. 35000.     0.     0.]
#                                                 self_employment_medicare_tax<2023, (default)> = [0. 0. 0. 0.]
#                                                   taxable_self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                           early_withdrawal_penalty<2023, (default)> = [0. 0. 0. 0.]
#                                           alimony_income<2023, (default)> = [0. 0. 0. 0.]
#                                           educator_expense<2023, (default)> = [0. 0. 0. 0.]
#                                           health_savings_account_ald<2023, (default)> = [0.]
#                                           self_employed_health_insurance_ald<2023, (default)> = [0.]
#                                             self_employed_health_insurance_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employed_health_insurance_premiums<2023, (default)> = [0. 0. 0. 0.]
#                                                 is_self_employed<2023, (default)> = [False False False False]
#                                                 health_insurance_premiums<2023, (default)> = [0. 0. 0. 0.]
#                                           self_employed_pension_contribution_ald<2023, (default)> = [0.]
#                                             self_employed_pension_contribution_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employed_pension_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                           ira_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                           sep_simple_qualified_plan_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                         filing_status<2023, (default)> = ['JOINT']
#                                       tax_unit_social_security<2023, (default)> = [0.]
#                                       social_security<2023, (default)> = [0. 0. 0. 0.]
#                                       is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                                       is_tax_unit_head<2023, (default)> = [ True False False False]
#                                     illicit_income<2023, (default)> = [0. 0. 0. 0.]
#                                     loss_ald<2023, (default)> = [0.]
#                                     self_employment_tax_ald<2023, (default)> = [0.]
#                                     student_loan_interest<2023, (default)> = [0. 0. 0. 0.]
#                                     early_withdrawal_penalty<2023, (default)> = [0. 0. 0. 0.]
#                                     alimony_income<2023, (default)> = [0. 0. 0. 0.]
#                                     educator_expense<2023, (default)> = [0. 0. 0. 0.]
#                                     health_savings_account_ald<2023, (default)> = [0.]
#                                     self_employed_health_insurance_ald<2023, (default)> = [0.]
#                                     self_employed_pension_contribution_ald<2023, (default)> = [0.]
#                                     ira_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                     sep_simple_qualified_plan_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                     qualified_adoption_assistance_expense<2023, (default)> = [0. 0. 0. 0.]
#                                     us_bonds_for_higher_ed<2023, (default)> = [0. 0. 0. 0.]
#                                     specified_possession_income<2023, (default)> = [0.]
#                                     puerto_rico_income<2023, (default)> = [0.]
#                                   filing_status<2023, (default)> = ['JOINT']
#                               taxable_social_security<2023, (default)> = [0. 0. 0. 0.]
#                               illicit_income<2023, (default)> = [0. 0. 0. 0.]
#                             above_the_line_deductions<2023, (default)> = [0.]
#                               loss_ald<2023, (default)> = [0.]
#                               self_employment_tax_ald<2023, (default)> = [0.]
#                               student_loan_interest<2023, (default)> = [0. 0. 0. 0.]
#                               early_withdrawal_penalty<2023, (default)> = [0. 0. 0. 0.]
#                               alimony_income<2023, (default)> = [0. 0. 0. 0.]
#                               educator_expense<2023, (default)> = [0. 0. 0. 0.]
#                               health_savings_account_ald<2023, (default)> = [0.]
#                               self_employed_health_insurance_ald<2023, (default)> = [0.]
#                               self_employed_pension_contribution_ald<2023, (default)> = [0.]
#                               ira_contributions<2023, (default)> = [0. 0. 0. 0.]
#                               sep_simple_qualified_plan_contributions<2023, (default)> = [0. 0. 0. 0.]
#                               qualified_adoption_assistance_expense<2023, (default)> = [0. 0. 0. 0.]
#                               us_bonds_for_higher_ed<2023, (default)> = [0. 0. 0. 0.]
#                               specified_possession_income<2023, (default)> = [0.]
#                               puerto_rico_income<2023, (default)> = [0.]
#                           foreign_earned_income_exclusion<2023, (default)> = [0.]
#                           student_loan_interest<2023, (default)> = [0. 0. 0. 0.]
#                           tax_exempt_social_security<2023, (default)> = [0.]
#                             tax_unit_social_security<2023, (default)> = [0.]
#                             tax_unit_taxable_social_security<2023, (default)> = [0.]
#                         tax_unit_fpg<2023, (default)> = [30000.]
#                           tax_unit_size<2023, (default)> = [4]
#                           state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#                     state_code_str<2023, (default)> = ['UT']
#                   is_infant_for_medicaid_nfc<2023, (default)> = [False False False False]
#                     age<2023, (default)> = [38. 35. 10. 10.]
#                 is_young_child_for_medicaid<2023, (default)> = [False False False False]
#                   is_young_child_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [2.6666667 2.6666667 2.6666667 2.6666667]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_young_child_for_medicaid_nfc<2023, (default)> = [False False False False]
#                     age<2023, (default)> = [38. 35. 10. 10.]
#                 is_older_child_for_medicaid<2023, (default)> = [False False False False]
#                   age<2023, (default)> = [38. 35. 10. 10.]
#                   medicaid_income_level<2023, (default)> = [2.6666667 2.6666667 2.6666667 2.6666667]
#                   state_code_str<2023, (default)> = ['UT']
#                 is_young_adult_for_medicaid<2023, (default)> = [False False False False]
#                   is_young_adult_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [2.6666667 2.6666667 2.6666667 2.6666667]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_young_adult_for_medicaid_nfc<2023, (default)> = [False False False False]
#                     age<2023, (default)> = [38. 35. 10. 10.]
#                 is_adult_for_medicaid<2023, (default)> = [False False False False]
#                   is_adult_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [2.6666667 2.6666667 2.6666667 2.6666667]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_adult_for_medicaid_nfc<2023, (default)> = [ True  True False False]
#                     age<2023, (default)> = [38. 35. 10. 10.]
#                 is_parent_for_medicaid<2023, (default)> = [False False False False]
#                   is_parent_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [2.6666667 2.6666667 2.6666667 2.6666667]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_parent_for_medicaid_nfc<2023, (default)> = [ True  True False False]
#                     is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                     tax_unit_count_dependents<2023, (default)> = [2]
#                       is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                 is_pregnant_for_medicaid<2023, (default)> = [False False False False]
#                   is_pregnant_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [2.6666667 2.6666667 2.6666667 2.6666667]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_pregnant_for_medicaid_nfc<2023, (default)> = [False False False False]
#                     is_pregnant<2023, (default)> = [False False False False]
#                     count_days_postpartum<2023, (default)> = [inf inf inf inf]
#                       under_60_days_postpartum<2023, (default)> = [False False False False]
#                       under_12_months_postpartum<2023, (default)> = [False False False False]
#                     state_code_str<2023, (default)> = ['UT']
#                 is_ssi_recipient_for_medicaid<2023, (default)> = [False False False False]
#                   state_code_str<2023, (default)> = ['UT']
#                   ssi<2023, (default)> = [0. 0. 0. 0.]
#             medicaid_benefit_value<2023, (default)> = [9966.585 9966.585 9966.585 9966.585]
#               state_code_str<2023, (default)> = ['UT']
#           is_pregnant<2023, (default)> = [False False False False]
#           wic_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#             is_pregnant<2023, (default)> = [False False False False]
#             is_mother<2023, (default)> = [False False False False]
#               is_female<2023, (default)> = [False False False False]
#               own_children_in_household<2023, (default)> = [0 0 0 0]
#               is_breastfeeding<2023, (default)> = [False False False False]
#             is_breastfeeding<2023, (default)> = [False False False False]
#             age<2023, (default)> = [38. 35. 10. 10.]
#         wic_category_str<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#           wic_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#         is_wic_at_nutritional_risk<2023, (default)> = [False False False False]
#           receives_wic<2023, (default)> = [False False False False]
#           meets_wic_income_test<2023, (default)> = [False]
#           meets_wic_categorical_eligibility<2023, (default)> = [False False False False]
#           wic_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#         would_claim_wic<2023, (default)> = [ True  True  True  True]
#       free_school_meals<2023, (default)> = [0.]
#         school_meal_tier<2023, (default)> = ['PAID']
#           school_meal_fpg_ratio<2023, (default)> = [2.6666667]
#             school_meal_countable_income<2023, (default)> = [80000.]
#             spm_unit_fpg<2023, (default)> = [30000.]
#           meets_school_meal_categorical_eligibility<2023, (default)> = [False]
#             snap<2023, (default)> = [0.]
#             tanf<2023, (default)> = [0.]
#             fdpir<2023, (default)> = [0.]
#         school_meal_net_subsidy<2023, (default)> = [0.]
#           school_meal_daily_subsidy<2023, (default)> = [0.72]
#             state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#             school_meal_tier<2023, (default)> = ['PAID']
#           school_meal_paid_daily_subsidy<2023, (default)> = [0.72]
#             state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#           is_in_k12_school<2023, (default)> = [False False  True  True]
#       reduced_price_school_meals<2023, (default)> = [0.]
#         school_meal_tier<2023, (default)> = ['PAID']
#         school_meal_net_subsidy<2023, (default)> = [0.]
#       lifeline<2023, (default)> = [0.]
#         is_rural<2023, (default)> = [False]
#         is_on_tribal_land<2023, (default)> = [False]
#         phone_cost<2023, (default)> = [1500.]
#         broadband_cost<2023, (default)> = [900.]
#         is_lifeline_eligible<2023, (default)> = [False]
#           medicaid<2023, (default)> = [0. 0. 0. 0.]
#           snap<2023, (default)> = [0.]
#           ssi<2023, (default)> = [0. 0. 0. 0.]
#           fcc_fpg_ratio<2023, (default)> = [2.6666667]
#             irs_gross_income<2023, (default)> = [45000. 35000.     0.     0.]
#             spm_unit_fpg<2023, (default)> = [30000.]
#       acp<2023, (default)> = [0.]
#         is_acp_eligible<2023, (default)> = [False]
#           lifeline<2023, (default)> = [0.]
#           free_school_meals<2023, (default)> = [0.]
#           reduced_price_school_meals<2023, (default)> = [0.]
#           pell_grant<2023, (default)> = [0.]
#           wic<2023, (default)> = [0. 0. 0. 0.]
#           medicaid<2023, (default)> = [0. 0. 0. 0.]
#           snap<2023, (default)> = [0.]
#           ssi<2023, (default)> = [0. 0. 0. 0.]
#           fcc_fpg_ratio<2023, (default)> = [2.6666667]
#           ebb<2023, (default)> = [0.]
#             is_ebb_eligible<2023, (default)> = [False]
#               is_lifeline_eligible<2023, (default)> = [False]
#               free_school_meals<2023, (default)> = [0.]
#               reduced_price_school_meals<2023, (default)> = [0.]
#               pell_grant<2023, (default)> = [0.]
#               experienced_covid_income_loss<2023, (default)> = [False]
#               enrolled_in_ebb<2023, (default)> = [False]
#             broadband_cost_after_lifeline<2023, (default)> = [900.]
#               broadband_cost<2023, (default)> = [900.]
#               lifeline<2023, (default)> = [0.]
#             is_on_tribal_land<2023, (default)> = [False]
#         broadband_cost_after_lifeline<2023, (default)> = [900.]
#         is_on_tribal_land<2023, (default)> = [False]
#       ebb<2023, (default)> = [0.]
#       tanf<2023, (default)> = [0.]
#       high_efficiency_electric_home_rebate<2023, (default)> = [0.]
#         capped_electric_heat_pump_clothes_dryer_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#             tax_unit_income_ami_ratio<2023, (default)> = [0.]
#           electric_heat_pump_clothes_dryer_expenditures<2023, (default)> = [0.]
#         capped_electric_load_service_center_upgrade_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           electric_load_service_center_upgrade_expenditures<2023, (default)> = [0.]
#         capped_electric_stove_cooktop_range_or_oven_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           electric_stove_cooktop_range_or_oven_expenditures<2023, (default)> = [0.]
#         capped_electric_wiring_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           electric_wiring_expenditures<2023, (default)> = [0.]
#         capped_heat_pump_water_heater_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           heat_pump_water_heater_expenditures<2023, (default)> = [0.]
#         capped_heat_pump_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           heat_pump_expenditures<2023, (default)> = [0.]
#         capped_insulation_air_sealing_ventilation_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           energy_efficient_insulation_expenditures<2023, (default)> = [0.]
#           air_sealing_ventilation_expenditures<2023, (default)> = [0.]
#       residential_efficiency_electrification_rebate<2023, (default)> = [0.]
#         residential_efficiency_electrification_retrofit_expenditures<2023, (default)> = [0.]
#         residential_efficiency_electrification_retrofit_energy_savings<2023, (default)> = [0.]
#         current_home_energy_use<2023, (default)> = [0.]
#         household_income_ami_ratio<2023, (default)> = [0.]
#         average_home_energy_use_in_state<2023, (default)> = [0.]
#       basic_income<2023, (default)> = [0.]
#         basic_income_eligible<2023, (default)> = [ True]
#         basic_income_before_phase_out<2023, (default)> = [0.]
#           tax_unit_size<2023, (default)> = [4]
#           age<2023, (default)> = [38. 35. 10. 10.]
#           tax_unit_fpg<2023, (default)> = [30000.]
#         basic_income_phase_out<2023, (default)> = [0.]
#           basic_income_before_phase_out<2023, (default)> = [0.]
#           adjusted_gross_income<2023, (default)> = [80000.]
#           filing_status<2023, (default)> = ['JOINT']
#       spm_unit_capped_housing_subsidy<2023, (default)> = [0.]
#         spm_unit_capped_housing_subsidy_reported<2023, (default)> = [0.]
#     household_refundable_tax_credits<2023, (default)> = [0.]
#       income_tax_refundable_credits<2023, (default)> = [0.]
#         eitc<2023, (default)> = [0.]
#           earned_income_tax_credit<2023, (default)> = [0.]
#             eitc_eligible<2023, (default)> = [ True]
#               is_child<2023, (default)> = [False False  True  True]
#               age<2023, (default)> = [38. 35. 10. 10.]
#               tax_exempt_interest_income<2023, (default)> = [0. 0. 0. 0.]
#               taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#               dividend_income<2023, (default)> = [0. 0. 0. 0.]
#               c01000<2023, (default)> = [0.]
#                 sep<2023, (default)> = [1]
#                 c23650<2023, (default)> = [0.]
#                   long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   short_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#               tax_unit_rental_income<2023, (default)> = [0.]
#                 rental_income<2023, (default)> = [0. 0. 0. 0.]
#               tax_unit_partnership_s_corp_income<2023, (default)> = [0.]
# ...
#                         blind_head<2023, (default)> = [False]
#                           is_blind<2023, (default)> = [False False False False]
#                           is_tax_unit_head<2023, (default)> = [ True False False False]
#                         blind_spouse<2023, (default)> = [False]
#                           is_blind<2023, (default)> = [False False False False]
#                           is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                         age_head<2023, (default)> = [38]
#                         age_spouse<2023, (default)> = [35]
#                 taxable_income_deductions_if_itemizing<2023, (default)> = [8477.512]
#                   charitable_deduction<2023, (default)> = [6000.]
#                   interest_deduction<2023, (default)> = [0.]
#                   salt_deduction<2023, (default)> = [2477.512]
#                     state_and_local_sales_or_income_tax<2023, (default)> = [2477.512]
#                       state_income_tax<2023, (default)> = [2477.512]
#                         ma_income_tax<2023, (default)> = [0.]
#                           MA<2023, (default)> = [False]
#                         md_income_tax<2023, (default)> = [0.]
#                           MD<2023, (default)> = [False]
#                         ny_income_tax<2023, (default)> = [0.]
#                           NY<2023, (default)> = [False]
#                         or_income_tax<2023, (default)> = [0.]
#                           OR<2023, (default)> = [False]
#                         pa_income_tax<2023, (default)> = [0.]
#                           PA<2023, (default)> = [False]
#                             state_code_str<2023, (default)> = ['UT']
#                         wa_income_tax<2023, (default)> = [0.]
#                           WA<2023, (default)> = [False]
#                         ut_income_tax<2023, (default)> = [2477.512]
#                           UT<2023, (default)> = [ True]
#                           ut_income_tax_before_refundable_credits<2023, (default)> = [2477.512]
#                             ut_income_tax_after_credits<2023, (default)> = [2477.512]
#                               ut_income_tax_before_credits<2023, (default)> = [3720.]
#                                 UT<2023, (default)> = [ True]
#                                 ut_taxable_income<2023, (default)> = [80000.]
#                                   UT<2023, (default)> = [ True]
#                                   ut_total_income<2023, (default)> = [80000.]
#                                     UT<2023, (default)> = [ True]
#                                     adjusted_gross_income<2023, (default)> = [80000.]
#                                     ut_additions_to_income<2023, (default)> = [0.]
#                                       UT<2023, (default)> = [ True]
#                                   salt_refund_last_year<2023, (default)> = [0.]
#                                   ut_subtractions_from_income<2023, (default)> = [0.]
#                                     UT<2023, (default)> = [ True]
#                               ut_taxpayer_credit<2023, (default)> = [1242.488]
#                                 UT<2023, (default)> = [ True]
#                                 ut_taxpayer_credit_max<2023, (default)> = [1878.24]
#                                   UT<2023, (default)> = [ True]
#                                   tax_unit_count_dependents<2023, (default)> = [2]
#                                   tax_unit_itemizes<2023, (default)> = [False]
#                                   standard_deduction<2023, (default)> = [27700.]
#                                   charitable_deduction<2023, (default)> = [6000.]
#                                   interest_deduction<2023, (default)> = [0.]
#                                   medical_expense_deduction<2023, (default)> = [0.]
#                                   casualty_loss_deduction<2023, (default)> = [0.]
#                                 ut_taxpayer_credit_reduction<2023, (default)> = [635.752]
#                                   UT<2023, (default)> = [ True]
#                                   filing_status<2023, (default)> = ['JOINT']
#                                   ut_taxable_income<2023, (default)> = [80000.]
#                             ut_apportionable_nonrefundable_credits<2023, (default)> = [0.]
#                               UT<2023, (default)> = [ True]
#                             ut_nonapportionable_nonrefundable_credits<2023, (default)> = [0.]
#                               UT<2023, (default)> = [ True]
#                             ut_recapture_low_inc_housing_credit<2023, (default)> = [0.]
#                               UT<2023, (default)> = [ True]
#                           ut_refundable_credits<2023, (default)> = [0.]
#                       local_income_tax<2023, (default)> = [0.]
#                       state_sales_tax<2023, (default)> = [0.]
#                       local_sales_tax<2023, (default)> = [0.]
#                     real_estate_taxes<2023, (default)> = [0. 0. 0. 0.]
#                     filing_status<2023, (default)> = ['JOINT']
#                   medical_expense_deduction<2023, (default)> = [0.]
#                   casualty_loss_deduction<2023, (default)> = [0.]
#                   qualified_business_income_deduction<2023, (default)> = [0.]
#                     qbid_amount<2023, (default)> = [0. 0. 0. 0.]
#                       qualified_business_income<2023, (default)> = [0. 0. 0. 0.]
#                         self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                         partnership_s_corp_income<2023, (default)> = [0. 0. 0. 0.]
#                         farm_income<2023, (default)> = [0. 0. 0. 0.]
#                         farm_rent_income<2023, (default)> = [0. 0. 0. 0.]
#                         self_employment_tax_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                         self_employed_health_insurance_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                         self_employed_pension_contribution_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                         business_is_qualified<2023, (default)> = [False False False False]
#                       w2_wages_from_qualified_business<2023, (default)> = [0. 0. 0. 0.]
#                       unadjusted_basis_qualified_property<2023, (default)> = [0. 0. 0. 0.]
#                       taxable_income_less_qbid<2023, (default)> = [52300.]
#                         adjusted_gross_income<2023, (default)> = [80000.]
#                         charitable_deduction<2023, (default)> = [6000.]
#                         interest_deduction<2023, (default)> = [0.]
#                         salt_deduction<2023, (default)> = [2477.512]
#                         medical_expense_deduction<2023, (default)> = [0.]
#                         casualty_loss_deduction<2023, (default)> = [0.]
#                         standard_deduction<2023, (default)> = [27700.]
#                       filing_status<2023, (default)> = ['JOINT']
#                       business_is_sstb<2023, (default)> = [False False False False]
#                     taxable_income_less_qbid<2023, (default)> = [52300.]
#                     adjusted_net_capital_gain<2023, (default)> = [0.]
#                       net_capital_gain<2023, (default)> = [0.]
#                         net_long_term_capital_gain<2023, (default)> = [0.]
#                           long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                           long_term_capital_losses<2023, (default)> = [0. 0. 0. 0.]
#                         net_short_term_capital_loss<2023, (default)> = [0.]
#                           short_term_capital_losses<2023, (default)> = [0. 0. 0. 0.]
#                           short_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                         qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                       qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                       unrecaptured_section_1250_gain<2023, (default)> = [0.]
#                       capital_gains_28_percent_rate_gain<2023, (default)> = [0.]
#                         long_term_capital_gains_on_collectibles<2023, (default)> = [0. 0. 0. 0.]
#                         long_term_capital_gains_on_small_business_stock<2023, (default)> = [0. 0. 0. 0.]
#                 taxable_income_deductions_if_not_itemizing<2023, (default)> = [27700.]
#                   standard_deduction<2023, (default)> = [27700.]
#                   qualified_business_income_deduction<2023, (default)> = [0.]
#             capital_gains_excluded_from_taxable_income<2023, (default)> = [0.]
#               net_capital_gain<2023, (default)> = [0.]
#               adjusted_net_capital_gain<2023, (default)> = [0.]
#               taxable_income<2023, (default)> = [52300.]
#               filing_status<2023, (default)> = ['JOINT']
#             filing_status<2023, (default)> = ['JOINT']
#           capital_gains_tax<2023, (default)> = [0.]
#             net_capital_gain<2023, (default)> = [0.]
#             taxable_income<2023, (default)> = [52300.]
#             adjusted_net_capital_gain<2023, (default)> = [0.]
#             capital_gains_excluded_from_taxable_income<2023, (default)> = [0.]
#             filing_status<2023, (default)> = ['JOINT']
#             unrecaptured_section_1250_gain<2023, (default)> = [0.]
#             qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#             capital_gains_28_percent_rate_gain<2023, (default)> = [0.]
#           alternative_minimum_tax<2023, (default)> = [0.]
#             c09600<2023, (default)> = [0.]
#               c62100<2023, (default)> = [80000.]
#                 amt_income<2023, (default)> = [80000.]
#                   taxable_income<2023, (default)> = [52300.]
#                   tax_unit_itemizes<2023, (default)> = [False]
#                   standard_deduction<2023, (default)> = [27700.]
#                   salt_deduction<2023, (default)> = [2477.512]
#                   filing_status<2023, (default)> = ['JOINT']
#               filing_status<2023, (default)> = ['JOINT']
#               age_head<2023, (default)> = [38]
#               age_spouse<2023, (default)> = [35]
#               filer_earned<2023, (default)> = [80000.]
#               sep<2023, (default)> = [1]
#               dwks10<2023, (default)> = [0.]
#                 dwks6<2023, (default)> = [0.]
#                   qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                   investment_income_form_4952<2023, (default)> = [0.]
#                 dwks9<2023, (default)> = [0.]
#                   long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                   c23650<2023, (default)> = [0.]
#                   non_sch_d_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   investment_income_form_4952<2023, (default)> = [0.]
#                 long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                 qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                 c23650<2023, (default)> = [0.]
#                 non_sch_d_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                 hasqdivltcg<2023, (default)> = [False]
#                   c01000<2023, (default)> = [0.]
#                   c23650<2023, (default)> = [0.]
#                   long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   non_sch_d_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#               dwks13<2023, (default)> = [0.]
#                 unrecaptured_section_1250_gain<2023, (default)> = [0.]
#                 capital_gains_28_percent_rate_gain<2023, (default)> = [0.]
#                 dwks9<2023, (default)> = [0.]
#                 dwks10<2023, (default)> = [0.]
#                 hasqdivltcg<2023, (default)> = [False]
#               dwks14<2023, (default)> = [0.]
#                 taxable_income<2023, (default)> = [52300.]
#                 dwks13<2023, (default)> = [0.]
#                 hasqdivltcg<2023, (default)> = [False]
#               dwks19<2023, (default)> = [0.]
#                 dwks14<2023, (default)> = [0.]
#                 filing_status<2023, (default)> = ['JOINT']
#                 taxable_income<2023, (default)> = [52300.]
#                 dwks10<2023, (default)> = [0.]
#                 hasqdivltcg<2023, (default)> = [False]
#               unrecaptured_section_1250_gain<2023, (default)> = [0.]
#               sep<2023, (default)> = [1]
#               foreign_tax_credit<2023, (default)> = [0.]
#               amt_form_completed<2023, (default)> = [False]
#               foreign_tax_credit<2023, (default)> = [0.]
#               taxbc<2023, (default)> = [5836.]
#                 regular_tax_before_credits<2023, (default)> = [5836.]
#                   filing_status<2023, (default)> = ['JOINT']
#                   taxable_income<2023, (default)> = [52300.]
#                   dwks14<2023, (default)> = [0.]
#                   dwks13<2023, (default)> = [0.]
#                   dwks19<2023, (default)> = [0.]
#                   dwks9<2023, (default)> = [0.]
#                   unrecaptured_section_1250_gain<2023, (default)> = [0.]
#                   dwks10<2023, (default)> = [0.]
#                   income_tax_main_rates<2023, (default)> = [5836.]
#                   hasqdivltcg<2023, (default)> = [False]
#               c05700<2023, (default)> = [0.]
#         net_investment_income_tax<2023, (default)> = [0.]
#           taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#           dividend_income<2023, (default)> = [0. 0. 0. 0.]
#           c01000<2023, (default)> = [0.]
#           rental_income<2023, (default)> = [0. 0. 0. 0.]
#           filing_status<2023, (default)> = ['JOINT']
#           adjusted_gross_income<2023, (default)> = [80000.]
#         recapture_of_investment_credit<2023, (default)> = [0.]
#         unreported_payroll_tax<2023, (default)> = [0.]
#         qualified_retirement_penalty<2023, (default)> = [0.]
#         income_tax_capped_non_refundable_credits<2023, (default)> = [4200.]
#           income_tax_non_refundable_credits<2023, (default)> = [4200.]
#             cdcc<2023, (default)> = [200.]
#             elderly_disabled_credit<2023, (default)> = [0.]
#             non_refundable_ctc<2023, (default)> = [4000.]
#               ctc<2023, (default)> = [4000.]
#               refundable_ctc<2023, (default)> = [0.]
#             non_refundable_american_opportunity_credit<2023, (default)> = [0.]
#             lifetime_learning_credit<2023, (default)> = [0.]
#             retirement_savings_credit<2023, (default)> = [0.]
#             residential_clean_energy_credit<2023, (default)> = [0.]
#             energy_efficient_home_improvement_credit<2023, (default)> = [0.]
#             new_clean_vehicle_credit<2023, (default)> = [0.]
#             used_clean_vehicle_credit<2023, (default)> = [0.]
#           income_tax_unavailable_non_refundable_credits<2023, (default)> = [0.]
#             income_tax_before_credits<2023, (default)> = [5836.]
#             income_tax_non_refundable_credits<2023, (default)> = [4200.]
#             income_tax_non_refundable_credits<2023, (default)> = [4200.]
#       ma_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         MA<2023, (default)> = [False]
#       md_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         MD<2023, (default)> = [False]
#       ny_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         NY<2023, (default)> = [False]
#       or_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         or_income_tax_before_credits<2023, (default)> = [0.]
#           OR<2023, (default)> = [False]
#         or_non_refundable_credits<2023, (default)> = [0.]
#           or_exemption_credit<2023, (default)> = [0.]
#             OR<2023, (default)> = [False]
#       pa_income_tax<2023, (default)> = [0.]
#       ut_income_tax_before_refundable_credits<2023, (default)> = [2477.512]
#       wa_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         WA<2023, (default)> = [False]
#       flat_tax<2023, (default)> = [0.]
#         positive_agi<2023, (default)> = [80000.]

# %% [markdown]
# #### 3.3.3. Effect of rate cut to 4.65% on high income household

# %%
simulation_1_h = Simulation(
    reform=reform_1,
    situation=situation_high,
)

simulation_1_h.trace = True
simulation_1_h.calculate("household_net_income", 2023)
simulation_1_h.tracer.print_computation_log()
# Out:
#   household_net_income<2023, (default)> = [150905.48]
#     household_market_income<2023, (default)> = [200000.]
#       employment_income<2023, (default)> = [100000. 100000.      0.      0.]
#       self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#       pension_income<2023, (default)> = [0. 0. 0. 0.]
#         tax_exempt_pension_income<2023, (default)> = [0. 0. 0. 0.]
#         taxable_pension_income<2023, (default)> = [0. 0. 0. 0.]
#       dividend_income<2023, (default)> = [0. 0. 0. 0.]
#         qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#         non_qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#       interest_income<2023, (default)> = [0. 0. 0. 0.]
#         tax_exempt_interest_income<2023, (default)> = [0. 0. 0. 0.]
#         taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#       gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#       capital_gains<2023, (default)> = [0. 0. 0. 0.]
#         short_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#         long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#       rental_income<2023, (default)> = [0. 0. 0. 0.]
#       illicit_income<2023, (default)> = [0. 0. 0. 0.]
#       farm_income<2023, (default)> = [0. 0. 0. 0.]
#     household_benefits<2023, (default)> = [0.]
#       social_security<2023, (default)> = [0. 0. 0. 0.]
#         social_security_dependents<2023, (default)> = [0. 0. 0. 0.]
#         social_security_disability<2023, (default)> = [0. 0. 0. 0.]
#         social_security_retirement<2023, (default)> = [0. 0. 0. 0.]
#         social_security_survivors<2023, (default)> = [0. 0. 0. 0.]
#       ssi<2023, (default)> = [0. 0. 0. 0.]
#         uncapped_ssi<2023, (default)> = [0. 0. 0. 0.]
#           ssi_amount_if_eligible<2023, (default)> = [16452. 10968. 10968. 10968.]
#             ssi_claim_is_joint<2023, (default)> = [ True False False False]
#               is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                 is_ssi_aged<2023, (default)> = [False False False False]
#                   age<2023, (default)> = [38. 35. 10. 10.]
#                 is_blind<2023, (default)> = [False False False False]
#                 is_ssi_disabled<2023, (default)> = [False False False False]
#                   is_ssi_aged<2023, (default)> = [False False False False]
#                   is_blind<2023, (default)> = [False False False False]
#                   ssi_reported<2023, (default)> = [0. 0. 0. 0.]
#               ssi_income_deemed_from_ineligible_spouse<2023, (default)> = [50000.     0.     0.     0.]
#                 ssi_earned_income<2023, (default)> = [100000. 100000.      0.      0.]
#                   employment_income<2023, (default)> = [100000. 100000.      0.      0.]
#                   self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                 ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#                   dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                   interest_income<2023, (default)> = [0. 0. 0. 0.]
#                   gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#                   social_security<2023, (default)> = [0. 0. 0. 0.]
#                   alimony_income<2023, (default)> = [0. 0. 0. 0.]
#                   pension_income<2023, (default)> = [0. 0. 0. 0.]
#                   unemployment_compensation<2023, (default)> = [0. 0. 0. 0.]
#                 ssi_earned_income_deemed_from_ineligible_spouse<2023, (default)> = [100000.      0.      0.      0.]
#                   is_ssi_ineligible_spouse<2023, (default)> = [False  True False False]
#                     is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                       is_child<2023, (default)> = [False False  True  True]
#                         age<2023, (default)> = [38. 35. 10. 10.]
#                       is_tax_unit_head<2023, (default)> = [ True False False False]
#                         is_child<2023, (default)> = [False False  True  True]
#                         age<2023, (default)> = [38. 35. 10. 10.]
#                       age<2023, (default)> = [38. 35. 10. 10.]
#                     is_ssi_eligible_spouse<2023, (default)> = [False False False False]
#                       is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                       is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                   ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#                   ssi_earned_income<2023, (default)> = [100000. 100000.      0.      0.]
#                   ssi_ineligible_child_allocation<2023, (default)> = [   0.    0. 5484. 5484.]
#                     ssi_earned_income<2023, (default)> = [100000. 100000.      0.      0.]
#                     ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#                     is_ssi_ineligible_child<2023, (default)> = [False False  True  True]
#                       is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                       is_child<2023, (default)> = [False False  True  True]
#                   is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                 ssi_unearned_income_deemed_from_ineligible_spouse<2023, (default)> = [0. 0. 0. 0.]
#                   is_ssi_ineligible_spouse<2023, (default)> = [False  True False False]
#                   ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#                   ssi_ineligible_child_allocation<2023, (default)> = [   0.    0. 5484. 5484.]
#                 is_ssi_ineligible_child<2023, (default)> = [False False  True  True]
#           meets_ssi_resource_test<2023, (default)> = [ True  True  True  True]
#             ssi_claim_is_joint<2023, (default)> = [ True False False False]
#             ssi_countable_resources<2023, (default)> = [0. 0. 0. 0.]
#           is_ssi_eligible_individual<2023, (default)> = [False False False False]
#             is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#             is_ssi_eligible_spouse<2023, (default)> = [False False False False]
#           ssi_countable_income<2023, (default)> = [0. 0. 0. 0.]
#             ssi_earned_income<2023, (default)> = [100000. 100000.      0.      0.]
#             ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#             ssi_unearned_income_deemed_from_ineligible_parent<2023, (default)> = [0. 0. 0. 0.]
#               is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#               is_child<2023, (default)> = [False False  True  True]
#               is_ssi_ineligible_parent<2023, (default)> = [False False False False]
#                 is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                 is_child<2023, (default)> = [False False  True  True]
#               ssi_earned_income<2023, (default)> = [100000. 100000.      0.      0.]
#               ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#               ssi_ineligible_child_allocation<2023, (default)> = [   0.    0. 5484. 5484.]
#               ssi_ineligible_parent_allocation<2023, (default)> = [0. 0. 0. 0.]
#                 is_ssi_ineligible_parent<2023, (default)> = [False False False False]
#             ssi_income_deemed_from_ineligible_spouse<2023, (default)> = [50000.     0.     0.     0.]
#             is_ssi_eligible_individual<2023, (default)> = [False False False False]
#       state_supplement<2023, (default)> = [0. 0. 0. 0.]
#         uncapped_ssi<2023, (default)> = [0. 0. 0. 0.]
#         maximum_state_supplement<2023, (default)> = [0. 0. 0. 0.]
#           is_ssi_eligible_individual<2023, (default)> = [False False False False]
#           state_code_str<2023, (default)> = ['UT']
#             state_code<2023, (default)> = ['UT']
#               state_name<2023, (default)> = ['UT']
#           state_living_arrangement<2023, (default)> = ['FULL_COST']
#           is_blind<2023, (default)> = [False False False False]
#           is_ssi_aged<2023, (default)> = [False False False False]
#           is_ssi_disabled<2023, (default)> = [False False False False]
#           ssi_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#           ssi_claim_is_joint<2023, (default)> = [ True False False False]
#         is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#         meets_ssi_resource_test<2023, (default)> = [ True  True  True  True]
#         ssi_claim_is_joint<2023, (default)> = [ True False False False]
#       ca_cvrp<2023, (default)> = [0. 0. 0. 0.]
#         CA<2023, (default)> = [False]
#           state_code_str<2023, (default)> = ['UT']
#       snap<2023, (default)> = [0.]
#         snap_normal_allotment<2023, (default)> = [0.]
#           is_snap_eligible<2023, (default)> = [False]
#             meets_snap_net_income_test<2023, (default)> = [False]
#               snap_net_income_fpg_ratio<2023, (default)> = [5.2043333]
#                 snap_net_income<2023, (default)> = [156130.]
#                   snap_gross_income<2023, (default)> = [200000.]
#                     snap_earned_income<2023, (default)> = [200000.]
#                       employment_income<2023, (default)> = [100000. 100000.      0.      0.]
#                       self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                     snap_unearned_income<2023, (default)> = [0.]
#                       dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                       interest_income<2023, (default)> = [0. 0. 0. 0.]
#                       gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#                       social_security<2023, (default)> = [0. 0. 0. 0.]
#                       ssi<2023, (default)> = [0. 0. 0. 0.]
#                   snap_deductions<2023, (default)> = [43870.]
#                     snap_standard_deduction<2023, (default)> = [2316.]
#                       state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#                         state_group<2023, (default)> = ['CONTIGUOUS_US']
#                           state_code<2023, (default)> = ['UT']
#                       spm_unit_size<2023, (default)> = [4]
#                     snap_earned_income_deduction<2023, (default)> = [40000.]
#                       snap_earned_income<2023, (default)> = [200000.]
#                     snap_dependent_care_deduction<2023, (default)> = [1500.]
#                       childcare_expenses<2023, (default)> = [1500.]
#                     snap_child_support_deduction<2023, (default)> = [0.]
#                       child_support_expense<2023, (default)> = [0. 0. 0. 0.]
#                       state_code_str<2023, (default)> = ['UT']
#                     snap_excess_medical_expense_deduction<2023, (default)> = [0.]
#                       is_usda_elderly<2023, (default)> = [False False False False]
#                         age<2023, (default)> = [38. 35. 10. 10.]
#                       is_usda_disabled<2023, (default)> = [False False False False]
#                         is_ssi_disabled<2023, (default)> = [False False False False]
#                         social_security_disability<2023, (default)> = [0. 0. 0. 0.]
#                         is_permanently_disabled_veteran<2023, (default)> = [False False False False]
#                         is_surviving_spouse_of_disabled_veteran<2023, (default)> = [False False False False]
#                         is_surviving_child_of_disabled_veteran<2023, (default)> = [False False False False]
#                       medical_out_of_pocket_expenses<2023, (default)> = [4000.    0.    0.    0.]
#                       state_code_str<2023, (default)> = ['UT']
#                     snap_excess_shelter_expense_deduction<2023, (default)> = [54.]
#                       snap_net_income_pre_shelter<2023, (default)> = [156184.]
#                         snap_gross_income<2023, (default)> = [200000.]
#                         snap_standard_deduction<2023, (default)> = [2316.]
#                         snap_earned_income_deduction<2023, (default)> = [40000.]
#                         snap_dependent_care_deduction<2023, (default)> = [1500.]
#                         snap_child_support_deduction<2023, (default)> = [0.]
#                         snap_excess_medical_expense_deduction<2023, (default)> = [0.]
#                       housing_cost<2023, (default)> = [36000.]
#                       snap_region_str<2023, (default)> = ['CONTIGUOUS_US']
#                         snap_region<2023, (default)> = ['CONTIGUOUS_US']
#                           state_group<2023, (default)> = ['CONTIGUOUS_US']
#                       has_usda_elderly_disabled<2023, (default)> = [False]
#                         is_usda_elderly<2023, (default)> = [False False False False]
#                         is_usda_disabled<2023, (default)> = [False False False False]
#                       snap_utility_allowance<2023, (default)> = [54.]
#                         snap_utility_allowance_type<2023, (default)> = ['IUA']
#                           count_distinct_utility_expenses<2023, (default)> = [1]
#                             heating_cooling_expense<2023, (default)> = [0.]
#                             electricity_expense<2023, (default)> = [0.]
#                             gas_expense<2023, (default)> = [0.]
#                             phone_expense<2023, (default)> = [2400.]
#                               phone_cost<2023, (default)> = [2400.]
#                             trash_expense<2023, (default)> = [0.]
#                             water_expense<2023, (default)> = [0.]
#                             sewage_expense<2023, (default)> = [0.]
#                           snap_utility_region_str<2023, (default)> = ['UT']
#                             snap_utility_region<2023, (default)> = ['UT']
#                               state_code<2023, (default)> = ['UT']
#                           has_heating_cooling_expense<2023, (default)> = [False]
#                             heating_cooling_expense<2023, (default)> = [0.]
#                         snap_utility_region_str<2023, (default)> = ['UT']
#                       state_code_str<2023, (default)> = ['UT']
#                       is_homeless<2023, (default)> = [False]
#                 spm_unit_fpg<2023, (default)> = [30000.]
#                   spm_unit_size<2023, (default)> = [4]
#                   state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#             meets_snap_gross_income_test<2023, (default)> = [False]
#               snap_gross_income_fpg_ratio<2023, (default)> = [6.6666665]
#                 snap_gross_income<2023, (default)> = [200000.]
#                 spm_unit_fpg<2023, (default)> = [30000.]
#               has_usda_elderly_disabled<2023, (default)> = [False]
#             meets_snap_asset_test<2023, (default)> = [ True]
#               has_usda_elderly_disabled<2023, (default)> = [False]
#               snap_assets<2023, (default)> = [0.]
#             meets_snap_categorical_eligibility<2023, (default)> = [False]
#               ssi<2023, (default)> = [0. 0. 0. 0.]
#               is_tanf_non_cash_eligible<2023, (default)> = [False]
#                 meets_tanf_non_cash_gross_income_test<2023, (default)> = [False]
#                   state_code_str<2023, (default)> = ['UT']
#                   snap_gross_income_fpg_ratio<2023, (default)> = [6.6666665]
#                 meets_tanf_non_cash_net_income_test<2023, (default)> = [ True]
#                   state_code_str<2023, (default)> = ['UT']
#                   is_tanf_non_cash_hheod<2023, (default)> = [False]
#                     state_code_str<2023, (default)> = ['UT']
#                     has_all_usda_elderly_disabled<2023, (default)> = [False]
#                       is_usda_elderly<2023, (default)> = [False False False False]
#                       is_usda_disabled<2023, (default)> = [False False False False]
#                     has_usda_elderly_disabled<2023, (default)> = [False]
#                   snap_net_income_fpg_ratio<2023, (default)> = [5.2043333]
#                 meets_tanf_non_cash_asset_test<2023, (default)> = [False]
#                   snap_assets<2023, (default)> = [0.]
#                   state_code_str<2023, (default)> = ['UT']
#           snap_expected_contribution<2023, (default)> = [46839.]
#             snap_net_income<2023, (default)> = [156130.]
#           snap_max_allotment<2023, (default)> = [11268.]
#             snap_region_str<2023, (default)> = ['CONTIGUOUS_US']
#             spm_unit_size<2023, (default)> = [4]
#             spm_unit_size<2023, (default)> = [4]
#           snap_min_allotment<2023, (default)> = [0.]
#             snap_region_str<2023, (default)> = ['CONTIGUOUS_US']
#             spm_unit_size<2023, (default)> = [4]
#         snap_emergency_allotment<2023, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-01, (default)> = [0.]
#             is_snap_eligible<2023, (default)> = [False]
#             snap_max_allotment<2023, (default)> = [11268.]
#             snap_normal_allotment<2023, (default)> = [0.]
#             state_code<2023, (default)> = ['UT']
#           snap_emergency_allotment_monthly<2023-02, (default)> = [0.]
#             is_snap_eligible<2023, (default)> = [False]
#             snap_max_allotment<2023, (default)> = [11268.]
#             snap_normal_allotment<2023, (default)> = [0.]
#             state_code<2023, (default)> = ['UT']
#           snap_emergency_allotment_monthly<2023-03, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-04, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-05, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-06, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-07, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-08, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-09, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-10, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-11, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-12, (default)> = [0.]
#       wic<2023, (default)> = [0. 0. 0. 0.]
#         meets_wic_income_test<2023, (default)> = [False]
#           school_meal_countable_income<2023, (default)> = [200000.]
#             employment_income<2023, (default)> = [100000. 100000.      0.      0.]
#             self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#             dividend_income<2023, (default)> = [0. 0. 0. 0.]
#             interest_income<2023, (default)> = [0. 0. 0. 0.]
#             gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#             social_security<2023, (default)> = [0. 0. 0. 0.]
#             ssi<2023, (default)> = [0. 0. 0. 0.]
#           wic_fpg<2023, (default)> = [30000.]
#             is_pregnant<2023, (default)> = [False False False False]
#             spm_unit_fpg<2023, (default)> = [30000.]
#             state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#         meets_wic_categorical_eligibility<2023, (default)> = [False False False False]
#           snap<2023, (default)> = [0.]
#           tanf<2023, (default)> = [0.]
#             tanf_reported<2023, (default)> = [0. 0. 0. 0.]
#             is_tanf_eligible<2023, (default)> = [False]
#               is_person_demographic_tanf_eligible<2023, (default)> = [False False  True  True]
#                 is_child<2023, (default)> = [False False  True  True]
#                 age<2023, (default)> = [38. 35. 10. 10.]
#                 is_full_time_student<2023, (default)> = [False False  True  True]
#                   is_full_time_college_student<2023, (default)> = [False False False False]
#                   is_in_k12_school<2023, (default)> = [False False  True  True]
#                     age<2023, (default)> = [38. 35. 10. 10.]
#                 is_pregnant<2023, (default)> = [False False False False]
#               is_tanf_enrolled<2023, (default)> = [False]
#               is_tanf_continuous_eligible<2023, (default)> = [False]
#                 tanf_gross_earned_income<2023, (default)> = [200000.]
#                   employment_income<2023, (default)> = [100000. 100000.      0.      0.]
#                   self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                 tanf_gross_unearned_income<2023, (default)> = [0.]
#                   dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                   interest_income<2023, (default)> = [0. 0. 0. 0.]
#                   gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#                   social_security<2023, (default)> = [0. 0. 0. 0.]
#                   ssi<2023, (default)> = [0. 0. 0. 0.]
#                 tanf_max_amount<2023, (default)> = [0.]
#                   spm_unit_size<2023, (default)> = [4]
#                   state_code_str<2023, (default)> = ['UT']
#               is_tanf_initial_eligible<2023, (default)> = [False]
#                 tanf_initial_employment_deduction<2023, (default)> = [0.]
#                   spm_unit_size<2023, (default)> = [4]
#                   state_code_str<2023, (default)> = ['UT']
#                   market_income<2023, (default)> = [100000. 100000.      0.      0.]
#                     employment_income<2023, (default)> = [100000. 100000.      0.      0.]
#                     self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                     pension_income<2023, (default)> = [0. 0. 0. 0.]
#                     dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                     interest_income<2023, (default)> = [0. 0. 0. 0.]
#                     gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#                     capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                     rental_income<2023, (default)> = [0. 0. 0. 0.]
#                     illicit_income<2023, (default)> = [0. 0. 0. 0.]
#                     farm_income<2023, (default)> = [0. 0. 0. 0.]
#                 tanf_gross_earned_income<2023, (default)> = [200000.]
#                 tanf_gross_unearned_income<2023, (default)> = [0.]
#                 tanf_max_amount<2023, (default)> = [0.]
#             tanf_amount_if_eligible<2023, (default)> = [0.]
#               tanf_max_amount<2023, (default)> = [0.]
#               tanf_countable_income<2023, (default)> = [200000.]
#                 state_code_str<2023, (default)> = ['UT']
#                 tanf_gross_unearned_income<2023, (default)> = [0.]
#                 tanf_gross_earned_income<2023, (default)> = [200000.]
#           medicaid<2023, (default)> = [0. 0. 0. 0.]
#             is_medicaid_eligible<2023, (default)> = [False False False False]
#               medicaid_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#                 is_infant_for_medicaid<2023, (default)> = [False False False False]
#                   is_infant_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [6.6666665 6.6666665 6.6666665 6.6666665]
#                       tax_unit_medicaid_income_level<2023, (default)> = [6.6666665]
#                         medicaid_income<2023, (default)> = [200000.]
#                           adjusted_gross_income<2023, (default)> = [200000.]
#                             irs_gross_income<2023, (default)> = [100000. 100000.      0.      0.]
#                               is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                               employment_income<2023, (default)> = [100000. 100000.      0.      0.]
#                               self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                               partnership_s_corp_income<2023, (default)> = [0. 0. 0. 0.]
#                               farm_income<2023, (default)> = [0. 0. 0. 0.]
#                               farm_rent_income<2023, (default)> = [0. 0. 0. 0.]
#                               capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                               taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#                               rental_income<2023, (default)> = [0. 0. 0. 0.]
#                               dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                               taxable_pension_income<2023, (default)> = [0. 0. 0. 0.]
#                               debt_relief<2023, (default)> = [0. 0. 0. 0.]
#                               taxable_unemployment_compensation<2023, (default)> = [0. 0. 0. 0.]
#                                 is_tax_unit_head<2023, (default)> = [ True False False False]
#                                 tax_unit_taxable_unemployment_compensation<2023, (default)> = [0.]
#                                   tax_unit_unemployment_compensation<2023, (default)> = [0.]
#                                     unemployment_compensation<2023, (default)> = [0. 0. 0. 0.]
#                                   taxable_uc_agi<2023, (default)> = [200000.]
#                                     is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                                     employment_income<2023, (default)> = [100000. 100000.      0.      0.]
#                                     self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                     partnership_s_corp_income<2023, (default)> = [0. 0. 0. 0.]
#                                     farm_income<2023, (default)> = [0. 0. 0. 0.]
#                                     farm_rent_income<2023, (default)> = [0. 0. 0. 0.]
#                                     capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                                     taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#                                     rental_income<2023, (default)> = [0. 0. 0. 0.]
#                                     dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                                     taxable_pension_income<2023, (default)> = [0. 0. 0. 0.]
#                                     debt_relief<2023, (default)> = [0. 0. 0. 0.]
#                                     taxable_social_security<2023, (default)> = [0. 0. 0. 0.]
#                                       tax_unit_taxable_social_security<2023, (default)> = [0.]
#                                         tax_unit_social_security<2023, (default)> = [0.]
#                                           social_security<2023, (default)> = [0. 0. 0. 0.]
#                                         taxable_ss_magi<2023, (default)> = [200000.]
#                                           is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                                           employment_income<2023, (default)> = [100000. 100000.      0.      0.]
#                                           self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                           partnership_s_corp_income<2023, (default)> = [0. 0. 0. 0.]
#                                           farm_income<2023, (default)> = [0. 0. 0. 0.]
#                                           farm_rent_income<2023, (default)> = [0. 0. 0. 0.]
#                                           capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                                           taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#                                           rental_income<2023, (default)> = [0. 0. 0. 0.]
#                                           dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                                           taxable_pension_income<2023, (default)> = [0. 0. 0. 0.]
#                                           debt_relief<2023, (default)> = [0. 0. 0. 0.]
#                                           illicit_income<2023, (default)> = [0. 0. 0. 0.]
#                                           unemployment_compensation<2023, (default)> = [0. 0. 0. 0.]
#                                           tax_exempt_interest_income<2023, (default)> = [0. 0. 0. 0.]
#                                           loss_ald<2023, (default)> = [0.]
#                                             filing_status<2023, (default)> = ['JOINT']
#                                               is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                                               tax_unit_dependents<2023, (default)> = [2]
#                                                 is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                                             self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                             maximum_capital_loss<2023, (default)> = [0.]
#                                               tax_unit_capital_loss<2023, (default)> = [0.]
#                                                 capital_loss<2023, (default)> = [0. 0. 0. 0.]
#                                                   capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                                               filing_status<2023, (default)> = ['JOINT']
#                                           self_employment_tax_ald<2023, (default)> = [0.]
#                                             self_employment_tax_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employment_tax<2023, (default)> = [0. 0. 0. 0.]
#                                                 self_employment_social_security_tax<2023, (default)> = [0. 0. 0. 0.]
#                                                   social_security_taxable_self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                                     taxable_self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                                       sey<2023, (default)> = [0. 0. 0. 0.]
#                                                         self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                                         farm_income<2023, (default)> = [0. 0. 0. 0.]
#                                                         k1bx14<2023, (default)> = [0. 0. 0. 0.]
#                                                     taxable_earnings_for_social_security<2023, (default)> = [100000. 100000.      0.      0.]
#                                                       payroll_tax_gross_wages<2023, (default)> = [100000. 100000.      0.      0.]
#                                                         employment_income<2023, (default)> = [100000. 100000.      0.      0.]
#                                                 self_employment_medicare_tax<2023, (default)> = [0. 0. 0. 0.]
#                                                   taxable_self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                           early_withdrawal_penalty<2023, (default)> = [0. 0. 0. 0.]
#                                           alimony_income<2023, (default)> = [0. 0. 0. 0.]
#                                           educator_expense<2023, (default)> = [0. 0. 0. 0.]
#                                           health_savings_account_ald<2023, (default)> = [0.]
#                                           self_employed_health_insurance_ald<2023, (default)> = [0.]
#                                             self_employed_health_insurance_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employed_health_insurance_premiums<2023, (default)> = [0. 0. 0. 0.]
#                                                 is_self_employed<2023, (default)> = [False False False False]
#                                                 health_insurance_premiums<2023, (default)> = [0. 0. 0. 0.]
#                                           self_employed_pension_contribution_ald<2023, (default)> = [0.]
#                                             self_employed_pension_contribution_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employed_pension_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                           ira_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                           sep_simple_qualified_plan_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                         filing_status<2023, (default)> = ['JOINT']
#                                       tax_unit_social_security<2023, (default)> = [0.]
#                                       social_security<2023, (default)> = [0. 0. 0. 0.]
#                                       is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                                       is_tax_unit_head<2023, (default)> = [ True False False False]
#                                     illicit_income<2023, (default)> = [0. 0. 0. 0.]
#                                     loss_ald<2023, (default)> = [0.]
#                                     self_employment_tax_ald<2023, (default)> = [0.]
#                                     student_loan_interest<2023, (default)> = [0. 0. 0. 0.]
#                                     early_withdrawal_penalty<2023, (default)> = [0. 0. 0. 0.]
#                                     alimony_income<2023, (default)> = [0. 0. 0. 0.]
#                                     educator_expense<2023, (default)> = [0. 0. 0. 0.]
#                                     health_savings_account_ald<2023, (default)> = [0.]
#                                     self_employed_health_insurance_ald<2023, (default)> = [0.]
#                                     self_employed_pension_contribution_ald<2023, (default)> = [0.]
#                                     ira_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                     sep_simple_qualified_plan_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                     qualified_adoption_assistance_expense<2023, (default)> = [0. 0. 0. 0.]
#                                     us_bonds_for_higher_ed<2023, (default)> = [0. 0. 0. 0.]
#                                     specified_possession_income<2023, (default)> = [0.]
#                                     puerto_rico_income<2023, (default)> = [0.]
#                                   filing_status<2023, (default)> = ['JOINT']
#                               taxable_social_security<2023, (default)> = [0. 0. 0. 0.]
#                               illicit_income<2023, (default)> = [0. 0. 0. 0.]
#                             above_the_line_deductions<2023, (default)> = [0.]
#                               loss_ald<2023, (default)> = [0.]
#                               self_employment_tax_ald<2023, (default)> = [0.]
#                               student_loan_interest<2023, (default)> = [0. 0. 0. 0.]
#                               early_withdrawal_penalty<2023, (default)> = [0. 0. 0. 0.]
#                               alimony_income<2023, (default)> = [0. 0. 0. 0.]
#                               educator_expense<2023, (default)> = [0. 0. 0. 0.]
#                               health_savings_account_ald<2023, (default)> = [0.]
#                               self_employed_health_insurance_ald<2023, (default)> = [0.]
#                               self_employed_pension_contribution_ald<2023, (default)> = [0.]
#                               ira_contributions<2023, (default)> = [0. 0. 0. 0.]
#                               sep_simple_qualified_plan_contributions<2023, (default)> = [0. 0. 0. 0.]
#                               qualified_adoption_assistance_expense<2023, (default)> = [0. 0. 0. 0.]
#                               us_bonds_for_higher_ed<2023, (default)> = [0. 0. 0. 0.]
#                               specified_possession_income<2023, (default)> = [0.]
#                               puerto_rico_income<2023, (default)> = [0.]
#                           foreign_earned_income_exclusion<2023, (default)> = [0.]
#                           student_loan_interest<2023, (default)> = [0. 0. 0. 0.]
#                           tax_exempt_social_security<2023, (default)> = [0.]
#                             tax_unit_social_security<2023, (default)> = [0.]
#                             tax_unit_taxable_social_security<2023, (default)> = [0.]
#                         tax_unit_fpg<2023, (default)> = [30000.]
#                           tax_unit_size<2023, (default)> = [4]
#                           state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#                     state_code_str<2023, (default)> = ['UT']
#                   is_infant_for_medicaid_nfc<2023, (default)> = [False False False False]
#                     age<2023, (default)> = [38. 35. 10. 10.]
#                 is_young_child_for_medicaid<2023, (default)> = [False False False False]
#                   is_young_child_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [6.6666665 6.6666665 6.6666665 6.6666665]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_young_child_for_medicaid_nfc<2023, (default)> = [False False False False]
#                     age<2023, (default)> = [38. 35. 10. 10.]
#                 is_older_child_for_medicaid<2023, (default)> = [False False False False]
#                   age<2023, (default)> = [38. 35. 10. 10.]
#                   medicaid_income_level<2023, (default)> = [6.6666665 6.6666665 6.6666665 6.6666665]
#                   state_code_str<2023, (default)> = ['UT']
#                 is_young_adult_for_medicaid<2023, (default)> = [False False False False]
#                   is_young_adult_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [6.6666665 6.6666665 6.6666665 6.6666665]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_young_adult_for_medicaid_nfc<2023, (default)> = [False False False False]
#                     age<2023, (default)> = [38. 35. 10. 10.]
#                 is_adult_for_medicaid<2023, (default)> = [False False False False]
#                   is_adult_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [6.6666665 6.6666665 6.6666665 6.6666665]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_adult_for_medicaid_nfc<2023, (default)> = [ True  True False False]
#                     age<2023, (default)> = [38. 35. 10. 10.]
#                 is_parent_for_medicaid<2023, (default)> = [False False False False]
#                   is_parent_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [6.6666665 6.6666665 6.6666665 6.6666665]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_parent_for_medicaid_nfc<2023, (default)> = [ True  True False False]
#                     is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                     tax_unit_count_dependents<2023, (default)> = [2]
#                       is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                 is_pregnant_for_medicaid<2023, (default)> = [False False False False]
#                   is_pregnant_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [6.6666665 6.6666665 6.6666665 6.6666665]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_pregnant_for_medicaid_nfc<2023, (default)> = [False False False False]
#                     is_pregnant<2023, (default)> = [False False False False]
#                     count_days_postpartum<2023, (default)> = [inf inf inf inf]
#                       under_60_days_postpartum<2023, (default)> = [False False False False]
#                       under_12_months_postpartum<2023, (default)> = [False False False False]
#                     state_code_str<2023, (default)> = ['UT']
#                 is_ssi_recipient_for_medicaid<2023, (default)> = [False False False False]
#                   state_code_str<2023, (default)> = ['UT']
#                   ssi<2023, (default)> = [0. 0. 0. 0.]
#             medicaid_benefit_value<2023, (default)> = [9966.585 9966.585 9966.585 9966.585]
#               state_code_str<2023, (default)> = ['UT']
#           is_pregnant<2023, (default)> = [False False False False]
#           wic_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#             is_pregnant<2023, (default)> = [False False False False]
#             is_mother<2023, (default)> = [False False False False]
#               is_female<2023, (default)> = [False False False False]
#               own_children_in_household<2023, (default)> = [0 0 0 0]
#               is_breastfeeding<2023, (default)> = [False False False False]
#             is_breastfeeding<2023, (default)> = [False False False False]
#             age<2023, (default)> = [38. 35. 10. 10.]
#         wic_category_str<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#           wic_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#         is_wic_at_nutritional_risk<2023, (default)> = [False False False False]
#           receives_wic<2023, (default)> = [False False False False]
#           meets_wic_income_test<2023, (default)> = [False]
#           meets_wic_categorical_eligibility<2023, (default)> = [False False False False]
#           wic_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#         would_claim_wic<2023, (default)> = [ True  True  True  True]
#       free_school_meals<2023, (default)> = [0.]
#         school_meal_tier<2023, (default)> = ['PAID']
#           school_meal_fpg_ratio<2023, (default)> = [6.6666665]
#             school_meal_countable_income<2023, (default)> = [200000.]
#             spm_unit_fpg<2023, (default)> = [30000.]
#           meets_school_meal_categorical_eligibility<2023, (default)> = [False]
#             snap<2023, (default)> = [0.]
#             tanf<2023, (default)> = [0.]
#             fdpir<2023, (default)> = [0.]
#         school_meal_net_subsidy<2023, (default)> = [0.]
#           school_meal_daily_subsidy<2023, (default)> = [0.72]
#             state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#             school_meal_tier<2023, (default)> = ['PAID']
#           school_meal_paid_daily_subsidy<2023, (default)> = [0.72]
#             state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#           is_in_k12_school<2023, (default)> = [False False  True  True]
#       reduced_price_school_meals<2023, (default)> = [0.]
#         school_meal_tier<2023, (default)> = ['PAID']
#         school_meal_net_subsidy<2023, (default)> = [0.]
#       lifeline<2023, (default)> = [0.]
#         is_rural<2023, (default)> = [False]
#         is_on_tribal_land<2023, (default)> = [False]
#         phone_cost<2023, (default)> = [2400.]
#         broadband_cost<2023, (default)> = [1200.]
#         is_lifeline_eligible<2023, (default)> = [False]
#           medicaid<2023, (default)> = [0. 0. 0. 0.]
#           snap<2023, (default)> = [0.]
#           ssi<2023, (default)> = [0. 0. 0. 0.]
#           fcc_fpg_ratio<2023, (default)> = [6.6666665]
#             irs_gross_income<2023, (default)> = [100000. 100000.      0.      0.]
#             spm_unit_fpg<2023, (default)> = [30000.]
#       acp<2023, (default)> = [0.]
#         is_acp_eligible<2023, (default)> = [False]
#           lifeline<2023, (default)> = [0.]
#           free_school_meals<2023, (default)> = [0.]
#           reduced_price_school_meals<2023, (default)> = [0.]
#           pell_grant<2023, (default)> = [0.]
#           wic<2023, (default)> = [0. 0. 0. 0.]
#           medicaid<2023, (default)> = [0. 0. 0. 0.]
#           snap<2023, (default)> = [0.]
#           ssi<2023, (default)> = [0. 0. 0. 0.]
#           fcc_fpg_ratio<2023, (default)> = [6.6666665]
#           ebb<2023, (default)> = [0.]
#             is_ebb_eligible<2023, (default)> = [False]
#               is_lifeline_eligible<2023, (default)> = [False]
#               free_school_meals<2023, (default)> = [0.]
#               reduced_price_school_meals<2023, (default)> = [0.]
#               pell_grant<2023, (default)> = [0.]
#               experienced_covid_income_loss<2023, (default)> = [False]
#               enrolled_in_ebb<2023, (default)> = [False]
#             broadband_cost_after_lifeline<2023, (default)> = [1200.]
#               broadband_cost<2023, (default)> = [1200.]
#               lifeline<2023, (default)> = [0.]
#             is_on_tribal_land<2023, (default)> = [False]
#         broadband_cost_after_lifeline<2023, (default)> = [1200.]
#         is_on_tribal_land<2023, (default)> = [False]
#       ebb<2023, (default)> = [0.]
#       tanf<2023, (default)> = [0.]
#       high_efficiency_electric_home_rebate<2023, (default)> = [0.]
#         capped_electric_heat_pump_clothes_dryer_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#             tax_unit_income_ami_ratio<2023, (default)> = [0.]
#           electric_heat_pump_clothes_dryer_expenditures<2023, (default)> = [0.]
#         capped_electric_load_service_center_upgrade_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           electric_load_service_center_upgrade_expenditures<2023, (default)> = [0.]
#         capped_electric_stove_cooktop_range_or_oven_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           electric_stove_cooktop_range_or_oven_expenditures<2023, (default)> = [0.]
#         capped_electric_wiring_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           electric_wiring_expenditures<2023, (default)> = [0.]
#         capped_heat_pump_water_heater_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           heat_pump_water_heater_expenditures<2023, (default)> = [0.]
#         capped_heat_pump_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           heat_pump_expenditures<2023, (default)> = [0.]
#         capped_insulation_air_sealing_ventilation_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           energy_efficient_insulation_expenditures<2023, (default)> = [0.]
#           air_sealing_ventilation_expenditures<2023, (default)> = [0.]
#       residential_efficiency_electrification_rebate<2023, (default)> = [0.]
#         residential_efficiency_electrification_retrofit_expenditures<2023, (default)> = [0.]
#         residential_efficiency_electrification_retrofit_energy_savings<2023, (default)> = [0.]
#         current_home_energy_use<2023, (default)> = [0.]
#         household_income_ami_ratio<2023, (default)> = [0.]
#         average_home_energy_use_in_state<2023, (default)> = [0.]
#       basic_income<2023, (default)> = [0.]
#         basic_income_eligible<2023, (default)> = [ True]
#         basic_income_before_phase_out<2023, (default)> = [0.]
#           tax_unit_size<2023, (default)> = [4]
#           age<2023, (default)> = [38. 35. 10. 10.]
#           tax_unit_fpg<2023, (default)> = [30000.]
#         basic_income_phase_out<2023, (default)> = [0.]
#           basic_income_before_phase_out<2023, (default)> = [0.]
#           adjusted_gross_income<2023, (default)> = [200000.]
#           filing_status<2023, (default)> = ['JOINT']
#       spm_unit_capped_housing_subsidy<2023, (default)> = [0.]
#         spm_unit_capped_housing_subsidy_reported<2023, (default)> = [0.]
#     household_refundable_tax_credits<2023, (default)> = [0.]
#       income_tax_refundable_credits<2023, (default)> = [0.]
#         eitc<2023, (default)> = [0.]
#           earned_income_tax_credit<2023, (default)> = [0.]
#             eitc_eligible<2023, (default)> = [ True]
#               is_child<2023, (default)> = [False False  True  True]
#               age<2023, (default)> = [38. 35. 10. 10.]
#               tax_exempt_interest_income<2023, (default)> = [0. 0. 0. 0.]
#               taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#               dividend_income<2023, (default)> = [0. 0. 0. 0.]
#               c01000<2023, (default)> = [0.]
#                 sep<2023, (default)> = [1]
#                 c23650<2023, (default)> = [0.]
#                   long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   short_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#               tax_unit_rental_income<2023, (default)> = [0.]
#                 rental_income<2023, (default)> = [0. 0. 0. 0.]
# ...
#                               income_tax_unavailable_non_refundable_credits<2023, (not_itemizing)> = [0.]
#                                 income_tax_before_credits<2023, (not_itemizing)> = [28521.]
#                                 income_tax_non_refundable_credits<2023, (not_itemizing)> = [4300.]
#                                 income_tax_non_refundable_credits<2023, (not_itemizing)> = [4300.]
#                           income_tax_refundable_credits<2023, (not_itemizing)> = [0.]
#                       state_income_tax<2023, (not_itemizing)> = [9617.512]
#                 taxable_income_deductions_if_itemizing<2023, (default)> = [30000.]
#                   charitable_deduction<2023, (default)> = [20000.]
#                   interest_deduction<2023, (default)> = [0.]
#                   salt_deduction<2023, (default)> = [10000.]
#                     state_and_local_sales_or_income_tax<2023, (default)> = [10079.512]
#                       state_income_tax<2023, (default)> = [10079.512]
#                         ma_income_tax<2023, (default)> = [0.]
#                           MA<2023, (default)> = [False]
#                         md_income_tax<2023, (default)> = [0.]
#                           MD<2023, (default)> = [False]
#                         ny_income_tax<2023, (default)> = [0.]
#                           NY<2023, (default)> = [False]
#                         or_income_tax<2023, (default)> = [0.]
#                           OR<2023, (default)> = [False]
#                         pa_income_tax<2023, (default)> = [0.]
#                           PA<2023, (default)> = [False]
#                             state_code_str<2023, (default)> = ['UT']
#                         wa_income_tax<2023, (default)> = [0.]
#                           WA<2023, (default)> = [False]
#                         ut_income_tax<2023, (default)> = [10079.512]
#                           UT<2023, (default)> = [ True]
#                           ut_income_tax_before_refundable_credits<2023, (default)> = [10079.512]
#                             ut_income_tax_after_credits<2023, (default)> = [10079.512]
#                               ut_income_tax_before_credits<2023, (default)> = [9300.]
#                                 UT<2023, (default)> = [ True]
#                                 ut_taxable_income<2023, (default)> = [200000.]
#                                   UT<2023, (default)> = [ True]
#                                   ut_total_income<2023, (default)> = [200000.]
#                                     UT<2023, (default)> = [ True]
#                                     adjusted_gross_income<2023, (default)> = [200000.]
#                                     ut_additions_to_income<2023, (default)> = [0.]
#                                       UT<2023, (default)> = [ True]
#                                   salt_refund_last_year<2023, (default)> = [0.]
#                                   ut_subtractions_from_income<2023, (default)> = [0.]
#                                     UT<2023, (default)> = [ True]
#                               ut_taxpayer_credit<2023, (default)> = [-779.51196]
#                                 UT<2023, (default)> = [ True]
#                                 ut_taxpayer_credit_max<2023, (default)> = [1416.24]
#                                   UT<2023, (default)> = [ True]
#                                   tax_unit_count_dependents<2023, (default)> = [2]
#                                   tax_unit_itemizes<2023, (default)> = [ True]
#                                   standard_deduction<2023, (default)> = [27700.]
#                                   charitable_deduction<2023, (default)> = [20000.]
#                                   interest_deduction<2023, (default)> = [0.]
#                                   medical_expense_deduction<2023, (default)> = [0.]
#                                   casualty_loss_deduction<2023, (default)> = [0.]
#                                 ut_taxpayer_credit_reduction<2023, (default)> = [2195.752]
#                                   UT<2023, (default)> = [ True]
#                                   filing_status<2023, (default)> = ['JOINT']
#                                   ut_taxable_income<2023, (default)> = [200000.]
#                             ut_apportionable_nonrefundable_credits<2023, (default)> = [0.]
#                               UT<2023, (default)> = [ True]
#                             ut_nonapportionable_nonrefundable_credits<2023, (default)> = [0.]
#                               UT<2023, (default)> = [ True]
#                             ut_recapture_low_inc_housing_credit<2023, (default)> = [0.]
#                               UT<2023, (default)> = [ True]
#                           ut_refundable_credits<2023, (default)> = [0.]
#                       local_income_tax<2023, (default)> = [0.]
#                       state_sales_tax<2023, (default)> = [0.]
#                       local_sales_tax<2023, (default)> = [0.]
#                     real_estate_taxes<2023, (default)> = [0. 0. 0. 0.]
#                     filing_status<2023, (default)> = ['JOINT']
#                   medical_expense_deduction<2023, (default)> = [0.]
#                   casualty_loss_deduction<2023, (default)> = [0.]
#                   qualified_business_income_deduction<2023, (default)> = [0.]
#                     qbid_amount<2023, (default)> = [0. 0. 0. 0.]
#                       qualified_business_income<2023, (default)> = [0. 0. 0. 0.]
#                         self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                         partnership_s_corp_income<2023, (default)> = [0. 0. 0. 0.]
#                         farm_income<2023, (default)> = [0. 0. 0. 0.]
#                         farm_rent_income<2023, (default)> = [0. 0. 0. 0.]
#                         self_employment_tax_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                         self_employed_health_insurance_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                         self_employed_pension_contribution_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                         business_is_qualified<2023, (default)> = [False False False False]
#                       w2_wages_from_qualified_business<2023, (default)> = [0. 0. 0. 0.]
#                       unadjusted_basis_qualified_property<2023, (default)> = [0. 0. 0. 0.]
#                       taxable_income_less_qbid<2023, (default)> = [170000.]
#                         adjusted_gross_income<2023, (default)> = [200000.]
#                         charitable_deduction<2023, (default)> = [20000.]
#                         interest_deduction<2023, (default)> = [0.]
#                         salt_deduction<2023, (default)> = [10000.]
#                         medical_expense_deduction<2023, (default)> = [0.]
#                         casualty_loss_deduction<2023, (default)> = [0.]
#                         standard_deduction<2023, (default)> = [27700.]
#                       filing_status<2023, (default)> = ['JOINT']
#                       business_is_sstb<2023, (default)> = [False False False False]
#                     taxable_income_less_qbid<2023, (default)> = [170000.]
#                     adjusted_net_capital_gain<2023, (default)> = [0.]
#                       net_capital_gain<2023, (default)> = [0.]
#                         net_long_term_capital_gain<2023, (default)> = [0.]
#                           long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                           long_term_capital_losses<2023, (default)> = [0. 0. 0. 0.]
#                         net_short_term_capital_loss<2023, (default)> = [0.]
#                           short_term_capital_losses<2023, (default)> = [0. 0. 0. 0.]
#                           short_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                         qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                       qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                       unrecaptured_section_1250_gain<2023, (default)> = [0.]
#                       capital_gains_28_percent_rate_gain<2023, (default)> = [0.]
#                         long_term_capital_gains_on_collectibles<2023, (default)> = [0. 0. 0. 0.]
#                         long_term_capital_gains_on_small_business_stock<2023, (default)> = [0. 0. 0. 0.]
#                 taxable_income_deductions_if_not_itemizing<2023, (default)> = [27700.]
#                   standard_deduction<2023, (default)> = [27700.]
#                   qualified_business_income_deduction<2023, (default)> = [0.]
#             capital_gains_excluded_from_taxable_income<2023, (default)> = [0.]
#               net_capital_gain<2023, (default)> = [0.]
#               adjusted_net_capital_gain<2023, (default)> = [0.]
#               taxable_income<2023, (default)> = [170000.]
#               filing_status<2023, (default)> = ['JOINT']
#             filing_status<2023, (default)> = ['JOINT']
#           capital_gains_tax<2023, (default)> = [0.]
#             net_capital_gain<2023, (default)> = [0.]
#             taxable_income<2023, (default)> = [170000.]
#             adjusted_net_capital_gain<2023, (default)> = [0.]
#             capital_gains_excluded_from_taxable_income<2023, (default)> = [0.]
#             filing_status<2023, (default)> = ['JOINT']
#             unrecaptured_section_1250_gain<2023, (default)> = [0.]
#             qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#             capital_gains_28_percent_rate_gain<2023, (default)> = [0.]
#           alternative_minimum_tax<2023, (default)> = [0.]
#             c09600<2023, (default)> = [0.]
#               c62100<2023, (default)> = [180000.]
#                 amt_income<2023, (default)> = [180000.]
#                   taxable_income<2023, (default)> = [170000.]
#                   tax_unit_itemizes<2023, (default)> = [ True]
#                   standard_deduction<2023, (default)> = [27700.]
#                   salt_deduction<2023, (default)> = [10000.]
#                   filing_status<2023, (default)> = ['JOINT']
#               filing_status<2023, (default)> = ['JOINT']
#               age_head<2023, (default)> = [38]
#               age_spouse<2023, (default)> = [35]
#               filer_earned<2023, (default)> = [200000.]
#               sep<2023, (default)> = [1]
#               dwks10<2023, (default)> = [0.]
#                 dwks6<2023, (default)> = [0.]
#                   qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                   investment_income_form_4952<2023, (default)> = [0.]
#                 dwks9<2023, (default)> = [0.]
#                   long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                   c23650<2023, (default)> = [0.]
#                   non_sch_d_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   investment_income_form_4952<2023, (default)> = [0.]
#                 long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                 qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                 c23650<2023, (default)> = [0.]
#                 non_sch_d_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                 hasqdivltcg<2023, (default)> = [False]
#                   c01000<2023, (default)> = [0.]
#                   c23650<2023, (default)> = [0.]
#                   long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   non_sch_d_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#               dwks13<2023, (default)> = [0.]
#                 unrecaptured_section_1250_gain<2023, (default)> = [0.]
#                 capital_gains_28_percent_rate_gain<2023, (default)> = [0.]
#                 dwks9<2023, (default)> = [0.]
#                 dwks10<2023, (default)> = [0.]
#                 hasqdivltcg<2023, (default)> = [False]
#               dwks14<2023, (default)> = [0.]
#                 taxable_income<2023, (default)> = [170000.]
#                 dwks13<2023, (default)> = [0.]
#                 hasqdivltcg<2023, (default)> = [False]
#               dwks19<2023, (default)> = [0.]
#                 dwks14<2023, (default)> = [0.]
#                 filing_status<2023, (default)> = ['JOINT']
#                 taxable_income<2023, (default)> = [170000.]
#                 dwks10<2023, (default)> = [0.]
#                 hasqdivltcg<2023, (default)> = [False]
#               unrecaptured_section_1250_gain<2023, (default)> = [0.]
#               sep<2023, (default)> = [1]
#               foreign_tax_credit<2023, (default)> = [0.]
#               amt_form_completed<2023, (default)> = [False]
#               foreign_tax_credit<2023, (default)> = [0.]
#               taxbc<2023, (default)> = [28015.]
#                 regular_tax_before_credits<2023, (default)> = [28015.]
#                   filing_status<2023, (default)> = ['JOINT']
#                   taxable_income<2023, (default)> = [170000.]
#                   dwks14<2023, (default)> = [0.]
#                   dwks13<2023, (default)> = [0.]
#                   dwks19<2023, (default)> = [0.]
#                   dwks9<2023, (default)> = [0.]
#                   unrecaptured_section_1250_gain<2023, (default)> = [0.]
#                   dwks10<2023, (default)> = [0.]
#                   income_tax_main_rates<2023, (default)> = [28015.]
#                   hasqdivltcg<2023, (default)> = [False]
#               c05700<2023, (default)> = [0.]
#         net_investment_income_tax<2023, (default)> = [0.]
#           taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#           dividend_income<2023, (default)> = [0. 0. 0. 0.]
#           c01000<2023, (default)> = [0.]
#           rental_income<2023, (default)> = [0. 0. 0. 0.]
#           filing_status<2023, (default)> = ['JOINT']
#           adjusted_gross_income<2023, (default)> = [200000.]
#         recapture_of_investment_credit<2023, (default)> = [0.]
#         unreported_payroll_tax<2023, (default)> = [0.]
#         qualified_retirement_penalty<2023, (default)> = [0.]
#         income_tax_capped_non_refundable_credits<2023, (default)> = [4300.]
#           income_tax_non_refundable_credits<2023, (default)> = [4300.]
#             cdcc<2023, (default)> = [300.]
#             elderly_disabled_credit<2023, (default)> = [0.]
#             non_refundable_ctc<2023, (default)> = [4000.]
#               ctc<2023, (default)> = [4000.]
#               refundable_ctc<2023, (default)> = [0.]
#             non_refundable_american_opportunity_credit<2023, (default)> = [0.]
#             lifetime_learning_credit<2023, (default)> = [0.]
#             retirement_savings_credit<2023, (default)> = [0.]
#             residential_clean_energy_credit<2023, (default)> = [0.]
#             energy_efficient_home_improvement_credit<2023, (default)> = [0.]
#             new_clean_vehicle_credit<2023, (default)> = [0.]
#             used_clean_vehicle_credit<2023, (default)> = [0.]
#           income_tax_unavailable_non_refundable_credits<2023, (default)> = [0.]
#             income_tax_before_credits<2023, (default)> = [28015.]
#             income_tax_non_refundable_credits<2023, (default)> = [4300.]
#             income_tax_non_refundable_credits<2023, (default)> = [4300.]
#       ma_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         MA<2023, (default)> = [False]
#       md_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         MD<2023, (default)> = [False]
#       ny_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         NY<2023, (default)> = [False]
#       or_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         or_income_tax_before_credits<2023, (default)> = [0.]
#           OR<2023, (default)> = [False]
#         or_non_refundable_credits<2023, (default)> = [0.]
#           or_exemption_credit<2023, (default)> = [0.]
#             OR<2023, (default)> = [False]
#       pa_income_tax<2023, (default)> = [0.]
#       ut_income_tax_before_refundable_credits<2023, (default)> = [10079.512]
#       wa_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         WA<2023, (default)> = [False]
#       flat_tax<2023, (default)> = [0.]
#         positive_agi<2023, (default)> = [200000.]

# %% [markdown]
# ### 3.4. Effects on three household types of rate cut to 4.50%

# %% [markdown]
# #### 3.4.1. Effect of rate cut to 4.50% on low income household

# %%
def modify_parameters_2(parameters):
    parameters.gov.states.ut.tax.income.rate.update(
        start=instant("2023-01-01"),
        stop=instant("2027-12-31"),
        value=0.045
    )

class reform_2(Reform):
    def apply(self):
        self.modify_parameters(modify_parameters_2)

simulation_2_l = Simulation(
    reform=reform_2,
    situation=situation_low,
)

simulation_2_l.trace = True
simulation_2_l.calculate("household_net_income", 2023)
simulation_2_l.tracer.print_computation_log()
# Out:
#   household_net_income<2023, (default)> = [42138.2]
#     household_market_income<2023, (default)> = [25000.]
#       employment_income<2023, (default)> = [25000.     0.     0.     0.]
#       self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#       pension_income<2023, (default)> = [0. 0. 0. 0.]
#         tax_exempt_pension_income<2023, (default)> = [0. 0. 0. 0.]
#         taxable_pension_income<2023, (default)> = [0. 0. 0. 0.]
#       dividend_income<2023, (default)> = [0. 0. 0. 0.]
#         qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#         non_qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#       interest_income<2023, (default)> = [0. 0. 0. 0.]
#         tax_exempt_interest_income<2023, (default)> = [0. 0. 0. 0.]
#         taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#       gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#       capital_gains<2023, (default)> = [0. 0. 0. 0.]
#         short_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#         long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#       rental_income<2023, (default)> = [0. 0. 0. 0.]
#       illicit_income<2023, (default)> = [0. 0. 0. 0.]
#       farm_income<2023, (default)> = [0. 0. 0. 0.]
#     household_benefits<2023, (default)> = [9246.7]
#       social_security<2023, (default)> = [0. 0. 0. 0.]
#         social_security_dependents<2023, (default)> = [0. 0. 0. 0.]
#         social_security_disability<2023, (default)> = [0. 0. 0. 0.]
#         social_security_retirement<2023, (default)> = [0. 0. 0. 0.]
#         social_security_survivors<2023, (default)> = [0. 0. 0. 0.]
#       ssi<2023, (default)> = [0. 0. 0. 0.]
#         uncapped_ssi<2023, (default)> = [0. 0. 0. 0.]
#           ssi_amount_if_eligible<2023, (default)> = [10968. 10968. 10968. 10968.]
#             ssi_claim_is_joint<2023, (default)> = [False False False False]
#               is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                 is_ssi_aged<2023, (default)> = [False False False False]
#                   age<2023, (default)> = [38. 35. 10.  6.]
#                 is_blind<2023, (default)> = [False False False False]
#                 is_ssi_disabled<2023, (default)> = [False False False False]
#                   is_ssi_aged<2023, (default)> = [False False False False]
#                   is_blind<2023, (default)> = [False False False False]
#                   ssi_reported<2023, (default)> = [0. 0. 0. 0.]
#               ssi_income_deemed_from_ineligible_spouse<2023, (default)> = [0. 0. 0. 0.]
#                 ssi_earned_income<2023, (default)> = [25000.     0.     0.     0.]
#                   employment_income<2023, (default)> = [25000.     0.     0.     0.]
#                   self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                 ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#                   dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                   interest_income<2023, (default)> = [0. 0. 0. 0.]
#                   gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#                   social_security<2023, (default)> = [0. 0. 0. 0.]
#                   alimony_income<2023, (default)> = [0. 0. 0. 0.]
#                   pension_income<2023, (default)> = [0. 0. 0. 0.]
#                   unemployment_compensation<2023, (default)> = [0. 0. 0. 0.]
#                 ssi_earned_income_deemed_from_ineligible_spouse<2023, (default)> = [0. 0. 0. 0.]
#                   is_ssi_ineligible_spouse<2023, (default)> = [False  True False False]
#                     is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                       is_child<2023, (default)> = [False False  True  True]
#                         age<2023, (default)> = [38. 35. 10.  6.]
#                       is_tax_unit_head<2023, (default)> = [ True False False False]
#                         is_child<2023, (default)> = [False False  True  True]
#                         age<2023, (default)> = [38. 35. 10.  6.]
#                       age<2023, (default)> = [38. 35. 10.  6.]
#                     is_ssi_eligible_spouse<2023, (default)> = [False False False False]
#                       is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                       is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                   ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#                   ssi_earned_income<2023, (default)> = [25000.     0.     0.     0.]
#                   ssi_ineligible_child_allocation<2023, (default)> = [   0.    0. 5484. 5484.]
#                     ssi_earned_income<2023, (default)> = [25000.     0.     0.     0.]
#                     ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#                     is_ssi_ineligible_child<2023, (default)> = [False False  True  True]
#                       is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                       is_child<2023, (default)> = [False False  True  True]
#                   is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                 ssi_unearned_income_deemed_from_ineligible_spouse<2023, (default)> = [0. 0. 0. 0.]
#                   is_ssi_ineligible_spouse<2023, (default)> = [False  True False False]
#                   ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#                   ssi_ineligible_child_allocation<2023, (default)> = [   0.    0. 5484. 5484.]
#                 is_ssi_ineligible_child<2023, (default)> = [False False  True  True]
#           meets_ssi_resource_test<2023, (default)> = [ True  True  True  True]
#             ssi_claim_is_joint<2023, (default)> = [False False False False]
#             ssi_countable_resources<2023, (default)> = [0. 0. 0. 0.]
#           is_ssi_eligible_individual<2023, (default)> = [False False False False]
#             is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#             is_ssi_eligible_spouse<2023, (default)> = [False False False False]
#           ssi_countable_income<2023, (default)> = [0. 0. 0. 0.]
#             ssi_earned_income<2023, (default)> = [25000.     0.     0.     0.]
#             ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#             ssi_unearned_income_deemed_from_ineligible_parent<2023, (default)> = [0. 0. 0. 0.]
#               is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#               is_child<2023, (default)> = [False False  True  True]
#               is_ssi_ineligible_parent<2023, (default)> = [False False False False]
#                 is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                 is_child<2023, (default)> = [False False  True  True]
#               ssi_earned_income<2023, (default)> = [25000.     0.     0.     0.]
#               ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#               ssi_ineligible_child_allocation<2023, (default)> = [   0.    0. 5484. 5484.]
#               ssi_ineligible_parent_allocation<2023, (default)> = [0. 0. 0. 0.]
#                 is_ssi_ineligible_parent<2023, (default)> = [False False False False]
#             ssi_income_deemed_from_ineligible_spouse<2023, (default)> = [0. 0. 0. 0.]
#             is_ssi_eligible_individual<2023, (default)> = [False False False False]
#       state_supplement<2023, (default)> = [0. 0. 0. 0.]
#         uncapped_ssi<2023, (default)> = [0. 0. 0. 0.]
#         maximum_state_supplement<2023, (default)> = [0. 0. 0. 0.]
#           is_ssi_eligible_individual<2023, (default)> = [False False False False]
#           state_code_str<2023, (default)> = ['UT']
#             state_code<2023, (default)> = ['UT']
#               state_name<2023, (default)> = ['UT']
#           state_living_arrangement<2023, (default)> = ['FULL_COST']
#           is_blind<2023, (default)> = [False False False False]
#           is_ssi_aged<2023, (default)> = [False False False False]
#           is_ssi_disabled<2023, (default)> = [False False False False]
#           ssi_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#           ssi_claim_is_joint<2023, (default)> = [False False False False]
#         is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#         meets_ssi_resource_test<2023, (default)> = [ True  True  True  True]
#         ssi_claim_is_joint<2023, (default)> = [False False False False]
#       ca_cvrp<2023, (default)> = [0. 0. 0. 0.]
#         CA<2023, (default)> = [False]
#           state_code_str<2023, (default)> = ['UT']
#       snap<2023, (default)> = [6860.5]
#         snap_normal_allotment<2023, (default)> = [5979.]
#           is_snap_eligible<2023, (default)> = [ True]
#             meets_snap_net_income_test<2023, (default)> = [ True]
#               snap_net_income_fpg_ratio<2023, (default)> = [0.5876667]
#                 snap_net_income<2023, (default)> = [17630.]
#                   snap_gross_income<2023, (default)> = [25000.]
#                     snap_earned_income<2023, (default)> = [25000.]
#                       employment_income<2023, (default)> = [25000.     0.     0.     0.]
#                       self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                     snap_unearned_income<2023, (default)> = [0.]
#                       dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                       interest_income<2023, (default)> = [0. 0. 0. 0.]
#                       gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#                       social_security<2023, (default)> = [0. 0. 0. 0.]
#                       ssi<2023, (default)> = [0. 0. 0. 0.]
#                   snap_deductions<2023, (default)> = [7370.]
#                     snap_standard_deduction<2023, (default)> = [2316.]
#                       state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#                         state_group<2023, (default)> = ['CONTIGUOUS_US']
#                           state_code<2023, (default)> = ['UT']
#                       spm_unit_size<2023, (default)> = [4]
#                     snap_earned_income_deduction<2023, (default)> = [5000.]
#                       snap_earned_income<2023, (default)> = [25000.]
#                     snap_dependent_care_deduction<2023, (default)> = [0.]
#                       childcare_expenses<2023, (default)> = [0.]
#                     snap_child_support_deduction<2023, (default)> = [0.]
#                       child_support_expense<2023, (default)> = [0. 0. 0. 0.]
#                       state_code_str<2023, (default)> = ['UT']
#                     snap_excess_medical_expense_deduction<2023, (default)> = [0.]
#                       is_usda_elderly<2023, (default)> = [False False False False]
#                         age<2023, (default)> = [38. 35. 10.  6.]
#                       is_usda_disabled<2023, (default)> = [False False False False]
#                         is_ssi_disabled<2023, (default)> = [False False False False]
#                         social_security_disability<2023, (default)> = [0. 0. 0. 0.]
#                         is_permanently_disabled_veteran<2023, (default)> = [False False False False]
#                         is_surviving_spouse_of_disabled_veteran<2023, (default)> = [False False False False]
#                         is_surviving_child_of_disabled_veteran<2023, (default)> = [False False False False]
#                       medical_out_of_pocket_expenses<2023, (default)> = [200.   0.   0.   0.]
#                       state_code_str<2023, (default)> = ['UT']
#                     snap_excess_shelter_expense_deduction<2023, (default)> = [54.]
#                       snap_net_income_pre_shelter<2023, (default)> = [17684.]
#                         snap_gross_income<2023, (default)> = [25000.]
#                         snap_standard_deduction<2023, (default)> = [2316.]
#                         snap_earned_income_deduction<2023, (default)> = [5000.]
#                         snap_dependent_care_deduction<2023, (default)> = [0.]
#                         snap_child_support_deduction<2023, (default)> = [0.]
#                         snap_excess_medical_expense_deduction<2023, (default)> = [0.]
#                       housing_cost<2023, (default)> = [8000.]
#                       snap_region_str<2023, (default)> = ['CONTIGUOUS_US']
#                         snap_region<2023, (default)> = ['CONTIGUOUS_US']
#                           state_group<2023, (default)> = ['CONTIGUOUS_US']
#                       has_usda_elderly_disabled<2023, (default)> = [False]
#                         is_usda_elderly<2023, (default)> = [False False False False]
#                         is_usda_disabled<2023, (default)> = [False False False False]
#                       snap_utility_allowance<2023, (default)> = [54.]
#                         snap_utility_allowance_type<2023, (default)> = ['IUA']
#                           count_distinct_utility_expenses<2023, (default)> = [1]
#                             heating_cooling_expense<2023, (default)> = [0.]
#                             electricity_expense<2023, (default)> = [0.]
#                             gas_expense<2023, (default)> = [0.]
#                             phone_expense<2023, (default)> = [700.]
#                               phone_cost<2023, (default)> = [700.]
#                             trash_expense<2023, (default)> = [0.]
#                             water_expense<2023, (default)> = [0.]
#                             sewage_expense<2023, (default)> = [0.]
#                           snap_utility_region_str<2023, (default)> = ['UT']
#                             snap_utility_region<2023, (default)> = ['UT']
#                               state_code<2023, (default)> = ['UT']
#                           has_heating_cooling_expense<2023, (default)> = [False]
#                             heating_cooling_expense<2023, (default)> = [0.]
#                         snap_utility_region_str<2023, (default)> = ['UT']
#                       state_code_str<2023, (default)> = ['UT']
#                       is_homeless<2023, (default)> = [False]
#                 spm_unit_fpg<2023, (default)> = [30000.]
#                   spm_unit_size<2023, (default)> = [4]
#                   state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#             meets_snap_gross_income_test<2023, (default)> = [ True]
#               snap_gross_income_fpg_ratio<2023, (default)> = [0.8333333]
#                 snap_gross_income<2023, (default)> = [25000.]
#                 spm_unit_fpg<2023, (default)> = [30000.]
#               has_usda_elderly_disabled<2023, (default)> = [False]
#             meets_snap_asset_test<2023, (default)> = [ True]
#               has_usda_elderly_disabled<2023, (default)> = [False]
#               snap_assets<2023, (default)> = [0.]
#             meets_snap_categorical_eligibility<2023, (default)> = [False]
#               ssi<2023, (default)> = [0. 0. 0. 0.]
#               is_tanf_non_cash_eligible<2023, (default)> = [False]
#                 meets_tanf_non_cash_gross_income_test<2023, (default)> = [False]
#                   state_code_str<2023, (default)> = ['UT']
#                   snap_gross_income_fpg_ratio<2023, (default)> = [0.8333333]
#                 meets_tanf_non_cash_net_income_test<2023, (default)> = [ True]
#                   state_code_str<2023, (default)> = ['UT']
#                   is_tanf_non_cash_hheod<2023, (default)> = [False]
#                     state_code_str<2023, (default)> = ['UT']
#                     has_all_usda_elderly_disabled<2023, (default)> = [False]
#                       is_usda_elderly<2023, (default)> = [False False False False]
#                       is_usda_disabled<2023, (default)> = [False False False False]
#                     has_usda_elderly_disabled<2023, (default)> = [False]
#                   snap_net_income_fpg_ratio<2023, (default)> = [0.5876667]
#                 meets_tanf_non_cash_asset_test<2023, (default)> = [False]
#                   snap_assets<2023, (default)> = [0.]
#                   state_code_str<2023, (default)> = ['UT']
#           snap_expected_contribution<2023, (default)> = [5289.]
#             snap_net_income<2023, (default)> = [17630.]
#           snap_max_allotment<2023, (default)> = [11268.]
#             snap_region_str<2023, (default)> = ['CONTIGUOUS_US']
#             spm_unit_size<2023, (default)> = [4]
#             spm_unit_size<2023, (default)> = [4]
#           snap_min_allotment<2023, (default)> = [0.]
#             snap_region_str<2023, (default)> = ['CONTIGUOUS_US']
#             spm_unit_size<2023, (default)> = [4]
#         snap_emergency_allotment<2023, (default)> = [881.5]
#           snap_emergency_allotment_monthly<2023-01, (default)> = [440.75]
#             is_snap_eligible<2023, (default)> = [ True]
#             snap_max_allotment<2023, (default)> = [11268.]
#             snap_normal_allotment<2023, (default)> = [5979.]
#             state_code<2023, (default)> = ['UT']
#           snap_emergency_allotment_monthly<2023-02, (default)> = [440.75]
#             is_snap_eligible<2023, (default)> = [ True]
#             snap_max_allotment<2023, (default)> = [11268.]
#             snap_normal_allotment<2023, (default)> = [5979.]
#             state_code<2023, (default)> = ['UT']
#           snap_emergency_allotment_monthly<2023-03, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-04, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-05, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-06, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-07, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-08, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-09, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-10, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-11, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-12, (default)> = [0.]
#       wic<2023, (default)> = [0. 0. 0. 0.]
#         meets_wic_income_test<2023, (default)> = [ True]
#           school_meal_countable_income<2023, (default)> = [25000.]
#             employment_income<2023, (default)> = [25000.     0.     0.     0.]
#             self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#             dividend_income<2023, (default)> = [0. 0. 0. 0.]
#             interest_income<2023, (default)> = [0. 0. 0. 0.]
#             gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#             social_security<2023, (default)> = [0. 0. 0. 0.]
#             ssi<2023, (default)> = [0. 0. 0. 0.]
#           wic_fpg<2023, (default)> = [30000.]
#             is_pregnant<2023, (default)> = [False False False False]
#             spm_unit_fpg<2023, (default)> = [30000.]
#             state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#         meets_wic_categorical_eligibility<2023, (default)> = [ True  True  True  True]
#           snap<2023, (default)> = [6860.5]
#           tanf<2023, (default)> = [0.]
#             tanf_reported<2023, (default)> = [0. 0. 0. 0.]
#             is_tanf_eligible<2023, (default)> = [False]
#               is_person_demographic_tanf_eligible<2023, (default)> = [False False  True  True]
#                 is_child<2023, (default)> = [False False  True  True]
#                 age<2023, (default)> = [38. 35. 10.  6.]
#                 is_full_time_student<2023, (default)> = [False False  True  True]
#                   is_full_time_college_student<2023, (default)> = [False False False False]
#                   is_in_k12_school<2023, (default)> = [False False  True  True]
#                     age<2023, (default)> = [38. 35. 10.  6.]
#                 is_pregnant<2023, (default)> = [False False False False]
#               is_tanf_enrolled<2023, (default)> = [False]
#               is_tanf_continuous_eligible<2023, (default)> = [False]
#                 tanf_gross_earned_income<2023, (default)> = [25000.]
#                   employment_income<2023, (default)> = [25000.     0.     0.     0.]
#                   self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                 tanf_gross_unearned_income<2023, (default)> = [0.]
#                   dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                   interest_income<2023, (default)> = [0. 0. 0. 0.]
#                   gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#                   social_security<2023, (default)> = [0. 0. 0. 0.]
#                   ssi<2023, (default)> = [0. 0. 0. 0.]
#                 tanf_max_amount<2023, (default)> = [0.]
#                   spm_unit_size<2023, (default)> = [4]
#                   state_code_str<2023, (default)> = ['UT']
#               is_tanf_initial_eligible<2023, (default)> = [False]
#                 tanf_initial_employment_deduction<2023, (default)> = [0.]
#                   spm_unit_size<2023, (default)> = [4]
#                   state_code_str<2023, (default)> = ['UT']
#                   market_income<2023, (default)> = [25000.     0.     0.     0.]
#                     employment_income<2023, (default)> = [25000.     0.     0.     0.]
#                     self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                     pension_income<2023, (default)> = [0. 0. 0. 0.]
#                     dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                     interest_income<2023, (default)> = [0. 0. 0. 0.]
#                     gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#                     capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                     rental_income<2023, (default)> = [0. 0. 0. 0.]
#                     illicit_income<2023, (default)> = [0. 0. 0. 0.]
#                     farm_income<2023, (default)> = [0. 0. 0. 0.]
#                 tanf_gross_earned_income<2023, (default)> = [25000.]
#                 tanf_gross_unearned_income<2023, (default)> = [0.]
#                 tanf_max_amount<2023, (default)> = [0.]
#             tanf_amount_if_eligible<2023, (default)> = [0.]
#               tanf_max_amount<2023, (default)> = [0.]
#               tanf_countable_income<2023, (default)> = [25000.]
#                 state_code_str<2023, (default)> = ['UT']
#                 tanf_gross_unearned_income<2023, (default)> = [0.]
#                 tanf_gross_earned_income<2023, (default)> = [25000.]
#           medicaid<2023, (default)> = [9966.585 9966.585 9966.585 9966.585]
#             is_medicaid_eligible<2023, (default)> = [ True  True  True  True]
#               medicaid_category<2023, (default)> = ['ADULT' 'ADULT' 'OLDER_CHILD' 'OLDER_CHILD']
#                 is_infant_for_medicaid<2023, (default)> = [False False False False]
#                   is_infant_for_medicaid_fc<2023, (default)> = [ True  True  True  True]
#                     medicaid_income_level<2023, (default)> = [0.8333333 0.8333333 0.8333333 0.8333333]
#                       tax_unit_medicaid_income_level<2023, (default)> = [0.8333333]
#                         medicaid_income<2023, (default)> = [25000.]
#                           adjusted_gross_income<2023, (default)> = [25000.]
#                             irs_gross_income<2023, (default)> = [25000.     0.     0.     0.]
#                               is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                               employment_income<2023, (default)> = [25000.     0.     0.     0.]
#                               self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                               partnership_s_corp_income<2023, (default)> = [0. 0. 0. 0.]
#                               farm_income<2023, (default)> = [0. 0. 0. 0.]
#                               farm_rent_income<2023, (default)> = [0. 0. 0. 0.]
#                               capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                               taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#                               rental_income<2023, (default)> = [0. 0. 0. 0.]
#                               dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                               taxable_pension_income<2023, (default)> = [0. 0. 0. 0.]
#                               debt_relief<2023, (default)> = [0. 0. 0. 0.]
#                               taxable_unemployment_compensation<2023, (default)> = [0. 0. 0. 0.]
#                                 is_tax_unit_head<2023, (default)> = [ True False False False]
#                                 tax_unit_taxable_unemployment_compensation<2023, (default)> = [0.]
#                                   tax_unit_unemployment_compensation<2023, (default)> = [0.]
#                                     unemployment_compensation<2023, (default)> = [0. 0. 0. 0.]
#                                   taxable_uc_agi<2023, (default)> = [25000.]
#                                     is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                                     employment_income<2023, (default)> = [25000.     0.     0.     0.]
#                                     self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                     partnership_s_corp_income<2023, (default)> = [0. 0. 0. 0.]
#                                     farm_income<2023, (default)> = [0. 0. 0. 0.]
#                                     farm_rent_income<2023, (default)> = [0. 0. 0. 0.]
#                                     capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                                     taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#                                     rental_income<2023, (default)> = [0. 0. 0. 0.]
#                                     dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                                     taxable_pension_income<2023, (default)> = [0. 0. 0. 0.]
#                                     debt_relief<2023, (default)> = [0. 0. 0. 0.]
#                                     taxable_social_security<2023, (default)> = [0. 0. 0. 0.]
#                                       tax_unit_taxable_social_security<2023, (default)> = [0.]
#                                         tax_unit_social_security<2023, (default)> = [0.]
#                                           social_security<2023, (default)> = [0. 0. 0. 0.]
#                                         taxable_ss_magi<2023, (default)> = [25000.]
#                                           is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                                           employment_income<2023, (default)> = [25000.     0.     0.     0.]
#                                           self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                           partnership_s_corp_income<2023, (default)> = [0. 0. 0. 0.]
#                                           farm_income<2023, (default)> = [0. 0. 0. 0.]
#                                           farm_rent_income<2023, (default)> = [0. 0. 0. 0.]
#                                           capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                                           taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#                                           rental_income<2023, (default)> = [0. 0. 0. 0.]
#                                           dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                                           taxable_pension_income<2023, (default)> = [0. 0. 0. 0.]
#                                           debt_relief<2023, (default)> = [0. 0. 0. 0.]
#                                           illicit_income<2023, (default)> = [0. 0. 0. 0.]
#                                           unemployment_compensation<2023, (default)> = [0. 0. 0. 0.]
#                                           tax_exempt_interest_income<2023, (default)> = [0. 0. 0. 0.]
#                                           loss_ald<2023, (default)> = [0.]
#                                             filing_status<2023, (default)> = ['JOINT']
#                                               is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                                               tax_unit_dependents<2023, (default)> = [2]
#                                                 is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                                             self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                             maximum_capital_loss<2023, (default)> = [0.]
#                                               tax_unit_capital_loss<2023, (default)> = [0.]
#                                                 capital_loss<2023, (default)> = [0. 0. 0. 0.]
#                                                   capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                                               filing_status<2023, (default)> = ['JOINT']
#                                           self_employment_tax_ald<2023, (default)> = [0.]
#                                             self_employment_tax_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employment_tax<2023, (default)> = [0. 0. 0. 0.]
#                                                 self_employment_social_security_tax<2023, (default)> = [0. 0. 0. 0.]
#                                                   social_security_taxable_self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                                     taxable_self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                                       sey<2023, (default)> = [0. 0. 0. 0.]
#                                                         self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                                         farm_income<2023, (default)> = [0. 0. 0. 0.]
#                                                         k1bx14<2023, (default)> = [0. 0. 0. 0.]
#                                                     taxable_earnings_for_social_security<2023, (default)> = [25000.     0.     0.     0.]
#                                                       payroll_tax_gross_wages<2023, (default)> = [25000.     0.     0.     0.]
#                                                         employment_income<2023, (default)> = [25000.     0.     0.     0.]
#                                                 self_employment_medicare_tax<2023, (default)> = [0. 0. 0. 0.]
#                                                   taxable_self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                           early_withdrawal_penalty<2023, (default)> = [0. 0. 0. 0.]
#                                           alimony_income<2023, (default)> = [0. 0. 0. 0.]
#                                           educator_expense<2023, (default)> = [0. 0. 0. 0.]
#                                           health_savings_account_ald<2023, (default)> = [0.]
#                                           self_employed_health_insurance_ald<2023, (default)> = [0.]
#                                             self_employed_health_insurance_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employed_health_insurance_premiums<2023, (default)> = [0. 0. 0. 0.]
#                                                 is_self_employed<2023, (default)> = [False False False False]
#                                                 health_insurance_premiums<2023, (default)> = [0. 0. 0. 0.]
#                                           self_employed_pension_contribution_ald<2023, (default)> = [0.]
#                                             self_employed_pension_contribution_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employed_pension_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                           ira_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                           sep_simple_qualified_plan_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                         filing_status<2023, (default)> = ['JOINT']
#                                       tax_unit_social_security<2023, (default)> = [0.]
#                                       social_security<2023, (default)> = [0. 0. 0. 0.]
#                                       is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                                       is_tax_unit_head<2023, (default)> = [ True False False False]
#                                     illicit_income<2023, (default)> = [0. 0. 0. 0.]
#                                     loss_ald<2023, (default)> = [0.]
#                                     self_employment_tax_ald<2023, (default)> = [0.]
#                                     student_loan_interest<2023, (default)> = [0. 0. 0. 0.]
#                                     early_withdrawal_penalty<2023, (default)> = [0. 0. 0. 0.]
#                                     alimony_income<2023, (default)> = [0. 0. 0. 0.]
#                                     educator_expense<2023, (default)> = [0. 0. 0. 0.]
#                                     health_savings_account_ald<2023, (default)> = [0.]
#                                     self_employed_health_insurance_ald<2023, (default)> = [0.]
#                                     self_employed_pension_contribution_ald<2023, (default)> = [0.]
#                                     ira_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                     sep_simple_qualified_plan_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                     qualified_adoption_assistance_expense<2023, (default)> = [0. 0. 0. 0.]
#                                     us_bonds_for_higher_ed<2023, (default)> = [0. 0. 0. 0.]
#                                     specified_possession_income<2023, (default)> = [0.]
#                                     puerto_rico_income<2023, (default)> = [0.]
#                                   filing_status<2023, (default)> = ['JOINT']
#                               taxable_social_security<2023, (default)> = [0. 0. 0. 0.]
#                               illicit_income<2023, (default)> = [0. 0. 0. 0.]
#                             above_the_line_deductions<2023, (default)> = [0.]
#                               loss_ald<2023, (default)> = [0.]
#                               self_employment_tax_ald<2023, (default)> = [0.]
#                               student_loan_interest<2023, (default)> = [0. 0. 0. 0.]
#                               early_withdrawal_penalty<2023, (default)> = [0. 0. 0. 0.]
#                               alimony_income<2023, (default)> = [0. 0. 0. 0.]
#                               educator_expense<2023, (default)> = [0. 0. 0. 0.]
#                               health_savings_account_ald<2023, (default)> = [0.]
#                               self_employed_health_insurance_ald<2023, (default)> = [0.]
#                               self_employed_pension_contribution_ald<2023, (default)> = [0.]
#                               ira_contributions<2023, (default)> = [0. 0. 0. 0.]
#                               sep_simple_qualified_plan_contributions<2023, (default)> = [0. 0. 0. 0.]
#                               qualified_adoption_assistance_expense<2023, (default)> = [0. 0. 0. 0.]
#                               us_bonds_for_higher_ed<2023, (default)> = [0. 0. 0. 0.]
#                               specified_possession_income<2023, (default)> = [0.]
#                               puerto_rico_income<2023, (default)> = [0.]
#                           foreign_earned_income_exclusion<2023, (default)> = [0.]
#                           student_loan_interest<2023, (default)> = [0. 0. 0. 0.]
#                           tax_exempt_social_security<2023, (default)> = [0.]
#                             tax_unit_social_security<2023, (default)> = [0.]
#                             tax_unit_taxable_social_security<2023, (default)> = [0.]
#                         tax_unit_fpg<2023, (default)> = [30000.]
#                           tax_unit_size<2023, (default)> = [4]
#                           state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#                     state_code_str<2023, (default)> = ['UT']
#                   is_infant_for_medicaid_nfc<2023, (default)> = [False False False False]
#                     age<2023, (default)> = [38. 35. 10.  6.]
#                 is_young_child_for_medicaid<2023, (default)> = [False False False False]
#                   is_young_child_for_medicaid_fc<2023, (default)> = [ True  True  True  True]
#                     medicaid_income_level<2023, (default)> = [0.8333333 0.8333333 0.8333333 0.8333333]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_young_child_for_medicaid_nfc<2023, (default)> = [False False False False]
#                     age<2023, (default)> = [38. 35. 10.  6.]
#                 is_older_child_for_medicaid<2023, (default)> = [False False  True  True]
#                   age<2023, (default)> = [38. 35. 10.  6.]
#                   medicaid_income_level<2023, (default)> = [0.8333333 0.8333333 0.8333333 0.8333333]
#                   state_code_str<2023, (default)> = ['UT']
#                 is_young_adult_for_medicaid<2023, (default)> = [False False False False]
#                   is_young_adult_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [0.8333333 0.8333333 0.8333333 0.8333333]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_young_adult_for_medicaid_nfc<2023, (default)> = [False False False False]
#                     age<2023, (default)> = [38. 35. 10.  6.]
#                 is_adult_for_medicaid<2023, (default)> = [ True  True False False]
#                   is_adult_for_medicaid_fc<2023, (default)> = [ True  True  True  True]
#                     medicaid_income_level<2023, (default)> = [0.8333333 0.8333333 0.8333333 0.8333333]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_adult_for_medicaid_nfc<2023, (default)> = [ True  True False False]
#                     age<2023, (default)> = [38. 35. 10.  6.]
#                 is_parent_for_medicaid<2023, (default)> = [False False False False]
#                   is_parent_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [0.8333333 0.8333333 0.8333333 0.8333333]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_parent_for_medicaid_nfc<2023, (default)> = [ True  True False False]
#                     is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                     tax_unit_count_dependents<2023, (default)> = [2]
#                       is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                 is_pregnant_for_medicaid<2023, (default)> = [False False False False]
#                   is_pregnant_for_medicaid_fc<2023, (default)> = [ True  True  True  True]
#                     medicaid_income_level<2023, (default)> = [0.8333333 0.8333333 0.8333333 0.8333333]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_pregnant_for_medicaid_nfc<2023, (default)> = [False False False False]
#                     is_pregnant<2023, (default)> = [False False False False]
#                     count_days_postpartum<2023, (default)> = [inf inf inf inf]
#                       under_60_days_postpartum<2023, (default)> = [False False False False]
#                       under_12_months_postpartum<2023, (default)> = [False False False False]
#                     state_code_str<2023, (default)> = ['UT']
#                 is_ssi_recipient_for_medicaid<2023, (default)> = [False False False False]
#                   state_code_str<2023, (default)> = ['UT']
#                   ssi<2023, (default)> = [0. 0. 0. 0.]
#             medicaid_benefit_value<2023, (default)> = [9966.585 9966.585 9966.585 9966.585]
#               state_code_str<2023, (default)> = ['UT']
#           is_pregnant<2023, (default)> = [False False False False]
#           wic_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#             is_pregnant<2023, (default)> = [False False False False]
#             is_mother<2023, (default)> = [False False False False]
#               is_female<2023, (default)> = [False False False False]
#               own_children_in_household<2023, (default)> = [0 0 0 0]
#               is_breastfeeding<2023, (default)> = [False False False False]
#             is_breastfeeding<2023, (default)> = [False False False False]
#             age<2023, (default)> = [38. 35. 10.  6.]
#         wic_category_str<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#           wic_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#         is_wic_at_nutritional_risk<2023, (default)> = [False False False False]
#           receives_wic<2023, (default)> = [False False False False]
#           meets_wic_income_test<2023, (default)> = [ True]
#           meets_wic_categorical_eligibility<2023, (default)> = [ True  True  True  True]
#           wic_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#         would_claim_wic<2023, (default)> = [ True  True  True  True]
#       free_school_meals<2023, (default)> = [1915.2]
#         school_meal_tier<2023, (default)> = ['FREE']
#           school_meal_fpg_ratio<2023, (default)> = [0.8333333]
#             school_meal_countable_income<2023, (default)> = [25000.]
#             spm_unit_fpg<2023, (default)> = [30000.]
#           meets_school_meal_categorical_eligibility<2023, (default)> = [ True]
#             snap<2023, (default)> = [6860.5]
#             tanf<2023, (default)> = [0.]
#             fdpir<2023, (default)> = [0.]
#         school_meal_net_subsidy<2023, (default)> = [1915.2]
#           school_meal_daily_subsidy<2023, (default)> = [6.04]
#             state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#             school_meal_tier<2023, (default)> = ['FREE']
#           school_meal_paid_daily_subsidy<2023, (default)> = [0.72]
#             state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#           is_in_k12_school<2023, (default)> = [False False  True  True]
#       reduced_price_school_meals<2023, (default)> = [0.]
#         school_meal_tier<2023, (default)> = ['FREE']
#         school_meal_net_subsidy<2023, (default)> = [1915.2]
#       lifeline<2023, (default)> = [111.]
#         is_rural<2023, (default)> = [False]
#         is_on_tribal_land<2023, (default)> = [False]
#         phone_cost<2023, (default)> = [700.]
#         broadband_cost<2023, (default)> = [600.]
#         is_lifeline_eligible<2023, (default)> = [ True]
#           medicaid<2023, (default)> = [9966.585 9966.585 9966.585 9966.585]
#           snap<2023, (default)> = [6860.5]
#           ssi<2023, (default)> = [0. 0. 0. 0.]
#           fcc_fpg_ratio<2023, (default)> = [0.8333333]
#             irs_gross_income<2023, (default)> = [25000.     0.     0.     0.]
#             spm_unit_fpg<2023, (default)> = [30000.]
#       acp<2023, (default)> = [360.]
#         is_acp_eligible<2023, (default)> = [ True]
#           lifeline<2023, (default)> = [111.]
#           free_school_meals<2023, (default)> = [1915.2]
#           reduced_price_school_meals<2023, (default)> = [0.]
#           pell_grant<2023, (default)> = [0.]
#           wic<2023, (default)> = [0. 0. 0. 0.]
#           medicaid<2023, (default)> = [9966.585 9966.585 9966.585 9966.585]
#           snap<2023, (default)> = [6860.5]
#           ssi<2023, (default)> = [0. 0. 0. 0.]
#           fcc_fpg_ratio<2023, (default)> = [0.8333333]
#           ebb<2023, (default)> = [0.]
#             is_ebb_eligible<2023, (default)> = [False]
#               is_lifeline_eligible<2023, (default)> = [ True]
#               free_school_meals<2023, (default)> = [1915.2]
#               reduced_price_school_meals<2023, (default)> = [0.]
#               pell_grant<2023, (default)> = [0.]
#               experienced_covid_income_loss<2023, (default)> = [False]
#               enrolled_in_ebb<2023, (default)> = [False]
#             broadband_cost_after_lifeline<2023, (default)> = [489.]
#               broadband_cost<2023, (default)> = [600.]
#               lifeline<2023, (default)> = [111.]
#             is_on_tribal_land<2023, (default)> = [False]
#         broadband_cost_after_lifeline<2023, (default)> = [489.]
#         is_on_tribal_land<2023, (default)> = [False]
#       ebb<2023, (default)> = [0.]
#       tanf<2023, (default)> = [0.]
#       high_efficiency_electric_home_rebate<2023, (default)> = [0.]
#         capped_electric_heat_pump_clothes_dryer_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#             tax_unit_income_ami_ratio<2023, (default)> = [0.]
#           electric_heat_pump_clothes_dryer_expenditures<2023, (default)> = [0.]
#         capped_electric_load_service_center_upgrade_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           electric_load_service_center_upgrade_expenditures<2023, (default)> = [0.]
#         capped_electric_stove_cooktop_range_or_oven_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           electric_stove_cooktop_range_or_oven_expenditures<2023, (default)> = [0.]
#         capped_electric_wiring_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           electric_wiring_expenditures<2023, (default)> = [0.]
#         capped_heat_pump_water_heater_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           heat_pump_water_heater_expenditures<2023, (default)> = [0.]
#         capped_heat_pump_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           heat_pump_expenditures<2023, (default)> = [0.]
#         capped_insulation_air_sealing_ventilation_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           energy_efficient_insulation_expenditures<2023, (default)> = [0.]
#           air_sealing_ventilation_expenditures<2023, (default)> = [0.]
#       residential_efficiency_electrification_rebate<2023, (default)> = [0.]
#         residential_efficiency_electrification_retrofit_expenditures<2023, (default)> = [0.]
#         residential_efficiency_electrification_retrofit_energy_savings<2023, (default)> = [0.]
#         current_home_energy_use<2023, (default)> = [0.]
#         household_income_ami_ratio<2023, (default)> = [0.]
#         average_home_energy_use_in_state<2023, (default)> = [0.]
#       basic_income<2023, (default)> = [0.]
#         basic_income_eligible<2023, (default)> = [ True]
#         basic_income_before_phase_out<2023, (default)> = [0.]
#           tax_unit_size<2023, (default)> = [4]
#           age<2023, (default)> = [38. 35. 10.  6.]
#           tax_unit_fpg<2023, (default)> = [30000.]
#         basic_income_phase_out<2023, (default)> = [0.]
#           basic_income_before_phase_out<2023, (default)> = [0.]
#           adjusted_gross_income<2023, (default)> = [25000.]
#           filing_status<2023, (default)> = ['JOINT']
#       spm_unit_capped_housing_subsidy<2023, (default)> = [0.]
#         spm_unit_capped_housing_subsidy_reported<2023, (default)> = [0.]
#     household_refundable_tax_credits<2023, (default)> = [9804.]
#       income_tax_refundable_credits<2023, (default)> = [9804.]
#         eitc<2023, (default)> = [6604.]
#           earned_income_tax_credit<2023, (default)> = [6604.]
#             eitc_eligible<2023, (default)> = [ True]
#               is_child<2023, (default)> = [False False  True  True]
#               age<2023, (default)> = [38. 35. 10.  6.]
#               tax_exempt_interest_income<2023, (default)> = [0. 0. 0. 0.]
#               taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#               dividend_income<2023, (default)> = [0. 0. 0. 0.]
#               c01000<2023, (default)> = [0.]
#                 sep<2023, (default)> = [1]
#                 c23650<2023, (default)> = [0.]
#                   long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   short_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#               tax_unit_rental_income<2023, (default)> = [0.]
#                 rental_income<2023, (default)> = [0. 0. 0. 0.]
# ...
#                       filing_status<2023, (default)> = ['JOINT']
#                       aged_blind_count<2023, (default)> = [0]
#                         blind_head<2023, (default)> = [False]
#                           is_blind<2023, (default)> = [False False False False]
#                           is_tax_unit_head<2023, (default)> = [ True False False False]
#                         blind_spouse<2023, (default)> = [False]
#                           is_blind<2023, (default)> = [False False False False]
#                           is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                         age_head<2023, (default)> = [38]
#                         age_spouse<2023, (default)> = [35]
#                 taxable_income_deductions_if_itemizing<2023, (default)> = [0.]
#                   charitable_deduction<2023, (default)> = [0.]
#                   interest_deduction<2023, (default)> = [0.]
#                   salt_deduction<2023, (default)> = [0.]
#                     state_and_local_sales_or_income_tax<2023, (default)> = [0.]
#                       state_income_tax<2023, (default)> = [0.]
#                         ma_income_tax<2023, (default)> = [0.]
#                           MA<2023, (default)> = [False]
#                         md_income_tax<2023, (default)> = [0.]
#                           MD<2023, (default)> = [False]
#                         ny_income_tax<2023, (default)> = [0.]
#                           NY<2023, (default)> = [False]
#                         or_income_tax<2023, (default)> = [0.]
#                           OR<2023, (default)> = [False]
#                         pa_income_tax<2023, (default)> = [0.]
#                           PA<2023, (default)> = [False]
#                             state_code_str<2023, (default)> = ['UT']
#                         wa_income_tax<2023, (default)> = [0.]
#                           WA<2023, (default)> = [False]
#                         ut_income_tax<2023, (default)> = [0.]
#                           UT<2023, (default)> = [ True]
#                           ut_income_tax_before_refundable_credits<2023, (default)> = [0.]
#                             ut_income_tax_after_credits<2023, (default)> = [0.]
#                               ut_income_tax_before_credits<2023, (default)> = [1125.]
#                                 UT<2023, (default)> = [ True]
#                                 ut_taxable_income<2023, (default)> = [25000.]
#                                   UT<2023, (default)> = [ True]
#                                   ut_total_income<2023, (default)> = [25000.]
#                                     UT<2023, (default)> = [ True]
#                                     adjusted_gross_income<2023, (default)> = [25000.]
#                                     ut_additions_to_income<2023, (default)> = [0.]
#                                       UT<2023, (default)> = [ True]
#                                   salt_refund_last_year<2023, (default)> = [0.]
#                                   ut_subtractions_from_income<2023, (default)> = [0.]
#                                     UT<2023, (default)> = [ True]
#                               ut_taxpayer_credit<2023, (default)> = [1878.24]
#                                 UT<2023, (default)> = [ True]
#                                 ut_taxpayer_credit_max<2023, (default)> = [1878.24]
#                                   UT<2023, (default)> = [ True]
#                                   tax_unit_count_dependents<2023, (default)> = [2]
#                                   tax_unit_itemizes<2023, (default)> = [False]
#                                   standard_deduction<2023, (default)> = [27700.]
#                                   charitable_deduction<2023, (default)> = [0.]
#                                   interest_deduction<2023, (default)> = [0.]
#                                   medical_expense_deduction<2023, (default)> = [0.]
#                                   casualty_loss_deduction<2023, (default)> = [0.]
#                                 ut_taxpayer_credit_reduction<2023, (default)> = [0.]
#                                   UT<2023, (default)> = [ True]
#                                   filing_status<2023, (default)> = ['JOINT']
#                                   ut_taxable_income<2023, (default)> = [25000.]
#                             ut_apportionable_nonrefundable_credits<2023, (default)> = [0.]
#                               UT<2023, (default)> = [ True]
#                             ut_nonapportionable_nonrefundable_credits<2023, (default)> = [0.]
#                               UT<2023, (default)> = [ True]
#                             ut_recapture_low_inc_housing_credit<2023, (default)> = [0.]
#                               UT<2023, (default)> = [ True]
#                           ut_refundable_credits<2023, (default)> = [0.]
#                       local_income_tax<2023, (default)> = [0.]
#                       state_sales_tax<2023, (default)> = [0.]
#                       local_sales_tax<2023, (default)> = [0.]
#                     real_estate_taxes<2023, (default)> = [0. 0. 0. 0.]
#                     filing_status<2023, (default)> = ['JOINT']
#                   medical_expense_deduction<2023, (default)> = [0.]
#                   casualty_loss_deduction<2023, (default)> = [0.]
#                   qualified_business_income_deduction<2023, (default)> = [0.]
#                     qbid_amount<2023, (default)> = [0. 0. 0. 0.]
#                       qualified_business_income<2023, (default)> = [0. 0. 0. 0.]
#                         self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                         partnership_s_corp_income<2023, (default)> = [0. 0. 0. 0.]
#                         farm_income<2023, (default)> = [0. 0. 0. 0.]
#                         farm_rent_income<2023, (default)> = [0. 0. 0. 0.]
#                         self_employment_tax_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                         self_employed_health_insurance_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                         self_employed_pension_contribution_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                         business_is_qualified<2023, (default)> = [False False False False]
#                       w2_wages_from_qualified_business<2023, (default)> = [0. 0. 0. 0.]
#                       unadjusted_basis_qualified_property<2023, (default)> = [0. 0. 0. 0.]
#                       taxable_income_less_qbid<2023, (default)> = [0.]
#                         adjusted_gross_income<2023, (default)> = [25000.]
#                         charitable_deduction<2023, (default)> = [0.]
#                         interest_deduction<2023, (default)> = [0.]
#                         salt_deduction<2023, (default)> = [0.]
#                         medical_expense_deduction<2023, (default)> = [0.]
#                         casualty_loss_deduction<2023, (default)> = [0.]
#                         standard_deduction<2023, (default)> = [27700.]
#                       filing_status<2023, (default)> = ['JOINT']
#                       business_is_sstb<2023, (default)> = [False False False False]
#                     taxable_income_less_qbid<2023, (default)> = [0.]
#                     adjusted_net_capital_gain<2023, (default)> = [0.]
#                       net_capital_gain<2023, (default)> = [0.]
#                         net_long_term_capital_gain<2023, (default)> = [0.]
#                           long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                           long_term_capital_losses<2023, (default)> = [0. 0. 0. 0.]
#                         net_short_term_capital_loss<2023, (default)> = [0.]
#                           short_term_capital_losses<2023, (default)> = [0. 0. 0. 0.]
#                           short_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                         qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                       qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                       unrecaptured_section_1250_gain<2023, (default)> = [0.]
#                       capital_gains_28_percent_rate_gain<2023, (default)> = [0.]
#                         long_term_capital_gains_on_collectibles<2023, (default)> = [0. 0. 0. 0.]
#                         long_term_capital_gains_on_small_business_stock<2023, (default)> = [0. 0. 0. 0.]
#                 taxable_income_deductions_if_not_itemizing<2023, (default)> = [27700.]
#                   standard_deduction<2023, (default)> = [27700.]
#                   qualified_business_income_deduction<2023, (default)> = [0.]
#             capital_gains_excluded_from_taxable_income<2023, (default)> = [0.]
#               net_capital_gain<2023, (default)> = [0.]
#               adjusted_net_capital_gain<2023, (default)> = [0.]
#               taxable_income<2023, (default)> = [0.]
#               filing_status<2023, (default)> = ['JOINT']
#             filing_status<2023, (default)> = ['JOINT']
#           capital_gains_tax<2023, (default)> = [0.]
#             net_capital_gain<2023, (default)> = [0.]
#             taxable_income<2023, (default)> = [0.]
#             adjusted_net_capital_gain<2023, (default)> = [0.]
#             capital_gains_excluded_from_taxable_income<2023, (default)> = [0.]
#             filing_status<2023, (default)> = ['JOINT']
#             unrecaptured_section_1250_gain<2023, (default)> = [0.]
#             qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#             capital_gains_28_percent_rate_gain<2023, (default)> = [0.]
#           alternative_minimum_tax<2023, (default)> = [0.]
#             c09600<2023, (default)> = [0.]
#               c62100<2023, (default)> = [27700.]
#                 amt_income<2023, (default)> = [27700.]
#                   taxable_income<2023, (default)> = [0.]
#                   tax_unit_itemizes<2023, (default)> = [False]
#                   standard_deduction<2023, (default)> = [27700.]
#                   salt_deduction<2023, (default)> = [0.]
#                   filing_status<2023, (default)> = ['JOINT']
#               filing_status<2023, (default)> = ['JOINT']
#               age_head<2023, (default)> = [38]
#               age_spouse<2023, (default)> = [35]
#               filer_earned<2023, (default)> = [25000.]
#               sep<2023, (default)> = [1]
#               dwks10<2023, (default)> = [0.]
#                 dwks6<2023, (default)> = [0.]
#                   qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                   investment_income_form_4952<2023, (default)> = [0.]
#                 dwks9<2023, (default)> = [0.]
#                   long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                   c23650<2023, (default)> = [0.]
#                   non_sch_d_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   investment_income_form_4952<2023, (default)> = [0.]
#                 long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                 qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                 c23650<2023, (default)> = [0.]
#                 non_sch_d_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                 hasqdivltcg<2023, (default)> = [False]
#                   c01000<2023, (default)> = [0.]
#                   c23650<2023, (default)> = [0.]
#                   long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   non_sch_d_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#               dwks13<2023, (default)> = [0.]
#                 unrecaptured_section_1250_gain<2023, (default)> = [0.]
#                 capital_gains_28_percent_rate_gain<2023, (default)> = [0.]
#                 dwks9<2023, (default)> = [0.]
#                 dwks10<2023, (default)> = [0.]
#                 hasqdivltcg<2023, (default)> = [False]
#               dwks14<2023, (default)> = [0.]
#                 taxable_income<2023, (default)> = [0.]
#                 dwks13<2023, (default)> = [0.]
#                 hasqdivltcg<2023, (default)> = [False]
#               dwks19<2023, (default)> = [0.]
#                 dwks14<2023, (default)> = [0.]
#                 filing_status<2023, (default)> = ['JOINT']
#                 taxable_income<2023, (default)> = [0.]
#                 dwks10<2023, (default)> = [0.]
#                 hasqdivltcg<2023, (default)> = [False]
#               unrecaptured_section_1250_gain<2023, (default)> = [0.]
#               sep<2023, (default)> = [1]
#               foreign_tax_credit<2023, (default)> = [0.]
#               amt_form_completed<2023, (default)> = [False]
#               foreign_tax_credit<2023, (default)> = [0.]
#               taxbc<2023, (default)> = [0.]
#                 regular_tax_before_credits<2023, (default)> = [0.]
#                   filing_status<2023, (default)> = ['JOINT']
#                   taxable_income<2023, (default)> = [0.]
#                   dwks14<2023, (default)> = [0.]
#                   dwks13<2023, (default)> = [0.]
#                   dwks19<2023, (default)> = [0.]
#                   dwks9<2023, (default)> = [0.]
#                   unrecaptured_section_1250_gain<2023, (default)> = [0.]
#                   dwks10<2023, (default)> = [0.]
#                   income_tax_main_rates<2023, (default)> = [0.]
#                   hasqdivltcg<2023, (default)> = [False]
#               c05700<2023, (default)> = [0.]
#         net_investment_income_tax<2023, (default)> = [0.]
#           taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#           dividend_income<2023, (default)> = [0. 0. 0. 0.]
#           c01000<2023, (default)> = [0.]
#           rental_income<2023, (default)> = [0. 0. 0. 0.]
#           filing_status<2023, (default)> = ['JOINT']
#           adjusted_gross_income<2023, (default)> = [25000.]
#         recapture_of_investment_credit<2023, (default)> = [0.]
#         unreported_payroll_tax<2023, (default)> = [0.]
#         qualified_retirement_penalty<2023, (default)> = [0.]
#         income_tax_capped_non_refundable_credits<2023, (default)> = [0.]
#           income_tax_non_refundable_credits<2023, (default)> = [800.]
#             cdcc<2023, (default)> = [0.]
#             elderly_disabled_credit<2023, (default)> = [0.]
#             non_refundable_ctc<2023, (default)> = [800.]
#               ctc<2023, (default)> = [4000.]
#               refundable_ctc<2023, (default)> = [3200.]
#             non_refundable_american_opportunity_credit<2023, (default)> = [0.]
#             lifetime_learning_credit<2023, (default)> = [0.]
#             retirement_savings_credit<2023, (default)> = [0.]
#             residential_clean_energy_credit<2023, (default)> = [0.]
#             energy_efficient_home_improvement_credit<2023, (default)> = [0.]
#             new_clean_vehicle_credit<2023, (default)> = [0.]
#             used_clean_vehicle_credit<2023, (default)> = [0.]
#           income_tax_unavailable_non_refundable_credits<2023, (default)> = [800.]
#             income_tax_before_credits<2023, (default)> = [0.]
#             income_tax_non_refundable_credits<2023, (default)> = [800.]
#             income_tax_non_refundable_credits<2023, (default)> = [800.]
#       ma_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         MA<2023, (default)> = [False]
#       md_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         MD<2023, (default)> = [False]
#       ny_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         NY<2023, (default)> = [False]
#       or_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         or_income_tax_before_credits<2023, (default)> = [0.]
#           OR<2023, (default)> = [False]
#         or_non_refundable_credits<2023, (default)> = [0.]
#           or_exemption_credit<2023, (default)> = [0.]
#             OR<2023, (default)> = [False]
#       pa_income_tax<2023, (default)> = [0.]
#       ut_income_tax_before_refundable_credits<2023, (default)> = [0.]
#       wa_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         WA<2023, (default)> = [False]
#       flat_tax<2023, (default)> = [0.]
#         positive_agi<2023, (default)> = [25000.]

# %% [markdown]
# #### 3.4.2. Effect of rate cut to 4.50% on middle income household

# %%
simulation_2_m = Simulation(
    reform=reform_2,
    situation=situation_mid,
)

simulation_2_m.trace = True
simulation_2_m.calculate("household_net_income", 2023)
simulation_2_m.tracer.print_computation_log()
# Out:
#   household_net_income<2023, (default)> = [69886.484]
#     household_market_income<2023, (default)> = [80000.]
#       employment_income<2023, (default)> = [45000. 35000.     0.     0.]
#       self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#       pension_income<2023, (default)> = [0. 0. 0. 0.]
#         tax_exempt_pension_income<2023, (default)> = [0. 0. 0. 0.]
#         taxable_pension_income<2023, (default)> = [0. 0. 0. 0.]
#       dividend_income<2023, (default)> = [0. 0. 0. 0.]
#         qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#         non_qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#       interest_income<2023, (default)> = [0. 0. 0. 0.]
#         tax_exempt_interest_income<2023, (default)> = [0. 0. 0. 0.]
#         taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#       gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#       capital_gains<2023, (default)> = [0. 0. 0. 0.]
#         short_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#         long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#       rental_income<2023, (default)> = [0. 0. 0. 0.]
#       illicit_income<2023, (default)> = [0. 0. 0. 0.]
#       farm_income<2023, (default)> = [0. 0. 0. 0.]
#     household_benefits<2023, (default)> = [0.]
#       social_security<2023, (default)> = [0. 0. 0. 0.]
#         social_security_dependents<2023, (default)> = [0. 0. 0. 0.]
#         social_security_disability<2023, (default)> = [0. 0. 0. 0.]
#         social_security_retirement<2023, (default)> = [0. 0. 0. 0.]
#         social_security_survivors<2023, (default)> = [0. 0. 0. 0.]
#       ssi<2023, (default)> = [0. 0. 0. 0.]
#         uncapped_ssi<2023, (default)> = [0. 0. 0. 0.]
#           ssi_amount_if_eligible<2023, (default)> = [16452. 10968. 10968. 10968.]
#             ssi_claim_is_joint<2023, (default)> = [ True False False False]
#               is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                 is_ssi_aged<2023, (default)> = [False False False False]
#                   age<2023, (default)> = [38. 35. 10. 10.]
#                 is_blind<2023, (default)> = [False False False False]
#                 is_ssi_disabled<2023, (default)> = [False False False False]
#                   is_ssi_aged<2023, (default)> = [False False False False]
#                   is_blind<2023, (default)> = [False False False False]
#                   ssi_reported<2023, (default)> = [0. 0. 0. 0.]
#               ssi_income_deemed_from_ineligible_spouse<2023, (default)> = [17500.     0.     0.     0.]
#                 ssi_earned_income<2023, (default)> = [45000. 35000.     0.     0.]
#                   employment_income<2023, (default)> = [45000. 35000.     0.     0.]
#                   self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                 ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#                   dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                   interest_income<2023, (default)> = [0. 0. 0. 0.]
#                   gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#                   social_security<2023, (default)> = [0. 0. 0. 0.]
#                   alimony_income<2023, (default)> = [0. 0. 0. 0.]
#                   pension_income<2023, (default)> = [0. 0. 0. 0.]
#                   unemployment_compensation<2023, (default)> = [0. 0. 0. 0.]
#                 ssi_earned_income_deemed_from_ineligible_spouse<2023, (default)> = [35000.     0.     0.     0.]
#                   is_ssi_ineligible_spouse<2023, (default)> = [False  True False False]
#                     is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                       is_child<2023, (default)> = [False False  True  True]
#                         age<2023, (default)> = [38. 35. 10. 10.]
#                       is_tax_unit_head<2023, (default)> = [ True False False False]
#                         is_child<2023, (default)> = [False False  True  True]
#                         age<2023, (default)> = [38. 35. 10. 10.]
#                       age<2023, (default)> = [38. 35. 10. 10.]
#                     is_ssi_eligible_spouse<2023, (default)> = [False False False False]
#                       is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                       is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                   ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#                   ssi_earned_income<2023, (default)> = [45000. 35000.     0.     0.]
#                   ssi_ineligible_child_allocation<2023, (default)> = [   0.    0. 5484. 5484.]
#                     ssi_earned_income<2023, (default)> = [45000. 35000.     0.     0.]
#                     ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#                     is_ssi_ineligible_child<2023, (default)> = [False False  True  True]
#                       is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                       is_child<2023, (default)> = [False False  True  True]
#                   is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                 ssi_unearned_income_deemed_from_ineligible_spouse<2023, (default)> = [0. 0. 0. 0.]
#                   is_ssi_ineligible_spouse<2023, (default)> = [False  True False False]
#                   ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#                   ssi_ineligible_child_allocation<2023, (default)> = [   0.    0. 5484. 5484.]
#                 is_ssi_ineligible_child<2023, (default)> = [False False  True  True]
#           meets_ssi_resource_test<2023, (default)> = [ True  True  True  True]
#             ssi_claim_is_joint<2023, (default)> = [ True False False False]
#             ssi_countable_resources<2023, (default)> = [0. 0. 0. 0.]
#           is_ssi_eligible_individual<2023, (default)> = [False False False False]
#             is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#             is_ssi_eligible_spouse<2023, (default)> = [False False False False]
#           ssi_countable_income<2023, (default)> = [0. 0. 0. 0.]
#             ssi_earned_income<2023, (default)> = [45000. 35000.     0.     0.]
#             ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#             ssi_unearned_income_deemed_from_ineligible_parent<2023, (default)> = [0. 0. 0. 0.]
#               is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#               is_child<2023, (default)> = [False False  True  True]
#               is_ssi_ineligible_parent<2023, (default)> = [False False False False]
#                 is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                 is_child<2023, (default)> = [False False  True  True]
#               ssi_earned_income<2023, (default)> = [45000. 35000.     0.     0.]
#               ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#               ssi_ineligible_child_allocation<2023, (default)> = [   0.    0. 5484. 5484.]
#               ssi_ineligible_parent_allocation<2023, (default)> = [0. 0. 0. 0.]
#                 is_ssi_ineligible_parent<2023, (default)> = [False False False False]
#             ssi_income_deemed_from_ineligible_spouse<2023, (default)> = [17500.     0.     0.     0.]
#             is_ssi_eligible_individual<2023, (default)> = [False False False False]
#       state_supplement<2023, (default)> = [0. 0. 0. 0.]
#         uncapped_ssi<2023, (default)> = [0. 0. 0. 0.]
#         maximum_state_supplement<2023, (default)> = [0. 0. 0. 0.]
#           is_ssi_eligible_individual<2023, (default)> = [False False False False]
#           state_code_str<2023, (default)> = ['UT']
#             state_code<2023, (default)> = ['UT']
#               state_name<2023, (default)> = ['UT']
#           state_living_arrangement<2023, (default)> = ['FULL_COST']
#           is_blind<2023, (default)> = [False False False False]
#           is_ssi_aged<2023, (default)> = [False False False False]
#           is_ssi_disabled<2023, (default)> = [False False False False]
#           ssi_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#           ssi_claim_is_joint<2023, (default)> = [ True False False False]
#         is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#         meets_ssi_resource_test<2023, (default)> = [ True  True  True  True]
#         ssi_claim_is_joint<2023, (default)> = [ True False False False]
#       ca_cvrp<2023, (default)> = [0. 0. 0. 0.]
#         CA<2023, (default)> = [False]
#           state_code_str<2023, (default)> = ['UT']
#       snap<2023, (default)> = [0.]
#         snap_normal_allotment<2023, (default)> = [0.]
#           is_snap_eligible<2023, (default)> = [False]
#             meets_snap_net_income_test<2023, (default)> = [False]
#               snap_net_income_fpg_ratio<2023, (default)> = [2.021]
#                 snap_net_income<2023, (default)> = [60630.]
#                   snap_gross_income<2023, (default)> = [80000.]
#                     snap_earned_income<2023, (default)> = [80000.]
#                       employment_income<2023, (default)> = [45000. 35000.     0.     0.]
#                       self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                     snap_unearned_income<2023, (default)> = [0.]
#                       dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                       interest_income<2023, (default)> = [0. 0. 0. 0.]
#                       gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#                       social_security<2023, (default)> = [0. 0. 0. 0.]
#                       ssi<2023, (default)> = [0. 0. 0. 0.]
#                   snap_deductions<2023, (default)> = [19370.]
#                     snap_standard_deduction<2023, (default)> = [2316.]
#                       state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#                         state_group<2023, (default)> = ['CONTIGUOUS_US']
#                           state_code<2023, (default)> = ['UT']
#                       spm_unit_size<2023, (default)> = [4]
#                     snap_earned_income_deduction<2023, (default)> = [16000.]
#                       snap_earned_income<2023, (default)> = [80000.]
#                     snap_dependent_care_deduction<2023, (default)> = [1000.]
#                       childcare_expenses<2023, (default)> = [1000.]
#                     snap_child_support_deduction<2023, (default)> = [0.]
#                       child_support_expense<2023, (default)> = [0. 0. 0. 0.]
#                       state_code_str<2023, (default)> = ['UT']
#                     snap_excess_medical_expense_deduction<2023, (default)> = [0.]
#                       is_usda_elderly<2023, (default)> = [False False False False]
#                         age<2023, (default)> = [38. 35. 10. 10.]
#                       is_usda_disabled<2023, (default)> = [False False False False]
#                         is_ssi_disabled<2023, (default)> = [False False False False]
#                         social_security_disability<2023, (default)> = [0. 0. 0. 0.]
#                         is_permanently_disabled_veteran<2023, (default)> = [False False False False]
#                         is_surviving_spouse_of_disabled_veteran<2023, (default)> = [False False False False]
#                         is_surviving_child_of_disabled_veteran<2023, (default)> = [False False False False]
#                       medical_out_of_pocket_expenses<2023, (default)> = [2000.    0.    0.    0.]
#                       state_code_str<2023, (default)> = ['UT']
#                     snap_excess_shelter_expense_deduction<2023, (default)> = [54.]
#                       snap_net_income_pre_shelter<2023, (default)> = [60684.]
#                         snap_gross_income<2023, (default)> = [80000.]
#                         snap_standard_deduction<2023, (default)> = [2316.]
#                         snap_earned_income_deduction<2023, (default)> = [16000.]
#                         snap_dependent_care_deduction<2023, (default)> = [1000.]
#                         snap_child_support_deduction<2023, (default)> = [0.]
#                         snap_excess_medical_expense_deduction<2023, (default)> = [0.]
#                       housing_cost<2023, (default)> = [20000.]
#                       snap_region_str<2023, (default)> = ['CONTIGUOUS_US']
#                         snap_region<2023, (default)> = ['CONTIGUOUS_US']
#                           state_group<2023, (default)> = ['CONTIGUOUS_US']
#                       has_usda_elderly_disabled<2023, (default)> = [False]
#                         is_usda_elderly<2023, (default)> = [False False False False]
#                         is_usda_disabled<2023, (default)> = [False False False False]
#                       snap_utility_allowance<2023, (default)> = [54.]
#                         snap_utility_allowance_type<2023, (default)> = ['IUA']
#                           count_distinct_utility_expenses<2023, (default)> = [1]
#                             heating_cooling_expense<2023, (default)> = [0.]
#                             electricity_expense<2023, (default)> = [0.]
#                             gas_expense<2023, (default)> = [0.]
#                             phone_expense<2023, (default)> = [1500.]
#                               phone_cost<2023, (default)> = [1500.]
#                             trash_expense<2023, (default)> = [0.]
#                             water_expense<2023, (default)> = [0.]
#                             sewage_expense<2023, (default)> = [0.]
#                           snap_utility_region_str<2023, (default)> = ['UT']
#                             snap_utility_region<2023, (default)> = ['UT']
#                               state_code<2023, (default)> = ['UT']
#                           has_heating_cooling_expense<2023, (default)> = [False]
#                             heating_cooling_expense<2023, (default)> = [0.]
#                         snap_utility_region_str<2023, (default)> = ['UT']
#                       state_code_str<2023, (default)> = ['UT']
#                       is_homeless<2023, (default)> = [False]
#                 spm_unit_fpg<2023, (default)> = [30000.]
#                   spm_unit_size<2023, (default)> = [4]
#                   state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#             meets_snap_gross_income_test<2023, (default)> = [False]
#               snap_gross_income_fpg_ratio<2023, (default)> = [2.6666667]
#                 snap_gross_income<2023, (default)> = [80000.]
#                 spm_unit_fpg<2023, (default)> = [30000.]
#               has_usda_elderly_disabled<2023, (default)> = [False]
#             meets_snap_asset_test<2023, (default)> = [ True]
#               has_usda_elderly_disabled<2023, (default)> = [False]
#               snap_assets<2023, (default)> = [0.]
#             meets_snap_categorical_eligibility<2023, (default)> = [False]
#               ssi<2023, (default)> = [0. 0. 0. 0.]
#               is_tanf_non_cash_eligible<2023, (default)> = [False]
#                 meets_tanf_non_cash_gross_income_test<2023, (default)> = [False]
#                   state_code_str<2023, (default)> = ['UT']
#                   snap_gross_income_fpg_ratio<2023, (default)> = [2.6666667]
#                 meets_tanf_non_cash_net_income_test<2023, (default)> = [ True]
#                   state_code_str<2023, (default)> = ['UT']
#                   is_tanf_non_cash_hheod<2023, (default)> = [False]
#                     state_code_str<2023, (default)> = ['UT']
#                     has_all_usda_elderly_disabled<2023, (default)> = [False]
#                       is_usda_elderly<2023, (default)> = [False False False False]
#                       is_usda_disabled<2023, (default)> = [False False False False]
#                     has_usda_elderly_disabled<2023, (default)> = [False]
#                   snap_net_income_fpg_ratio<2023, (default)> = [2.021]
#                 meets_tanf_non_cash_asset_test<2023, (default)> = [False]
#                   snap_assets<2023, (default)> = [0.]
#                   state_code_str<2023, (default)> = ['UT']
#           snap_expected_contribution<2023, (default)> = [18189.]
#             snap_net_income<2023, (default)> = [60630.]
#           snap_max_allotment<2023, (default)> = [11268.]
#             snap_region_str<2023, (default)> = ['CONTIGUOUS_US']
#             spm_unit_size<2023, (default)> = [4]
#             spm_unit_size<2023, (default)> = [4]
#           snap_min_allotment<2023, (default)> = [0.]
#             snap_region_str<2023, (default)> = ['CONTIGUOUS_US']
#             spm_unit_size<2023, (default)> = [4]
#         snap_emergency_allotment<2023, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-01, (default)> = [0.]
#             is_snap_eligible<2023, (default)> = [False]
#             snap_max_allotment<2023, (default)> = [11268.]
#             snap_normal_allotment<2023, (default)> = [0.]
#             state_code<2023, (default)> = ['UT']
#           snap_emergency_allotment_monthly<2023-02, (default)> = [0.]
#             is_snap_eligible<2023, (default)> = [False]
#             snap_max_allotment<2023, (default)> = [11268.]
#             snap_normal_allotment<2023, (default)> = [0.]
#             state_code<2023, (default)> = ['UT']
#           snap_emergency_allotment_monthly<2023-03, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-04, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-05, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-06, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-07, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-08, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-09, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-10, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-11, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-12, (default)> = [0.]
#       wic<2023, (default)> = [0. 0. 0. 0.]
#         meets_wic_income_test<2023, (default)> = [False]
#           school_meal_countable_income<2023, (default)> = [80000.]
#             employment_income<2023, (default)> = [45000. 35000.     0.     0.]
#             self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#             dividend_income<2023, (default)> = [0. 0. 0. 0.]
#             interest_income<2023, (default)> = [0. 0. 0. 0.]
#             gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#             social_security<2023, (default)> = [0. 0. 0. 0.]
#             ssi<2023, (default)> = [0. 0. 0. 0.]
#           wic_fpg<2023, (default)> = [30000.]
#             is_pregnant<2023, (default)> = [False False False False]
#             spm_unit_fpg<2023, (default)> = [30000.]
#             state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#         meets_wic_categorical_eligibility<2023, (default)> = [False False False False]
#           snap<2023, (default)> = [0.]
#           tanf<2023, (default)> = [0.]
#             tanf_reported<2023, (default)> = [0. 0. 0. 0.]
#             is_tanf_eligible<2023, (default)> = [False]
#               is_person_demographic_tanf_eligible<2023, (default)> = [False False  True  True]
#                 is_child<2023, (default)> = [False False  True  True]
#                 age<2023, (default)> = [38. 35. 10. 10.]
#                 is_full_time_student<2023, (default)> = [False False  True  True]
#                   is_full_time_college_student<2023, (default)> = [False False False False]
#                   is_in_k12_school<2023, (default)> = [False False  True  True]
#                     age<2023, (default)> = [38. 35. 10. 10.]
#                 is_pregnant<2023, (default)> = [False False False False]
#               is_tanf_enrolled<2023, (default)> = [False]
#               is_tanf_continuous_eligible<2023, (default)> = [False]
#                 tanf_gross_earned_income<2023, (default)> = [80000.]
#                   employment_income<2023, (default)> = [45000. 35000.     0.     0.]
#                   self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                 tanf_gross_unearned_income<2023, (default)> = [0.]
#                   dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                   interest_income<2023, (default)> = [0. 0. 0. 0.]
#                   gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#                   social_security<2023, (default)> = [0. 0. 0. 0.]
#                   ssi<2023, (default)> = [0. 0. 0. 0.]
#                 tanf_max_amount<2023, (default)> = [0.]
#                   spm_unit_size<2023, (default)> = [4]
#                   state_code_str<2023, (default)> = ['UT']
#               is_tanf_initial_eligible<2023, (default)> = [False]
#                 tanf_initial_employment_deduction<2023, (default)> = [0.]
#                   spm_unit_size<2023, (default)> = [4]
#                   state_code_str<2023, (default)> = ['UT']
#                   market_income<2023, (default)> = [45000. 35000.     0.     0.]
#                     employment_income<2023, (default)> = [45000. 35000.     0.     0.]
#                     self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                     pension_income<2023, (default)> = [0. 0. 0. 0.]
#                     dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                     interest_income<2023, (default)> = [0. 0. 0. 0.]
#                     gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#                     capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                     rental_income<2023, (default)> = [0. 0. 0. 0.]
#                     illicit_income<2023, (default)> = [0. 0. 0. 0.]
#                     farm_income<2023, (default)> = [0. 0. 0. 0.]
#                 tanf_gross_earned_income<2023, (default)> = [80000.]
#                 tanf_gross_unearned_income<2023, (default)> = [0.]
#                 tanf_max_amount<2023, (default)> = [0.]
#             tanf_amount_if_eligible<2023, (default)> = [0.]
#               tanf_max_amount<2023, (default)> = [0.]
#               tanf_countable_income<2023, (default)> = [80000.]
#                 state_code_str<2023, (default)> = ['UT']
#                 tanf_gross_unearned_income<2023, (default)> = [0.]
#                 tanf_gross_earned_income<2023, (default)> = [80000.]
#           medicaid<2023, (default)> = [0. 0. 0. 0.]
#             is_medicaid_eligible<2023, (default)> = [False False False False]
#               medicaid_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#                 is_infant_for_medicaid<2023, (default)> = [False False False False]
#                   is_infant_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [2.6666667 2.6666667 2.6666667 2.6666667]
#                       tax_unit_medicaid_income_level<2023, (default)> = [2.6666667]
#                         medicaid_income<2023, (default)> = [80000.]
#                           adjusted_gross_income<2023, (default)> = [80000.]
#                             irs_gross_income<2023, (default)> = [45000. 35000.     0.     0.]
#                               is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                               employment_income<2023, (default)> = [45000. 35000.     0.     0.]
#                               self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                               partnership_s_corp_income<2023, (default)> = [0. 0. 0. 0.]
#                               farm_income<2023, (default)> = [0. 0. 0. 0.]
#                               farm_rent_income<2023, (default)> = [0. 0. 0. 0.]
#                               capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                               taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#                               rental_income<2023, (default)> = [0. 0. 0. 0.]
#                               dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                               taxable_pension_income<2023, (default)> = [0. 0. 0. 0.]
#                               debt_relief<2023, (default)> = [0. 0. 0. 0.]
#                               taxable_unemployment_compensation<2023, (default)> = [0. 0. 0. 0.]
#                                 is_tax_unit_head<2023, (default)> = [ True False False False]
#                                 tax_unit_taxable_unemployment_compensation<2023, (default)> = [0.]
#                                   tax_unit_unemployment_compensation<2023, (default)> = [0.]
#                                     unemployment_compensation<2023, (default)> = [0. 0. 0. 0.]
#                                   taxable_uc_agi<2023, (default)> = [80000.]
#                                     is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                                     employment_income<2023, (default)> = [45000. 35000.     0.     0.]
#                                     self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                     partnership_s_corp_income<2023, (default)> = [0. 0. 0. 0.]
#                                     farm_income<2023, (default)> = [0. 0. 0. 0.]
#                                     farm_rent_income<2023, (default)> = [0. 0. 0. 0.]
#                                     capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                                     taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#                                     rental_income<2023, (default)> = [0. 0. 0. 0.]
#                                     dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                                     taxable_pension_income<2023, (default)> = [0. 0. 0. 0.]
#                                     debt_relief<2023, (default)> = [0. 0. 0. 0.]
#                                     taxable_social_security<2023, (default)> = [0. 0. 0. 0.]
#                                       tax_unit_taxable_social_security<2023, (default)> = [0.]
#                                         tax_unit_social_security<2023, (default)> = [0.]
#                                           social_security<2023, (default)> = [0. 0. 0. 0.]
#                                         taxable_ss_magi<2023, (default)> = [80000.]
#                                           is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                                           employment_income<2023, (default)> = [45000. 35000.     0.     0.]
#                                           self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                           partnership_s_corp_income<2023, (default)> = [0. 0. 0. 0.]
#                                           farm_income<2023, (default)> = [0. 0. 0. 0.]
#                                           farm_rent_income<2023, (default)> = [0. 0. 0. 0.]
#                                           capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                                           taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#                                           rental_income<2023, (default)> = [0. 0. 0. 0.]
#                                           dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                                           taxable_pension_income<2023, (default)> = [0. 0. 0. 0.]
#                                           debt_relief<2023, (default)> = [0. 0. 0. 0.]
#                                           illicit_income<2023, (default)> = [0. 0. 0. 0.]
#                                           unemployment_compensation<2023, (default)> = [0. 0. 0. 0.]
#                                           tax_exempt_interest_income<2023, (default)> = [0. 0. 0. 0.]
#                                           loss_ald<2023, (default)> = [0.]
#                                             filing_status<2023, (default)> = ['JOINT']
#                                               is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                                               tax_unit_dependents<2023, (default)> = [2]
#                                                 is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                                             self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                             maximum_capital_loss<2023, (default)> = [0.]
#                                               tax_unit_capital_loss<2023, (default)> = [0.]
#                                                 capital_loss<2023, (default)> = [0. 0. 0. 0.]
#                                                   capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                                               filing_status<2023, (default)> = ['JOINT']
#                                           self_employment_tax_ald<2023, (default)> = [0.]
#                                             self_employment_tax_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employment_tax<2023, (default)> = [0. 0. 0. 0.]
#                                                 self_employment_social_security_tax<2023, (default)> = [0. 0. 0. 0.]
#                                                   social_security_taxable_self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                                     taxable_self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                                       sey<2023, (default)> = [0. 0. 0. 0.]
#                                                         self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                                         farm_income<2023, (default)> = [0. 0. 0. 0.]
#                                                         k1bx14<2023, (default)> = [0. 0. 0. 0.]
#                                                     taxable_earnings_for_social_security<2023, (default)> = [45000. 35000.     0.     0.]
#                                                       payroll_tax_gross_wages<2023, (default)> = [45000. 35000.     0.     0.]
#                                                         employment_income<2023, (default)> = [45000. 35000.     0.     0.]
#                                                 self_employment_medicare_tax<2023, (default)> = [0. 0. 0. 0.]
#                                                   taxable_self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                           early_withdrawal_penalty<2023, (default)> = [0. 0. 0. 0.]
#                                           alimony_income<2023, (default)> = [0. 0. 0. 0.]
#                                           educator_expense<2023, (default)> = [0. 0. 0. 0.]
#                                           health_savings_account_ald<2023, (default)> = [0.]
#                                           self_employed_health_insurance_ald<2023, (default)> = [0.]
#                                             self_employed_health_insurance_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employed_health_insurance_premiums<2023, (default)> = [0. 0. 0. 0.]
#                                                 is_self_employed<2023, (default)> = [False False False False]
#                                                 health_insurance_premiums<2023, (default)> = [0. 0. 0. 0.]
#                                           self_employed_pension_contribution_ald<2023, (default)> = [0.]
#                                             self_employed_pension_contribution_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employed_pension_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                           ira_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                           sep_simple_qualified_plan_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                         filing_status<2023, (default)> = ['JOINT']
#                                       tax_unit_social_security<2023, (default)> = [0.]
#                                       social_security<2023, (default)> = [0. 0. 0. 0.]
#                                       is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                                       is_tax_unit_head<2023, (default)> = [ True False False False]
#                                     illicit_income<2023, (default)> = [0. 0. 0. 0.]
#                                     loss_ald<2023, (default)> = [0.]
#                                     self_employment_tax_ald<2023, (default)> = [0.]
#                                     student_loan_interest<2023, (default)> = [0. 0. 0. 0.]
#                                     early_withdrawal_penalty<2023, (default)> = [0. 0. 0. 0.]
#                                     alimony_income<2023, (default)> = [0. 0. 0. 0.]
#                                     educator_expense<2023, (default)> = [0. 0. 0. 0.]
#                                     health_savings_account_ald<2023, (default)> = [0.]
#                                     self_employed_health_insurance_ald<2023, (default)> = [0.]
#                                     self_employed_pension_contribution_ald<2023, (default)> = [0.]
#                                     ira_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                     sep_simple_qualified_plan_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                     qualified_adoption_assistance_expense<2023, (default)> = [0. 0. 0. 0.]
#                                     us_bonds_for_higher_ed<2023, (default)> = [0. 0. 0. 0.]
#                                     specified_possession_income<2023, (default)> = [0.]
#                                     puerto_rico_income<2023, (default)> = [0.]
#                                   filing_status<2023, (default)> = ['JOINT']
#                               taxable_social_security<2023, (default)> = [0. 0. 0. 0.]
#                               illicit_income<2023, (default)> = [0. 0. 0. 0.]
#                             above_the_line_deductions<2023, (default)> = [0.]
#                               loss_ald<2023, (default)> = [0.]
#                               self_employment_tax_ald<2023, (default)> = [0.]
#                               student_loan_interest<2023, (default)> = [0. 0. 0. 0.]
#                               early_withdrawal_penalty<2023, (default)> = [0. 0. 0. 0.]
#                               alimony_income<2023, (default)> = [0. 0. 0. 0.]
#                               educator_expense<2023, (default)> = [0. 0. 0. 0.]
#                               health_savings_account_ald<2023, (default)> = [0.]
#                               self_employed_health_insurance_ald<2023, (default)> = [0.]
#                               self_employed_pension_contribution_ald<2023, (default)> = [0.]
#                               ira_contributions<2023, (default)> = [0. 0. 0. 0.]
#                               sep_simple_qualified_plan_contributions<2023, (default)> = [0. 0. 0. 0.]
#                               qualified_adoption_assistance_expense<2023, (default)> = [0. 0. 0. 0.]
#                               us_bonds_for_higher_ed<2023, (default)> = [0. 0. 0. 0.]
#                               specified_possession_income<2023, (default)> = [0.]
#                               puerto_rico_income<2023, (default)> = [0.]
#                           foreign_earned_income_exclusion<2023, (default)> = [0.]
#                           student_loan_interest<2023, (default)> = [0. 0. 0. 0.]
#                           tax_exempt_social_security<2023, (default)> = [0.]
#                             tax_unit_social_security<2023, (default)> = [0.]
#                             tax_unit_taxable_social_security<2023, (default)> = [0.]
#                         tax_unit_fpg<2023, (default)> = [30000.]
#                           tax_unit_size<2023, (default)> = [4]
#                           state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#                     state_code_str<2023, (default)> = ['UT']
#                   is_infant_for_medicaid_nfc<2023, (default)> = [False False False False]
#                     age<2023, (default)> = [38. 35. 10. 10.]
#                 is_young_child_for_medicaid<2023, (default)> = [False False False False]
#                   is_young_child_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [2.6666667 2.6666667 2.6666667 2.6666667]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_young_child_for_medicaid_nfc<2023, (default)> = [False False False False]
#                     age<2023, (default)> = [38. 35. 10. 10.]
#                 is_older_child_for_medicaid<2023, (default)> = [False False False False]
#                   age<2023, (default)> = [38. 35. 10. 10.]
#                   medicaid_income_level<2023, (default)> = [2.6666667 2.6666667 2.6666667 2.6666667]
#                   state_code_str<2023, (default)> = ['UT']
#                 is_young_adult_for_medicaid<2023, (default)> = [False False False False]
#                   is_young_adult_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [2.6666667 2.6666667 2.6666667 2.6666667]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_young_adult_for_medicaid_nfc<2023, (default)> = [False False False False]
#                     age<2023, (default)> = [38. 35. 10. 10.]
#                 is_adult_for_medicaid<2023, (default)> = [False False False False]
#                   is_adult_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [2.6666667 2.6666667 2.6666667 2.6666667]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_adult_for_medicaid_nfc<2023, (default)> = [ True  True False False]
#                     age<2023, (default)> = [38. 35. 10. 10.]
#                 is_parent_for_medicaid<2023, (default)> = [False False False False]
#                   is_parent_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [2.6666667 2.6666667 2.6666667 2.6666667]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_parent_for_medicaid_nfc<2023, (default)> = [ True  True False False]
#                     is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                     tax_unit_count_dependents<2023, (default)> = [2]
#                       is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                 is_pregnant_for_medicaid<2023, (default)> = [False False False False]
#                   is_pregnant_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [2.6666667 2.6666667 2.6666667 2.6666667]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_pregnant_for_medicaid_nfc<2023, (default)> = [False False False False]
#                     is_pregnant<2023, (default)> = [False False False False]
#                     count_days_postpartum<2023, (default)> = [inf inf inf inf]
#                       under_60_days_postpartum<2023, (default)> = [False False False False]
#                       under_12_months_postpartum<2023, (default)> = [False False False False]
#                     state_code_str<2023, (default)> = ['UT']
#                 is_ssi_recipient_for_medicaid<2023, (default)> = [False False False False]
#                   state_code_str<2023, (default)> = ['UT']
#                   ssi<2023, (default)> = [0. 0. 0. 0.]
#             medicaid_benefit_value<2023, (default)> = [9966.585 9966.585 9966.585 9966.585]
#               state_code_str<2023, (default)> = ['UT']
#           is_pregnant<2023, (default)> = [False False False False]
#           wic_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#             is_pregnant<2023, (default)> = [False False False False]
#             is_mother<2023, (default)> = [False False False False]
#               is_female<2023, (default)> = [False False False False]
#               own_children_in_household<2023, (default)> = [0 0 0 0]
#               is_breastfeeding<2023, (default)> = [False False False False]
#             is_breastfeeding<2023, (default)> = [False False False False]
#             age<2023, (default)> = [38. 35. 10. 10.]
#         wic_category_str<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#           wic_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#         is_wic_at_nutritional_risk<2023, (default)> = [False False False False]
#           receives_wic<2023, (default)> = [False False False False]
#           meets_wic_income_test<2023, (default)> = [False]
#           meets_wic_categorical_eligibility<2023, (default)> = [False False False False]
#           wic_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#         would_claim_wic<2023, (default)> = [ True  True  True  True]
#       free_school_meals<2023, (default)> = [0.]
#         school_meal_tier<2023, (default)> = ['PAID']
#           school_meal_fpg_ratio<2023, (default)> = [2.6666667]
#             school_meal_countable_income<2023, (default)> = [80000.]
#             spm_unit_fpg<2023, (default)> = [30000.]
#           meets_school_meal_categorical_eligibility<2023, (default)> = [False]
#             snap<2023, (default)> = [0.]
#             tanf<2023, (default)> = [0.]
#             fdpir<2023, (default)> = [0.]
#         school_meal_net_subsidy<2023, (default)> = [0.]
#           school_meal_daily_subsidy<2023, (default)> = [0.72]
#             state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#             school_meal_tier<2023, (default)> = ['PAID']
#           school_meal_paid_daily_subsidy<2023, (default)> = [0.72]
#             state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#           is_in_k12_school<2023, (default)> = [False False  True  True]
#       reduced_price_school_meals<2023, (default)> = [0.]
#         school_meal_tier<2023, (default)> = ['PAID']
#         school_meal_net_subsidy<2023, (default)> = [0.]
#       lifeline<2023, (default)> = [0.]
#         is_rural<2023, (default)> = [False]
#         is_on_tribal_land<2023, (default)> = [False]
#         phone_cost<2023, (default)> = [1500.]
#         broadband_cost<2023, (default)> = [900.]
#         is_lifeline_eligible<2023, (default)> = [False]
#           medicaid<2023, (default)> = [0. 0. 0. 0.]
#           snap<2023, (default)> = [0.]
#           ssi<2023, (default)> = [0. 0. 0. 0.]
#           fcc_fpg_ratio<2023, (default)> = [2.6666667]
#             irs_gross_income<2023, (default)> = [45000. 35000.     0.     0.]
#             spm_unit_fpg<2023, (default)> = [30000.]
#       acp<2023, (default)> = [0.]
#         is_acp_eligible<2023, (default)> = [False]
#           lifeline<2023, (default)> = [0.]
#           free_school_meals<2023, (default)> = [0.]
#           reduced_price_school_meals<2023, (default)> = [0.]
#           pell_grant<2023, (default)> = [0.]
#           wic<2023, (default)> = [0. 0. 0. 0.]
#           medicaid<2023, (default)> = [0. 0. 0. 0.]
#           snap<2023, (default)> = [0.]
#           ssi<2023, (default)> = [0. 0. 0. 0.]
#           fcc_fpg_ratio<2023, (default)> = [2.6666667]
#           ebb<2023, (default)> = [0.]
#             is_ebb_eligible<2023, (default)> = [False]
#               is_lifeline_eligible<2023, (default)> = [False]
#               free_school_meals<2023, (default)> = [0.]
#               reduced_price_school_meals<2023, (default)> = [0.]
#               pell_grant<2023, (default)> = [0.]
#               experienced_covid_income_loss<2023, (default)> = [False]
#               enrolled_in_ebb<2023, (default)> = [False]
#             broadband_cost_after_lifeline<2023, (default)> = [900.]
#               broadband_cost<2023, (default)> = [900.]
#               lifeline<2023, (default)> = [0.]
#             is_on_tribal_land<2023, (default)> = [False]
#         broadband_cost_after_lifeline<2023, (default)> = [900.]
#         is_on_tribal_land<2023, (default)> = [False]
#       ebb<2023, (default)> = [0.]
#       tanf<2023, (default)> = [0.]
#       high_efficiency_electric_home_rebate<2023, (default)> = [0.]
#         capped_electric_heat_pump_clothes_dryer_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#             tax_unit_income_ami_ratio<2023, (default)> = [0.]
#           electric_heat_pump_clothes_dryer_expenditures<2023, (default)> = [0.]
#         capped_electric_load_service_center_upgrade_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           electric_load_service_center_upgrade_expenditures<2023, (default)> = [0.]
#         capped_electric_stove_cooktop_range_or_oven_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           electric_stove_cooktop_range_or_oven_expenditures<2023, (default)> = [0.]
#         capped_electric_wiring_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           electric_wiring_expenditures<2023, (default)> = [0.]
#         capped_heat_pump_water_heater_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           heat_pump_water_heater_expenditures<2023, (default)> = [0.]
#         capped_heat_pump_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           heat_pump_expenditures<2023, (default)> = [0.]
#         capped_insulation_air_sealing_ventilation_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           energy_efficient_insulation_expenditures<2023, (default)> = [0.]
#           air_sealing_ventilation_expenditures<2023, (default)> = [0.]
#       residential_efficiency_electrification_rebate<2023, (default)> = [0.]
#         residential_efficiency_electrification_retrofit_expenditures<2023, (default)> = [0.]
#         residential_efficiency_electrification_retrofit_energy_savings<2023, (default)> = [0.]
#         current_home_energy_use<2023, (default)> = [0.]
#         household_income_ami_ratio<2023, (default)> = [0.]
#         average_home_energy_use_in_state<2023, (default)> = [0.]
#       basic_income<2023, (default)> = [0.]
#         basic_income_eligible<2023, (default)> = [ True]
#         basic_income_before_phase_out<2023, (default)> = [0.]
#           tax_unit_size<2023, (default)> = [4]
#           age<2023, (default)> = [38. 35. 10. 10.]
#           tax_unit_fpg<2023, (default)> = [30000.]
#         basic_income_phase_out<2023, (default)> = [0.]
#           basic_income_before_phase_out<2023, (default)> = [0.]
#           adjusted_gross_income<2023, (default)> = [80000.]
#           filing_status<2023, (default)> = ['JOINT']
#       spm_unit_capped_housing_subsidy<2023, (default)> = [0.]
#         spm_unit_capped_housing_subsidy_reported<2023, (default)> = [0.]
#     household_refundable_tax_credits<2023, (default)> = [0.]
#       income_tax_refundable_credits<2023, (default)> = [0.]
#         eitc<2023, (default)> = [0.]
#           earned_income_tax_credit<2023, (default)> = [0.]
#             eitc_eligible<2023, (default)> = [ True]
#               is_child<2023, (default)> = [False False  True  True]
#               age<2023, (default)> = [38. 35. 10. 10.]
#               tax_exempt_interest_income<2023, (default)> = [0. 0. 0. 0.]
#               taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#               dividend_income<2023, (default)> = [0. 0. 0. 0.]
#               c01000<2023, (default)> = [0.]
#                 sep<2023, (default)> = [1]
#                 c23650<2023, (default)> = [0.]
#                   long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   short_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#               tax_unit_rental_income<2023, (default)> = [0.]
#                 rental_income<2023, (default)> = [0. 0. 0. 0.]
#               tax_unit_partnership_s_corp_income<2023, (default)> = [0.]
# ...
#                         blind_head<2023, (default)> = [False]
#                           is_blind<2023, (default)> = [False False False False]
#                           is_tax_unit_head<2023, (default)> = [ True False False False]
#                         blind_spouse<2023, (default)> = [False]
#                           is_blind<2023, (default)> = [False False False False]
#                           is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                         age_head<2023, (default)> = [38]
#                         age_spouse<2023, (default)> = [35]
#                 taxable_income_deductions_if_itemizing<2023, (default)> = [8357.512]
#                   charitable_deduction<2023, (default)> = [6000.]
#                   interest_deduction<2023, (default)> = [0.]
#                   salt_deduction<2023, (default)> = [2357.5122]
#                     state_and_local_sales_or_income_tax<2023, (default)> = [2357.5122]
#                       state_income_tax<2023, (default)> = [2357.5122]
#                         ma_income_tax<2023, (default)> = [0.]
#                           MA<2023, (default)> = [False]
#                         md_income_tax<2023, (default)> = [0.]
#                           MD<2023, (default)> = [False]
#                         ny_income_tax<2023, (default)> = [0.]
#                           NY<2023, (default)> = [False]
#                         or_income_tax<2023, (default)> = [0.]
#                           OR<2023, (default)> = [False]
#                         pa_income_tax<2023, (default)> = [0.]
#                           PA<2023, (default)> = [False]
#                             state_code_str<2023, (default)> = ['UT']
#                         wa_income_tax<2023, (default)> = [0.]
#                           WA<2023, (default)> = [False]
#                         ut_income_tax<2023, (default)> = [2357.5122]
#                           UT<2023, (default)> = [ True]
#                           ut_income_tax_before_refundable_credits<2023, (default)> = [2357.5122]
#                             ut_income_tax_after_credits<2023, (default)> = [2357.5122]
#                               ut_income_tax_before_credits<2023, (default)> = [3600.0002]
#                                 UT<2023, (default)> = [ True]
#                                 ut_taxable_income<2023, (default)> = [80000.]
#                                   UT<2023, (default)> = [ True]
#                                   ut_total_income<2023, (default)> = [80000.]
#                                     UT<2023, (default)> = [ True]
#                                     adjusted_gross_income<2023, (default)> = [80000.]
#                                     ut_additions_to_income<2023, (default)> = [0.]
#                                       UT<2023, (default)> = [ True]
#                                   salt_refund_last_year<2023, (default)> = [0.]
#                                   ut_subtractions_from_income<2023, (default)> = [0.]
#                                     UT<2023, (default)> = [ True]
#                               ut_taxpayer_credit<2023, (default)> = [1242.488]
#                                 UT<2023, (default)> = [ True]
#                                 ut_taxpayer_credit_max<2023, (default)> = [1878.24]
#                                   UT<2023, (default)> = [ True]
#                                   tax_unit_count_dependents<2023, (default)> = [2]
#                                   tax_unit_itemizes<2023, (default)> = [False]
#                                   standard_deduction<2023, (default)> = [27700.]
#                                   charitable_deduction<2023, (default)> = [6000.]
#                                   interest_deduction<2023, (default)> = [0.]
#                                   medical_expense_deduction<2023, (default)> = [0.]
#                                   casualty_loss_deduction<2023, (default)> = [0.]
#                                 ut_taxpayer_credit_reduction<2023, (default)> = [635.752]
#                                   UT<2023, (default)> = [ True]
#                                   filing_status<2023, (default)> = ['JOINT']
#                                   ut_taxable_income<2023, (default)> = [80000.]
#                             ut_apportionable_nonrefundable_credits<2023, (default)> = [0.]
#                               UT<2023, (default)> = [ True]
#                             ut_nonapportionable_nonrefundable_credits<2023, (default)> = [0.]
#                               UT<2023, (default)> = [ True]
#                             ut_recapture_low_inc_housing_credit<2023, (default)> = [0.]
#                               UT<2023, (default)> = [ True]
#                           ut_refundable_credits<2023, (default)> = [0.]
#                       local_income_tax<2023, (default)> = [0.]
#                       state_sales_tax<2023, (default)> = [0.]
#                       local_sales_tax<2023, (default)> = [0.]
#                     real_estate_taxes<2023, (default)> = [0. 0. 0. 0.]
#                     filing_status<2023, (default)> = ['JOINT']
#                   medical_expense_deduction<2023, (default)> = [0.]
#                   casualty_loss_deduction<2023, (default)> = [0.]
#                   qualified_business_income_deduction<2023, (default)> = [0.]
#                     qbid_amount<2023, (default)> = [0. 0. 0. 0.]
#                       qualified_business_income<2023, (default)> = [0. 0. 0. 0.]
#                         self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                         partnership_s_corp_income<2023, (default)> = [0. 0. 0. 0.]
#                         farm_income<2023, (default)> = [0. 0. 0. 0.]
#                         farm_rent_income<2023, (default)> = [0. 0. 0. 0.]
#                         self_employment_tax_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                         self_employed_health_insurance_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                         self_employed_pension_contribution_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                         business_is_qualified<2023, (default)> = [False False False False]
#                       w2_wages_from_qualified_business<2023, (default)> = [0. 0. 0. 0.]
#                       unadjusted_basis_qualified_property<2023, (default)> = [0. 0. 0. 0.]
#                       taxable_income_less_qbid<2023, (default)> = [52300.]
#                         adjusted_gross_income<2023, (default)> = [80000.]
#                         charitable_deduction<2023, (default)> = [6000.]
#                         interest_deduction<2023, (default)> = [0.]
#                         salt_deduction<2023, (default)> = [2357.5122]
#                         medical_expense_deduction<2023, (default)> = [0.]
#                         casualty_loss_deduction<2023, (default)> = [0.]
#                         standard_deduction<2023, (default)> = [27700.]
#                       filing_status<2023, (default)> = ['JOINT']
#                       business_is_sstb<2023, (default)> = [False False False False]
#                     taxable_income_less_qbid<2023, (default)> = [52300.]
#                     adjusted_net_capital_gain<2023, (default)> = [0.]
#                       net_capital_gain<2023, (default)> = [0.]
#                         net_long_term_capital_gain<2023, (default)> = [0.]
#                           long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                           long_term_capital_losses<2023, (default)> = [0. 0. 0. 0.]
#                         net_short_term_capital_loss<2023, (default)> = [0.]
#                           short_term_capital_losses<2023, (default)> = [0. 0. 0. 0.]
#                           short_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                         qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                       qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                       unrecaptured_section_1250_gain<2023, (default)> = [0.]
#                       capital_gains_28_percent_rate_gain<2023, (default)> = [0.]
#                         long_term_capital_gains_on_collectibles<2023, (default)> = [0. 0. 0. 0.]
#                         long_term_capital_gains_on_small_business_stock<2023, (default)> = [0. 0. 0. 0.]
#                 taxable_income_deductions_if_not_itemizing<2023, (default)> = [27700.]
#                   standard_deduction<2023, (default)> = [27700.]
#                   qualified_business_income_deduction<2023, (default)> = [0.]
#             capital_gains_excluded_from_taxable_income<2023, (default)> = [0.]
#               net_capital_gain<2023, (default)> = [0.]
#               adjusted_net_capital_gain<2023, (default)> = [0.]
#               taxable_income<2023, (default)> = [52300.]
#               filing_status<2023, (default)> = ['JOINT']
#             filing_status<2023, (default)> = ['JOINT']
#           capital_gains_tax<2023, (default)> = [0.]
#             net_capital_gain<2023, (default)> = [0.]
#             taxable_income<2023, (default)> = [52300.]
#             adjusted_net_capital_gain<2023, (default)> = [0.]
#             capital_gains_excluded_from_taxable_income<2023, (default)> = [0.]
#             filing_status<2023, (default)> = ['JOINT']
#             unrecaptured_section_1250_gain<2023, (default)> = [0.]
#             qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#             capital_gains_28_percent_rate_gain<2023, (default)> = [0.]
#           alternative_minimum_tax<2023, (default)> = [0.]
#             c09600<2023, (default)> = [0.]
#               c62100<2023, (default)> = [80000.]
#                 amt_income<2023, (default)> = [80000.]
#                   taxable_income<2023, (default)> = [52300.]
#                   tax_unit_itemizes<2023, (default)> = [False]
#                   standard_deduction<2023, (default)> = [27700.]
#                   salt_deduction<2023, (default)> = [2357.5122]
#                   filing_status<2023, (default)> = ['JOINT']
#               filing_status<2023, (default)> = ['JOINT']
#               age_head<2023, (default)> = [38]
#               age_spouse<2023, (default)> = [35]
#               filer_earned<2023, (default)> = [80000.]
#               sep<2023, (default)> = [1]
#               dwks10<2023, (default)> = [0.]
#                 dwks6<2023, (default)> = [0.]
#                   qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                   investment_income_form_4952<2023, (default)> = [0.]
#                 dwks9<2023, (default)> = [0.]
#                   long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                   c23650<2023, (default)> = [0.]
#                   non_sch_d_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   investment_income_form_4952<2023, (default)> = [0.]
#                 long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                 qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                 c23650<2023, (default)> = [0.]
#                 non_sch_d_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                 hasqdivltcg<2023, (default)> = [False]
#                   c01000<2023, (default)> = [0.]
#                   c23650<2023, (default)> = [0.]
#                   long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   non_sch_d_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#               dwks13<2023, (default)> = [0.]
#                 unrecaptured_section_1250_gain<2023, (default)> = [0.]
#                 capital_gains_28_percent_rate_gain<2023, (default)> = [0.]
#                 dwks9<2023, (default)> = [0.]
#                 dwks10<2023, (default)> = [0.]
#                 hasqdivltcg<2023, (default)> = [False]
#               dwks14<2023, (default)> = [0.]
#                 taxable_income<2023, (default)> = [52300.]
#                 dwks13<2023, (default)> = [0.]
#                 hasqdivltcg<2023, (default)> = [False]
#               dwks19<2023, (default)> = [0.]
#                 dwks14<2023, (default)> = [0.]
#                 filing_status<2023, (default)> = ['JOINT']
#                 taxable_income<2023, (default)> = [52300.]
#                 dwks10<2023, (default)> = [0.]
#                 hasqdivltcg<2023, (default)> = [False]
#               unrecaptured_section_1250_gain<2023, (default)> = [0.]
#               sep<2023, (default)> = [1]
#               foreign_tax_credit<2023, (default)> = [0.]
#               amt_form_completed<2023, (default)> = [False]
#               foreign_tax_credit<2023, (default)> = [0.]
#               taxbc<2023, (default)> = [5836.]
#                 regular_tax_before_credits<2023, (default)> = [5836.]
#                   filing_status<2023, (default)> = ['JOINT']
#                   taxable_income<2023, (default)> = [52300.]
#                   dwks14<2023, (default)> = [0.]
#                   dwks13<2023, (default)> = [0.]
#                   dwks19<2023, (default)> = [0.]
#                   dwks9<2023, (default)> = [0.]
#                   unrecaptured_section_1250_gain<2023, (default)> = [0.]
#                   dwks10<2023, (default)> = [0.]
#                   income_tax_main_rates<2023, (default)> = [5836.]
#                   hasqdivltcg<2023, (default)> = [False]
#               c05700<2023, (default)> = [0.]
#         net_investment_income_tax<2023, (default)> = [0.]
#           taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#           dividend_income<2023, (default)> = [0. 0. 0. 0.]
#           c01000<2023, (default)> = [0.]
#           rental_income<2023, (default)> = [0. 0. 0. 0.]
#           filing_status<2023, (default)> = ['JOINT']
#           adjusted_gross_income<2023, (default)> = [80000.]
#         recapture_of_investment_credit<2023, (default)> = [0.]
#         unreported_payroll_tax<2023, (default)> = [0.]
#         qualified_retirement_penalty<2023, (default)> = [0.]
#         income_tax_capped_non_refundable_credits<2023, (default)> = [4200.]
#           income_tax_non_refundable_credits<2023, (default)> = [4200.]
#             cdcc<2023, (default)> = [200.]
#             elderly_disabled_credit<2023, (default)> = [0.]
#             non_refundable_ctc<2023, (default)> = [4000.]
#               ctc<2023, (default)> = [4000.]
#               refundable_ctc<2023, (default)> = [0.]
#             non_refundable_american_opportunity_credit<2023, (default)> = [0.]
#             lifetime_learning_credit<2023, (default)> = [0.]
#             retirement_savings_credit<2023, (default)> = [0.]
#             residential_clean_energy_credit<2023, (default)> = [0.]
#             energy_efficient_home_improvement_credit<2023, (default)> = [0.]
#             new_clean_vehicle_credit<2023, (default)> = [0.]
#             used_clean_vehicle_credit<2023, (default)> = [0.]
#           income_tax_unavailable_non_refundable_credits<2023, (default)> = [0.]
#             income_tax_before_credits<2023, (default)> = [5836.]
#             income_tax_non_refundable_credits<2023, (default)> = [4200.]
#             income_tax_non_refundable_credits<2023, (default)> = [4200.]
#       ma_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         MA<2023, (default)> = [False]
#       md_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         MD<2023, (default)> = [False]
#       ny_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         NY<2023, (default)> = [False]
#       or_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         or_income_tax_before_credits<2023, (default)> = [0.]
#           OR<2023, (default)> = [False]
#         or_non_refundable_credits<2023, (default)> = [0.]
#           or_exemption_credit<2023, (default)> = [0.]
#             OR<2023, (default)> = [False]
#       pa_income_tax<2023, (default)> = [0.]
#       ut_income_tax_before_refundable_credits<2023, (default)> = [2357.5122]
#       wa_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         WA<2023, (default)> = [False]
#       flat_tax<2023, (default)> = [0.]
#         positive_agi<2023, (default)> = [80000.]

# %% [markdown]
# #### 3.4.3. Effect of rate cut to 4.50% on high income household

# %%
simulation_2_h = Simulation(
    reform=reform_2,
    situation=situation_high,
)

simulation_2_h.trace = True
simulation_2_h.calculate("household_net_income", 2023)
simulation_2_h.tracer.print_computation_log()
# Out:
#   household_net_income<2023, (default)> = [151161.48]
#     household_market_income<2023, (default)> = [200000.]
#       employment_income<2023, (default)> = [100000. 100000.      0.      0.]
#       self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#       pension_income<2023, (default)> = [0. 0. 0. 0.]
#         tax_exempt_pension_income<2023, (default)> = [0. 0. 0. 0.]
#         taxable_pension_income<2023, (default)> = [0. 0. 0. 0.]
#       dividend_income<2023, (default)> = [0. 0. 0. 0.]
#         qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#         non_qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#       interest_income<2023, (default)> = [0. 0. 0. 0.]
#         tax_exempt_interest_income<2023, (default)> = [0. 0. 0. 0.]
#         taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#       gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#       capital_gains<2023, (default)> = [0. 0. 0. 0.]
#         short_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#         long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#       rental_income<2023, (default)> = [0. 0. 0. 0.]
#       illicit_income<2023, (default)> = [0. 0. 0. 0.]
#       farm_income<2023, (default)> = [0. 0. 0. 0.]
#     household_benefits<2023, (default)> = [0.]
#       social_security<2023, (default)> = [0. 0. 0. 0.]
#         social_security_dependents<2023, (default)> = [0. 0. 0. 0.]
#         social_security_disability<2023, (default)> = [0. 0. 0. 0.]
#         social_security_retirement<2023, (default)> = [0. 0. 0. 0.]
#         social_security_survivors<2023, (default)> = [0. 0. 0. 0.]
#       ssi<2023, (default)> = [0. 0. 0. 0.]
#         uncapped_ssi<2023, (default)> = [0. 0. 0. 0.]
#           ssi_amount_if_eligible<2023, (default)> = [16452. 10968. 10968. 10968.]
#             ssi_claim_is_joint<2023, (default)> = [ True False False False]
#               is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                 is_ssi_aged<2023, (default)> = [False False False False]
#                   age<2023, (default)> = [38. 35. 10. 10.]
#                 is_blind<2023, (default)> = [False False False False]
#                 is_ssi_disabled<2023, (default)> = [False False False False]
#                   is_ssi_aged<2023, (default)> = [False False False False]
#                   is_blind<2023, (default)> = [False False False False]
#                   ssi_reported<2023, (default)> = [0. 0. 0. 0.]
#               ssi_income_deemed_from_ineligible_spouse<2023, (default)> = [50000.     0.     0.     0.]
#                 ssi_earned_income<2023, (default)> = [100000. 100000.      0.      0.]
#                   employment_income<2023, (default)> = [100000. 100000.      0.      0.]
#                   self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                 ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#                   dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                   interest_income<2023, (default)> = [0. 0. 0. 0.]
#                   gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#                   social_security<2023, (default)> = [0. 0. 0. 0.]
#                   alimony_income<2023, (default)> = [0. 0. 0. 0.]
#                   pension_income<2023, (default)> = [0. 0. 0. 0.]
#                   unemployment_compensation<2023, (default)> = [0. 0. 0. 0.]
#                 ssi_earned_income_deemed_from_ineligible_spouse<2023, (default)> = [100000.      0.      0.      0.]
#                   is_ssi_ineligible_spouse<2023, (default)> = [False  True False False]
#                     is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                       is_child<2023, (default)> = [False False  True  True]
#                         age<2023, (default)> = [38. 35. 10. 10.]
#                       is_tax_unit_head<2023, (default)> = [ True False False False]
#                         is_child<2023, (default)> = [False False  True  True]
#                         age<2023, (default)> = [38. 35. 10. 10.]
#                       age<2023, (default)> = [38. 35. 10. 10.]
#                     is_ssi_eligible_spouse<2023, (default)> = [False False False False]
#                       is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                       is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                   ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#                   ssi_earned_income<2023, (default)> = [100000. 100000.      0.      0.]
#                   ssi_ineligible_child_allocation<2023, (default)> = [   0.    0. 5484. 5484.]
#                     ssi_earned_income<2023, (default)> = [100000. 100000.      0.      0.]
#                     ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#                     is_ssi_ineligible_child<2023, (default)> = [False False  True  True]
#                       is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                       is_child<2023, (default)> = [False False  True  True]
#                   is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                 ssi_unearned_income_deemed_from_ineligible_spouse<2023, (default)> = [0. 0. 0. 0.]
#                   is_ssi_ineligible_spouse<2023, (default)> = [False  True False False]
#                   ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#                   ssi_ineligible_child_allocation<2023, (default)> = [   0.    0. 5484. 5484.]
#                 is_ssi_ineligible_child<2023, (default)> = [False False  True  True]
#           meets_ssi_resource_test<2023, (default)> = [ True  True  True  True]
#             ssi_claim_is_joint<2023, (default)> = [ True False False False]
#             ssi_countable_resources<2023, (default)> = [0. 0. 0. 0.]
#           is_ssi_eligible_individual<2023, (default)> = [False False False False]
#             is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#             is_ssi_eligible_spouse<2023, (default)> = [False False False False]
#           ssi_countable_income<2023, (default)> = [0. 0. 0. 0.]
#             ssi_earned_income<2023, (default)> = [100000. 100000.      0.      0.]
#             ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#             ssi_unearned_income_deemed_from_ineligible_parent<2023, (default)> = [0. 0. 0. 0.]
#               is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#               is_child<2023, (default)> = [False False  True  True]
#               is_ssi_ineligible_parent<2023, (default)> = [False False False False]
#                 is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                 is_child<2023, (default)> = [False False  True  True]
#               ssi_earned_income<2023, (default)> = [100000. 100000.      0.      0.]
#               ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#               ssi_ineligible_child_allocation<2023, (default)> = [   0.    0. 5484. 5484.]
#               ssi_ineligible_parent_allocation<2023, (default)> = [0. 0. 0. 0.]
#                 is_ssi_ineligible_parent<2023, (default)> = [False False False False]
#             ssi_income_deemed_from_ineligible_spouse<2023, (default)> = [50000.     0.     0.     0.]
#             is_ssi_eligible_individual<2023, (default)> = [False False False False]
#       state_supplement<2023, (default)> = [0. 0. 0. 0.]
#         uncapped_ssi<2023, (default)> = [0. 0. 0. 0.]
#         maximum_state_supplement<2023, (default)> = [0. 0. 0. 0.]
#           is_ssi_eligible_individual<2023, (default)> = [False False False False]
#           state_code_str<2023, (default)> = ['UT']
#             state_code<2023, (default)> = ['UT']
#               state_name<2023, (default)> = ['UT']
#           state_living_arrangement<2023, (default)> = ['FULL_COST']
#           is_blind<2023, (default)> = [False False False False]
#           is_ssi_aged<2023, (default)> = [False False False False]
#           is_ssi_disabled<2023, (default)> = [False False False False]
#           ssi_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#           ssi_claim_is_joint<2023, (default)> = [ True False False False]
#         is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#         meets_ssi_resource_test<2023, (default)> = [ True  True  True  True]
#         ssi_claim_is_joint<2023, (default)> = [ True False False False]
#       ca_cvrp<2023, (default)> = [0. 0. 0. 0.]
#         CA<2023, (default)> = [False]
#           state_code_str<2023, (default)> = ['UT']
#       snap<2023, (default)> = [0.]
#         snap_normal_allotment<2023, (default)> = [0.]
#           is_snap_eligible<2023, (default)> = [False]
#             meets_snap_net_income_test<2023, (default)> = [False]
#               snap_net_income_fpg_ratio<2023, (default)> = [5.2043333]
#                 snap_net_income<2023, (default)> = [156130.]
#                   snap_gross_income<2023, (default)> = [200000.]
#                     snap_earned_income<2023, (default)> = [200000.]
#                       employment_income<2023, (default)> = [100000. 100000.      0.      0.]
#                       self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                     snap_unearned_income<2023, (default)> = [0.]
#                       dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                       interest_income<2023, (default)> = [0. 0. 0. 0.]
#                       gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#                       social_security<2023, (default)> = [0. 0. 0. 0.]
#                       ssi<2023, (default)> = [0. 0. 0. 0.]
#                   snap_deductions<2023, (default)> = [43870.]
#                     snap_standard_deduction<2023, (default)> = [2316.]
#                       state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#                         state_group<2023, (default)> = ['CONTIGUOUS_US']
#                           state_code<2023, (default)> = ['UT']
#                       spm_unit_size<2023, (default)> = [4]
#                     snap_earned_income_deduction<2023, (default)> = [40000.]
#                       snap_earned_income<2023, (default)> = [200000.]
#                     snap_dependent_care_deduction<2023, (default)> = [1500.]
#                       childcare_expenses<2023, (default)> = [1500.]
#                     snap_child_support_deduction<2023, (default)> = [0.]
#                       child_support_expense<2023, (default)> = [0. 0. 0. 0.]
#                       state_code_str<2023, (default)> = ['UT']
#                     snap_excess_medical_expense_deduction<2023, (default)> = [0.]
#                       is_usda_elderly<2023, (default)> = [False False False False]
#                         age<2023, (default)> = [38. 35. 10. 10.]
#                       is_usda_disabled<2023, (default)> = [False False False False]
#                         is_ssi_disabled<2023, (default)> = [False False False False]
#                         social_security_disability<2023, (default)> = [0. 0. 0. 0.]
#                         is_permanently_disabled_veteran<2023, (default)> = [False False False False]
#                         is_surviving_spouse_of_disabled_veteran<2023, (default)> = [False False False False]
#                         is_surviving_child_of_disabled_veteran<2023, (default)> = [False False False False]
#                       medical_out_of_pocket_expenses<2023, (default)> = [4000.    0.    0.    0.]
#                       state_code_str<2023, (default)> = ['UT']
#                     snap_excess_shelter_expense_deduction<2023, (default)> = [54.]
#                       snap_net_income_pre_shelter<2023, (default)> = [156184.]
#                         snap_gross_income<2023, (default)> = [200000.]
#                         snap_standard_deduction<2023, (default)> = [2316.]
#                         snap_earned_income_deduction<2023, (default)> = [40000.]
#                         snap_dependent_care_deduction<2023, (default)> = [1500.]
#                         snap_child_support_deduction<2023, (default)> = [0.]
#                         snap_excess_medical_expense_deduction<2023, (default)> = [0.]
#                       housing_cost<2023, (default)> = [36000.]
#                       snap_region_str<2023, (default)> = ['CONTIGUOUS_US']
#                         snap_region<2023, (default)> = ['CONTIGUOUS_US']
#                           state_group<2023, (default)> = ['CONTIGUOUS_US']
#                       has_usda_elderly_disabled<2023, (default)> = [False]
#                         is_usda_elderly<2023, (default)> = [False False False False]
#                         is_usda_disabled<2023, (default)> = [False False False False]
#                       snap_utility_allowance<2023, (default)> = [54.]
#                         snap_utility_allowance_type<2023, (default)> = ['IUA']
#                           count_distinct_utility_expenses<2023, (default)> = [1]
#                             heating_cooling_expense<2023, (default)> = [0.]
#                             electricity_expense<2023, (default)> = [0.]
#                             gas_expense<2023, (default)> = [0.]
#                             phone_expense<2023, (default)> = [2400.]
#                               phone_cost<2023, (default)> = [2400.]
#                             trash_expense<2023, (default)> = [0.]
#                             water_expense<2023, (default)> = [0.]
#                             sewage_expense<2023, (default)> = [0.]
#                           snap_utility_region_str<2023, (default)> = ['UT']
#                             snap_utility_region<2023, (default)> = ['UT']
#                               state_code<2023, (default)> = ['UT']
#                           has_heating_cooling_expense<2023, (default)> = [False]
#                             heating_cooling_expense<2023, (default)> = [0.]
#                         snap_utility_region_str<2023, (default)> = ['UT']
#                       state_code_str<2023, (default)> = ['UT']
#                       is_homeless<2023, (default)> = [False]
#                 spm_unit_fpg<2023, (default)> = [30000.]
#                   spm_unit_size<2023, (default)> = [4]
#                   state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#             meets_snap_gross_income_test<2023, (default)> = [False]
#               snap_gross_income_fpg_ratio<2023, (default)> = [6.6666665]
#                 snap_gross_income<2023, (default)> = [200000.]
#                 spm_unit_fpg<2023, (default)> = [30000.]
#               has_usda_elderly_disabled<2023, (default)> = [False]
#             meets_snap_asset_test<2023, (default)> = [ True]
#               has_usda_elderly_disabled<2023, (default)> = [False]
#               snap_assets<2023, (default)> = [0.]
#             meets_snap_categorical_eligibility<2023, (default)> = [False]
#               ssi<2023, (default)> = [0. 0. 0. 0.]
#               is_tanf_non_cash_eligible<2023, (default)> = [False]
#                 meets_tanf_non_cash_gross_income_test<2023, (default)> = [False]
#                   state_code_str<2023, (default)> = ['UT']
#                   snap_gross_income_fpg_ratio<2023, (default)> = [6.6666665]
#                 meets_tanf_non_cash_net_income_test<2023, (default)> = [ True]
#                   state_code_str<2023, (default)> = ['UT']
#                   is_tanf_non_cash_hheod<2023, (default)> = [False]
#                     state_code_str<2023, (default)> = ['UT']
#                     has_all_usda_elderly_disabled<2023, (default)> = [False]
#                       is_usda_elderly<2023, (default)> = [False False False False]
#                       is_usda_disabled<2023, (default)> = [False False False False]
#                     has_usda_elderly_disabled<2023, (default)> = [False]
#                   snap_net_income_fpg_ratio<2023, (default)> = [5.2043333]
#                 meets_tanf_non_cash_asset_test<2023, (default)> = [False]
#                   snap_assets<2023, (default)> = [0.]
#                   state_code_str<2023, (default)> = ['UT']
#           snap_expected_contribution<2023, (default)> = [46839.]
#             snap_net_income<2023, (default)> = [156130.]
#           snap_max_allotment<2023, (default)> = [11268.]
#             snap_region_str<2023, (default)> = ['CONTIGUOUS_US']
#             spm_unit_size<2023, (default)> = [4]
#             spm_unit_size<2023, (default)> = [4]
#           snap_min_allotment<2023, (default)> = [0.]
#             snap_region_str<2023, (default)> = ['CONTIGUOUS_US']
#             spm_unit_size<2023, (default)> = [4]
#         snap_emergency_allotment<2023, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-01, (default)> = [0.]
#             is_snap_eligible<2023, (default)> = [False]
#             snap_max_allotment<2023, (default)> = [11268.]
#             snap_normal_allotment<2023, (default)> = [0.]
#             state_code<2023, (default)> = ['UT']
#           snap_emergency_allotment_monthly<2023-02, (default)> = [0.]
#             is_snap_eligible<2023, (default)> = [False]
#             snap_max_allotment<2023, (default)> = [11268.]
#             snap_normal_allotment<2023, (default)> = [0.]
#             state_code<2023, (default)> = ['UT']
#           snap_emergency_allotment_monthly<2023-03, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-04, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-05, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-06, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-07, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-08, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-09, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-10, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-11, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-12, (default)> = [0.]
#       wic<2023, (default)> = [0. 0. 0. 0.]
#         meets_wic_income_test<2023, (default)> = [False]
#           school_meal_countable_income<2023, (default)> = [200000.]
#             employment_income<2023, (default)> = [100000. 100000.      0.      0.]
#             self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#             dividend_income<2023, (default)> = [0. 0. 0. 0.]
#             interest_income<2023, (default)> = [0. 0. 0. 0.]
#             gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#             social_security<2023, (default)> = [0. 0. 0. 0.]
#             ssi<2023, (default)> = [0. 0. 0. 0.]
#           wic_fpg<2023, (default)> = [30000.]
#             is_pregnant<2023, (default)> = [False False False False]
#             spm_unit_fpg<2023, (default)> = [30000.]
#             state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#         meets_wic_categorical_eligibility<2023, (default)> = [False False False False]
#           snap<2023, (default)> = [0.]
#           tanf<2023, (default)> = [0.]
#             tanf_reported<2023, (default)> = [0. 0. 0. 0.]
#             is_tanf_eligible<2023, (default)> = [False]
#               is_person_demographic_tanf_eligible<2023, (default)> = [False False  True  True]
#                 is_child<2023, (default)> = [False False  True  True]
#                 age<2023, (default)> = [38. 35. 10. 10.]
#                 is_full_time_student<2023, (default)> = [False False  True  True]
#                   is_full_time_college_student<2023, (default)> = [False False False False]
#                   is_in_k12_school<2023, (default)> = [False False  True  True]
#                     age<2023, (default)> = [38. 35. 10. 10.]
#                 is_pregnant<2023, (default)> = [False False False False]
#               is_tanf_enrolled<2023, (default)> = [False]
#               is_tanf_continuous_eligible<2023, (default)> = [False]
#                 tanf_gross_earned_income<2023, (default)> = [200000.]
#                   employment_income<2023, (default)> = [100000. 100000.      0.      0.]
#                   self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                 tanf_gross_unearned_income<2023, (default)> = [0.]
#                   dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                   interest_income<2023, (default)> = [0. 0. 0. 0.]
#                   gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#                   social_security<2023, (default)> = [0. 0. 0. 0.]
#                   ssi<2023, (default)> = [0. 0. 0. 0.]
#                 tanf_max_amount<2023, (default)> = [0.]
#                   spm_unit_size<2023, (default)> = [4]
#                   state_code_str<2023, (default)> = ['UT']
#               is_tanf_initial_eligible<2023, (default)> = [False]
#                 tanf_initial_employment_deduction<2023, (default)> = [0.]
#                   spm_unit_size<2023, (default)> = [4]
#                   state_code_str<2023, (default)> = ['UT']
#                   market_income<2023, (default)> = [100000. 100000.      0.      0.]
#                     employment_income<2023, (default)> = [100000. 100000.      0.      0.]
#                     self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                     pension_income<2023, (default)> = [0. 0. 0. 0.]
#                     dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                     interest_income<2023, (default)> = [0. 0. 0. 0.]
#                     gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#                     capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                     rental_income<2023, (default)> = [0. 0. 0. 0.]
#                     illicit_income<2023, (default)> = [0. 0. 0. 0.]
#                     farm_income<2023, (default)> = [0. 0. 0. 0.]
#                 tanf_gross_earned_income<2023, (default)> = [200000.]
#                 tanf_gross_unearned_income<2023, (default)> = [0.]
#                 tanf_max_amount<2023, (default)> = [0.]
#             tanf_amount_if_eligible<2023, (default)> = [0.]
#               tanf_max_amount<2023, (default)> = [0.]
#               tanf_countable_income<2023, (default)> = [200000.]
#                 state_code_str<2023, (default)> = ['UT']
#                 tanf_gross_unearned_income<2023, (default)> = [0.]
#                 tanf_gross_earned_income<2023, (default)> = [200000.]
#           medicaid<2023, (default)> = [0. 0. 0. 0.]
#             is_medicaid_eligible<2023, (default)> = [False False False False]
#               medicaid_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#                 is_infant_for_medicaid<2023, (default)> = [False False False False]
#                   is_infant_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [6.6666665 6.6666665 6.6666665 6.6666665]
#                       tax_unit_medicaid_income_level<2023, (default)> = [6.6666665]
#                         medicaid_income<2023, (default)> = [200000.]
#                           adjusted_gross_income<2023, (default)> = [200000.]
#                             irs_gross_income<2023, (default)> = [100000. 100000.      0.      0.]
#                               is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                               employment_income<2023, (default)> = [100000. 100000.      0.      0.]
#                               self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                               partnership_s_corp_income<2023, (default)> = [0. 0. 0. 0.]
#                               farm_income<2023, (default)> = [0. 0. 0. 0.]
#                               farm_rent_income<2023, (default)> = [0. 0. 0. 0.]
#                               capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                               taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#                               rental_income<2023, (default)> = [0. 0. 0. 0.]
#                               dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                               taxable_pension_income<2023, (default)> = [0. 0. 0. 0.]
#                               debt_relief<2023, (default)> = [0. 0. 0. 0.]
#                               taxable_unemployment_compensation<2023, (default)> = [0. 0. 0. 0.]
#                                 is_tax_unit_head<2023, (default)> = [ True False False False]
#                                 tax_unit_taxable_unemployment_compensation<2023, (default)> = [0.]
#                                   tax_unit_unemployment_compensation<2023, (default)> = [0.]
#                                     unemployment_compensation<2023, (default)> = [0. 0. 0. 0.]
#                                   taxable_uc_agi<2023, (default)> = [200000.]
#                                     is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                                     employment_income<2023, (default)> = [100000. 100000.      0.      0.]
#                                     self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                     partnership_s_corp_income<2023, (default)> = [0. 0. 0. 0.]
#                                     farm_income<2023, (default)> = [0. 0. 0. 0.]
#                                     farm_rent_income<2023, (default)> = [0. 0. 0. 0.]
#                                     capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                                     taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#                                     rental_income<2023, (default)> = [0. 0. 0. 0.]
#                                     dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                                     taxable_pension_income<2023, (default)> = [0. 0. 0. 0.]
#                                     debt_relief<2023, (default)> = [0. 0. 0. 0.]
#                                     taxable_social_security<2023, (default)> = [0. 0. 0. 0.]
#                                       tax_unit_taxable_social_security<2023, (default)> = [0.]
#                                         tax_unit_social_security<2023, (default)> = [0.]
#                                           social_security<2023, (default)> = [0. 0. 0. 0.]
#                                         taxable_ss_magi<2023, (default)> = [200000.]
#                                           is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                                           employment_income<2023, (default)> = [100000. 100000.      0.      0.]
#                                           self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                           partnership_s_corp_income<2023, (default)> = [0. 0. 0. 0.]
#                                           farm_income<2023, (default)> = [0. 0. 0. 0.]
#                                           farm_rent_income<2023, (default)> = [0. 0. 0. 0.]
#                                           capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                                           taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#                                           rental_income<2023, (default)> = [0. 0. 0. 0.]
#                                           dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                                           taxable_pension_income<2023, (default)> = [0. 0. 0. 0.]
#                                           debt_relief<2023, (default)> = [0. 0. 0. 0.]
#                                           illicit_income<2023, (default)> = [0. 0. 0. 0.]
#                                           unemployment_compensation<2023, (default)> = [0. 0. 0. 0.]
#                                           tax_exempt_interest_income<2023, (default)> = [0. 0. 0. 0.]
#                                           loss_ald<2023, (default)> = [0.]
#                                             filing_status<2023, (default)> = ['JOINT']
#                                               is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                                               tax_unit_dependents<2023, (default)> = [2]
#                                                 is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                                             self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                             maximum_capital_loss<2023, (default)> = [0.]
#                                               tax_unit_capital_loss<2023, (default)> = [0.]
#                                                 capital_loss<2023, (default)> = [0. 0. 0. 0.]
#                                                   capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                                               filing_status<2023, (default)> = ['JOINT']
#                                           self_employment_tax_ald<2023, (default)> = [0.]
#                                             self_employment_tax_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employment_tax<2023, (default)> = [0. 0. 0. 0.]
#                                                 self_employment_social_security_tax<2023, (default)> = [0. 0. 0. 0.]
#                                                   social_security_taxable_self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                                     taxable_self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                                       sey<2023, (default)> = [0. 0. 0. 0.]
#                                                         self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                                         farm_income<2023, (default)> = [0. 0. 0. 0.]
#                                                         k1bx14<2023, (default)> = [0. 0. 0. 0.]
#                                                     taxable_earnings_for_social_security<2023, (default)> = [100000. 100000.      0.      0.]
#                                                       payroll_tax_gross_wages<2023, (default)> = [100000. 100000.      0.      0.]
#                                                         employment_income<2023, (default)> = [100000. 100000.      0.      0.]
#                                                 self_employment_medicare_tax<2023, (default)> = [0. 0. 0. 0.]
#                                                   taxable_self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                           early_withdrawal_penalty<2023, (default)> = [0. 0. 0. 0.]
#                                           alimony_income<2023, (default)> = [0. 0. 0. 0.]
#                                           educator_expense<2023, (default)> = [0. 0. 0. 0.]
#                                           health_savings_account_ald<2023, (default)> = [0.]
#                                           self_employed_health_insurance_ald<2023, (default)> = [0.]
#                                             self_employed_health_insurance_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employed_health_insurance_premiums<2023, (default)> = [0. 0. 0. 0.]
#                                                 is_self_employed<2023, (default)> = [False False False False]
#                                                 health_insurance_premiums<2023, (default)> = [0. 0. 0. 0.]
#                                           self_employed_pension_contribution_ald<2023, (default)> = [0.]
#                                             self_employed_pension_contribution_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employed_pension_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                           ira_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                           sep_simple_qualified_plan_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                         filing_status<2023, (default)> = ['JOINT']
#                                       tax_unit_social_security<2023, (default)> = [0.]
#                                       social_security<2023, (default)> = [0. 0. 0. 0.]
#                                       is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                                       is_tax_unit_head<2023, (default)> = [ True False False False]
#                                     illicit_income<2023, (default)> = [0. 0. 0. 0.]
#                                     loss_ald<2023, (default)> = [0.]
#                                     self_employment_tax_ald<2023, (default)> = [0.]
#                                     student_loan_interest<2023, (default)> = [0. 0. 0. 0.]
#                                     early_withdrawal_penalty<2023, (default)> = [0. 0. 0. 0.]
#                                     alimony_income<2023, (default)> = [0. 0. 0. 0.]
#                                     educator_expense<2023, (default)> = [0. 0. 0. 0.]
#                                     health_savings_account_ald<2023, (default)> = [0.]
#                                     self_employed_health_insurance_ald<2023, (default)> = [0.]
#                                     self_employed_pension_contribution_ald<2023, (default)> = [0.]
#                                     ira_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                     sep_simple_qualified_plan_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                     qualified_adoption_assistance_expense<2023, (default)> = [0. 0. 0. 0.]
#                                     us_bonds_for_higher_ed<2023, (default)> = [0. 0. 0. 0.]
#                                     specified_possession_income<2023, (default)> = [0.]
#                                     puerto_rico_income<2023, (default)> = [0.]
#                                   filing_status<2023, (default)> = ['JOINT']
#                               taxable_social_security<2023, (default)> = [0. 0. 0. 0.]
#                               illicit_income<2023, (default)> = [0. 0. 0. 0.]
#                             above_the_line_deductions<2023, (default)> = [0.]
#                               loss_ald<2023, (default)> = [0.]
#                               self_employment_tax_ald<2023, (default)> = [0.]
#                               student_loan_interest<2023, (default)> = [0. 0. 0. 0.]
#                               early_withdrawal_penalty<2023, (default)> = [0. 0. 0. 0.]
#                               alimony_income<2023, (default)> = [0. 0. 0. 0.]
#                               educator_expense<2023, (default)> = [0. 0. 0. 0.]
#                               health_savings_account_ald<2023, (default)> = [0.]
#                               self_employed_health_insurance_ald<2023, (default)> = [0.]
#                               self_employed_pension_contribution_ald<2023, (default)> = [0.]
#                               ira_contributions<2023, (default)> = [0. 0. 0. 0.]
#                               sep_simple_qualified_plan_contributions<2023, (default)> = [0. 0. 0. 0.]
#                               qualified_adoption_assistance_expense<2023, (default)> = [0. 0. 0. 0.]
#                               us_bonds_for_higher_ed<2023, (default)> = [0. 0. 0. 0.]
#                               specified_possession_income<2023, (default)> = [0.]
#                               puerto_rico_income<2023, (default)> = [0.]
#                           foreign_earned_income_exclusion<2023, (default)> = [0.]
#                           student_loan_interest<2023, (default)> = [0. 0. 0. 0.]
#                           tax_exempt_social_security<2023, (default)> = [0.]
#                             tax_unit_social_security<2023, (default)> = [0.]
#                             tax_unit_taxable_social_security<2023, (default)> = [0.]
#                         tax_unit_fpg<2023, (default)> = [30000.]
#                           tax_unit_size<2023, (default)> = [4]
#                           state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#                     state_code_str<2023, (default)> = ['UT']
#                   is_infant_for_medicaid_nfc<2023, (default)> = [False False False False]
#                     age<2023, (default)> = [38. 35. 10. 10.]
#                 is_young_child_for_medicaid<2023, (default)> = [False False False False]
#                   is_young_child_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [6.6666665 6.6666665 6.6666665 6.6666665]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_young_child_for_medicaid_nfc<2023, (default)> = [False False False False]
#                     age<2023, (default)> = [38. 35. 10. 10.]
#                 is_older_child_for_medicaid<2023, (default)> = [False False False False]
#                   age<2023, (default)> = [38. 35. 10. 10.]
#                   medicaid_income_level<2023, (default)> = [6.6666665 6.6666665 6.6666665 6.6666665]
#                   state_code_str<2023, (default)> = ['UT']
#                 is_young_adult_for_medicaid<2023, (default)> = [False False False False]
#                   is_young_adult_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [6.6666665 6.6666665 6.6666665 6.6666665]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_young_adult_for_medicaid_nfc<2023, (default)> = [False False False False]
#                     age<2023, (default)> = [38. 35. 10. 10.]
#                 is_adult_for_medicaid<2023, (default)> = [False False False False]
#                   is_adult_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [6.6666665 6.6666665 6.6666665 6.6666665]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_adult_for_medicaid_nfc<2023, (default)> = [ True  True False False]
#                     age<2023, (default)> = [38. 35. 10. 10.]
#                 is_parent_for_medicaid<2023, (default)> = [False False False False]
#                   is_parent_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [6.6666665 6.6666665 6.6666665 6.6666665]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_parent_for_medicaid_nfc<2023, (default)> = [ True  True False False]
#                     is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                     tax_unit_count_dependents<2023, (default)> = [2]
#                       is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                 is_pregnant_for_medicaid<2023, (default)> = [False False False False]
#                   is_pregnant_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [6.6666665 6.6666665 6.6666665 6.6666665]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_pregnant_for_medicaid_nfc<2023, (default)> = [False False False False]
#                     is_pregnant<2023, (default)> = [False False False False]
#                     count_days_postpartum<2023, (default)> = [inf inf inf inf]
#                       under_60_days_postpartum<2023, (default)> = [False False False False]
#                       under_12_months_postpartum<2023, (default)> = [False False False False]
#                     state_code_str<2023, (default)> = ['UT']
#                 is_ssi_recipient_for_medicaid<2023, (default)> = [False False False False]
#                   state_code_str<2023, (default)> = ['UT']
#                   ssi<2023, (default)> = [0. 0. 0. 0.]
#             medicaid_benefit_value<2023, (default)> = [9966.585 9966.585 9966.585 9966.585]
#               state_code_str<2023, (default)> = ['UT']
#           is_pregnant<2023, (default)> = [False False False False]
#           wic_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#             is_pregnant<2023, (default)> = [False False False False]
#             is_mother<2023, (default)> = [False False False False]
#               is_female<2023, (default)> = [False False False False]
#               own_children_in_household<2023, (default)> = [0 0 0 0]
#               is_breastfeeding<2023, (default)> = [False False False False]
#             is_breastfeeding<2023, (default)> = [False False False False]
#             age<2023, (default)> = [38. 35. 10. 10.]
#         wic_category_str<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#           wic_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#         is_wic_at_nutritional_risk<2023, (default)> = [False False False False]
#           receives_wic<2023, (default)> = [False False False False]
#           meets_wic_income_test<2023, (default)> = [False]
#           meets_wic_categorical_eligibility<2023, (default)> = [False False False False]
#           wic_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#         would_claim_wic<2023, (default)> = [ True  True  True  True]
#       free_school_meals<2023, (default)> = [0.]
#         school_meal_tier<2023, (default)> = ['PAID']
#           school_meal_fpg_ratio<2023, (default)> = [6.6666665]
#             school_meal_countable_income<2023, (default)> = [200000.]
#             spm_unit_fpg<2023, (default)> = [30000.]
#           meets_school_meal_categorical_eligibility<2023, (default)> = [False]
#             snap<2023, (default)> = [0.]
#             tanf<2023, (default)> = [0.]
#             fdpir<2023, (default)> = [0.]
#         school_meal_net_subsidy<2023, (default)> = [0.]
#           school_meal_daily_subsidy<2023, (default)> = [0.72]
#             state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#             school_meal_tier<2023, (default)> = ['PAID']
#           school_meal_paid_daily_subsidy<2023, (default)> = [0.72]
#             state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#           is_in_k12_school<2023, (default)> = [False False  True  True]
#       reduced_price_school_meals<2023, (default)> = [0.]
#         school_meal_tier<2023, (default)> = ['PAID']
#         school_meal_net_subsidy<2023, (default)> = [0.]
#       lifeline<2023, (default)> = [0.]
#         is_rural<2023, (default)> = [False]
#         is_on_tribal_land<2023, (default)> = [False]
#         phone_cost<2023, (default)> = [2400.]
#         broadband_cost<2023, (default)> = [1200.]
#         is_lifeline_eligible<2023, (default)> = [False]
#           medicaid<2023, (default)> = [0. 0. 0. 0.]
#           snap<2023, (default)> = [0.]
#           ssi<2023, (default)> = [0. 0. 0. 0.]
#           fcc_fpg_ratio<2023, (default)> = [6.6666665]
#             irs_gross_income<2023, (default)> = [100000. 100000.      0.      0.]
#             spm_unit_fpg<2023, (default)> = [30000.]
#       acp<2023, (default)> = [0.]
#         is_acp_eligible<2023, (default)> = [False]
#           lifeline<2023, (default)> = [0.]
#           free_school_meals<2023, (default)> = [0.]
#           reduced_price_school_meals<2023, (default)> = [0.]
#           pell_grant<2023, (default)> = [0.]
#           wic<2023, (default)> = [0. 0. 0. 0.]
#           medicaid<2023, (default)> = [0. 0. 0. 0.]
#           snap<2023, (default)> = [0.]
#           ssi<2023, (default)> = [0. 0. 0. 0.]
#           fcc_fpg_ratio<2023, (default)> = [6.6666665]
#           ebb<2023, (default)> = [0.]
#             is_ebb_eligible<2023, (default)> = [False]
#               is_lifeline_eligible<2023, (default)> = [False]
#               free_school_meals<2023, (default)> = [0.]
#               reduced_price_school_meals<2023, (default)> = [0.]
#               pell_grant<2023, (default)> = [0.]
#               experienced_covid_income_loss<2023, (default)> = [False]
#               enrolled_in_ebb<2023, (default)> = [False]
#             broadband_cost_after_lifeline<2023, (default)> = [1200.]
#               broadband_cost<2023, (default)> = [1200.]
#               lifeline<2023, (default)> = [0.]
#             is_on_tribal_land<2023, (default)> = [False]
#         broadband_cost_after_lifeline<2023, (default)> = [1200.]
#         is_on_tribal_land<2023, (default)> = [False]
#       ebb<2023, (default)> = [0.]
#       tanf<2023, (default)> = [0.]
#       high_efficiency_electric_home_rebate<2023, (default)> = [0.]
#         capped_electric_heat_pump_clothes_dryer_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#             tax_unit_income_ami_ratio<2023, (default)> = [0.]
#           electric_heat_pump_clothes_dryer_expenditures<2023, (default)> = [0.]
#         capped_electric_load_service_center_upgrade_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           electric_load_service_center_upgrade_expenditures<2023, (default)> = [0.]
#         capped_electric_stove_cooktop_range_or_oven_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           electric_stove_cooktop_range_or_oven_expenditures<2023, (default)> = [0.]
#         capped_electric_wiring_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           electric_wiring_expenditures<2023, (default)> = [0.]
#         capped_heat_pump_water_heater_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           heat_pump_water_heater_expenditures<2023, (default)> = [0.]
#         capped_heat_pump_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           heat_pump_expenditures<2023, (default)> = [0.]
#         capped_insulation_air_sealing_ventilation_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           energy_efficient_insulation_expenditures<2023, (default)> = [0.]
#           air_sealing_ventilation_expenditures<2023, (default)> = [0.]
#       residential_efficiency_electrification_rebate<2023, (default)> = [0.]
#         residential_efficiency_electrification_retrofit_expenditures<2023, (default)> = [0.]
#         residential_efficiency_electrification_retrofit_energy_savings<2023, (default)> = [0.]
#         current_home_energy_use<2023, (default)> = [0.]
#         household_income_ami_ratio<2023, (default)> = [0.]
#         average_home_energy_use_in_state<2023, (default)> = [0.]
#       basic_income<2023, (default)> = [0.]
#         basic_income_eligible<2023, (default)> = [ True]
#         basic_income_before_phase_out<2023, (default)> = [0.]
#           tax_unit_size<2023, (default)> = [4]
#           age<2023, (default)> = [38. 35. 10. 10.]
#           tax_unit_fpg<2023, (default)> = [30000.]
#         basic_income_phase_out<2023, (default)> = [0.]
#           basic_income_before_phase_out<2023, (default)> = [0.]
#           adjusted_gross_income<2023, (default)> = [200000.]
#           filing_status<2023, (default)> = ['JOINT']
#       spm_unit_capped_housing_subsidy<2023, (default)> = [0.]
#         spm_unit_capped_housing_subsidy_reported<2023, (default)> = [0.]
#     household_refundable_tax_credits<2023, (default)> = [0.]
#       income_tax_refundable_credits<2023, (default)> = [0.]
#         eitc<2023, (default)> = [0.]
#           earned_income_tax_credit<2023, (default)> = [0.]
#             eitc_eligible<2023, (default)> = [ True]
#               is_child<2023, (default)> = [False False  True  True]
#               age<2023, (default)> = [38. 35. 10. 10.]
#               tax_exempt_interest_income<2023, (default)> = [0. 0. 0. 0.]
#               taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#               dividend_income<2023, (default)> = [0. 0. 0. 0.]
#               c01000<2023, (default)> = [0.]
#                 sep<2023, (default)> = [1]
#                 c23650<2023, (default)> = [0.]
#                   long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   short_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#               tax_unit_rental_income<2023, (default)> = [0.]
#                 rental_income<2023, (default)> = [0. 0. 0. 0.]
# ...
#                               income_tax_unavailable_non_refundable_credits<2023, (not_itemizing)> = [0.]
#                                 income_tax_before_credits<2023, (not_itemizing)> = [28521.]
#                                 income_tax_non_refundable_credits<2023, (not_itemizing)> = [4300.]
#                                 income_tax_non_refundable_credits<2023, (not_itemizing)> = [4300.]
#                           income_tax_refundable_credits<2023, (not_itemizing)> = [0.]
#                       state_income_tax<2023, (not_itemizing)> = [9317.512]
#                 taxable_income_deductions_if_itemizing<2023, (default)> = [29317.512]
#                   charitable_deduction<2023, (default)> = [20000.]
#                   interest_deduction<2023, (default)> = [0.]
#                   salt_deduction<2023, (default)> = [9317.512]
#                     state_and_local_sales_or_income_tax<2023, (default)> = [9317.512]
#                       state_income_tax<2023, (default)> = [9317.512]
#                         ma_income_tax<2023, (default)> = [0.]
#                           MA<2023, (default)> = [False]
#                         md_income_tax<2023, (default)> = [0.]
#                           MD<2023, (default)> = [False]
#                         ny_income_tax<2023, (default)> = [0.]
#                           NY<2023, (default)> = [False]
#                         or_income_tax<2023, (default)> = [0.]
#                           OR<2023, (default)> = [False]
#                         pa_income_tax<2023, (default)> = [0.]
#                           PA<2023, (default)> = [False]
#                             state_code_str<2023, (default)> = ['UT']
#                         wa_income_tax<2023, (default)> = [0.]
#                           WA<2023, (default)> = [False]
#                         ut_income_tax<2023, (default)> = [9317.512]
#                           UT<2023, (default)> = [ True]
#                           ut_income_tax_before_refundable_credits<2023, (default)> = [9317.512]
#                             ut_income_tax_after_credits<2023, (default)> = [9317.512]
#                               ut_income_tax_before_credits<2023, (default)> = [9000.]
#                                 UT<2023, (default)> = [ True]
#                                 ut_taxable_income<2023, (default)> = [200000.]
#                                   UT<2023, (default)> = [ True]
#                                   ut_total_income<2023, (default)> = [200000.]
#                                     UT<2023, (default)> = [ True]
#                                     adjusted_gross_income<2023, (default)> = [200000.]
#                                     ut_additions_to_income<2023, (default)> = [0.]
#                                       UT<2023, (default)> = [ True]
#                                   salt_refund_last_year<2023, (default)> = [0.]
#                                   ut_subtractions_from_income<2023, (default)> = [0.]
#                                     UT<2023, (default)> = [ True]
#                               ut_taxpayer_credit<2023, (default)> = [-317.51196]
#                                 UT<2023, (default)> = [ True]
#                                 ut_taxpayer_credit_max<2023, (default)> = [1878.24]
#                                   UT<2023, (default)> = [ True]
#                                   tax_unit_count_dependents<2023, (default)> = [2]
#                                   tax_unit_itemizes<2023, (default)> = [False]
#                                   standard_deduction<2023, (default)> = [27700.]
#                                   charitable_deduction<2023, (default)> = [20000.]
#                                   interest_deduction<2023, (default)> = [0.]
#                                   medical_expense_deduction<2023, (default)> = [0.]
#                                   casualty_loss_deduction<2023, (default)> = [0.]
#                                 ut_taxpayer_credit_reduction<2023, (default)> = [2195.752]
#                                   UT<2023, (default)> = [ True]
#                                   filing_status<2023, (default)> = ['JOINT']
#                                   ut_taxable_income<2023, (default)> = [200000.]
#                             ut_apportionable_nonrefundable_credits<2023, (default)> = [0.]
#                               UT<2023, (default)> = [ True]
#                             ut_nonapportionable_nonrefundable_credits<2023, (default)> = [0.]
#                               UT<2023, (default)> = [ True]
#                             ut_recapture_low_inc_housing_credit<2023, (default)> = [0.]
#                               UT<2023, (default)> = [ True]
#                           ut_refundable_credits<2023, (default)> = [0.]
#                       local_income_tax<2023, (default)> = [0.]
#                       state_sales_tax<2023, (default)> = [0.]
#                       local_sales_tax<2023, (default)> = [0.]
#                     real_estate_taxes<2023, (default)> = [0. 0. 0. 0.]
#                     filing_status<2023, (default)> = ['JOINT']
#                   medical_expense_deduction<2023, (default)> = [0.]
#                   casualty_loss_deduction<2023, (default)> = [0.]
#                   qualified_business_income_deduction<2023, (default)> = [0.]
#                     qbid_amount<2023, (default)> = [0. 0. 0. 0.]
#                       qualified_business_income<2023, (default)> = [0. 0. 0. 0.]
#                         self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                         partnership_s_corp_income<2023, (default)> = [0. 0. 0. 0.]
#                         farm_income<2023, (default)> = [0. 0. 0. 0.]
#                         farm_rent_income<2023, (default)> = [0. 0. 0. 0.]
#                         self_employment_tax_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                         self_employed_health_insurance_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                         self_employed_pension_contribution_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                         business_is_qualified<2023, (default)> = [False False False False]
#                       w2_wages_from_qualified_business<2023, (default)> = [0. 0. 0. 0.]
#                       unadjusted_basis_qualified_property<2023, (default)> = [0. 0. 0. 0.]
#                       taxable_income_less_qbid<2023, (default)> = [170682.48]
#                         adjusted_gross_income<2023, (default)> = [200000.]
#                         charitable_deduction<2023, (default)> = [20000.]
#                         interest_deduction<2023, (default)> = [0.]
#                         salt_deduction<2023, (default)> = [9317.512]
#                         medical_expense_deduction<2023, (default)> = [0.]
#                         casualty_loss_deduction<2023, (default)> = [0.]
#                         standard_deduction<2023, (default)> = [27700.]
#                       filing_status<2023, (default)> = ['JOINT']
#                       business_is_sstb<2023, (default)> = [False False False False]
#                     taxable_income_less_qbid<2023, (default)> = [170682.48]
#                     adjusted_net_capital_gain<2023, (default)> = [0.]
#                       net_capital_gain<2023, (default)> = [0.]
#                         net_long_term_capital_gain<2023, (default)> = [0.]
#                           long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                           long_term_capital_losses<2023, (default)> = [0. 0. 0. 0.]
#                         net_short_term_capital_loss<2023, (default)> = [0.]
#                           short_term_capital_losses<2023, (default)> = [0. 0. 0. 0.]
#                           short_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                         qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                       qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                       unrecaptured_section_1250_gain<2023, (default)> = [0.]
#                       capital_gains_28_percent_rate_gain<2023, (default)> = [0.]
#                         long_term_capital_gains_on_collectibles<2023, (default)> = [0. 0. 0. 0.]
#                         long_term_capital_gains_on_small_business_stock<2023, (default)> = [0. 0. 0. 0.]
#                 taxable_income_deductions_if_not_itemizing<2023, (default)> = [27700.]
#                   standard_deduction<2023, (default)> = [27700.]
#                   qualified_business_income_deduction<2023, (default)> = [0.]
#             capital_gains_excluded_from_taxable_income<2023, (default)> = [0.]
#               net_capital_gain<2023, (default)> = [0.]
#               adjusted_net_capital_gain<2023, (default)> = [0.]
#               taxable_income<2023, (default)> = [172300.]
#               filing_status<2023, (default)> = ['JOINT']
#             filing_status<2023, (default)> = ['JOINT']
#           capital_gains_tax<2023, (default)> = [0.]
#             net_capital_gain<2023, (default)> = [0.]
#             taxable_income<2023, (default)> = [172300.]
#             adjusted_net_capital_gain<2023, (default)> = [0.]
#             capital_gains_excluded_from_taxable_income<2023, (default)> = [0.]
#             filing_status<2023, (default)> = ['JOINT']
#             unrecaptured_section_1250_gain<2023, (default)> = [0.]
#             qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#             capital_gains_28_percent_rate_gain<2023, (default)> = [0.]
#           alternative_minimum_tax<2023, (default)> = [0.]
#             c09600<2023, (default)> = [0.]
#               c62100<2023, (default)> = [200000.]
#                 amt_income<2023, (default)> = [200000.]
#                   taxable_income<2023, (default)> = [172300.]
#                   tax_unit_itemizes<2023, (default)> = [False]
#                   standard_deduction<2023, (default)> = [27700.]
#                   salt_deduction<2023, (default)> = [9317.512]
#                   filing_status<2023, (default)> = ['JOINT']
#               filing_status<2023, (default)> = ['JOINT']
#               age_head<2023, (default)> = [38]
#               age_spouse<2023, (default)> = [35]
#               filer_earned<2023, (default)> = [200000.]
#               sep<2023, (default)> = [1]
#               dwks10<2023, (default)> = [0.]
#                 dwks6<2023, (default)> = [0.]
#                   qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                   investment_income_form_4952<2023, (default)> = [0.]
#                 dwks9<2023, (default)> = [0.]
#                   long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                   c23650<2023, (default)> = [0.]
#                   non_sch_d_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   investment_income_form_4952<2023, (default)> = [0.]
#                 long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                 qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                 c23650<2023, (default)> = [0.]
#                 non_sch_d_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                 hasqdivltcg<2023, (default)> = [False]
#                   c01000<2023, (default)> = [0.]
#                   c23650<2023, (default)> = [0.]
#                   long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   non_sch_d_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#               dwks13<2023, (default)> = [0.]
#                 unrecaptured_section_1250_gain<2023, (default)> = [0.]
#                 capital_gains_28_percent_rate_gain<2023, (default)> = [0.]
#                 dwks9<2023, (default)> = [0.]
#                 dwks10<2023, (default)> = [0.]
#                 hasqdivltcg<2023, (default)> = [False]
#               dwks14<2023, (default)> = [0.]
#                 taxable_income<2023, (default)> = [172300.]
#                 dwks13<2023, (default)> = [0.]
#                 hasqdivltcg<2023, (default)> = [False]
#               dwks19<2023, (default)> = [0.]
#                 dwks14<2023, (default)> = [0.]
#                 filing_status<2023, (default)> = ['JOINT']
#                 taxable_income<2023, (default)> = [172300.]
#                 dwks10<2023, (default)> = [0.]
#                 hasqdivltcg<2023, (default)> = [False]
#               unrecaptured_section_1250_gain<2023, (default)> = [0.]
#               sep<2023, (default)> = [1]
#               foreign_tax_credit<2023, (default)> = [0.]
#               amt_form_completed<2023, (default)> = [False]
#               foreign_tax_credit<2023, (default)> = [0.]
#               taxbc<2023, (default)> = [28521.]
#                 regular_tax_before_credits<2023, (default)> = [28521.]
#                   filing_status<2023, (default)> = ['JOINT']
#                   taxable_income<2023, (default)> = [172300.]
#                   dwks14<2023, (default)> = [0.]
#                   dwks13<2023, (default)> = [0.]
#                   dwks19<2023, (default)> = [0.]
#                   dwks9<2023, (default)> = [0.]
#                   unrecaptured_section_1250_gain<2023, (default)> = [0.]
#                   dwks10<2023, (default)> = [0.]
#                   income_tax_main_rates<2023, (default)> = [28521.]
#                   hasqdivltcg<2023, (default)> = [False]
#               c05700<2023, (default)> = [0.]
#         net_investment_income_tax<2023, (default)> = [0.]
#           taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#           dividend_income<2023, (default)> = [0. 0. 0. 0.]
#           c01000<2023, (default)> = [0.]
#           rental_income<2023, (default)> = [0. 0. 0. 0.]
#           filing_status<2023, (default)> = ['JOINT']
#           adjusted_gross_income<2023, (default)> = [200000.]
#         recapture_of_investment_credit<2023, (default)> = [0.]
#         unreported_payroll_tax<2023, (default)> = [0.]
#         qualified_retirement_penalty<2023, (default)> = [0.]
#         income_tax_capped_non_refundable_credits<2023, (default)> = [4300.]
#           income_tax_non_refundable_credits<2023, (default)> = [4300.]
#             cdcc<2023, (default)> = [300.]
#             elderly_disabled_credit<2023, (default)> = [0.]
#             non_refundable_ctc<2023, (default)> = [4000.]
#               ctc<2023, (default)> = [4000.]
#               refundable_ctc<2023, (default)> = [0.]
#             non_refundable_american_opportunity_credit<2023, (default)> = [0.]
#             lifetime_learning_credit<2023, (default)> = [0.]
#             retirement_savings_credit<2023, (default)> = [0.]
#             residential_clean_energy_credit<2023, (default)> = [0.]
#             energy_efficient_home_improvement_credit<2023, (default)> = [0.]
#             new_clean_vehicle_credit<2023, (default)> = [0.]
#             used_clean_vehicle_credit<2023, (default)> = [0.]
#           income_tax_unavailable_non_refundable_credits<2023, (default)> = [0.]
#             income_tax_before_credits<2023, (default)> = [28521.]
#             income_tax_non_refundable_credits<2023, (default)> = [4300.]
#             income_tax_non_refundable_credits<2023, (default)> = [4300.]
#       ma_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         MA<2023, (default)> = [False]
#       md_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         MD<2023, (default)> = [False]
#       ny_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         NY<2023, (default)> = [False]
#       or_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         or_income_tax_before_credits<2023, (default)> = [0.]
#           OR<2023, (default)> = [False]
#         or_non_refundable_credits<2023, (default)> = [0.]
#           or_exemption_credit<2023, (default)> = [0.]
#             OR<2023, (default)> = [False]
#       pa_income_tax<2023, (default)> = [0.]
#       ut_income_tax_before_refundable_credits<2023, (default)> = [9317.512]
#       wa_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         WA<2023, (default)> = [False]
#       flat_tax<2023, (default)> = [0.]
#         positive_agi<2023, (default)> = [200000.]

# %% [markdown]
# ### 3.5. Effects on three household types of rate cut to 4.00%

# %% [markdown]
# #### 3.5.1. Effect of rate cut to 4.00% on low income household

# %%
def modify_parameters_3(parameters):
    parameters.gov.states.ut.tax.income.rate.update(
        start=instant("2023-01-01"),
        stop=instant("2027-12-31"),
        value=0.04
    )

class reform_3(Reform):
    def apply(self):
        self.modify_parameters(modify_parameters_3)

simulation_3_l = Simulation(
    reform=reform_3,
    situation=situation_low,
)

simulation_3_l.trace = True
simulation_3_l.calculate("household_net_income", 2023)
simulation_3_l.tracer.print_computation_log()
# Out:
#   household_net_income<2023, (default)> = [42138.2]
#     household_market_income<2023, (default)> = [25000.]
#       employment_income<2023, (default)> = [25000.     0.     0.     0.]
#       self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#       pension_income<2023, (default)> = [0. 0. 0. 0.]
#         tax_exempt_pension_income<2023, (default)> = [0. 0. 0. 0.]
#         taxable_pension_income<2023, (default)> = [0. 0. 0. 0.]
#       dividend_income<2023, (default)> = [0. 0. 0. 0.]
#         qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#         non_qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#       interest_income<2023, (default)> = [0. 0. 0. 0.]
#         tax_exempt_interest_income<2023, (default)> = [0. 0. 0. 0.]
#         taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#       gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#       capital_gains<2023, (default)> = [0. 0. 0. 0.]
#         short_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#         long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#       rental_income<2023, (default)> = [0. 0. 0. 0.]
#       illicit_income<2023, (default)> = [0. 0. 0. 0.]
#       farm_income<2023, (default)> = [0. 0. 0. 0.]
#     household_benefits<2023, (default)> = [9246.7]
#       social_security<2023, (default)> = [0. 0. 0. 0.]
#         social_security_dependents<2023, (default)> = [0. 0. 0. 0.]
#         social_security_disability<2023, (default)> = [0. 0. 0. 0.]
#         social_security_retirement<2023, (default)> = [0. 0. 0. 0.]
#         social_security_survivors<2023, (default)> = [0. 0. 0. 0.]
#       ssi<2023, (default)> = [0. 0. 0. 0.]
#         uncapped_ssi<2023, (default)> = [0. 0. 0. 0.]
#           ssi_amount_if_eligible<2023, (default)> = [10968. 10968. 10968. 10968.]
#             ssi_claim_is_joint<2023, (default)> = [False False False False]
#               is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                 is_ssi_aged<2023, (default)> = [False False False False]
#                   age<2023, (default)> = [38. 35. 10.  6.]
#                 is_blind<2023, (default)> = [False False False False]
#                 is_ssi_disabled<2023, (default)> = [False False False False]
#                   is_ssi_aged<2023, (default)> = [False False False False]
#                   is_blind<2023, (default)> = [False False False False]
#                   ssi_reported<2023, (default)> = [0. 0. 0. 0.]
#               ssi_income_deemed_from_ineligible_spouse<2023, (default)> = [0. 0. 0. 0.]
#                 ssi_earned_income<2023, (default)> = [25000.     0.     0.     0.]
#                   employment_income<2023, (default)> = [25000.     0.     0.     0.]
#                   self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                 ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#                   dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                   interest_income<2023, (default)> = [0. 0. 0. 0.]
#                   gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#                   social_security<2023, (default)> = [0. 0. 0. 0.]
#                   alimony_income<2023, (default)> = [0. 0. 0. 0.]
#                   pension_income<2023, (default)> = [0. 0. 0. 0.]
#                   unemployment_compensation<2023, (default)> = [0. 0. 0. 0.]
#                 ssi_earned_income_deemed_from_ineligible_spouse<2023, (default)> = [0. 0. 0. 0.]
#                   is_ssi_ineligible_spouse<2023, (default)> = [False  True False False]
#                     is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                       is_child<2023, (default)> = [False False  True  True]
#                         age<2023, (default)> = [38. 35. 10.  6.]
#                       is_tax_unit_head<2023, (default)> = [ True False False False]
#                         is_child<2023, (default)> = [False False  True  True]
#                         age<2023, (default)> = [38. 35. 10.  6.]
#                       age<2023, (default)> = [38. 35. 10.  6.]
#                     is_ssi_eligible_spouse<2023, (default)> = [False False False False]
#                       is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                       is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                   ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#                   ssi_earned_income<2023, (default)> = [25000.     0.     0.     0.]
#                   ssi_ineligible_child_allocation<2023, (default)> = [   0.    0. 5484. 5484.]
#                     ssi_earned_income<2023, (default)> = [25000.     0.     0.     0.]
#                     ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#                     is_ssi_ineligible_child<2023, (default)> = [False False  True  True]
#                       is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                       is_child<2023, (default)> = [False False  True  True]
#                   is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                 ssi_unearned_income_deemed_from_ineligible_spouse<2023, (default)> = [0. 0. 0. 0.]
#                   is_ssi_ineligible_spouse<2023, (default)> = [False  True False False]
#                   ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#                   ssi_ineligible_child_allocation<2023, (default)> = [   0.    0. 5484. 5484.]
#                 is_ssi_ineligible_child<2023, (default)> = [False False  True  True]
#           meets_ssi_resource_test<2023, (default)> = [ True  True  True  True]
#             ssi_claim_is_joint<2023, (default)> = [False False False False]
#             ssi_countable_resources<2023, (default)> = [0. 0. 0. 0.]
#           is_ssi_eligible_individual<2023, (default)> = [False False False False]
#             is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#             is_ssi_eligible_spouse<2023, (default)> = [False False False False]
#           ssi_countable_income<2023, (default)> = [0. 0. 0. 0.]
#             ssi_earned_income<2023, (default)> = [25000.     0.     0.     0.]
#             ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#             ssi_unearned_income_deemed_from_ineligible_parent<2023, (default)> = [0. 0. 0. 0.]
#               is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#               is_child<2023, (default)> = [False False  True  True]
#               is_ssi_ineligible_parent<2023, (default)> = [False False False False]
#                 is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                 is_child<2023, (default)> = [False False  True  True]
#               ssi_earned_income<2023, (default)> = [25000.     0.     0.     0.]
#               ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#               ssi_ineligible_child_allocation<2023, (default)> = [   0.    0. 5484. 5484.]
#               ssi_ineligible_parent_allocation<2023, (default)> = [0. 0. 0. 0.]
#                 is_ssi_ineligible_parent<2023, (default)> = [False False False False]
#             ssi_income_deemed_from_ineligible_spouse<2023, (default)> = [0. 0. 0. 0.]
#             is_ssi_eligible_individual<2023, (default)> = [False False False False]
#       state_supplement<2023, (default)> = [0. 0. 0. 0.]
#         uncapped_ssi<2023, (default)> = [0. 0. 0. 0.]
#         maximum_state_supplement<2023, (default)> = [0. 0. 0. 0.]
#           is_ssi_eligible_individual<2023, (default)> = [False False False False]
#           state_code_str<2023, (default)> = ['UT']
#             state_code<2023, (default)> = ['UT']
#               state_name<2023, (default)> = ['UT']
#           state_living_arrangement<2023, (default)> = ['FULL_COST']
#           is_blind<2023, (default)> = [False False False False]
#           is_ssi_aged<2023, (default)> = [False False False False]
#           is_ssi_disabled<2023, (default)> = [False False False False]
#           ssi_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#           ssi_claim_is_joint<2023, (default)> = [False False False False]
#         is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#         meets_ssi_resource_test<2023, (default)> = [ True  True  True  True]
#         ssi_claim_is_joint<2023, (default)> = [False False False False]
#       ca_cvrp<2023, (default)> = [0. 0. 0. 0.]
#         CA<2023, (default)> = [False]
#           state_code_str<2023, (default)> = ['UT']
#       snap<2023, (default)> = [6860.5]
#         snap_normal_allotment<2023, (default)> = [5979.]
#           is_snap_eligible<2023, (default)> = [ True]
#             meets_snap_net_income_test<2023, (default)> = [ True]
#               snap_net_income_fpg_ratio<2023, (default)> = [0.5876667]
#                 snap_net_income<2023, (default)> = [17630.]
#                   snap_gross_income<2023, (default)> = [25000.]
#                     snap_earned_income<2023, (default)> = [25000.]
#                       employment_income<2023, (default)> = [25000.     0.     0.     0.]
#                       self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                     snap_unearned_income<2023, (default)> = [0.]
#                       dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                       interest_income<2023, (default)> = [0. 0. 0. 0.]
#                       gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#                       social_security<2023, (default)> = [0. 0. 0. 0.]
#                       ssi<2023, (default)> = [0. 0. 0. 0.]
#                   snap_deductions<2023, (default)> = [7370.]
#                     snap_standard_deduction<2023, (default)> = [2316.]
#                       state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#                         state_group<2023, (default)> = ['CONTIGUOUS_US']
#                           state_code<2023, (default)> = ['UT']
#                       spm_unit_size<2023, (default)> = [4]
#                     snap_earned_income_deduction<2023, (default)> = [5000.]
#                       snap_earned_income<2023, (default)> = [25000.]
#                     snap_dependent_care_deduction<2023, (default)> = [0.]
#                       childcare_expenses<2023, (default)> = [0.]
#                     snap_child_support_deduction<2023, (default)> = [0.]
#                       child_support_expense<2023, (default)> = [0. 0. 0. 0.]
#                       state_code_str<2023, (default)> = ['UT']
#                     snap_excess_medical_expense_deduction<2023, (default)> = [0.]
#                       is_usda_elderly<2023, (default)> = [False False False False]
#                         age<2023, (default)> = [38. 35. 10.  6.]
#                       is_usda_disabled<2023, (default)> = [False False False False]
#                         is_ssi_disabled<2023, (default)> = [False False False False]
#                         social_security_disability<2023, (default)> = [0. 0. 0. 0.]
#                         is_permanently_disabled_veteran<2023, (default)> = [False False False False]
#                         is_surviving_spouse_of_disabled_veteran<2023, (default)> = [False False False False]
#                         is_surviving_child_of_disabled_veteran<2023, (default)> = [False False False False]
#                       medical_out_of_pocket_expenses<2023, (default)> = [200.   0.   0.   0.]
#                       state_code_str<2023, (default)> = ['UT']
#                     snap_excess_shelter_expense_deduction<2023, (default)> = [54.]
#                       snap_net_income_pre_shelter<2023, (default)> = [17684.]
#                         snap_gross_income<2023, (default)> = [25000.]
#                         snap_standard_deduction<2023, (default)> = [2316.]
#                         snap_earned_income_deduction<2023, (default)> = [5000.]
#                         snap_dependent_care_deduction<2023, (default)> = [0.]
#                         snap_child_support_deduction<2023, (default)> = [0.]
#                         snap_excess_medical_expense_deduction<2023, (default)> = [0.]
#                       housing_cost<2023, (default)> = [8000.]
#                       snap_region_str<2023, (default)> = ['CONTIGUOUS_US']
#                         snap_region<2023, (default)> = ['CONTIGUOUS_US']
#                           state_group<2023, (default)> = ['CONTIGUOUS_US']
#                       has_usda_elderly_disabled<2023, (default)> = [False]
#                         is_usda_elderly<2023, (default)> = [False False False False]
#                         is_usda_disabled<2023, (default)> = [False False False False]
#                       snap_utility_allowance<2023, (default)> = [54.]
#                         snap_utility_allowance_type<2023, (default)> = ['IUA']
#                           count_distinct_utility_expenses<2023, (default)> = [1]
#                             heating_cooling_expense<2023, (default)> = [0.]
#                             electricity_expense<2023, (default)> = [0.]
#                             gas_expense<2023, (default)> = [0.]
#                             phone_expense<2023, (default)> = [700.]
#                               phone_cost<2023, (default)> = [700.]
#                             trash_expense<2023, (default)> = [0.]
#                             water_expense<2023, (default)> = [0.]
#                             sewage_expense<2023, (default)> = [0.]
#                           snap_utility_region_str<2023, (default)> = ['UT']
#                             snap_utility_region<2023, (default)> = ['UT']
#                               state_code<2023, (default)> = ['UT']
#                           has_heating_cooling_expense<2023, (default)> = [False]
#                             heating_cooling_expense<2023, (default)> = [0.]
#                         snap_utility_region_str<2023, (default)> = ['UT']
#                       state_code_str<2023, (default)> = ['UT']
#                       is_homeless<2023, (default)> = [False]
#                 spm_unit_fpg<2023, (default)> = [30000.]
#                   spm_unit_size<2023, (default)> = [4]
#                   state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#             meets_snap_gross_income_test<2023, (default)> = [ True]
#               snap_gross_income_fpg_ratio<2023, (default)> = [0.8333333]
#                 snap_gross_income<2023, (default)> = [25000.]
#                 spm_unit_fpg<2023, (default)> = [30000.]
#               has_usda_elderly_disabled<2023, (default)> = [False]
#             meets_snap_asset_test<2023, (default)> = [ True]
#               has_usda_elderly_disabled<2023, (default)> = [False]
#               snap_assets<2023, (default)> = [0.]
#             meets_snap_categorical_eligibility<2023, (default)> = [False]
#               ssi<2023, (default)> = [0. 0. 0. 0.]
#               is_tanf_non_cash_eligible<2023, (default)> = [False]
#                 meets_tanf_non_cash_gross_income_test<2023, (default)> = [False]
#                   state_code_str<2023, (default)> = ['UT']
#                   snap_gross_income_fpg_ratio<2023, (default)> = [0.8333333]
#                 meets_tanf_non_cash_net_income_test<2023, (default)> = [ True]
#                   state_code_str<2023, (default)> = ['UT']
#                   is_tanf_non_cash_hheod<2023, (default)> = [False]
#                     state_code_str<2023, (default)> = ['UT']
#                     has_all_usda_elderly_disabled<2023, (default)> = [False]
#                       is_usda_elderly<2023, (default)> = [False False False False]
#                       is_usda_disabled<2023, (default)> = [False False False False]
#                     has_usda_elderly_disabled<2023, (default)> = [False]
#                   snap_net_income_fpg_ratio<2023, (default)> = [0.5876667]
#                 meets_tanf_non_cash_asset_test<2023, (default)> = [False]
#                   snap_assets<2023, (default)> = [0.]
#                   state_code_str<2023, (default)> = ['UT']
#           snap_expected_contribution<2023, (default)> = [5289.]
#             snap_net_income<2023, (default)> = [17630.]
#           snap_max_allotment<2023, (default)> = [11268.]
#             snap_region_str<2023, (default)> = ['CONTIGUOUS_US']
#             spm_unit_size<2023, (default)> = [4]
#             spm_unit_size<2023, (default)> = [4]
#           snap_min_allotment<2023, (default)> = [0.]
#             snap_region_str<2023, (default)> = ['CONTIGUOUS_US']
#             spm_unit_size<2023, (default)> = [4]
#         snap_emergency_allotment<2023, (default)> = [881.5]
#           snap_emergency_allotment_monthly<2023-01, (default)> = [440.75]
#             is_snap_eligible<2023, (default)> = [ True]
#             snap_max_allotment<2023, (default)> = [11268.]
#             snap_normal_allotment<2023, (default)> = [5979.]
#             state_code<2023, (default)> = ['UT']
#           snap_emergency_allotment_monthly<2023-02, (default)> = [440.75]
#             is_snap_eligible<2023, (default)> = [ True]
#             snap_max_allotment<2023, (default)> = [11268.]
#             snap_normal_allotment<2023, (default)> = [5979.]
#             state_code<2023, (default)> = ['UT']
#           snap_emergency_allotment_monthly<2023-03, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-04, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-05, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-06, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-07, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-08, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-09, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-10, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-11, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-12, (default)> = [0.]
#       wic<2023, (default)> = [0. 0. 0. 0.]
#         meets_wic_income_test<2023, (default)> = [ True]
#           school_meal_countable_income<2023, (default)> = [25000.]
#             employment_income<2023, (default)> = [25000.     0.     0.     0.]
#             self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#             dividend_income<2023, (default)> = [0. 0. 0. 0.]
#             interest_income<2023, (default)> = [0. 0. 0. 0.]
#             gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#             social_security<2023, (default)> = [0. 0. 0. 0.]
#             ssi<2023, (default)> = [0. 0. 0. 0.]
#           wic_fpg<2023, (default)> = [30000.]
#             is_pregnant<2023, (default)> = [False False False False]
#             spm_unit_fpg<2023, (default)> = [30000.]
#             state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#         meets_wic_categorical_eligibility<2023, (default)> = [ True  True  True  True]
#           snap<2023, (default)> = [6860.5]
#           tanf<2023, (default)> = [0.]
#             tanf_reported<2023, (default)> = [0. 0. 0. 0.]
#             is_tanf_eligible<2023, (default)> = [False]
#               is_person_demographic_tanf_eligible<2023, (default)> = [False False  True  True]
#                 is_child<2023, (default)> = [False False  True  True]
#                 age<2023, (default)> = [38. 35. 10.  6.]
#                 is_full_time_student<2023, (default)> = [False False  True  True]
#                   is_full_time_college_student<2023, (default)> = [False False False False]
#                   is_in_k12_school<2023, (default)> = [False False  True  True]
#                     age<2023, (default)> = [38. 35. 10.  6.]
#                 is_pregnant<2023, (default)> = [False False False False]
#               is_tanf_enrolled<2023, (default)> = [False]
#               is_tanf_continuous_eligible<2023, (default)> = [False]
#                 tanf_gross_earned_income<2023, (default)> = [25000.]
#                   employment_income<2023, (default)> = [25000.     0.     0.     0.]
#                   self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                 tanf_gross_unearned_income<2023, (default)> = [0.]
#                   dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                   interest_income<2023, (default)> = [0. 0. 0. 0.]
#                   gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#                   social_security<2023, (default)> = [0. 0. 0. 0.]
#                   ssi<2023, (default)> = [0. 0. 0. 0.]
#                 tanf_max_amount<2023, (default)> = [0.]
#                   spm_unit_size<2023, (default)> = [4]
#                   state_code_str<2023, (default)> = ['UT']
#               is_tanf_initial_eligible<2023, (default)> = [False]
#                 tanf_initial_employment_deduction<2023, (default)> = [0.]
#                   spm_unit_size<2023, (default)> = [4]
#                   state_code_str<2023, (default)> = ['UT']
#                   market_income<2023, (default)> = [25000.     0.     0.     0.]
#                     employment_income<2023, (default)> = [25000.     0.     0.     0.]
#                     self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                     pension_income<2023, (default)> = [0. 0. 0. 0.]
#                     dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                     interest_income<2023, (default)> = [0. 0. 0. 0.]
#                     gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#                     capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                     rental_income<2023, (default)> = [0. 0. 0. 0.]
#                     illicit_income<2023, (default)> = [0. 0. 0. 0.]
#                     farm_income<2023, (default)> = [0. 0. 0. 0.]
#                 tanf_gross_earned_income<2023, (default)> = [25000.]
#                 tanf_gross_unearned_income<2023, (default)> = [0.]
#                 tanf_max_amount<2023, (default)> = [0.]
#             tanf_amount_if_eligible<2023, (default)> = [0.]
#               tanf_max_amount<2023, (default)> = [0.]
#               tanf_countable_income<2023, (default)> = [25000.]
#                 state_code_str<2023, (default)> = ['UT']
#                 tanf_gross_unearned_income<2023, (default)> = [0.]
#                 tanf_gross_earned_income<2023, (default)> = [25000.]
#           medicaid<2023, (default)> = [9966.585 9966.585 9966.585 9966.585]
#             is_medicaid_eligible<2023, (default)> = [ True  True  True  True]
#               medicaid_category<2023, (default)> = ['ADULT' 'ADULT' 'OLDER_CHILD' 'OLDER_CHILD']
#                 is_infant_for_medicaid<2023, (default)> = [False False False False]
#                   is_infant_for_medicaid_fc<2023, (default)> = [ True  True  True  True]
#                     medicaid_income_level<2023, (default)> = [0.8333333 0.8333333 0.8333333 0.8333333]
#                       tax_unit_medicaid_income_level<2023, (default)> = [0.8333333]
#                         medicaid_income<2023, (default)> = [25000.]
#                           adjusted_gross_income<2023, (default)> = [25000.]
#                             irs_gross_income<2023, (default)> = [25000.     0.     0.     0.]
#                               is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                               employment_income<2023, (default)> = [25000.     0.     0.     0.]
#                               self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                               partnership_s_corp_income<2023, (default)> = [0. 0. 0. 0.]
#                               farm_income<2023, (default)> = [0. 0. 0. 0.]
#                               farm_rent_income<2023, (default)> = [0. 0. 0. 0.]
#                               capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                               taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#                               rental_income<2023, (default)> = [0. 0. 0. 0.]
#                               dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                               taxable_pension_income<2023, (default)> = [0. 0. 0. 0.]
#                               debt_relief<2023, (default)> = [0. 0. 0. 0.]
#                               taxable_unemployment_compensation<2023, (default)> = [0. 0. 0. 0.]
#                                 is_tax_unit_head<2023, (default)> = [ True False False False]
#                                 tax_unit_taxable_unemployment_compensation<2023, (default)> = [0.]
#                                   tax_unit_unemployment_compensation<2023, (default)> = [0.]
#                                     unemployment_compensation<2023, (default)> = [0. 0. 0. 0.]
#                                   taxable_uc_agi<2023, (default)> = [25000.]
#                                     is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                                     employment_income<2023, (default)> = [25000.     0.     0.     0.]
#                                     self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                     partnership_s_corp_income<2023, (default)> = [0. 0. 0. 0.]
#                                     farm_income<2023, (default)> = [0. 0. 0. 0.]
#                                     farm_rent_income<2023, (default)> = [0. 0. 0. 0.]
#                                     capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                                     taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#                                     rental_income<2023, (default)> = [0. 0. 0. 0.]
#                                     dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                                     taxable_pension_income<2023, (default)> = [0. 0. 0. 0.]
#                                     debt_relief<2023, (default)> = [0. 0. 0. 0.]
#                                     taxable_social_security<2023, (default)> = [0. 0. 0. 0.]
#                                       tax_unit_taxable_social_security<2023, (default)> = [0.]
#                                         tax_unit_social_security<2023, (default)> = [0.]
#                                           social_security<2023, (default)> = [0. 0. 0. 0.]
#                                         taxable_ss_magi<2023, (default)> = [25000.]
#                                           is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                                           employment_income<2023, (default)> = [25000.     0.     0.     0.]
#                                           self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                           partnership_s_corp_income<2023, (default)> = [0. 0. 0. 0.]
#                                           farm_income<2023, (default)> = [0. 0. 0. 0.]
#                                           farm_rent_income<2023, (default)> = [0. 0. 0. 0.]
#                                           capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                                           taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#                                           rental_income<2023, (default)> = [0. 0. 0. 0.]
#                                           dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                                           taxable_pension_income<2023, (default)> = [0. 0. 0. 0.]
#                                           debt_relief<2023, (default)> = [0. 0. 0. 0.]
#                                           illicit_income<2023, (default)> = [0. 0. 0. 0.]
#                                           unemployment_compensation<2023, (default)> = [0. 0. 0. 0.]
#                                           tax_exempt_interest_income<2023, (default)> = [0. 0. 0. 0.]
#                                           loss_ald<2023, (default)> = [0.]
#                                             filing_status<2023, (default)> = ['JOINT']
#                                               is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                                               tax_unit_dependents<2023, (default)> = [2]
#                                                 is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                                             self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                             maximum_capital_loss<2023, (default)> = [0.]
#                                               tax_unit_capital_loss<2023, (default)> = [0.]
#                                                 capital_loss<2023, (default)> = [0. 0. 0. 0.]
#                                                   capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                                               filing_status<2023, (default)> = ['JOINT']
#                                           self_employment_tax_ald<2023, (default)> = [0.]
#                                             self_employment_tax_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employment_tax<2023, (default)> = [0. 0. 0. 0.]
#                                                 self_employment_social_security_tax<2023, (default)> = [0. 0. 0. 0.]
#                                                   social_security_taxable_self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                                     taxable_self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                                       sey<2023, (default)> = [0. 0. 0. 0.]
#                                                         self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                                         farm_income<2023, (default)> = [0. 0. 0. 0.]
#                                                         k1bx14<2023, (default)> = [0. 0. 0. 0.]
#                                                     taxable_earnings_for_social_security<2023, (default)> = [25000.     0.     0.     0.]
#                                                       payroll_tax_gross_wages<2023, (default)> = [25000.     0.     0.     0.]
#                                                         employment_income<2023, (default)> = [25000.     0.     0.     0.]
#                                                 self_employment_medicare_tax<2023, (default)> = [0. 0. 0. 0.]
#                                                   taxable_self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                           early_withdrawal_penalty<2023, (default)> = [0. 0. 0. 0.]
#                                           alimony_income<2023, (default)> = [0. 0. 0. 0.]
#                                           educator_expense<2023, (default)> = [0. 0. 0. 0.]
#                                           health_savings_account_ald<2023, (default)> = [0.]
#                                           self_employed_health_insurance_ald<2023, (default)> = [0.]
#                                             self_employed_health_insurance_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employed_health_insurance_premiums<2023, (default)> = [0. 0. 0. 0.]
#                                                 is_self_employed<2023, (default)> = [False False False False]
#                                                 health_insurance_premiums<2023, (default)> = [0. 0. 0. 0.]
#                                           self_employed_pension_contribution_ald<2023, (default)> = [0.]
#                                             self_employed_pension_contribution_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employed_pension_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                           ira_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                           sep_simple_qualified_plan_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                         filing_status<2023, (default)> = ['JOINT']
#                                       tax_unit_social_security<2023, (default)> = [0.]
#                                       social_security<2023, (default)> = [0. 0. 0. 0.]
#                                       is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                                       is_tax_unit_head<2023, (default)> = [ True False False False]
#                                     illicit_income<2023, (default)> = [0. 0. 0. 0.]
#                                     loss_ald<2023, (default)> = [0.]
#                                     self_employment_tax_ald<2023, (default)> = [0.]
#                                     student_loan_interest<2023, (default)> = [0. 0. 0. 0.]
#                                     early_withdrawal_penalty<2023, (default)> = [0. 0. 0. 0.]
#                                     alimony_income<2023, (default)> = [0. 0. 0. 0.]
#                                     educator_expense<2023, (default)> = [0. 0. 0. 0.]
#                                     health_savings_account_ald<2023, (default)> = [0.]
#                                     self_employed_health_insurance_ald<2023, (default)> = [0.]
#                                     self_employed_pension_contribution_ald<2023, (default)> = [0.]
#                                     ira_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                     sep_simple_qualified_plan_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                     qualified_adoption_assistance_expense<2023, (default)> = [0. 0. 0. 0.]
#                                     us_bonds_for_higher_ed<2023, (default)> = [0. 0. 0. 0.]
#                                     specified_possession_income<2023, (default)> = [0.]
#                                     puerto_rico_income<2023, (default)> = [0.]
#                                   filing_status<2023, (default)> = ['JOINT']
#                               taxable_social_security<2023, (default)> = [0. 0. 0. 0.]
#                               illicit_income<2023, (default)> = [0. 0. 0. 0.]
#                             above_the_line_deductions<2023, (default)> = [0.]
#                               loss_ald<2023, (default)> = [0.]
#                               self_employment_tax_ald<2023, (default)> = [0.]
#                               student_loan_interest<2023, (default)> = [0. 0. 0. 0.]
#                               early_withdrawal_penalty<2023, (default)> = [0. 0. 0. 0.]
#                               alimony_income<2023, (default)> = [0. 0. 0. 0.]
#                               educator_expense<2023, (default)> = [0. 0. 0. 0.]
#                               health_savings_account_ald<2023, (default)> = [0.]
#                               self_employed_health_insurance_ald<2023, (default)> = [0.]
#                               self_employed_pension_contribution_ald<2023, (default)> = [0.]
#                               ira_contributions<2023, (default)> = [0. 0. 0. 0.]
#                               sep_simple_qualified_plan_contributions<2023, (default)> = [0. 0. 0. 0.]
#                               qualified_adoption_assistance_expense<2023, (default)> = [0. 0. 0. 0.]
#                               us_bonds_for_higher_ed<2023, (default)> = [0. 0. 0. 0.]
#                               specified_possession_income<2023, (default)> = [0.]
#                               puerto_rico_income<2023, (default)> = [0.]
#                           foreign_earned_income_exclusion<2023, (default)> = [0.]
#                           student_loan_interest<2023, (default)> = [0. 0. 0. 0.]
#                           tax_exempt_social_security<2023, (default)> = [0.]
#                             tax_unit_social_security<2023, (default)> = [0.]
#                             tax_unit_taxable_social_security<2023, (default)> = [0.]
#                         tax_unit_fpg<2023, (default)> = [30000.]
#                           tax_unit_size<2023, (default)> = [4]
#                           state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#                     state_code_str<2023, (default)> = ['UT']
#                   is_infant_for_medicaid_nfc<2023, (default)> = [False False False False]
#                     age<2023, (default)> = [38. 35. 10.  6.]
#                 is_young_child_for_medicaid<2023, (default)> = [False False False False]
#                   is_young_child_for_medicaid_fc<2023, (default)> = [ True  True  True  True]
#                     medicaid_income_level<2023, (default)> = [0.8333333 0.8333333 0.8333333 0.8333333]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_young_child_for_medicaid_nfc<2023, (default)> = [False False False False]
#                     age<2023, (default)> = [38. 35. 10.  6.]
#                 is_older_child_for_medicaid<2023, (default)> = [False False  True  True]
#                   age<2023, (default)> = [38. 35. 10.  6.]
#                   medicaid_income_level<2023, (default)> = [0.8333333 0.8333333 0.8333333 0.8333333]
#                   state_code_str<2023, (default)> = ['UT']
#                 is_young_adult_for_medicaid<2023, (default)> = [False False False False]
#                   is_young_adult_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [0.8333333 0.8333333 0.8333333 0.8333333]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_young_adult_for_medicaid_nfc<2023, (default)> = [False False False False]
#                     age<2023, (default)> = [38. 35. 10.  6.]
#                 is_adult_for_medicaid<2023, (default)> = [ True  True False False]
#                   is_adult_for_medicaid_fc<2023, (default)> = [ True  True  True  True]
#                     medicaid_income_level<2023, (default)> = [0.8333333 0.8333333 0.8333333 0.8333333]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_adult_for_medicaid_nfc<2023, (default)> = [ True  True False False]
#                     age<2023, (default)> = [38. 35. 10.  6.]
#                 is_parent_for_medicaid<2023, (default)> = [False False False False]
#                   is_parent_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [0.8333333 0.8333333 0.8333333 0.8333333]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_parent_for_medicaid_nfc<2023, (default)> = [ True  True False False]
#                     is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                     tax_unit_count_dependents<2023, (default)> = [2]
#                       is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                 is_pregnant_for_medicaid<2023, (default)> = [False False False False]
#                   is_pregnant_for_medicaid_fc<2023, (default)> = [ True  True  True  True]
#                     medicaid_income_level<2023, (default)> = [0.8333333 0.8333333 0.8333333 0.8333333]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_pregnant_for_medicaid_nfc<2023, (default)> = [False False False False]
#                     is_pregnant<2023, (default)> = [False False False False]
#                     count_days_postpartum<2023, (default)> = [inf inf inf inf]
#                       under_60_days_postpartum<2023, (default)> = [False False False False]
#                       under_12_months_postpartum<2023, (default)> = [False False False False]
#                     state_code_str<2023, (default)> = ['UT']
#                 is_ssi_recipient_for_medicaid<2023, (default)> = [False False False False]
#                   state_code_str<2023, (default)> = ['UT']
#                   ssi<2023, (default)> = [0. 0. 0. 0.]
#             medicaid_benefit_value<2023, (default)> = [9966.585 9966.585 9966.585 9966.585]
#               state_code_str<2023, (default)> = ['UT']
#           is_pregnant<2023, (default)> = [False False False False]
#           wic_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#             is_pregnant<2023, (default)> = [False False False False]
#             is_mother<2023, (default)> = [False False False False]
#               is_female<2023, (default)> = [False False False False]
#               own_children_in_household<2023, (default)> = [0 0 0 0]
#               is_breastfeeding<2023, (default)> = [False False False False]
#             is_breastfeeding<2023, (default)> = [False False False False]
#             age<2023, (default)> = [38. 35. 10.  6.]
#         wic_category_str<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#           wic_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#         is_wic_at_nutritional_risk<2023, (default)> = [False False False False]
#           receives_wic<2023, (default)> = [False False False False]
#           meets_wic_income_test<2023, (default)> = [ True]
#           meets_wic_categorical_eligibility<2023, (default)> = [ True  True  True  True]
#           wic_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#         would_claim_wic<2023, (default)> = [ True  True  True  True]
#       free_school_meals<2023, (default)> = [1915.2]
#         school_meal_tier<2023, (default)> = ['FREE']
#           school_meal_fpg_ratio<2023, (default)> = [0.8333333]
#             school_meal_countable_income<2023, (default)> = [25000.]
#             spm_unit_fpg<2023, (default)> = [30000.]
#           meets_school_meal_categorical_eligibility<2023, (default)> = [ True]
#             snap<2023, (default)> = [6860.5]
#             tanf<2023, (default)> = [0.]
#             fdpir<2023, (default)> = [0.]
#         school_meal_net_subsidy<2023, (default)> = [1915.2]
#           school_meal_daily_subsidy<2023, (default)> = [6.04]
#             state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#             school_meal_tier<2023, (default)> = ['FREE']
#           school_meal_paid_daily_subsidy<2023, (default)> = [0.72]
#             state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#           is_in_k12_school<2023, (default)> = [False False  True  True]
#       reduced_price_school_meals<2023, (default)> = [0.]
#         school_meal_tier<2023, (default)> = ['FREE']
#         school_meal_net_subsidy<2023, (default)> = [1915.2]
#       lifeline<2023, (default)> = [111.]
#         is_rural<2023, (default)> = [False]
#         is_on_tribal_land<2023, (default)> = [False]
#         phone_cost<2023, (default)> = [700.]
#         broadband_cost<2023, (default)> = [600.]
#         is_lifeline_eligible<2023, (default)> = [ True]
#           medicaid<2023, (default)> = [9966.585 9966.585 9966.585 9966.585]
#           snap<2023, (default)> = [6860.5]
#           ssi<2023, (default)> = [0. 0. 0. 0.]
#           fcc_fpg_ratio<2023, (default)> = [0.8333333]
#             irs_gross_income<2023, (default)> = [25000.     0.     0.     0.]
#             spm_unit_fpg<2023, (default)> = [30000.]
#       acp<2023, (default)> = [360.]
#         is_acp_eligible<2023, (default)> = [ True]
#           lifeline<2023, (default)> = [111.]
#           free_school_meals<2023, (default)> = [1915.2]
#           reduced_price_school_meals<2023, (default)> = [0.]
#           pell_grant<2023, (default)> = [0.]
#           wic<2023, (default)> = [0. 0. 0. 0.]
#           medicaid<2023, (default)> = [9966.585 9966.585 9966.585 9966.585]
#           snap<2023, (default)> = [6860.5]
#           ssi<2023, (default)> = [0. 0. 0. 0.]
#           fcc_fpg_ratio<2023, (default)> = [0.8333333]
#           ebb<2023, (default)> = [0.]
#             is_ebb_eligible<2023, (default)> = [False]
#               is_lifeline_eligible<2023, (default)> = [ True]
#               free_school_meals<2023, (default)> = [1915.2]
#               reduced_price_school_meals<2023, (default)> = [0.]
#               pell_grant<2023, (default)> = [0.]
#               experienced_covid_income_loss<2023, (default)> = [False]
#               enrolled_in_ebb<2023, (default)> = [False]
#             broadband_cost_after_lifeline<2023, (default)> = [489.]
#               broadband_cost<2023, (default)> = [600.]
#               lifeline<2023, (default)> = [111.]
#             is_on_tribal_land<2023, (default)> = [False]
#         broadband_cost_after_lifeline<2023, (default)> = [489.]
#         is_on_tribal_land<2023, (default)> = [False]
#       ebb<2023, (default)> = [0.]
#       tanf<2023, (default)> = [0.]
#       high_efficiency_electric_home_rebate<2023, (default)> = [0.]
#         capped_electric_heat_pump_clothes_dryer_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#             tax_unit_income_ami_ratio<2023, (default)> = [0.]
#           electric_heat_pump_clothes_dryer_expenditures<2023, (default)> = [0.]
#         capped_electric_load_service_center_upgrade_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           electric_load_service_center_upgrade_expenditures<2023, (default)> = [0.]
#         capped_electric_stove_cooktop_range_or_oven_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           electric_stove_cooktop_range_or_oven_expenditures<2023, (default)> = [0.]
#         capped_electric_wiring_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           electric_wiring_expenditures<2023, (default)> = [0.]
#         capped_heat_pump_water_heater_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           heat_pump_water_heater_expenditures<2023, (default)> = [0.]
#         capped_heat_pump_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           heat_pump_expenditures<2023, (default)> = [0.]
#         capped_insulation_air_sealing_ventilation_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           energy_efficient_insulation_expenditures<2023, (default)> = [0.]
#           air_sealing_ventilation_expenditures<2023, (default)> = [0.]
#       residential_efficiency_electrification_rebate<2023, (default)> = [0.]
#         residential_efficiency_electrification_retrofit_expenditures<2023, (default)> = [0.]
#         residential_efficiency_electrification_retrofit_energy_savings<2023, (default)> = [0.]
#         current_home_energy_use<2023, (default)> = [0.]
#         household_income_ami_ratio<2023, (default)> = [0.]
#         average_home_energy_use_in_state<2023, (default)> = [0.]
#       basic_income<2023, (default)> = [0.]
#         basic_income_eligible<2023, (default)> = [ True]
#         basic_income_before_phase_out<2023, (default)> = [0.]
#           tax_unit_size<2023, (default)> = [4]
#           age<2023, (default)> = [38. 35. 10.  6.]
#           tax_unit_fpg<2023, (default)> = [30000.]
#         basic_income_phase_out<2023, (default)> = [0.]
#           basic_income_before_phase_out<2023, (default)> = [0.]
#           adjusted_gross_income<2023, (default)> = [25000.]
#           filing_status<2023, (default)> = ['JOINT']
#       spm_unit_capped_housing_subsidy<2023, (default)> = [0.]
#         spm_unit_capped_housing_subsidy_reported<2023, (default)> = [0.]
#     household_refundable_tax_credits<2023, (default)> = [9804.]
#       income_tax_refundable_credits<2023, (default)> = [9804.]
#         eitc<2023, (default)> = [6604.]
#           earned_income_tax_credit<2023, (default)> = [6604.]
#             eitc_eligible<2023, (default)> = [ True]
#               is_child<2023, (default)> = [False False  True  True]
#               age<2023, (default)> = [38. 35. 10.  6.]
#               tax_exempt_interest_income<2023, (default)> = [0. 0. 0. 0.]
#               taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#               dividend_income<2023, (default)> = [0. 0. 0. 0.]
#               c01000<2023, (default)> = [0.]
#                 sep<2023, (default)> = [1]
#                 c23650<2023, (default)> = [0.]
#                   long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   short_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#               tax_unit_rental_income<2023, (default)> = [0.]
#                 rental_income<2023, (default)> = [0. 0. 0. 0.]
# ...
#                       filing_status<2023, (default)> = ['JOINT']
#                       aged_blind_count<2023, (default)> = [0]
#                         blind_head<2023, (default)> = [False]
#                           is_blind<2023, (default)> = [False False False False]
#                           is_tax_unit_head<2023, (default)> = [ True False False False]
#                         blind_spouse<2023, (default)> = [False]
#                           is_blind<2023, (default)> = [False False False False]
#                           is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                         age_head<2023, (default)> = [38]
#                         age_spouse<2023, (default)> = [35]
#                 taxable_income_deductions_if_itemizing<2023, (default)> = [0.]
#                   charitable_deduction<2023, (default)> = [0.]
#                   interest_deduction<2023, (default)> = [0.]
#                   salt_deduction<2023, (default)> = [0.]
#                     state_and_local_sales_or_income_tax<2023, (default)> = [0.]
#                       state_income_tax<2023, (default)> = [0.]
#                         ma_income_tax<2023, (default)> = [0.]
#                           MA<2023, (default)> = [False]
#                         md_income_tax<2023, (default)> = [0.]
#                           MD<2023, (default)> = [False]
#                         ny_income_tax<2023, (default)> = [0.]
#                           NY<2023, (default)> = [False]
#                         or_income_tax<2023, (default)> = [0.]
#                           OR<2023, (default)> = [False]
#                         pa_income_tax<2023, (default)> = [0.]
#                           PA<2023, (default)> = [False]
#                             state_code_str<2023, (default)> = ['UT']
#                         wa_income_tax<2023, (default)> = [0.]
#                           WA<2023, (default)> = [False]
#                         ut_income_tax<2023, (default)> = [0.]
#                           UT<2023, (default)> = [ True]
#                           ut_income_tax_before_refundable_credits<2023, (default)> = [0.]
#                             ut_income_tax_after_credits<2023, (default)> = [0.]
#                               ut_income_tax_before_credits<2023, (default)> = [1000.]
#                                 UT<2023, (default)> = [ True]
#                                 ut_taxable_income<2023, (default)> = [25000.]
#                                   UT<2023, (default)> = [ True]
#                                   ut_total_income<2023, (default)> = [25000.]
#                                     UT<2023, (default)> = [ True]
#                                     adjusted_gross_income<2023, (default)> = [25000.]
#                                     ut_additions_to_income<2023, (default)> = [0.]
#                                       UT<2023, (default)> = [ True]
#                                   salt_refund_last_year<2023, (default)> = [0.]
#                                   ut_subtractions_from_income<2023, (default)> = [0.]
#                                     UT<2023, (default)> = [ True]
#                               ut_taxpayer_credit<2023, (default)> = [1878.24]
#                                 UT<2023, (default)> = [ True]
#                                 ut_taxpayer_credit_max<2023, (default)> = [1878.24]
#                                   UT<2023, (default)> = [ True]
#                                   tax_unit_count_dependents<2023, (default)> = [2]
#                                   tax_unit_itemizes<2023, (default)> = [False]
#                                   standard_deduction<2023, (default)> = [27700.]
#                                   charitable_deduction<2023, (default)> = [0.]
#                                   interest_deduction<2023, (default)> = [0.]
#                                   medical_expense_deduction<2023, (default)> = [0.]
#                                   casualty_loss_deduction<2023, (default)> = [0.]
#                                 ut_taxpayer_credit_reduction<2023, (default)> = [0.]
#                                   UT<2023, (default)> = [ True]
#                                   filing_status<2023, (default)> = ['JOINT']
#                                   ut_taxable_income<2023, (default)> = [25000.]
#                             ut_apportionable_nonrefundable_credits<2023, (default)> = [0.]
#                               UT<2023, (default)> = [ True]
#                             ut_nonapportionable_nonrefundable_credits<2023, (default)> = [0.]
#                               UT<2023, (default)> = [ True]
#                             ut_recapture_low_inc_housing_credit<2023, (default)> = [0.]
#                               UT<2023, (default)> = [ True]
#                           ut_refundable_credits<2023, (default)> = [0.]
#                       local_income_tax<2023, (default)> = [0.]
#                       state_sales_tax<2023, (default)> = [0.]
#                       local_sales_tax<2023, (default)> = [0.]
#                     real_estate_taxes<2023, (default)> = [0. 0. 0. 0.]
#                     filing_status<2023, (default)> = ['JOINT']
#                   medical_expense_deduction<2023, (default)> = [0.]
#                   casualty_loss_deduction<2023, (default)> = [0.]
#                   qualified_business_income_deduction<2023, (default)> = [0.]
#                     qbid_amount<2023, (default)> = [0. 0. 0. 0.]
#                       qualified_business_income<2023, (default)> = [0. 0. 0. 0.]
#                         self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                         partnership_s_corp_income<2023, (default)> = [0. 0. 0. 0.]
#                         farm_income<2023, (default)> = [0. 0. 0. 0.]
#                         farm_rent_income<2023, (default)> = [0. 0. 0. 0.]
#                         self_employment_tax_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                         self_employed_health_insurance_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                         self_employed_pension_contribution_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                         business_is_qualified<2023, (default)> = [False False False False]
#                       w2_wages_from_qualified_business<2023, (default)> = [0. 0. 0. 0.]
#                       unadjusted_basis_qualified_property<2023, (default)> = [0. 0. 0. 0.]
#                       taxable_income_less_qbid<2023, (default)> = [0.]
#                         adjusted_gross_income<2023, (default)> = [25000.]
#                         charitable_deduction<2023, (default)> = [0.]
#                         interest_deduction<2023, (default)> = [0.]
#                         salt_deduction<2023, (default)> = [0.]
#                         medical_expense_deduction<2023, (default)> = [0.]
#                         casualty_loss_deduction<2023, (default)> = [0.]
#                         standard_deduction<2023, (default)> = [27700.]
#                       filing_status<2023, (default)> = ['JOINT']
#                       business_is_sstb<2023, (default)> = [False False False False]
#                     taxable_income_less_qbid<2023, (default)> = [0.]
#                     adjusted_net_capital_gain<2023, (default)> = [0.]
#                       net_capital_gain<2023, (default)> = [0.]
#                         net_long_term_capital_gain<2023, (default)> = [0.]
#                           long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                           long_term_capital_losses<2023, (default)> = [0. 0. 0. 0.]
#                         net_short_term_capital_loss<2023, (default)> = [0.]
#                           short_term_capital_losses<2023, (default)> = [0. 0. 0. 0.]
#                           short_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                         qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                       qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                       unrecaptured_section_1250_gain<2023, (default)> = [0.]
#                       capital_gains_28_percent_rate_gain<2023, (default)> = [0.]
#                         long_term_capital_gains_on_collectibles<2023, (default)> = [0. 0. 0. 0.]
#                         long_term_capital_gains_on_small_business_stock<2023, (default)> = [0. 0. 0. 0.]
#                 taxable_income_deductions_if_not_itemizing<2023, (default)> = [27700.]
#                   standard_deduction<2023, (default)> = [27700.]
#                   qualified_business_income_deduction<2023, (default)> = [0.]
#             capital_gains_excluded_from_taxable_income<2023, (default)> = [0.]
#               net_capital_gain<2023, (default)> = [0.]
#               adjusted_net_capital_gain<2023, (default)> = [0.]
#               taxable_income<2023, (default)> = [0.]
#               filing_status<2023, (default)> = ['JOINT']
#             filing_status<2023, (default)> = ['JOINT']
#           capital_gains_tax<2023, (default)> = [0.]
#             net_capital_gain<2023, (default)> = [0.]
#             taxable_income<2023, (default)> = [0.]
#             adjusted_net_capital_gain<2023, (default)> = [0.]
#             capital_gains_excluded_from_taxable_income<2023, (default)> = [0.]
#             filing_status<2023, (default)> = ['JOINT']
#             unrecaptured_section_1250_gain<2023, (default)> = [0.]
#             qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#             capital_gains_28_percent_rate_gain<2023, (default)> = [0.]
#           alternative_minimum_tax<2023, (default)> = [0.]
#             c09600<2023, (default)> = [0.]
#               c62100<2023, (default)> = [27700.]
#                 amt_income<2023, (default)> = [27700.]
#                   taxable_income<2023, (default)> = [0.]
#                   tax_unit_itemizes<2023, (default)> = [False]
#                   standard_deduction<2023, (default)> = [27700.]
#                   salt_deduction<2023, (default)> = [0.]
#                   filing_status<2023, (default)> = ['JOINT']
#               filing_status<2023, (default)> = ['JOINT']
#               age_head<2023, (default)> = [38]
#               age_spouse<2023, (default)> = [35]
#               filer_earned<2023, (default)> = [25000.]
#               sep<2023, (default)> = [1]
#               dwks10<2023, (default)> = [0.]
#                 dwks6<2023, (default)> = [0.]
#                   qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                   investment_income_form_4952<2023, (default)> = [0.]
#                 dwks9<2023, (default)> = [0.]
#                   long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                   c23650<2023, (default)> = [0.]
#                   non_sch_d_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   investment_income_form_4952<2023, (default)> = [0.]
#                 long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                 qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                 c23650<2023, (default)> = [0.]
#                 non_sch_d_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                 hasqdivltcg<2023, (default)> = [False]
#                   c01000<2023, (default)> = [0.]
#                   c23650<2023, (default)> = [0.]
#                   long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   non_sch_d_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#               dwks13<2023, (default)> = [0.]
#                 unrecaptured_section_1250_gain<2023, (default)> = [0.]
#                 capital_gains_28_percent_rate_gain<2023, (default)> = [0.]
#                 dwks9<2023, (default)> = [0.]
#                 dwks10<2023, (default)> = [0.]
#                 hasqdivltcg<2023, (default)> = [False]
#               dwks14<2023, (default)> = [0.]
#                 taxable_income<2023, (default)> = [0.]
#                 dwks13<2023, (default)> = [0.]
#                 hasqdivltcg<2023, (default)> = [False]
#               dwks19<2023, (default)> = [0.]
#                 dwks14<2023, (default)> = [0.]
#                 filing_status<2023, (default)> = ['JOINT']
#                 taxable_income<2023, (default)> = [0.]
#                 dwks10<2023, (default)> = [0.]
#                 hasqdivltcg<2023, (default)> = [False]
#               unrecaptured_section_1250_gain<2023, (default)> = [0.]
#               sep<2023, (default)> = [1]
#               foreign_tax_credit<2023, (default)> = [0.]
#               amt_form_completed<2023, (default)> = [False]
#               foreign_tax_credit<2023, (default)> = [0.]
#               taxbc<2023, (default)> = [0.]
#                 regular_tax_before_credits<2023, (default)> = [0.]
#                   filing_status<2023, (default)> = ['JOINT']
#                   taxable_income<2023, (default)> = [0.]
#                   dwks14<2023, (default)> = [0.]
#                   dwks13<2023, (default)> = [0.]
#                   dwks19<2023, (default)> = [0.]
#                   dwks9<2023, (default)> = [0.]
#                   unrecaptured_section_1250_gain<2023, (default)> = [0.]
#                   dwks10<2023, (default)> = [0.]
#                   income_tax_main_rates<2023, (default)> = [0.]
#                   hasqdivltcg<2023, (default)> = [False]
#               c05700<2023, (default)> = [0.]
#         net_investment_income_tax<2023, (default)> = [0.]
#           taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#           dividend_income<2023, (default)> = [0. 0. 0. 0.]
#           c01000<2023, (default)> = [0.]
#           rental_income<2023, (default)> = [0. 0. 0. 0.]
#           filing_status<2023, (default)> = ['JOINT']
#           adjusted_gross_income<2023, (default)> = [25000.]
#         recapture_of_investment_credit<2023, (default)> = [0.]
#         unreported_payroll_tax<2023, (default)> = [0.]
#         qualified_retirement_penalty<2023, (default)> = [0.]
#         income_tax_capped_non_refundable_credits<2023, (default)> = [0.]
#           income_tax_non_refundable_credits<2023, (default)> = [800.]
#             cdcc<2023, (default)> = [0.]
#             elderly_disabled_credit<2023, (default)> = [0.]
#             non_refundable_ctc<2023, (default)> = [800.]
#               ctc<2023, (default)> = [4000.]
#               refundable_ctc<2023, (default)> = [3200.]
#             non_refundable_american_opportunity_credit<2023, (default)> = [0.]
#             lifetime_learning_credit<2023, (default)> = [0.]
#             retirement_savings_credit<2023, (default)> = [0.]
#             residential_clean_energy_credit<2023, (default)> = [0.]
#             energy_efficient_home_improvement_credit<2023, (default)> = [0.]
#             new_clean_vehicle_credit<2023, (default)> = [0.]
#             used_clean_vehicle_credit<2023, (default)> = [0.]
#           income_tax_unavailable_non_refundable_credits<2023, (default)> = [800.]
#             income_tax_before_credits<2023, (default)> = [0.]
#             income_tax_non_refundable_credits<2023, (default)> = [800.]
#             income_tax_non_refundable_credits<2023, (default)> = [800.]
#       ma_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         MA<2023, (default)> = [False]
#       md_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         MD<2023, (default)> = [False]
#       ny_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         NY<2023, (default)> = [False]
#       or_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         or_income_tax_before_credits<2023, (default)> = [0.]
#           OR<2023, (default)> = [False]
#         or_non_refundable_credits<2023, (default)> = [0.]
#           or_exemption_credit<2023, (default)> = [0.]
#             OR<2023, (default)> = [False]
#       pa_income_tax<2023, (default)> = [0.]
#       ut_income_tax_before_refundable_credits<2023, (default)> = [0.]
#       wa_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         WA<2023, (default)> = [False]
#       flat_tax<2023, (default)> = [0.]
#         positive_agi<2023, (default)> = [25000.]

# %% [markdown]
# #### 3.5.2. Effect of rate cut to 4.00% on middle income household

# %%
simulation_3_m = Simulation(
    reform=reform_3,
    situation=situation_mid,
)

simulation_3_m.trace = True
simulation_3_m.calculate("household_net_income", 2023)
simulation_3_m.tracer.print_computation_log()
# Out:
#   household_net_income<2023, (default)> = [70286.484]
#     household_market_income<2023, (default)> = [80000.]
#       employment_income<2023, (default)> = [45000. 35000.     0.     0.]
#       self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#       pension_income<2023, (default)> = [0. 0. 0. 0.]
#         tax_exempt_pension_income<2023, (default)> = [0. 0. 0. 0.]
#         taxable_pension_income<2023, (default)> = [0. 0. 0. 0.]
#       dividend_income<2023, (default)> = [0. 0. 0. 0.]
#         qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#         non_qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#       interest_income<2023, (default)> = [0. 0. 0. 0.]
#         tax_exempt_interest_income<2023, (default)> = [0. 0. 0. 0.]
#         taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#       gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#       capital_gains<2023, (default)> = [0. 0. 0. 0.]
#         short_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#         long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#       rental_income<2023, (default)> = [0. 0. 0. 0.]
#       illicit_income<2023, (default)> = [0. 0. 0. 0.]
#       farm_income<2023, (default)> = [0. 0. 0. 0.]
#     household_benefits<2023, (default)> = [0.]
#       social_security<2023, (default)> = [0. 0. 0. 0.]
#         social_security_dependents<2023, (default)> = [0. 0. 0. 0.]
#         social_security_disability<2023, (default)> = [0. 0. 0. 0.]
#         social_security_retirement<2023, (default)> = [0. 0. 0. 0.]
#         social_security_survivors<2023, (default)> = [0. 0. 0. 0.]
#       ssi<2023, (default)> = [0. 0. 0. 0.]
#         uncapped_ssi<2023, (default)> = [0. 0. 0. 0.]
#           ssi_amount_if_eligible<2023, (default)> = [16452. 10968. 10968. 10968.]
#             ssi_claim_is_joint<2023, (default)> = [ True False False False]
#               is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                 is_ssi_aged<2023, (default)> = [False False False False]
#                   age<2023, (default)> = [38. 35. 10. 10.]
#                 is_blind<2023, (default)> = [False False False False]
#                 is_ssi_disabled<2023, (default)> = [False False False False]
#                   is_ssi_aged<2023, (default)> = [False False False False]
#                   is_blind<2023, (default)> = [False False False False]
#                   ssi_reported<2023, (default)> = [0. 0. 0. 0.]
#               ssi_income_deemed_from_ineligible_spouse<2023, (default)> = [17500.     0.     0.     0.]
#                 ssi_earned_income<2023, (default)> = [45000. 35000.     0.     0.]
#                   employment_income<2023, (default)> = [45000. 35000.     0.     0.]
#                   self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                 ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#                   dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                   interest_income<2023, (default)> = [0. 0. 0. 0.]
#                   gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#                   social_security<2023, (default)> = [0. 0. 0. 0.]
#                   alimony_income<2023, (default)> = [0. 0. 0. 0.]
#                   pension_income<2023, (default)> = [0. 0. 0. 0.]
#                   unemployment_compensation<2023, (default)> = [0. 0. 0. 0.]
#                 ssi_earned_income_deemed_from_ineligible_spouse<2023, (default)> = [35000.     0.     0.     0.]
#                   is_ssi_ineligible_spouse<2023, (default)> = [False  True False False]
#                     is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                       is_child<2023, (default)> = [False False  True  True]
#                         age<2023, (default)> = [38. 35. 10. 10.]
#                       is_tax_unit_head<2023, (default)> = [ True False False False]
#                         is_child<2023, (default)> = [False False  True  True]
#                         age<2023, (default)> = [38. 35. 10. 10.]
#                       age<2023, (default)> = [38. 35. 10. 10.]
#                     is_ssi_eligible_spouse<2023, (default)> = [False False False False]
#                       is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                       is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                   ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#                   ssi_earned_income<2023, (default)> = [45000. 35000.     0.     0.]
#                   ssi_ineligible_child_allocation<2023, (default)> = [   0.    0. 5484. 5484.]
#                     ssi_earned_income<2023, (default)> = [45000. 35000.     0.     0.]
#                     ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#                     is_ssi_ineligible_child<2023, (default)> = [False False  True  True]
#                       is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                       is_child<2023, (default)> = [False False  True  True]
#                   is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                 ssi_unearned_income_deemed_from_ineligible_spouse<2023, (default)> = [0. 0. 0. 0.]
#                   is_ssi_ineligible_spouse<2023, (default)> = [False  True False False]
#                   ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#                   ssi_ineligible_child_allocation<2023, (default)> = [   0.    0. 5484. 5484.]
#                 is_ssi_ineligible_child<2023, (default)> = [False False  True  True]
#           meets_ssi_resource_test<2023, (default)> = [ True  True  True  True]
#             ssi_claim_is_joint<2023, (default)> = [ True False False False]
#             ssi_countable_resources<2023, (default)> = [0. 0. 0. 0.]
#           is_ssi_eligible_individual<2023, (default)> = [False False False False]
#             is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#             is_ssi_eligible_spouse<2023, (default)> = [False False False False]
#           ssi_countable_income<2023, (default)> = [0. 0. 0. 0.]
#             ssi_earned_income<2023, (default)> = [45000. 35000.     0.     0.]
#             ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#             ssi_unearned_income_deemed_from_ineligible_parent<2023, (default)> = [0. 0. 0. 0.]
#               is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#               is_child<2023, (default)> = [False False  True  True]
#               is_ssi_ineligible_parent<2023, (default)> = [False False False False]
#                 is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                 is_child<2023, (default)> = [False False  True  True]
#               ssi_earned_income<2023, (default)> = [45000. 35000.     0.     0.]
#               ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#               ssi_ineligible_child_allocation<2023, (default)> = [   0.    0. 5484. 5484.]
#               ssi_ineligible_parent_allocation<2023, (default)> = [0. 0. 0. 0.]
#                 is_ssi_ineligible_parent<2023, (default)> = [False False False False]
#             ssi_income_deemed_from_ineligible_spouse<2023, (default)> = [17500.     0.     0.     0.]
#             is_ssi_eligible_individual<2023, (default)> = [False False False False]
#       state_supplement<2023, (default)> = [0. 0. 0. 0.]
#         uncapped_ssi<2023, (default)> = [0. 0. 0. 0.]
#         maximum_state_supplement<2023, (default)> = [0. 0. 0. 0.]
#           is_ssi_eligible_individual<2023, (default)> = [False False False False]
#           state_code_str<2023, (default)> = ['UT']
#             state_code<2023, (default)> = ['UT']
#               state_name<2023, (default)> = ['UT']
#           state_living_arrangement<2023, (default)> = ['FULL_COST']
#           is_blind<2023, (default)> = [False False False False]
#           is_ssi_aged<2023, (default)> = [False False False False]
#           is_ssi_disabled<2023, (default)> = [False False False False]
#           ssi_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#           ssi_claim_is_joint<2023, (default)> = [ True False False False]
#         is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#         meets_ssi_resource_test<2023, (default)> = [ True  True  True  True]
#         ssi_claim_is_joint<2023, (default)> = [ True False False False]
#       ca_cvrp<2023, (default)> = [0. 0. 0. 0.]
#         CA<2023, (default)> = [False]
#           state_code_str<2023, (default)> = ['UT']
#       snap<2023, (default)> = [0.]
#         snap_normal_allotment<2023, (default)> = [0.]
#           is_snap_eligible<2023, (default)> = [False]
#             meets_snap_net_income_test<2023, (default)> = [False]
#               snap_net_income_fpg_ratio<2023, (default)> = [2.021]
#                 snap_net_income<2023, (default)> = [60630.]
#                   snap_gross_income<2023, (default)> = [80000.]
#                     snap_earned_income<2023, (default)> = [80000.]
#                       employment_income<2023, (default)> = [45000. 35000.     0.     0.]
#                       self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                     snap_unearned_income<2023, (default)> = [0.]
#                       dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                       interest_income<2023, (default)> = [0. 0. 0. 0.]
#                       gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#                       social_security<2023, (default)> = [0. 0. 0. 0.]
#                       ssi<2023, (default)> = [0. 0. 0. 0.]
#                   snap_deductions<2023, (default)> = [19370.]
#                     snap_standard_deduction<2023, (default)> = [2316.]
#                       state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#                         state_group<2023, (default)> = ['CONTIGUOUS_US']
#                           state_code<2023, (default)> = ['UT']
#                       spm_unit_size<2023, (default)> = [4]
#                     snap_earned_income_deduction<2023, (default)> = [16000.]
#                       snap_earned_income<2023, (default)> = [80000.]
#                     snap_dependent_care_deduction<2023, (default)> = [1000.]
#                       childcare_expenses<2023, (default)> = [1000.]
#                     snap_child_support_deduction<2023, (default)> = [0.]
#                       child_support_expense<2023, (default)> = [0. 0. 0. 0.]
#                       state_code_str<2023, (default)> = ['UT']
#                     snap_excess_medical_expense_deduction<2023, (default)> = [0.]
#                       is_usda_elderly<2023, (default)> = [False False False False]
#                         age<2023, (default)> = [38. 35. 10. 10.]
#                       is_usda_disabled<2023, (default)> = [False False False False]
#                         is_ssi_disabled<2023, (default)> = [False False False False]
#                         social_security_disability<2023, (default)> = [0. 0. 0. 0.]
#                         is_permanently_disabled_veteran<2023, (default)> = [False False False False]
#                         is_surviving_spouse_of_disabled_veteran<2023, (default)> = [False False False False]
#                         is_surviving_child_of_disabled_veteran<2023, (default)> = [False False False False]
#                       medical_out_of_pocket_expenses<2023, (default)> = [2000.    0.    0.    0.]
#                       state_code_str<2023, (default)> = ['UT']
#                     snap_excess_shelter_expense_deduction<2023, (default)> = [54.]
#                       snap_net_income_pre_shelter<2023, (default)> = [60684.]
#                         snap_gross_income<2023, (default)> = [80000.]
#                         snap_standard_deduction<2023, (default)> = [2316.]
#                         snap_earned_income_deduction<2023, (default)> = [16000.]
#                         snap_dependent_care_deduction<2023, (default)> = [1000.]
#                         snap_child_support_deduction<2023, (default)> = [0.]
#                         snap_excess_medical_expense_deduction<2023, (default)> = [0.]
#                       housing_cost<2023, (default)> = [20000.]
#                       snap_region_str<2023, (default)> = ['CONTIGUOUS_US']
#                         snap_region<2023, (default)> = ['CONTIGUOUS_US']
#                           state_group<2023, (default)> = ['CONTIGUOUS_US']
#                       has_usda_elderly_disabled<2023, (default)> = [False]
#                         is_usda_elderly<2023, (default)> = [False False False False]
#                         is_usda_disabled<2023, (default)> = [False False False False]
#                       snap_utility_allowance<2023, (default)> = [54.]
#                         snap_utility_allowance_type<2023, (default)> = ['IUA']
#                           count_distinct_utility_expenses<2023, (default)> = [1]
#                             heating_cooling_expense<2023, (default)> = [0.]
#                             electricity_expense<2023, (default)> = [0.]
#                             gas_expense<2023, (default)> = [0.]
#                             phone_expense<2023, (default)> = [1500.]
#                               phone_cost<2023, (default)> = [1500.]
#                             trash_expense<2023, (default)> = [0.]
#                             water_expense<2023, (default)> = [0.]
#                             sewage_expense<2023, (default)> = [0.]
#                           snap_utility_region_str<2023, (default)> = ['UT']
#                             snap_utility_region<2023, (default)> = ['UT']
#                               state_code<2023, (default)> = ['UT']
#                           has_heating_cooling_expense<2023, (default)> = [False]
#                             heating_cooling_expense<2023, (default)> = [0.]
#                         snap_utility_region_str<2023, (default)> = ['UT']
#                       state_code_str<2023, (default)> = ['UT']
#                       is_homeless<2023, (default)> = [False]
#                 spm_unit_fpg<2023, (default)> = [30000.]
#                   spm_unit_size<2023, (default)> = [4]
#                   state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#             meets_snap_gross_income_test<2023, (default)> = [False]
#               snap_gross_income_fpg_ratio<2023, (default)> = [2.6666667]
#                 snap_gross_income<2023, (default)> = [80000.]
#                 spm_unit_fpg<2023, (default)> = [30000.]
#               has_usda_elderly_disabled<2023, (default)> = [False]
#             meets_snap_asset_test<2023, (default)> = [ True]
#               has_usda_elderly_disabled<2023, (default)> = [False]
#               snap_assets<2023, (default)> = [0.]
#             meets_snap_categorical_eligibility<2023, (default)> = [False]
#               ssi<2023, (default)> = [0. 0. 0. 0.]
#               is_tanf_non_cash_eligible<2023, (default)> = [False]
#                 meets_tanf_non_cash_gross_income_test<2023, (default)> = [False]
#                   state_code_str<2023, (default)> = ['UT']
#                   snap_gross_income_fpg_ratio<2023, (default)> = [2.6666667]
#                 meets_tanf_non_cash_net_income_test<2023, (default)> = [ True]
#                   state_code_str<2023, (default)> = ['UT']
#                   is_tanf_non_cash_hheod<2023, (default)> = [False]
#                     state_code_str<2023, (default)> = ['UT']
#                     has_all_usda_elderly_disabled<2023, (default)> = [False]
#                       is_usda_elderly<2023, (default)> = [False False False False]
#                       is_usda_disabled<2023, (default)> = [False False False False]
#                     has_usda_elderly_disabled<2023, (default)> = [False]
#                   snap_net_income_fpg_ratio<2023, (default)> = [2.021]
#                 meets_tanf_non_cash_asset_test<2023, (default)> = [False]
#                   snap_assets<2023, (default)> = [0.]
#                   state_code_str<2023, (default)> = ['UT']
#           snap_expected_contribution<2023, (default)> = [18189.]
#             snap_net_income<2023, (default)> = [60630.]
#           snap_max_allotment<2023, (default)> = [11268.]
#             snap_region_str<2023, (default)> = ['CONTIGUOUS_US']
#             spm_unit_size<2023, (default)> = [4]
#             spm_unit_size<2023, (default)> = [4]
#           snap_min_allotment<2023, (default)> = [0.]
#             snap_region_str<2023, (default)> = ['CONTIGUOUS_US']
#             spm_unit_size<2023, (default)> = [4]
#         snap_emergency_allotment<2023, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-01, (default)> = [0.]
#             is_snap_eligible<2023, (default)> = [False]
#             snap_max_allotment<2023, (default)> = [11268.]
#             snap_normal_allotment<2023, (default)> = [0.]
#             state_code<2023, (default)> = ['UT']
#           snap_emergency_allotment_monthly<2023-02, (default)> = [0.]
#             is_snap_eligible<2023, (default)> = [False]
#             snap_max_allotment<2023, (default)> = [11268.]
#             snap_normal_allotment<2023, (default)> = [0.]
#             state_code<2023, (default)> = ['UT']
#           snap_emergency_allotment_monthly<2023-03, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-04, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-05, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-06, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-07, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-08, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-09, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-10, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-11, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-12, (default)> = [0.]
#       wic<2023, (default)> = [0. 0. 0. 0.]
#         meets_wic_income_test<2023, (default)> = [False]
#           school_meal_countable_income<2023, (default)> = [80000.]
#             employment_income<2023, (default)> = [45000. 35000.     0.     0.]
#             self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#             dividend_income<2023, (default)> = [0. 0. 0. 0.]
#             interest_income<2023, (default)> = [0. 0. 0. 0.]
#             gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#             social_security<2023, (default)> = [0. 0. 0. 0.]
#             ssi<2023, (default)> = [0. 0. 0. 0.]
#           wic_fpg<2023, (default)> = [30000.]
#             is_pregnant<2023, (default)> = [False False False False]
#             spm_unit_fpg<2023, (default)> = [30000.]
#             state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#         meets_wic_categorical_eligibility<2023, (default)> = [False False False False]
#           snap<2023, (default)> = [0.]
#           tanf<2023, (default)> = [0.]
#             tanf_reported<2023, (default)> = [0. 0. 0. 0.]
#             is_tanf_eligible<2023, (default)> = [False]
#               is_person_demographic_tanf_eligible<2023, (default)> = [False False  True  True]
#                 is_child<2023, (default)> = [False False  True  True]
#                 age<2023, (default)> = [38. 35. 10. 10.]
#                 is_full_time_student<2023, (default)> = [False False  True  True]
#                   is_full_time_college_student<2023, (default)> = [False False False False]
#                   is_in_k12_school<2023, (default)> = [False False  True  True]
#                     age<2023, (default)> = [38. 35. 10. 10.]
#                 is_pregnant<2023, (default)> = [False False False False]
#               is_tanf_enrolled<2023, (default)> = [False]
#               is_tanf_continuous_eligible<2023, (default)> = [False]
#                 tanf_gross_earned_income<2023, (default)> = [80000.]
#                   employment_income<2023, (default)> = [45000. 35000.     0.     0.]
#                   self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                 tanf_gross_unearned_income<2023, (default)> = [0.]
#                   dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                   interest_income<2023, (default)> = [0. 0. 0. 0.]
#                   gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#                   social_security<2023, (default)> = [0. 0. 0. 0.]
#                   ssi<2023, (default)> = [0. 0. 0. 0.]
#                 tanf_max_amount<2023, (default)> = [0.]
#                   spm_unit_size<2023, (default)> = [4]
#                   state_code_str<2023, (default)> = ['UT']
#               is_tanf_initial_eligible<2023, (default)> = [False]
#                 tanf_initial_employment_deduction<2023, (default)> = [0.]
#                   spm_unit_size<2023, (default)> = [4]
#                   state_code_str<2023, (default)> = ['UT']
#                   market_income<2023, (default)> = [45000. 35000.     0.     0.]
#                     employment_income<2023, (default)> = [45000. 35000.     0.     0.]
#                     self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                     pension_income<2023, (default)> = [0. 0. 0. 0.]
#                     dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                     interest_income<2023, (default)> = [0. 0. 0. 0.]
#                     gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#                     capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                     rental_income<2023, (default)> = [0. 0. 0. 0.]
#                     illicit_income<2023, (default)> = [0. 0. 0. 0.]
#                     farm_income<2023, (default)> = [0. 0. 0. 0.]
#                 tanf_gross_earned_income<2023, (default)> = [80000.]
#                 tanf_gross_unearned_income<2023, (default)> = [0.]
#                 tanf_max_amount<2023, (default)> = [0.]
#             tanf_amount_if_eligible<2023, (default)> = [0.]
#               tanf_max_amount<2023, (default)> = [0.]
#               tanf_countable_income<2023, (default)> = [80000.]
#                 state_code_str<2023, (default)> = ['UT']
#                 tanf_gross_unearned_income<2023, (default)> = [0.]
#                 tanf_gross_earned_income<2023, (default)> = [80000.]
#           medicaid<2023, (default)> = [0. 0. 0. 0.]
#             is_medicaid_eligible<2023, (default)> = [False False False False]
#               medicaid_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#                 is_infant_for_medicaid<2023, (default)> = [False False False False]
#                   is_infant_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [2.6666667 2.6666667 2.6666667 2.6666667]
#                       tax_unit_medicaid_income_level<2023, (default)> = [2.6666667]
#                         medicaid_income<2023, (default)> = [80000.]
#                           adjusted_gross_income<2023, (default)> = [80000.]
#                             irs_gross_income<2023, (default)> = [45000. 35000.     0.     0.]
#                               is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                               employment_income<2023, (default)> = [45000. 35000.     0.     0.]
#                               self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                               partnership_s_corp_income<2023, (default)> = [0. 0. 0. 0.]
#                               farm_income<2023, (default)> = [0. 0. 0. 0.]
#                               farm_rent_income<2023, (default)> = [0. 0. 0. 0.]
#                               capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                               taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#                               rental_income<2023, (default)> = [0. 0. 0. 0.]
#                               dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                               taxable_pension_income<2023, (default)> = [0. 0. 0. 0.]
#                               debt_relief<2023, (default)> = [0. 0. 0. 0.]
#                               taxable_unemployment_compensation<2023, (default)> = [0. 0. 0. 0.]
#                                 is_tax_unit_head<2023, (default)> = [ True False False False]
#                                 tax_unit_taxable_unemployment_compensation<2023, (default)> = [0.]
#                                   tax_unit_unemployment_compensation<2023, (default)> = [0.]
#                                     unemployment_compensation<2023, (default)> = [0. 0. 0. 0.]
#                                   taxable_uc_agi<2023, (default)> = [80000.]
#                                     is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                                     employment_income<2023, (default)> = [45000. 35000.     0.     0.]
#                                     self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                     partnership_s_corp_income<2023, (default)> = [0. 0. 0. 0.]
#                                     farm_income<2023, (default)> = [0. 0. 0. 0.]
#                                     farm_rent_income<2023, (default)> = [0. 0. 0. 0.]
#                                     capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                                     taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#                                     rental_income<2023, (default)> = [0. 0. 0. 0.]
#                                     dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                                     taxable_pension_income<2023, (default)> = [0. 0. 0. 0.]
#                                     debt_relief<2023, (default)> = [0. 0. 0. 0.]
#                                     taxable_social_security<2023, (default)> = [0. 0. 0. 0.]
#                                       tax_unit_taxable_social_security<2023, (default)> = [0.]
#                                         tax_unit_social_security<2023, (default)> = [0.]
#                                           social_security<2023, (default)> = [0. 0. 0. 0.]
#                                         taxable_ss_magi<2023, (default)> = [80000.]
#                                           is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                                           employment_income<2023, (default)> = [45000. 35000.     0.     0.]
#                                           self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                           partnership_s_corp_income<2023, (default)> = [0. 0. 0. 0.]
#                                           farm_income<2023, (default)> = [0. 0. 0. 0.]
#                                           farm_rent_income<2023, (default)> = [0. 0. 0. 0.]
#                                           capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                                           taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#                                           rental_income<2023, (default)> = [0. 0. 0. 0.]
#                                           dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                                           taxable_pension_income<2023, (default)> = [0. 0. 0. 0.]
#                                           debt_relief<2023, (default)> = [0. 0. 0. 0.]
#                                           illicit_income<2023, (default)> = [0. 0. 0. 0.]
#                                           unemployment_compensation<2023, (default)> = [0. 0. 0. 0.]
#                                           tax_exempt_interest_income<2023, (default)> = [0. 0. 0. 0.]
#                                           loss_ald<2023, (default)> = [0.]
#                                             filing_status<2023, (default)> = ['JOINT']
#                                               is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                                               tax_unit_dependents<2023, (default)> = [2]
#                                                 is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                                             self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                             maximum_capital_loss<2023, (default)> = [0.]
#                                               tax_unit_capital_loss<2023, (default)> = [0.]
#                                                 capital_loss<2023, (default)> = [0. 0. 0. 0.]
#                                                   capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                                               filing_status<2023, (default)> = ['JOINT']
#                                           self_employment_tax_ald<2023, (default)> = [0.]
#                                             self_employment_tax_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employment_tax<2023, (default)> = [0. 0. 0. 0.]
#                                                 self_employment_social_security_tax<2023, (default)> = [0. 0. 0. 0.]
#                                                   social_security_taxable_self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                                     taxable_self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                                       sey<2023, (default)> = [0. 0. 0. 0.]
#                                                         self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                                         farm_income<2023, (default)> = [0. 0. 0. 0.]
#                                                         k1bx14<2023, (default)> = [0. 0. 0. 0.]
#                                                     taxable_earnings_for_social_security<2023, (default)> = [45000. 35000.     0.     0.]
#                                                       payroll_tax_gross_wages<2023, (default)> = [45000. 35000.     0.     0.]
#                                                         employment_income<2023, (default)> = [45000. 35000.     0.     0.]
#                                                 self_employment_medicare_tax<2023, (default)> = [0. 0. 0. 0.]
#                                                   taxable_self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                           early_withdrawal_penalty<2023, (default)> = [0. 0. 0. 0.]
#                                           alimony_income<2023, (default)> = [0. 0. 0. 0.]
#                                           educator_expense<2023, (default)> = [0. 0. 0. 0.]
#                                           health_savings_account_ald<2023, (default)> = [0.]
#                                           self_employed_health_insurance_ald<2023, (default)> = [0.]
#                                             self_employed_health_insurance_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employed_health_insurance_premiums<2023, (default)> = [0. 0. 0. 0.]
#                                                 is_self_employed<2023, (default)> = [False False False False]
#                                                 health_insurance_premiums<2023, (default)> = [0. 0. 0. 0.]
#                                           self_employed_pension_contribution_ald<2023, (default)> = [0.]
#                                             self_employed_pension_contribution_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employed_pension_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                           ira_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                           sep_simple_qualified_plan_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                         filing_status<2023, (default)> = ['JOINT']
#                                       tax_unit_social_security<2023, (default)> = [0.]
#                                       social_security<2023, (default)> = [0. 0. 0. 0.]
#                                       is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                                       is_tax_unit_head<2023, (default)> = [ True False False False]
#                                     illicit_income<2023, (default)> = [0. 0. 0. 0.]
#                                     loss_ald<2023, (default)> = [0.]
#                                     self_employment_tax_ald<2023, (default)> = [0.]
#                                     student_loan_interest<2023, (default)> = [0. 0. 0. 0.]
#                                     early_withdrawal_penalty<2023, (default)> = [0. 0. 0. 0.]
#                                     alimony_income<2023, (default)> = [0. 0. 0. 0.]
#                                     educator_expense<2023, (default)> = [0. 0. 0. 0.]
#                                     health_savings_account_ald<2023, (default)> = [0.]
#                                     self_employed_health_insurance_ald<2023, (default)> = [0.]
#                                     self_employed_pension_contribution_ald<2023, (default)> = [0.]
#                                     ira_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                     sep_simple_qualified_plan_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                     qualified_adoption_assistance_expense<2023, (default)> = [0. 0. 0. 0.]
#                                     us_bonds_for_higher_ed<2023, (default)> = [0. 0. 0. 0.]
#                                     specified_possession_income<2023, (default)> = [0.]
#                                     puerto_rico_income<2023, (default)> = [0.]
#                                   filing_status<2023, (default)> = ['JOINT']
#                               taxable_social_security<2023, (default)> = [0. 0. 0. 0.]
#                               illicit_income<2023, (default)> = [0. 0. 0. 0.]
#                             above_the_line_deductions<2023, (default)> = [0.]
#                               loss_ald<2023, (default)> = [0.]
#                               self_employment_tax_ald<2023, (default)> = [0.]
#                               student_loan_interest<2023, (default)> = [0. 0. 0. 0.]
#                               early_withdrawal_penalty<2023, (default)> = [0. 0. 0. 0.]
#                               alimony_income<2023, (default)> = [0. 0. 0. 0.]
#                               educator_expense<2023, (default)> = [0. 0. 0. 0.]
#                               health_savings_account_ald<2023, (default)> = [0.]
#                               self_employed_health_insurance_ald<2023, (default)> = [0.]
#                               self_employed_pension_contribution_ald<2023, (default)> = [0.]
#                               ira_contributions<2023, (default)> = [0. 0. 0. 0.]
#                               sep_simple_qualified_plan_contributions<2023, (default)> = [0. 0. 0. 0.]
#                               qualified_adoption_assistance_expense<2023, (default)> = [0. 0. 0. 0.]
#                               us_bonds_for_higher_ed<2023, (default)> = [0. 0. 0. 0.]
#                               specified_possession_income<2023, (default)> = [0.]
#                               puerto_rico_income<2023, (default)> = [0.]
#                           foreign_earned_income_exclusion<2023, (default)> = [0.]
#                           student_loan_interest<2023, (default)> = [0. 0. 0. 0.]
#                           tax_exempt_social_security<2023, (default)> = [0.]
#                             tax_unit_social_security<2023, (default)> = [0.]
#                             tax_unit_taxable_social_security<2023, (default)> = [0.]
#                         tax_unit_fpg<2023, (default)> = [30000.]
#                           tax_unit_size<2023, (default)> = [4]
#                           state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#                     state_code_str<2023, (default)> = ['UT']
#                   is_infant_for_medicaid_nfc<2023, (default)> = [False False False False]
#                     age<2023, (default)> = [38. 35. 10. 10.]
#                 is_young_child_for_medicaid<2023, (default)> = [False False False False]
#                   is_young_child_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [2.6666667 2.6666667 2.6666667 2.6666667]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_young_child_for_medicaid_nfc<2023, (default)> = [False False False False]
#                     age<2023, (default)> = [38. 35. 10. 10.]
#                 is_older_child_for_medicaid<2023, (default)> = [False False False False]
#                   age<2023, (default)> = [38. 35. 10. 10.]
#                   medicaid_income_level<2023, (default)> = [2.6666667 2.6666667 2.6666667 2.6666667]
#                   state_code_str<2023, (default)> = ['UT']
#                 is_young_adult_for_medicaid<2023, (default)> = [False False False False]
#                   is_young_adult_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [2.6666667 2.6666667 2.6666667 2.6666667]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_young_adult_for_medicaid_nfc<2023, (default)> = [False False False False]
#                     age<2023, (default)> = [38. 35. 10. 10.]
#                 is_adult_for_medicaid<2023, (default)> = [False False False False]
#                   is_adult_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [2.6666667 2.6666667 2.6666667 2.6666667]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_adult_for_medicaid_nfc<2023, (default)> = [ True  True False False]
#                     age<2023, (default)> = [38. 35. 10. 10.]
#                 is_parent_for_medicaid<2023, (default)> = [False False False False]
#                   is_parent_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [2.6666667 2.6666667 2.6666667 2.6666667]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_parent_for_medicaid_nfc<2023, (default)> = [ True  True False False]
#                     is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                     tax_unit_count_dependents<2023, (default)> = [2]
#                       is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                 is_pregnant_for_medicaid<2023, (default)> = [False False False False]
#                   is_pregnant_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [2.6666667 2.6666667 2.6666667 2.6666667]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_pregnant_for_medicaid_nfc<2023, (default)> = [False False False False]
#                     is_pregnant<2023, (default)> = [False False False False]
#                     count_days_postpartum<2023, (default)> = [inf inf inf inf]
#                       under_60_days_postpartum<2023, (default)> = [False False False False]
#                       under_12_months_postpartum<2023, (default)> = [False False False False]
#                     state_code_str<2023, (default)> = ['UT']
#                 is_ssi_recipient_for_medicaid<2023, (default)> = [False False False False]
#                   state_code_str<2023, (default)> = ['UT']
#                   ssi<2023, (default)> = [0. 0. 0. 0.]
#             medicaid_benefit_value<2023, (default)> = [9966.585 9966.585 9966.585 9966.585]
#               state_code_str<2023, (default)> = ['UT']
#           is_pregnant<2023, (default)> = [False False False False]
#           wic_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#             is_pregnant<2023, (default)> = [False False False False]
#             is_mother<2023, (default)> = [False False False False]
#               is_female<2023, (default)> = [False False False False]
#               own_children_in_household<2023, (default)> = [0 0 0 0]
#               is_breastfeeding<2023, (default)> = [False False False False]
#             is_breastfeeding<2023, (default)> = [False False False False]
#             age<2023, (default)> = [38. 35. 10. 10.]
#         wic_category_str<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#           wic_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#         is_wic_at_nutritional_risk<2023, (default)> = [False False False False]
#           receives_wic<2023, (default)> = [False False False False]
#           meets_wic_income_test<2023, (default)> = [False]
#           meets_wic_categorical_eligibility<2023, (default)> = [False False False False]
#           wic_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#         would_claim_wic<2023, (default)> = [ True  True  True  True]
#       free_school_meals<2023, (default)> = [0.]
#         school_meal_tier<2023, (default)> = ['PAID']
#           school_meal_fpg_ratio<2023, (default)> = [2.6666667]
#             school_meal_countable_income<2023, (default)> = [80000.]
#             spm_unit_fpg<2023, (default)> = [30000.]
#           meets_school_meal_categorical_eligibility<2023, (default)> = [False]
#             snap<2023, (default)> = [0.]
#             tanf<2023, (default)> = [0.]
#             fdpir<2023, (default)> = [0.]
#         school_meal_net_subsidy<2023, (default)> = [0.]
#           school_meal_daily_subsidy<2023, (default)> = [0.72]
#             state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#             school_meal_tier<2023, (default)> = ['PAID']
#           school_meal_paid_daily_subsidy<2023, (default)> = [0.72]
#             state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#           is_in_k12_school<2023, (default)> = [False False  True  True]
#       reduced_price_school_meals<2023, (default)> = [0.]
#         school_meal_tier<2023, (default)> = ['PAID']
#         school_meal_net_subsidy<2023, (default)> = [0.]
#       lifeline<2023, (default)> = [0.]
#         is_rural<2023, (default)> = [False]
#         is_on_tribal_land<2023, (default)> = [False]
#         phone_cost<2023, (default)> = [1500.]
#         broadband_cost<2023, (default)> = [900.]
#         is_lifeline_eligible<2023, (default)> = [False]
#           medicaid<2023, (default)> = [0. 0. 0. 0.]
#           snap<2023, (default)> = [0.]
#           ssi<2023, (default)> = [0. 0. 0. 0.]
#           fcc_fpg_ratio<2023, (default)> = [2.6666667]
#             irs_gross_income<2023, (default)> = [45000. 35000.     0.     0.]
#             spm_unit_fpg<2023, (default)> = [30000.]
#       acp<2023, (default)> = [0.]
#         is_acp_eligible<2023, (default)> = [False]
#           lifeline<2023, (default)> = [0.]
#           free_school_meals<2023, (default)> = [0.]
#           reduced_price_school_meals<2023, (default)> = [0.]
#           pell_grant<2023, (default)> = [0.]
#           wic<2023, (default)> = [0. 0. 0. 0.]
#           medicaid<2023, (default)> = [0. 0. 0. 0.]
#           snap<2023, (default)> = [0.]
#           ssi<2023, (default)> = [0. 0. 0. 0.]
#           fcc_fpg_ratio<2023, (default)> = [2.6666667]
#           ebb<2023, (default)> = [0.]
#             is_ebb_eligible<2023, (default)> = [False]
#               is_lifeline_eligible<2023, (default)> = [False]
#               free_school_meals<2023, (default)> = [0.]
#               reduced_price_school_meals<2023, (default)> = [0.]
#               pell_grant<2023, (default)> = [0.]
#               experienced_covid_income_loss<2023, (default)> = [False]
#               enrolled_in_ebb<2023, (default)> = [False]
#             broadband_cost_after_lifeline<2023, (default)> = [900.]
#               broadband_cost<2023, (default)> = [900.]
#               lifeline<2023, (default)> = [0.]
#             is_on_tribal_land<2023, (default)> = [False]
#         broadband_cost_after_lifeline<2023, (default)> = [900.]
#         is_on_tribal_land<2023, (default)> = [False]
#       ebb<2023, (default)> = [0.]
#       tanf<2023, (default)> = [0.]
#       high_efficiency_electric_home_rebate<2023, (default)> = [0.]
#         capped_electric_heat_pump_clothes_dryer_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#             tax_unit_income_ami_ratio<2023, (default)> = [0.]
#           electric_heat_pump_clothes_dryer_expenditures<2023, (default)> = [0.]
#         capped_electric_load_service_center_upgrade_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           electric_load_service_center_upgrade_expenditures<2023, (default)> = [0.]
#         capped_electric_stove_cooktop_range_or_oven_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           electric_stove_cooktop_range_or_oven_expenditures<2023, (default)> = [0.]
#         capped_electric_wiring_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           electric_wiring_expenditures<2023, (default)> = [0.]
#         capped_heat_pump_water_heater_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           heat_pump_water_heater_expenditures<2023, (default)> = [0.]
#         capped_heat_pump_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           heat_pump_expenditures<2023, (default)> = [0.]
#         capped_insulation_air_sealing_ventilation_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           energy_efficient_insulation_expenditures<2023, (default)> = [0.]
#           air_sealing_ventilation_expenditures<2023, (default)> = [0.]
#       residential_efficiency_electrification_rebate<2023, (default)> = [0.]
#         residential_efficiency_electrification_retrofit_expenditures<2023, (default)> = [0.]
#         residential_efficiency_electrification_retrofit_energy_savings<2023, (default)> = [0.]
#         current_home_energy_use<2023, (default)> = [0.]
#         household_income_ami_ratio<2023, (default)> = [0.]
#         average_home_energy_use_in_state<2023, (default)> = [0.]
#       basic_income<2023, (default)> = [0.]
#         basic_income_eligible<2023, (default)> = [ True]
#         basic_income_before_phase_out<2023, (default)> = [0.]
#           tax_unit_size<2023, (default)> = [4]
#           age<2023, (default)> = [38. 35. 10. 10.]
#           tax_unit_fpg<2023, (default)> = [30000.]
#         basic_income_phase_out<2023, (default)> = [0.]
#           basic_income_before_phase_out<2023, (default)> = [0.]
#           adjusted_gross_income<2023, (default)> = [80000.]
#           filing_status<2023, (default)> = ['JOINT']
#       spm_unit_capped_housing_subsidy<2023, (default)> = [0.]
#         spm_unit_capped_housing_subsidy_reported<2023, (default)> = [0.]
#     household_refundable_tax_credits<2023, (default)> = [0.]
#       income_tax_refundable_credits<2023, (default)> = [0.]
#         eitc<2023, (default)> = [0.]
#           earned_income_tax_credit<2023, (default)> = [0.]
#             eitc_eligible<2023, (default)> = [ True]
#               is_child<2023, (default)> = [False False  True  True]
#               age<2023, (default)> = [38. 35. 10. 10.]
#               tax_exempt_interest_income<2023, (default)> = [0. 0. 0. 0.]
#               taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#               dividend_income<2023, (default)> = [0. 0. 0. 0.]
#               c01000<2023, (default)> = [0.]
#                 sep<2023, (default)> = [1]
#                 c23650<2023, (default)> = [0.]
#                   long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   short_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#               tax_unit_rental_income<2023, (default)> = [0.]
#                 rental_income<2023, (default)> = [0. 0. 0. 0.]
#               tax_unit_partnership_s_corp_income<2023, (default)> = [0.]
# ...
#                         blind_head<2023, (default)> = [False]
#                           is_blind<2023, (default)> = [False False False False]
#                           is_tax_unit_head<2023, (default)> = [ True False False False]
#                         blind_spouse<2023, (default)> = [False]
#                           is_blind<2023, (default)> = [False False False False]
#                           is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                         age_head<2023, (default)> = [38]
#                         age_spouse<2023, (default)> = [35]
#                 taxable_income_deductions_if_itemizing<2023, (default)> = [7957.5117]
#                   charitable_deduction<2023, (default)> = [6000.]
#                   interest_deduction<2023, (default)> = [0.]
#                   salt_deduction<2023, (default)> = [1957.512]
#                     state_and_local_sales_or_income_tax<2023, (default)> = [1957.512]
#                       state_income_tax<2023, (default)> = [1957.512]
#                         ma_income_tax<2023, (default)> = [0.]
#                           MA<2023, (default)> = [False]
#                         md_income_tax<2023, (default)> = [0.]
#                           MD<2023, (default)> = [False]
#                         ny_income_tax<2023, (default)> = [0.]
#                           NY<2023, (default)> = [False]
#                         or_income_tax<2023, (default)> = [0.]
#                           OR<2023, (default)> = [False]
#                         pa_income_tax<2023, (default)> = [0.]
#                           PA<2023, (default)> = [False]
#                             state_code_str<2023, (default)> = ['UT']
#                         wa_income_tax<2023, (default)> = [0.]
#                           WA<2023, (default)> = [False]
#                         ut_income_tax<2023, (default)> = [1957.512]
#                           UT<2023, (default)> = [ True]
#                           ut_income_tax_before_refundable_credits<2023, (default)> = [1957.512]
#                             ut_income_tax_after_credits<2023, (default)> = [1957.512]
#                               ut_income_tax_before_credits<2023, (default)> = [3200.]
#                                 UT<2023, (default)> = [ True]
#                                 ut_taxable_income<2023, (default)> = [80000.]
#                                   UT<2023, (default)> = [ True]
#                                   ut_total_income<2023, (default)> = [80000.]
#                                     UT<2023, (default)> = [ True]
#                                     adjusted_gross_income<2023, (default)> = [80000.]
#                                     ut_additions_to_income<2023, (default)> = [0.]
#                                       UT<2023, (default)> = [ True]
#                                   salt_refund_last_year<2023, (default)> = [0.]
#                                   ut_subtractions_from_income<2023, (default)> = [0.]
#                                     UT<2023, (default)> = [ True]
#                               ut_taxpayer_credit<2023, (default)> = [1242.488]
#                                 UT<2023, (default)> = [ True]
#                                 ut_taxpayer_credit_max<2023, (default)> = [1878.24]
#                                   UT<2023, (default)> = [ True]
#                                   tax_unit_count_dependents<2023, (default)> = [2]
#                                   tax_unit_itemizes<2023, (default)> = [False]
#                                   standard_deduction<2023, (default)> = [27700.]
#                                   charitable_deduction<2023, (default)> = [6000.]
#                                   interest_deduction<2023, (default)> = [0.]
#                                   medical_expense_deduction<2023, (default)> = [0.]
#                                   casualty_loss_deduction<2023, (default)> = [0.]
#                                 ut_taxpayer_credit_reduction<2023, (default)> = [635.752]
#                                   UT<2023, (default)> = [ True]
#                                   filing_status<2023, (default)> = ['JOINT']
#                                   ut_taxable_income<2023, (default)> = [80000.]
#                             ut_apportionable_nonrefundable_credits<2023, (default)> = [0.]
#                               UT<2023, (default)> = [ True]
#                             ut_nonapportionable_nonrefundable_credits<2023, (default)> = [0.]
#                               UT<2023, (default)> = [ True]
#                             ut_recapture_low_inc_housing_credit<2023, (default)> = [0.]
#                               UT<2023, (default)> = [ True]
#                           ut_refundable_credits<2023, (default)> = [0.]
#                       local_income_tax<2023, (default)> = [0.]
#                       state_sales_tax<2023, (default)> = [0.]
#                       local_sales_tax<2023, (default)> = [0.]
#                     real_estate_taxes<2023, (default)> = [0. 0. 0. 0.]
#                     filing_status<2023, (default)> = ['JOINT']
#                   medical_expense_deduction<2023, (default)> = [0.]
#                   casualty_loss_deduction<2023, (default)> = [0.]
#                   qualified_business_income_deduction<2023, (default)> = [0.]
#                     qbid_amount<2023, (default)> = [0. 0. 0. 0.]
#                       qualified_business_income<2023, (default)> = [0. 0. 0. 0.]
#                         self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                         partnership_s_corp_income<2023, (default)> = [0. 0. 0. 0.]
#                         farm_income<2023, (default)> = [0. 0. 0. 0.]
#                         farm_rent_income<2023, (default)> = [0. 0. 0. 0.]
#                         self_employment_tax_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                         self_employed_health_insurance_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                         self_employed_pension_contribution_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                         business_is_qualified<2023, (default)> = [False False False False]
#                       w2_wages_from_qualified_business<2023, (default)> = [0. 0. 0. 0.]
#                       unadjusted_basis_qualified_property<2023, (default)> = [0. 0. 0. 0.]
#                       taxable_income_less_qbid<2023, (default)> = [52300.]
#                         adjusted_gross_income<2023, (default)> = [80000.]
#                         charitable_deduction<2023, (default)> = [6000.]
#                         interest_deduction<2023, (default)> = [0.]
#                         salt_deduction<2023, (default)> = [1957.512]
#                         medical_expense_deduction<2023, (default)> = [0.]
#                         casualty_loss_deduction<2023, (default)> = [0.]
#                         standard_deduction<2023, (default)> = [27700.]
#                       filing_status<2023, (default)> = ['JOINT']
#                       business_is_sstb<2023, (default)> = [False False False False]
#                     taxable_income_less_qbid<2023, (default)> = [52300.]
#                     adjusted_net_capital_gain<2023, (default)> = [0.]
#                       net_capital_gain<2023, (default)> = [0.]
#                         net_long_term_capital_gain<2023, (default)> = [0.]
#                           long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                           long_term_capital_losses<2023, (default)> = [0. 0. 0. 0.]
#                         net_short_term_capital_loss<2023, (default)> = [0.]
#                           short_term_capital_losses<2023, (default)> = [0. 0. 0. 0.]
#                           short_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                         qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                       qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                       unrecaptured_section_1250_gain<2023, (default)> = [0.]
#                       capital_gains_28_percent_rate_gain<2023, (default)> = [0.]
#                         long_term_capital_gains_on_collectibles<2023, (default)> = [0. 0. 0. 0.]
#                         long_term_capital_gains_on_small_business_stock<2023, (default)> = [0. 0. 0. 0.]
#                 taxable_income_deductions_if_not_itemizing<2023, (default)> = [27700.]
#                   standard_deduction<2023, (default)> = [27700.]
#                   qualified_business_income_deduction<2023, (default)> = [0.]
#             capital_gains_excluded_from_taxable_income<2023, (default)> = [0.]
#               net_capital_gain<2023, (default)> = [0.]
#               adjusted_net_capital_gain<2023, (default)> = [0.]
#               taxable_income<2023, (default)> = [52300.]
#               filing_status<2023, (default)> = ['JOINT']
#             filing_status<2023, (default)> = ['JOINT']
#           capital_gains_tax<2023, (default)> = [0.]
#             net_capital_gain<2023, (default)> = [0.]
#             taxable_income<2023, (default)> = [52300.]
#             adjusted_net_capital_gain<2023, (default)> = [0.]
#             capital_gains_excluded_from_taxable_income<2023, (default)> = [0.]
#             filing_status<2023, (default)> = ['JOINT']
#             unrecaptured_section_1250_gain<2023, (default)> = [0.]
#             qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#             capital_gains_28_percent_rate_gain<2023, (default)> = [0.]
#           alternative_minimum_tax<2023, (default)> = [0.]
#             c09600<2023, (default)> = [0.]
#               c62100<2023, (default)> = [80000.]
#                 amt_income<2023, (default)> = [80000.]
#                   taxable_income<2023, (default)> = [52300.]
#                   tax_unit_itemizes<2023, (default)> = [False]
#                   standard_deduction<2023, (default)> = [27700.]
#                   salt_deduction<2023, (default)> = [1957.512]
#                   filing_status<2023, (default)> = ['JOINT']
#               filing_status<2023, (default)> = ['JOINT']
#               age_head<2023, (default)> = [38]
#               age_spouse<2023, (default)> = [35]
#               filer_earned<2023, (default)> = [80000.]
#               sep<2023, (default)> = [1]
#               dwks10<2023, (default)> = [0.]
#                 dwks6<2023, (default)> = [0.]
#                   qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                   investment_income_form_4952<2023, (default)> = [0.]
#                 dwks9<2023, (default)> = [0.]
#                   long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                   c23650<2023, (default)> = [0.]
#                   non_sch_d_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   investment_income_form_4952<2023, (default)> = [0.]
#                 long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                 qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                 c23650<2023, (default)> = [0.]
#                 non_sch_d_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                 hasqdivltcg<2023, (default)> = [False]
#                   c01000<2023, (default)> = [0.]
#                   c23650<2023, (default)> = [0.]
#                   long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   non_sch_d_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#               dwks13<2023, (default)> = [0.]
#                 unrecaptured_section_1250_gain<2023, (default)> = [0.]
#                 capital_gains_28_percent_rate_gain<2023, (default)> = [0.]
#                 dwks9<2023, (default)> = [0.]
#                 dwks10<2023, (default)> = [0.]
#                 hasqdivltcg<2023, (default)> = [False]
#               dwks14<2023, (default)> = [0.]
#                 taxable_income<2023, (default)> = [52300.]
#                 dwks13<2023, (default)> = [0.]
#                 hasqdivltcg<2023, (default)> = [False]
#               dwks19<2023, (default)> = [0.]
#                 dwks14<2023, (default)> = [0.]
#                 filing_status<2023, (default)> = ['JOINT']
#                 taxable_income<2023, (default)> = [52300.]
#                 dwks10<2023, (default)> = [0.]
#                 hasqdivltcg<2023, (default)> = [False]
#               unrecaptured_section_1250_gain<2023, (default)> = [0.]
#               sep<2023, (default)> = [1]
#               foreign_tax_credit<2023, (default)> = [0.]
#               amt_form_completed<2023, (default)> = [False]
#               foreign_tax_credit<2023, (default)> = [0.]
#               taxbc<2023, (default)> = [5836.]
#                 regular_tax_before_credits<2023, (default)> = [5836.]
#                   filing_status<2023, (default)> = ['JOINT']
#                   taxable_income<2023, (default)> = [52300.]
#                   dwks14<2023, (default)> = [0.]
#                   dwks13<2023, (default)> = [0.]
#                   dwks19<2023, (default)> = [0.]
#                   dwks9<2023, (default)> = [0.]
#                   unrecaptured_section_1250_gain<2023, (default)> = [0.]
#                   dwks10<2023, (default)> = [0.]
#                   income_tax_main_rates<2023, (default)> = [5836.]
#                   hasqdivltcg<2023, (default)> = [False]
#               c05700<2023, (default)> = [0.]
#         net_investment_income_tax<2023, (default)> = [0.]
#           taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#           dividend_income<2023, (default)> = [0. 0. 0. 0.]
#           c01000<2023, (default)> = [0.]
#           rental_income<2023, (default)> = [0. 0. 0. 0.]
#           filing_status<2023, (default)> = ['JOINT']
#           adjusted_gross_income<2023, (default)> = [80000.]
#         recapture_of_investment_credit<2023, (default)> = [0.]
#         unreported_payroll_tax<2023, (default)> = [0.]
#         qualified_retirement_penalty<2023, (default)> = [0.]
#         income_tax_capped_non_refundable_credits<2023, (default)> = [4200.]
#           income_tax_non_refundable_credits<2023, (default)> = [4200.]
#             cdcc<2023, (default)> = [200.]
#             elderly_disabled_credit<2023, (default)> = [0.]
#             non_refundable_ctc<2023, (default)> = [4000.]
#               ctc<2023, (default)> = [4000.]
#               refundable_ctc<2023, (default)> = [0.]
#             non_refundable_american_opportunity_credit<2023, (default)> = [0.]
#             lifetime_learning_credit<2023, (default)> = [0.]
#             retirement_savings_credit<2023, (default)> = [0.]
#             residential_clean_energy_credit<2023, (default)> = [0.]
#             energy_efficient_home_improvement_credit<2023, (default)> = [0.]
#             new_clean_vehicle_credit<2023, (default)> = [0.]
#             used_clean_vehicle_credit<2023, (default)> = [0.]
#           income_tax_unavailable_non_refundable_credits<2023, (default)> = [0.]
#             income_tax_before_credits<2023, (default)> = [5836.]
#             income_tax_non_refundable_credits<2023, (default)> = [4200.]
#             income_tax_non_refundable_credits<2023, (default)> = [4200.]
#       ma_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         MA<2023, (default)> = [False]
#       md_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         MD<2023, (default)> = [False]
#       ny_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         NY<2023, (default)> = [False]
#       or_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         or_income_tax_before_credits<2023, (default)> = [0.]
#           OR<2023, (default)> = [False]
#         or_non_refundable_credits<2023, (default)> = [0.]
#           or_exemption_credit<2023, (default)> = [0.]
#             OR<2023, (default)> = [False]
#       pa_income_tax<2023, (default)> = [0.]
#       ut_income_tax_before_refundable_credits<2023, (default)> = [1957.512]
#       wa_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         WA<2023, (default)> = [False]
#       flat_tax<2023, (default)> = [0.]
#         positive_agi<2023, (default)> = [80000.]

# %% [markdown]
# #### 3.5.3. Effect of rate cut to 4.00% on high income household

# %%
simulation_3_h = Simulation(
    reform=reform_3,
    situation=situation_high,
)

simulation_3_h.trace = True
simulation_3_h.calculate("household_net_income", 2023)
simulation_3_h.tracer.print_computation_log()
# Out:
#   household_net_income<2023, (default)> = [152161.48]
#     household_market_income<2023, (default)> = [200000.]
#       employment_income<2023, (default)> = [100000. 100000.      0.      0.]
#       self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#       pension_income<2023, (default)> = [0. 0. 0. 0.]
#         tax_exempt_pension_income<2023, (default)> = [0. 0. 0. 0.]
#         taxable_pension_income<2023, (default)> = [0. 0. 0. 0.]
#       dividend_income<2023, (default)> = [0. 0. 0. 0.]
#         qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#         non_qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#       interest_income<2023, (default)> = [0. 0. 0. 0.]
#         tax_exempt_interest_income<2023, (default)> = [0. 0. 0. 0.]
#         taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#       gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#       capital_gains<2023, (default)> = [0. 0. 0. 0.]
#         short_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#         long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#       rental_income<2023, (default)> = [0. 0. 0. 0.]
#       illicit_income<2023, (default)> = [0. 0. 0. 0.]
#       farm_income<2023, (default)> = [0. 0. 0. 0.]
#     household_benefits<2023, (default)> = [0.]
#       social_security<2023, (default)> = [0. 0. 0. 0.]
#         social_security_dependents<2023, (default)> = [0. 0. 0. 0.]
#         social_security_disability<2023, (default)> = [0. 0. 0. 0.]
#         social_security_retirement<2023, (default)> = [0. 0. 0. 0.]
#         social_security_survivors<2023, (default)> = [0. 0. 0. 0.]
#       ssi<2023, (default)> = [0. 0. 0. 0.]
#         uncapped_ssi<2023, (default)> = [0. 0. 0. 0.]
#           ssi_amount_if_eligible<2023, (default)> = [16452. 10968. 10968. 10968.]
#             ssi_claim_is_joint<2023, (default)> = [ True False False False]
#               is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                 is_ssi_aged<2023, (default)> = [False False False False]
#                   age<2023, (default)> = [38. 35. 10. 10.]
#                 is_blind<2023, (default)> = [False False False False]
#                 is_ssi_disabled<2023, (default)> = [False False False False]
#                   is_ssi_aged<2023, (default)> = [False False False False]
#                   is_blind<2023, (default)> = [False False False False]
#                   ssi_reported<2023, (default)> = [0. 0. 0. 0.]
#               ssi_income_deemed_from_ineligible_spouse<2023, (default)> = [50000.     0.     0.     0.]
#                 ssi_earned_income<2023, (default)> = [100000. 100000.      0.      0.]
#                   employment_income<2023, (default)> = [100000. 100000.      0.      0.]
#                   self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                 ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#                   dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                   interest_income<2023, (default)> = [0. 0. 0. 0.]
#                   gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#                   social_security<2023, (default)> = [0. 0. 0. 0.]
#                   alimony_income<2023, (default)> = [0. 0. 0. 0.]
#                   pension_income<2023, (default)> = [0. 0. 0. 0.]
#                   unemployment_compensation<2023, (default)> = [0. 0. 0. 0.]
#                 ssi_earned_income_deemed_from_ineligible_spouse<2023, (default)> = [100000.      0.      0.      0.]
#                   is_ssi_ineligible_spouse<2023, (default)> = [False  True False False]
#                     is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                       is_child<2023, (default)> = [False False  True  True]
#                         age<2023, (default)> = [38. 35. 10. 10.]
#                       is_tax_unit_head<2023, (default)> = [ True False False False]
#                         is_child<2023, (default)> = [False False  True  True]
#                         age<2023, (default)> = [38. 35. 10. 10.]
#                       age<2023, (default)> = [38. 35. 10. 10.]
#                     is_ssi_eligible_spouse<2023, (default)> = [False False False False]
#                       is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                       is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                   ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#                   ssi_earned_income<2023, (default)> = [100000. 100000.      0.      0.]
#                   ssi_ineligible_child_allocation<2023, (default)> = [   0.    0. 5484. 5484.]
#                     ssi_earned_income<2023, (default)> = [100000. 100000.      0.      0.]
#                     ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#                     is_ssi_ineligible_child<2023, (default)> = [False False  True  True]
#                       is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                       is_child<2023, (default)> = [False False  True  True]
#                   is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                 ssi_unearned_income_deemed_from_ineligible_spouse<2023, (default)> = [0. 0. 0. 0.]
#                   is_ssi_ineligible_spouse<2023, (default)> = [False  True False False]
#                   ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#                   ssi_ineligible_child_allocation<2023, (default)> = [   0.    0. 5484. 5484.]
#                 is_ssi_ineligible_child<2023, (default)> = [False False  True  True]
#           meets_ssi_resource_test<2023, (default)> = [ True  True  True  True]
#             ssi_claim_is_joint<2023, (default)> = [ True False False False]
#             ssi_countable_resources<2023, (default)> = [0. 0. 0. 0.]
#           is_ssi_eligible_individual<2023, (default)> = [False False False False]
#             is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#             is_ssi_eligible_spouse<2023, (default)> = [False False False False]
#           ssi_countable_income<2023, (default)> = [0. 0. 0. 0.]
#             ssi_earned_income<2023, (default)> = [100000. 100000.      0.      0.]
#             ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#             ssi_unearned_income_deemed_from_ineligible_parent<2023, (default)> = [0. 0. 0. 0.]
#               is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#               is_child<2023, (default)> = [False False  True  True]
#               is_ssi_ineligible_parent<2023, (default)> = [False False False False]
#                 is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#                 is_child<2023, (default)> = [False False  True  True]
#               ssi_earned_income<2023, (default)> = [100000. 100000.      0.      0.]
#               ssi_unearned_income<2023, (default)> = [0. 0. 0. 0.]
#               ssi_ineligible_child_allocation<2023, (default)> = [   0.    0. 5484. 5484.]
#               ssi_ineligible_parent_allocation<2023, (default)> = [0. 0. 0. 0.]
#                 is_ssi_ineligible_parent<2023, (default)> = [False False False False]
#             ssi_income_deemed_from_ineligible_spouse<2023, (default)> = [50000.     0.     0.     0.]
#             is_ssi_eligible_individual<2023, (default)> = [False False False False]
#       state_supplement<2023, (default)> = [0. 0. 0. 0.]
#         uncapped_ssi<2023, (default)> = [0. 0. 0. 0.]
#         maximum_state_supplement<2023, (default)> = [0. 0. 0. 0.]
#           is_ssi_eligible_individual<2023, (default)> = [False False False False]
#           state_code_str<2023, (default)> = ['UT']
#             state_code<2023, (default)> = ['UT']
#               state_name<2023, (default)> = ['UT']
#           state_living_arrangement<2023, (default)> = ['FULL_COST']
#           is_blind<2023, (default)> = [False False False False]
#           is_ssi_aged<2023, (default)> = [False False False False]
#           is_ssi_disabled<2023, (default)> = [False False False False]
#           ssi_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#           ssi_claim_is_joint<2023, (default)> = [ True False False False]
#         is_ssi_aged_blind_disabled<2023, (default)> = [False False False False]
#         meets_ssi_resource_test<2023, (default)> = [ True  True  True  True]
#         ssi_claim_is_joint<2023, (default)> = [ True False False False]
#       ca_cvrp<2023, (default)> = [0. 0. 0. 0.]
#         CA<2023, (default)> = [False]
#           state_code_str<2023, (default)> = ['UT']
#       snap<2023, (default)> = [0.]
#         snap_normal_allotment<2023, (default)> = [0.]
#           is_snap_eligible<2023, (default)> = [False]
#             meets_snap_net_income_test<2023, (default)> = [False]
#               snap_net_income_fpg_ratio<2023, (default)> = [5.2043333]
#                 snap_net_income<2023, (default)> = [156130.]
#                   snap_gross_income<2023, (default)> = [200000.]
#                     snap_earned_income<2023, (default)> = [200000.]
#                       employment_income<2023, (default)> = [100000. 100000.      0.      0.]
#                       self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                     snap_unearned_income<2023, (default)> = [0.]
#                       dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                       interest_income<2023, (default)> = [0. 0. 0. 0.]
#                       gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#                       social_security<2023, (default)> = [0. 0. 0. 0.]
#                       ssi<2023, (default)> = [0. 0. 0. 0.]
#                   snap_deductions<2023, (default)> = [43870.]
#                     snap_standard_deduction<2023, (default)> = [2316.]
#                       state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#                         state_group<2023, (default)> = ['CONTIGUOUS_US']
#                           state_code<2023, (default)> = ['UT']
#                       spm_unit_size<2023, (default)> = [4]
#                     snap_earned_income_deduction<2023, (default)> = [40000.]
#                       snap_earned_income<2023, (default)> = [200000.]
#                     snap_dependent_care_deduction<2023, (default)> = [1500.]
#                       childcare_expenses<2023, (default)> = [1500.]
#                     snap_child_support_deduction<2023, (default)> = [0.]
#                       child_support_expense<2023, (default)> = [0. 0. 0. 0.]
#                       state_code_str<2023, (default)> = ['UT']
#                     snap_excess_medical_expense_deduction<2023, (default)> = [0.]
#                       is_usda_elderly<2023, (default)> = [False False False False]
#                         age<2023, (default)> = [38. 35. 10. 10.]
#                       is_usda_disabled<2023, (default)> = [False False False False]
#                         is_ssi_disabled<2023, (default)> = [False False False False]
#                         social_security_disability<2023, (default)> = [0. 0. 0. 0.]
#                         is_permanently_disabled_veteran<2023, (default)> = [False False False False]
#                         is_surviving_spouse_of_disabled_veteran<2023, (default)> = [False False False False]
#                         is_surviving_child_of_disabled_veteran<2023, (default)> = [False False False False]
#                       medical_out_of_pocket_expenses<2023, (default)> = [4000.    0.    0.    0.]
#                       state_code_str<2023, (default)> = ['UT']
#                     snap_excess_shelter_expense_deduction<2023, (default)> = [54.]
#                       snap_net_income_pre_shelter<2023, (default)> = [156184.]
#                         snap_gross_income<2023, (default)> = [200000.]
#                         snap_standard_deduction<2023, (default)> = [2316.]
#                         snap_earned_income_deduction<2023, (default)> = [40000.]
#                         snap_dependent_care_deduction<2023, (default)> = [1500.]
#                         snap_child_support_deduction<2023, (default)> = [0.]
#                         snap_excess_medical_expense_deduction<2023, (default)> = [0.]
#                       housing_cost<2023, (default)> = [36000.]
#                       snap_region_str<2023, (default)> = ['CONTIGUOUS_US']
#                         snap_region<2023, (default)> = ['CONTIGUOUS_US']
#                           state_group<2023, (default)> = ['CONTIGUOUS_US']
#                       has_usda_elderly_disabled<2023, (default)> = [False]
#                         is_usda_elderly<2023, (default)> = [False False False False]
#                         is_usda_disabled<2023, (default)> = [False False False False]
#                       snap_utility_allowance<2023, (default)> = [54.]
#                         snap_utility_allowance_type<2023, (default)> = ['IUA']
#                           count_distinct_utility_expenses<2023, (default)> = [1]
#                             heating_cooling_expense<2023, (default)> = [0.]
#                             electricity_expense<2023, (default)> = [0.]
#                             gas_expense<2023, (default)> = [0.]
#                             phone_expense<2023, (default)> = [2400.]
#                               phone_cost<2023, (default)> = [2400.]
#                             trash_expense<2023, (default)> = [0.]
#                             water_expense<2023, (default)> = [0.]
#                             sewage_expense<2023, (default)> = [0.]
#                           snap_utility_region_str<2023, (default)> = ['UT']
#                             snap_utility_region<2023, (default)> = ['UT']
#                               state_code<2023, (default)> = ['UT']
#                           has_heating_cooling_expense<2023, (default)> = [False]
#                             heating_cooling_expense<2023, (default)> = [0.]
#                         snap_utility_region_str<2023, (default)> = ['UT']
#                       state_code_str<2023, (default)> = ['UT']
#                       is_homeless<2023, (default)> = [False]
#                 spm_unit_fpg<2023, (default)> = [30000.]
#                   spm_unit_size<2023, (default)> = [4]
#                   state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#             meets_snap_gross_income_test<2023, (default)> = [False]
#               snap_gross_income_fpg_ratio<2023, (default)> = [6.6666665]
#                 snap_gross_income<2023, (default)> = [200000.]
#                 spm_unit_fpg<2023, (default)> = [30000.]
#               has_usda_elderly_disabled<2023, (default)> = [False]
#             meets_snap_asset_test<2023, (default)> = [ True]
#               has_usda_elderly_disabled<2023, (default)> = [False]
#               snap_assets<2023, (default)> = [0.]
#             meets_snap_categorical_eligibility<2023, (default)> = [False]
#               ssi<2023, (default)> = [0. 0. 0. 0.]
#               is_tanf_non_cash_eligible<2023, (default)> = [False]
#                 meets_tanf_non_cash_gross_income_test<2023, (default)> = [False]
#                   state_code_str<2023, (default)> = ['UT']
#                   snap_gross_income_fpg_ratio<2023, (default)> = [6.6666665]
#                 meets_tanf_non_cash_net_income_test<2023, (default)> = [ True]
#                   state_code_str<2023, (default)> = ['UT']
#                   is_tanf_non_cash_hheod<2023, (default)> = [False]
#                     state_code_str<2023, (default)> = ['UT']
#                     has_all_usda_elderly_disabled<2023, (default)> = [False]
#                       is_usda_elderly<2023, (default)> = [False False False False]
#                       is_usda_disabled<2023, (default)> = [False False False False]
#                     has_usda_elderly_disabled<2023, (default)> = [False]
#                   snap_net_income_fpg_ratio<2023, (default)> = [5.2043333]
#                 meets_tanf_non_cash_asset_test<2023, (default)> = [False]
#                   snap_assets<2023, (default)> = [0.]
#                   state_code_str<2023, (default)> = ['UT']
#           snap_expected_contribution<2023, (default)> = [46839.]
#             snap_net_income<2023, (default)> = [156130.]
#           snap_max_allotment<2023, (default)> = [11268.]
#             snap_region_str<2023, (default)> = ['CONTIGUOUS_US']
#             spm_unit_size<2023, (default)> = [4]
#             spm_unit_size<2023, (default)> = [4]
#           snap_min_allotment<2023, (default)> = [0.]
#             snap_region_str<2023, (default)> = ['CONTIGUOUS_US']
#             spm_unit_size<2023, (default)> = [4]
#         snap_emergency_allotment<2023, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-01, (default)> = [0.]
#             is_snap_eligible<2023, (default)> = [False]
#             snap_max_allotment<2023, (default)> = [11268.]
#             snap_normal_allotment<2023, (default)> = [0.]
#             state_code<2023, (default)> = ['UT']
#           snap_emergency_allotment_monthly<2023-02, (default)> = [0.]
#             is_snap_eligible<2023, (default)> = [False]
#             snap_max_allotment<2023, (default)> = [11268.]
#             snap_normal_allotment<2023, (default)> = [0.]
#             state_code<2023, (default)> = ['UT']
#           snap_emergency_allotment_monthly<2023-03, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-04, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-05, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-06, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-07, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-08, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-09, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-10, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-11, (default)> = [0.]
#           snap_emergency_allotment_monthly<2023-12, (default)> = [0.]
#       wic<2023, (default)> = [0. 0. 0. 0.]
#         meets_wic_income_test<2023, (default)> = [False]
#           school_meal_countable_income<2023, (default)> = [200000.]
#             employment_income<2023, (default)> = [100000. 100000.      0.      0.]
#             self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#             dividend_income<2023, (default)> = [0. 0. 0. 0.]
#             interest_income<2023, (default)> = [0. 0. 0. 0.]
#             gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#             social_security<2023, (default)> = [0. 0. 0. 0.]
#             ssi<2023, (default)> = [0. 0. 0. 0.]
#           wic_fpg<2023, (default)> = [30000.]
#             is_pregnant<2023, (default)> = [False False False False]
#             spm_unit_fpg<2023, (default)> = [30000.]
#             state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#         meets_wic_categorical_eligibility<2023, (default)> = [False False False False]
#           snap<2023, (default)> = [0.]
#           tanf<2023, (default)> = [0.]
#             tanf_reported<2023, (default)> = [0. 0. 0. 0.]
#             is_tanf_eligible<2023, (default)> = [False]
#               is_person_demographic_tanf_eligible<2023, (default)> = [False False  True  True]
#                 is_child<2023, (default)> = [False False  True  True]
#                 age<2023, (default)> = [38. 35. 10. 10.]
#                 is_full_time_student<2023, (default)> = [False False  True  True]
#                   is_full_time_college_student<2023, (default)> = [False False False False]
#                   is_in_k12_school<2023, (default)> = [False False  True  True]
#                     age<2023, (default)> = [38. 35. 10. 10.]
#                 is_pregnant<2023, (default)> = [False False False False]
#               is_tanf_enrolled<2023, (default)> = [False]
#               is_tanf_continuous_eligible<2023, (default)> = [False]
#                 tanf_gross_earned_income<2023, (default)> = [200000.]
#                   employment_income<2023, (default)> = [100000. 100000.      0.      0.]
#                   self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                 tanf_gross_unearned_income<2023, (default)> = [0.]
#                   dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                   interest_income<2023, (default)> = [0. 0. 0. 0.]
#                   gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#                   social_security<2023, (default)> = [0. 0. 0. 0.]
#                   ssi<2023, (default)> = [0. 0. 0. 0.]
#                 tanf_max_amount<2023, (default)> = [0.]
#                   spm_unit_size<2023, (default)> = [4]
#                   state_code_str<2023, (default)> = ['UT']
#               is_tanf_initial_eligible<2023, (default)> = [False]
#                 tanf_initial_employment_deduction<2023, (default)> = [0.]
#                   spm_unit_size<2023, (default)> = [4]
#                   state_code_str<2023, (default)> = ['UT']
#                   market_income<2023, (default)> = [100000. 100000.      0.      0.]
#                     employment_income<2023, (default)> = [100000. 100000.      0.      0.]
#                     self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                     pension_income<2023, (default)> = [0. 0. 0. 0.]
#                     dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                     interest_income<2023, (default)> = [0. 0. 0. 0.]
#                     gi_cash_assistance<2023, (default)> = [0. 0. 0. 0.]
#                     capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                     rental_income<2023, (default)> = [0. 0. 0. 0.]
#                     illicit_income<2023, (default)> = [0. 0. 0. 0.]
#                     farm_income<2023, (default)> = [0. 0. 0. 0.]
#                 tanf_gross_earned_income<2023, (default)> = [200000.]
#                 tanf_gross_unearned_income<2023, (default)> = [0.]
#                 tanf_max_amount<2023, (default)> = [0.]
#             tanf_amount_if_eligible<2023, (default)> = [0.]
#               tanf_max_amount<2023, (default)> = [0.]
#               tanf_countable_income<2023, (default)> = [200000.]
#                 state_code_str<2023, (default)> = ['UT']
#                 tanf_gross_unearned_income<2023, (default)> = [0.]
#                 tanf_gross_earned_income<2023, (default)> = [200000.]
#           medicaid<2023, (default)> = [0. 0. 0. 0.]
#             is_medicaid_eligible<2023, (default)> = [False False False False]
#               medicaid_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#                 is_infant_for_medicaid<2023, (default)> = [False False False False]
#                   is_infant_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [6.6666665 6.6666665 6.6666665 6.6666665]
#                       tax_unit_medicaid_income_level<2023, (default)> = [6.6666665]
#                         medicaid_income<2023, (default)> = [200000.]
#                           adjusted_gross_income<2023, (default)> = [200000.]
#                             irs_gross_income<2023, (default)> = [100000. 100000.      0.      0.]
#                               is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                               employment_income<2023, (default)> = [100000. 100000.      0.      0.]
#                               self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                               partnership_s_corp_income<2023, (default)> = [0. 0. 0. 0.]
#                               farm_income<2023, (default)> = [0. 0. 0. 0.]
#                               farm_rent_income<2023, (default)> = [0. 0. 0. 0.]
#                               capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                               taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#                               rental_income<2023, (default)> = [0. 0. 0. 0.]
#                               dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                               taxable_pension_income<2023, (default)> = [0. 0. 0. 0.]
#                               debt_relief<2023, (default)> = [0. 0. 0. 0.]
#                               taxable_unemployment_compensation<2023, (default)> = [0. 0. 0. 0.]
#                                 is_tax_unit_head<2023, (default)> = [ True False False False]
#                                 tax_unit_taxable_unemployment_compensation<2023, (default)> = [0.]
#                                   tax_unit_unemployment_compensation<2023, (default)> = [0.]
#                                     unemployment_compensation<2023, (default)> = [0. 0. 0. 0.]
#                                   taxable_uc_agi<2023, (default)> = [200000.]
#                                     is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                                     employment_income<2023, (default)> = [100000. 100000.      0.      0.]
#                                     self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                     partnership_s_corp_income<2023, (default)> = [0. 0. 0. 0.]
#                                     farm_income<2023, (default)> = [0. 0. 0. 0.]
#                                     farm_rent_income<2023, (default)> = [0. 0. 0. 0.]
#                                     capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                                     taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#                                     rental_income<2023, (default)> = [0. 0. 0. 0.]
#                                     dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                                     taxable_pension_income<2023, (default)> = [0. 0. 0. 0.]
#                                     debt_relief<2023, (default)> = [0. 0. 0. 0.]
#                                     taxable_social_security<2023, (default)> = [0. 0. 0. 0.]
#                                       tax_unit_taxable_social_security<2023, (default)> = [0.]
#                                         tax_unit_social_security<2023, (default)> = [0.]
#                                           social_security<2023, (default)> = [0. 0. 0. 0.]
#                                         taxable_ss_magi<2023, (default)> = [200000.]
#                                           is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                                           employment_income<2023, (default)> = [100000. 100000.      0.      0.]
#                                           self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                           partnership_s_corp_income<2023, (default)> = [0. 0. 0. 0.]
#                                           farm_income<2023, (default)> = [0. 0. 0. 0.]
#                                           farm_rent_income<2023, (default)> = [0. 0. 0. 0.]
#                                           capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                                           taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#                                           rental_income<2023, (default)> = [0. 0. 0. 0.]
#                                           dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                                           taxable_pension_income<2023, (default)> = [0. 0. 0. 0.]
#                                           debt_relief<2023, (default)> = [0. 0. 0. 0.]
#                                           illicit_income<2023, (default)> = [0. 0. 0. 0.]
#                                           unemployment_compensation<2023, (default)> = [0. 0. 0. 0.]
#                                           tax_exempt_interest_income<2023, (default)> = [0. 0. 0. 0.]
#                                           loss_ald<2023, (default)> = [0.]
#                                             filing_status<2023, (default)> = ['JOINT']
#                                               is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                                               tax_unit_dependents<2023, (default)> = [2]
#                                                 is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                                             self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                             maximum_capital_loss<2023, (default)> = [0.]
#                                               tax_unit_capital_loss<2023, (default)> = [0.]
#                                                 capital_loss<2023, (default)> = [0. 0. 0. 0.]
#                                                   capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                                               filing_status<2023, (default)> = ['JOINT']
#                                           self_employment_tax_ald<2023, (default)> = [0.]
#                                             self_employment_tax_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employment_tax<2023, (default)> = [0. 0. 0. 0.]
#                                                 self_employment_social_security_tax<2023, (default)> = [0. 0. 0. 0.]
#                                                   social_security_taxable_self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                                     taxable_self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                                       sey<2023, (default)> = [0. 0. 0. 0.]
#                                                         self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                                         farm_income<2023, (default)> = [0. 0. 0. 0.]
#                                                         k1bx14<2023, (default)> = [0. 0. 0. 0.]
#                                                     taxable_earnings_for_social_security<2023, (default)> = [100000. 100000.      0.      0.]
#                                                       payroll_tax_gross_wages<2023, (default)> = [100000. 100000.      0.      0.]
#                                                         employment_income<2023, (default)> = [100000. 100000.      0.      0.]
#                                                 self_employment_medicare_tax<2023, (default)> = [0. 0. 0. 0.]
#                                                   taxable_self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                           early_withdrawal_penalty<2023, (default)> = [0. 0. 0. 0.]
#                                           alimony_income<2023, (default)> = [0. 0. 0. 0.]
#                                           educator_expense<2023, (default)> = [0. 0. 0. 0.]
#                                           health_savings_account_ald<2023, (default)> = [0.]
#                                           self_employed_health_insurance_ald<2023, (default)> = [0.]
#                                             self_employed_health_insurance_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employed_health_insurance_premiums<2023, (default)> = [0. 0. 0. 0.]
#                                                 is_self_employed<2023, (default)> = [False False False False]
#                                                 health_insurance_premiums<2023, (default)> = [0. 0. 0. 0.]
#                                           self_employed_pension_contribution_ald<2023, (default)> = [0.]
#                                             self_employed_pension_contribution_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                                               self_employed_pension_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                           ira_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                           sep_simple_qualified_plan_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                         filing_status<2023, (default)> = ['JOINT']
#                                       tax_unit_social_security<2023, (default)> = [0.]
#                                       social_security<2023, (default)> = [0. 0. 0. 0.]
#                                       is_tax_unit_spouse<2023, (default)> = [False  True False False]
#                                       is_tax_unit_head<2023, (default)> = [ True False False False]
#                                     illicit_income<2023, (default)> = [0. 0. 0. 0.]
#                                     loss_ald<2023, (default)> = [0.]
#                                     self_employment_tax_ald<2023, (default)> = [0.]
#                                     student_loan_interest<2023, (default)> = [0. 0. 0. 0.]
#                                     early_withdrawal_penalty<2023, (default)> = [0. 0. 0. 0.]
#                                     alimony_income<2023, (default)> = [0. 0. 0. 0.]
#                                     educator_expense<2023, (default)> = [0. 0. 0. 0.]
#                                     health_savings_account_ald<2023, (default)> = [0.]
#                                     self_employed_health_insurance_ald<2023, (default)> = [0.]
#                                     self_employed_pension_contribution_ald<2023, (default)> = [0.]
#                                     ira_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                     sep_simple_qualified_plan_contributions<2023, (default)> = [0. 0. 0. 0.]
#                                     qualified_adoption_assistance_expense<2023, (default)> = [0. 0. 0. 0.]
#                                     us_bonds_for_higher_ed<2023, (default)> = [0. 0. 0. 0.]
#                                     specified_possession_income<2023, (default)> = [0.]
#                                     puerto_rico_income<2023, (default)> = [0.]
#                                   filing_status<2023, (default)> = ['JOINT']
#                               taxable_social_security<2023, (default)> = [0. 0. 0. 0.]
#                               illicit_income<2023, (default)> = [0. 0. 0. 0.]
#                             above_the_line_deductions<2023, (default)> = [0.]
#                               loss_ald<2023, (default)> = [0.]
#                               self_employment_tax_ald<2023, (default)> = [0.]
#                               student_loan_interest<2023, (default)> = [0. 0. 0. 0.]
#                               early_withdrawal_penalty<2023, (default)> = [0. 0. 0. 0.]
#                               alimony_income<2023, (default)> = [0. 0. 0. 0.]
#                               educator_expense<2023, (default)> = [0. 0. 0. 0.]
#                               health_savings_account_ald<2023, (default)> = [0.]
#                               self_employed_health_insurance_ald<2023, (default)> = [0.]
#                               self_employed_pension_contribution_ald<2023, (default)> = [0.]
#                               ira_contributions<2023, (default)> = [0. 0. 0. 0.]
#                               sep_simple_qualified_plan_contributions<2023, (default)> = [0. 0. 0. 0.]
#                               qualified_adoption_assistance_expense<2023, (default)> = [0. 0. 0. 0.]
#                               us_bonds_for_higher_ed<2023, (default)> = [0. 0. 0. 0.]
#                               specified_possession_income<2023, (default)> = [0.]
#                               puerto_rico_income<2023, (default)> = [0.]
#                           foreign_earned_income_exclusion<2023, (default)> = [0.]
#                           student_loan_interest<2023, (default)> = [0. 0. 0. 0.]
#                           tax_exempt_social_security<2023, (default)> = [0.]
#                             tax_unit_social_security<2023, (default)> = [0.]
#                             tax_unit_taxable_social_security<2023, (default)> = [0.]
#                         tax_unit_fpg<2023, (default)> = [30000.]
#                           tax_unit_size<2023, (default)> = [4]
#                           state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#                     state_code_str<2023, (default)> = ['UT']
#                   is_infant_for_medicaid_nfc<2023, (default)> = [False False False False]
#                     age<2023, (default)> = [38. 35. 10. 10.]
#                 is_young_child_for_medicaid<2023, (default)> = [False False False False]
#                   is_young_child_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [6.6666665 6.6666665 6.6666665 6.6666665]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_young_child_for_medicaid_nfc<2023, (default)> = [False False False False]
#                     age<2023, (default)> = [38. 35. 10. 10.]
#                 is_older_child_for_medicaid<2023, (default)> = [False False False False]
#                   age<2023, (default)> = [38. 35. 10. 10.]
#                   medicaid_income_level<2023, (default)> = [6.6666665 6.6666665 6.6666665 6.6666665]
#                   state_code_str<2023, (default)> = ['UT']
#                 is_young_adult_for_medicaid<2023, (default)> = [False False False False]
#                   is_young_adult_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [6.6666665 6.6666665 6.6666665 6.6666665]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_young_adult_for_medicaid_nfc<2023, (default)> = [False False False False]
#                     age<2023, (default)> = [38. 35. 10. 10.]
#                 is_adult_for_medicaid<2023, (default)> = [False False False False]
#                   is_adult_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [6.6666665 6.6666665 6.6666665 6.6666665]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_adult_for_medicaid_nfc<2023, (default)> = [ True  True False False]
#                     age<2023, (default)> = [38. 35. 10. 10.]
#                 is_parent_for_medicaid<2023, (default)> = [False False False False]
#                   is_parent_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [6.6666665 6.6666665 6.6666665 6.6666665]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_parent_for_medicaid_nfc<2023, (default)> = [ True  True False False]
#                     is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                     tax_unit_count_dependents<2023, (default)> = [2]
#                       is_tax_unit_dependent<2023, (default)> = [False False  True  True]
#                 is_pregnant_for_medicaid<2023, (default)> = [False False False False]
#                   is_pregnant_for_medicaid_fc<2023, (default)> = [False False False False]
#                     medicaid_income_level<2023, (default)> = [6.6666665 6.6666665 6.6666665 6.6666665]
#                     state_code_str<2023, (default)> = ['UT']
#                   is_pregnant_for_medicaid_nfc<2023, (default)> = [False False False False]
#                     is_pregnant<2023, (default)> = [False False False False]
#                     count_days_postpartum<2023, (default)> = [inf inf inf inf]
#                       under_60_days_postpartum<2023, (default)> = [False False False False]
#                       under_12_months_postpartum<2023, (default)> = [False False False False]
#                     state_code_str<2023, (default)> = ['UT']
#                 is_ssi_recipient_for_medicaid<2023, (default)> = [False False False False]
#                   state_code_str<2023, (default)> = ['UT']
#                   ssi<2023, (default)> = [0. 0. 0. 0.]
#             medicaid_benefit_value<2023, (default)> = [9966.585 9966.585 9966.585 9966.585]
#               state_code_str<2023, (default)> = ['UT']
#           is_pregnant<2023, (default)> = [False False False False]
#           wic_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#             is_pregnant<2023, (default)> = [False False False False]
#             is_mother<2023, (default)> = [False False False False]
#               is_female<2023, (default)> = [False False False False]
#               own_children_in_household<2023, (default)> = [0 0 0 0]
#               is_breastfeeding<2023, (default)> = [False False False False]
#             is_breastfeeding<2023, (default)> = [False False False False]
#             age<2023, (default)> = [38. 35. 10. 10.]
#         wic_category_str<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#           wic_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#         is_wic_at_nutritional_risk<2023, (default)> = [False False False False]
#           receives_wic<2023, (default)> = [False False False False]
#           meets_wic_income_test<2023, (default)> = [False]
#           meets_wic_categorical_eligibility<2023, (default)> = [False False False False]
#           wic_category<2023, (default)> = ['NONE' 'NONE' 'NONE' 'NONE']
#         would_claim_wic<2023, (default)> = [ True  True  True  True]
#       free_school_meals<2023, (default)> = [0.]
#         school_meal_tier<2023, (default)> = ['PAID']
#           school_meal_fpg_ratio<2023, (default)> = [6.6666665]
#             school_meal_countable_income<2023, (default)> = [200000.]
#             spm_unit_fpg<2023, (default)> = [30000.]
#           meets_school_meal_categorical_eligibility<2023, (default)> = [False]
#             snap<2023, (default)> = [0.]
#             tanf<2023, (default)> = [0.]
#             fdpir<2023, (default)> = [0.]
#         school_meal_net_subsidy<2023, (default)> = [0.]
#           school_meal_daily_subsidy<2023, (default)> = [0.72]
#             state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#             school_meal_tier<2023, (default)> = ['PAID']
#           school_meal_paid_daily_subsidy<2023, (default)> = [0.72]
#             state_group_str<2023, (default)> = ['CONTIGUOUS_US']
#           is_in_k12_school<2023, (default)> = [False False  True  True]
#       reduced_price_school_meals<2023, (default)> = [0.]
#         school_meal_tier<2023, (default)> = ['PAID']
#         school_meal_net_subsidy<2023, (default)> = [0.]
#       lifeline<2023, (default)> = [0.]
#         is_rural<2023, (default)> = [False]
#         is_on_tribal_land<2023, (default)> = [False]
#         phone_cost<2023, (default)> = [2400.]
#         broadband_cost<2023, (default)> = [1200.]
#         is_lifeline_eligible<2023, (default)> = [False]
#           medicaid<2023, (default)> = [0. 0. 0. 0.]
#           snap<2023, (default)> = [0.]
#           ssi<2023, (default)> = [0. 0. 0. 0.]
#           fcc_fpg_ratio<2023, (default)> = [6.6666665]
#             irs_gross_income<2023, (default)> = [100000. 100000.      0.      0.]
#             spm_unit_fpg<2023, (default)> = [30000.]
#       acp<2023, (default)> = [0.]
#         is_acp_eligible<2023, (default)> = [False]
#           lifeline<2023, (default)> = [0.]
#           free_school_meals<2023, (default)> = [0.]
#           reduced_price_school_meals<2023, (default)> = [0.]
#           pell_grant<2023, (default)> = [0.]
#           wic<2023, (default)> = [0. 0. 0. 0.]
#           medicaid<2023, (default)> = [0. 0. 0. 0.]
#           snap<2023, (default)> = [0.]
#           ssi<2023, (default)> = [0. 0. 0. 0.]
#           fcc_fpg_ratio<2023, (default)> = [6.6666665]
#           ebb<2023, (default)> = [0.]
#             is_ebb_eligible<2023, (default)> = [False]
#               is_lifeline_eligible<2023, (default)> = [False]
#               free_school_meals<2023, (default)> = [0.]
#               reduced_price_school_meals<2023, (default)> = [0.]
#               pell_grant<2023, (default)> = [0.]
#               experienced_covid_income_loss<2023, (default)> = [False]
#               enrolled_in_ebb<2023, (default)> = [False]
#             broadband_cost_after_lifeline<2023, (default)> = [1200.]
#               broadband_cost<2023, (default)> = [1200.]
#               lifeline<2023, (default)> = [0.]
#             is_on_tribal_land<2023, (default)> = [False]
#         broadband_cost_after_lifeline<2023, (default)> = [1200.]
#         is_on_tribal_land<2023, (default)> = [False]
#       ebb<2023, (default)> = [0.]
#       tanf<2023, (default)> = [0.]
#       high_efficiency_electric_home_rebate<2023, (default)> = [0.]
#         capped_electric_heat_pump_clothes_dryer_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#             tax_unit_income_ami_ratio<2023, (default)> = [0.]
#           electric_heat_pump_clothes_dryer_expenditures<2023, (default)> = [0.]
#         capped_electric_load_service_center_upgrade_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           electric_load_service_center_upgrade_expenditures<2023, (default)> = [0.]
#         capped_electric_stove_cooktop_range_or_oven_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           electric_stove_cooktop_range_or_oven_expenditures<2023, (default)> = [0.]
#         capped_electric_wiring_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           electric_wiring_expenditures<2023, (default)> = [0.]
#         capped_heat_pump_water_heater_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           heat_pump_water_heater_expenditures<2023, (default)> = [0.]
#         capped_heat_pump_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           heat_pump_expenditures<2023, (default)> = [0.]
#         capped_insulation_air_sealing_ventilation_rebate<2023, (default)> = [0.]
#           high_efficiency_electric_home_rebate_percent_covered<2023, (default)> = [1.]
#           energy_efficient_insulation_expenditures<2023, (default)> = [0.]
#           air_sealing_ventilation_expenditures<2023, (default)> = [0.]
#       residential_efficiency_electrification_rebate<2023, (default)> = [0.]
#         residential_efficiency_electrification_retrofit_expenditures<2023, (default)> = [0.]
#         residential_efficiency_electrification_retrofit_energy_savings<2023, (default)> = [0.]
#         current_home_energy_use<2023, (default)> = [0.]
#         household_income_ami_ratio<2023, (default)> = [0.]
#         average_home_energy_use_in_state<2023, (default)> = [0.]
#       basic_income<2023, (default)> = [0.]
#         basic_income_eligible<2023, (default)> = [ True]
#         basic_income_before_phase_out<2023, (default)> = [0.]
#           tax_unit_size<2023, (default)> = [4]
#           age<2023, (default)> = [38. 35. 10. 10.]
#           tax_unit_fpg<2023, (default)> = [30000.]
#         basic_income_phase_out<2023, (default)> = [0.]
#           basic_income_before_phase_out<2023, (default)> = [0.]
#           adjusted_gross_income<2023, (default)> = [200000.]
#           filing_status<2023, (default)> = ['JOINT']
#       spm_unit_capped_housing_subsidy<2023, (default)> = [0.]
#         spm_unit_capped_housing_subsidy_reported<2023, (default)> = [0.]
#     household_refundable_tax_credits<2023, (default)> = [0.]
#       income_tax_refundable_credits<2023, (default)> = [0.]
#         eitc<2023, (default)> = [0.]
#           earned_income_tax_credit<2023, (default)> = [0.]
#             eitc_eligible<2023, (default)> = [ True]
#               is_child<2023, (default)> = [False False  True  True]
#               age<2023, (default)> = [38. 35. 10. 10.]
#               tax_exempt_interest_income<2023, (default)> = [0. 0. 0. 0.]
#               taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#               dividend_income<2023, (default)> = [0. 0. 0. 0.]
#               c01000<2023, (default)> = [0.]
#                 sep<2023, (default)> = [1]
#                 c23650<2023, (default)> = [0.]
#                   long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   short_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#               tax_unit_rental_income<2023, (default)> = [0.]
#                 rental_income<2023, (default)> = [0. 0. 0. 0.]
# ...
#                               income_tax_unavailable_non_refundable_credits<2023, (not_itemizing)> = [0.]
#                                 income_tax_before_credits<2023, (not_itemizing)> = [28521.]
#                                 income_tax_non_refundable_credits<2023, (not_itemizing)> = [4300.]
#                                 income_tax_non_refundable_credits<2023, (not_itemizing)> = [4300.]
#                           income_tax_refundable_credits<2023, (not_itemizing)> = [0.]
#                       state_income_tax<2023, (not_itemizing)> = [8317.512]
#                 taxable_income_deductions_if_itemizing<2023, (default)> = [28317.512]
#                   charitable_deduction<2023, (default)> = [20000.]
#                   interest_deduction<2023, (default)> = [0.]
#                   salt_deduction<2023, (default)> = [8317.512]
#                     state_and_local_sales_or_income_tax<2023, (default)> = [8317.512]
#                       state_income_tax<2023, (default)> = [8317.512]
#                         ma_income_tax<2023, (default)> = [0.]
#                           MA<2023, (default)> = [False]
#                         md_income_tax<2023, (default)> = [0.]
#                           MD<2023, (default)> = [False]
#                         ny_income_tax<2023, (default)> = [0.]
#                           NY<2023, (default)> = [False]
#                         or_income_tax<2023, (default)> = [0.]
#                           OR<2023, (default)> = [False]
#                         pa_income_tax<2023, (default)> = [0.]
#                           PA<2023, (default)> = [False]
#                             state_code_str<2023, (default)> = ['UT']
#                         wa_income_tax<2023, (default)> = [0.]
#                           WA<2023, (default)> = [False]
#                         ut_income_tax<2023, (default)> = [8317.512]
#                           UT<2023, (default)> = [ True]
#                           ut_income_tax_before_refundable_credits<2023, (default)> = [8317.512]
#                             ut_income_tax_after_credits<2023, (default)> = [8317.512]
#                               ut_income_tax_before_credits<2023, (default)> = [8000.]
#                                 UT<2023, (default)> = [ True]
#                                 ut_taxable_income<2023, (default)> = [200000.]
#                                   UT<2023, (default)> = [ True]
#                                   ut_total_income<2023, (default)> = [200000.]
#                                     UT<2023, (default)> = [ True]
#                                     adjusted_gross_income<2023, (default)> = [200000.]
#                                     ut_additions_to_income<2023, (default)> = [0.]
#                                       UT<2023, (default)> = [ True]
#                                   salt_refund_last_year<2023, (default)> = [0.]
#                                   ut_subtractions_from_income<2023, (default)> = [0.]
#                                     UT<2023, (default)> = [ True]
#                               ut_taxpayer_credit<2023, (default)> = [-317.51196]
#                                 UT<2023, (default)> = [ True]
#                                 ut_taxpayer_credit_max<2023, (default)> = [1878.24]
#                                   UT<2023, (default)> = [ True]
#                                   tax_unit_count_dependents<2023, (default)> = [2]
#                                   tax_unit_itemizes<2023, (default)> = [False]
#                                   standard_deduction<2023, (default)> = [27700.]
#                                   charitable_deduction<2023, (default)> = [20000.]
#                                   interest_deduction<2023, (default)> = [0.]
#                                   medical_expense_deduction<2023, (default)> = [0.]
#                                   casualty_loss_deduction<2023, (default)> = [0.]
#                                 ut_taxpayer_credit_reduction<2023, (default)> = [2195.752]
#                                   UT<2023, (default)> = [ True]
#                                   filing_status<2023, (default)> = ['JOINT']
#                                   ut_taxable_income<2023, (default)> = [200000.]
#                             ut_apportionable_nonrefundable_credits<2023, (default)> = [0.]
#                               UT<2023, (default)> = [ True]
#                             ut_nonapportionable_nonrefundable_credits<2023, (default)> = [0.]
#                               UT<2023, (default)> = [ True]
#                             ut_recapture_low_inc_housing_credit<2023, (default)> = [0.]
#                               UT<2023, (default)> = [ True]
#                           ut_refundable_credits<2023, (default)> = [0.]
#                       local_income_tax<2023, (default)> = [0.]
#                       state_sales_tax<2023, (default)> = [0.]
#                       local_sales_tax<2023, (default)> = [0.]
#                     real_estate_taxes<2023, (default)> = [0. 0. 0. 0.]
#                     filing_status<2023, (default)> = ['JOINT']
#                   medical_expense_deduction<2023, (default)> = [0.]
#                   casualty_loss_deduction<2023, (default)> = [0.]
#                   qualified_business_income_deduction<2023, (default)> = [0.]
#                     qbid_amount<2023, (default)> = [0. 0. 0. 0.]
#                       qualified_business_income<2023, (default)> = [0. 0. 0. 0.]
#                         self_employment_income<2023, (default)> = [0. 0. 0. 0.]
#                         partnership_s_corp_income<2023, (default)> = [0. 0. 0. 0.]
#                         farm_income<2023, (default)> = [0. 0. 0. 0.]
#                         farm_rent_income<2023, (default)> = [0. 0. 0. 0.]
#                         self_employment_tax_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                         self_employed_health_insurance_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                         self_employed_pension_contribution_ald_person<2023, (default)> = [0. 0. 0. 0.]
#                         business_is_qualified<2023, (default)> = [False False False False]
#                       w2_wages_from_qualified_business<2023, (default)> = [0. 0. 0. 0.]
#                       unadjusted_basis_qualified_property<2023, (default)> = [0. 0. 0. 0.]
#                       taxable_income_less_qbid<2023, (default)> = [171682.48]
#                         adjusted_gross_income<2023, (default)> = [200000.]
#                         charitable_deduction<2023, (default)> = [20000.]
#                         interest_deduction<2023, (default)> = [0.]
#                         salt_deduction<2023, (default)> = [8317.512]
#                         medical_expense_deduction<2023, (default)> = [0.]
#                         casualty_loss_deduction<2023, (default)> = [0.]
#                         standard_deduction<2023, (default)> = [27700.]
#                       filing_status<2023, (default)> = ['JOINT']
#                       business_is_sstb<2023, (default)> = [False False False False]
#                     taxable_income_less_qbid<2023, (default)> = [171682.48]
#                     adjusted_net_capital_gain<2023, (default)> = [0.]
#                       net_capital_gain<2023, (default)> = [0.]
#                         net_long_term_capital_gain<2023, (default)> = [0.]
#                           long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                           long_term_capital_losses<2023, (default)> = [0. 0. 0. 0.]
#                         net_short_term_capital_loss<2023, (default)> = [0.]
#                           short_term_capital_losses<2023, (default)> = [0. 0. 0. 0.]
#                           short_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                         qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                       qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                       unrecaptured_section_1250_gain<2023, (default)> = [0.]
#                       capital_gains_28_percent_rate_gain<2023, (default)> = [0.]
#                         long_term_capital_gains_on_collectibles<2023, (default)> = [0. 0. 0. 0.]
#                         long_term_capital_gains_on_small_business_stock<2023, (default)> = [0. 0. 0. 0.]
#                 taxable_income_deductions_if_not_itemizing<2023, (default)> = [27700.]
#                   standard_deduction<2023, (default)> = [27700.]
#                   qualified_business_income_deduction<2023, (default)> = [0.]
#             capital_gains_excluded_from_taxable_income<2023, (default)> = [0.]
#               net_capital_gain<2023, (default)> = [0.]
#               adjusted_net_capital_gain<2023, (default)> = [0.]
#               taxable_income<2023, (default)> = [172300.]
#               filing_status<2023, (default)> = ['JOINT']
#             filing_status<2023, (default)> = ['JOINT']
#           capital_gains_tax<2023, (default)> = [0.]
#             net_capital_gain<2023, (default)> = [0.]
#             taxable_income<2023, (default)> = [172300.]
#             adjusted_net_capital_gain<2023, (default)> = [0.]
#             capital_gains_excluded_from_taxable_income<2023, (default)> = [0.]
#             filing_status<2023, (default)> = ['JOINT']
#             unrecaptured_section_1250_gain<2023, (default)> = [0.]
#             qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#             capital_gains_28_percent_rate_gain<2023, (default)> = [0.]
#           alternative_minimum_tax<2023, (default)> = [0.]
#             c09600<2023, (default)> = [0.]
#               c62100<2023, (default)> = [200000.]
#                 amt_income<2023, (default)> = [200000.]
#                   taxable_income<2023, (default)> = [172300.]
#                   tax_unit_itemizes<2023, (default)> = [False]
#                   standard_deduction<2023, (default)> = [27700.]
#                   salt_deduction<2023, (default)> = [8317.512]
#                   filing_status<2023, (default)> = ['JOINT']
#               filing_status<2023, (default)> = ['JOINT']
#               age_head<2023, (default)> = [38]
#               age_spouse<2023, (default)> = [35]
#               filer_earned<2023, (default)> = [200000.]
#               sep<2023, (default)> = [1]
#               dwks10<2023, (default)> = [0.]
#                 dwks6<2023, (default)> = [0.]
#                   qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                   investment_income_form_4952<2023, (default)> = [0.]
#                 dwks9<2023, (default)> = [0.]
#                   long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                   c23650<2023, (default)> = [0.]
#                   non_sch_d_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   investment_income_form_4952<2023, (default)> = [0.]
#                 long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                 qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#                 c23650<2023, (default)> = [0.]
#                 non_sch_d_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                 hasqdivltcg<2023, (default)> = [False]
#                   c01000<2023, (default)> = [0.]
#                   c23650<2023, (default)> = [0.]
#                   long_term_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   non_sch_d_capital_gains<2023, (default)> = [0. 0. 0. 0.]
#                   qualified_dividend_income<2023, (default)> = [0. 0. 0. 0.]
#               dwks13<2023, (default)> = [0.]
#                 unrecaptured_section_1250_gain<2023, (default)> = [0.]
#                 capital_gains_28_percent_rate_gain<2023, (default)> = [0.]
#                 dwks9<2023, (default)> = [0.]
#                 dwks10<2023, (default)> = [0.]
#                 hasqdivltcg<2023, (default)> = [False]
#               dwks14<2023, (default)> = [0.]
#                 taxable_income<2023, (default)> = [172300.]
#                 dwks13<2023, (default)> = [0.]
#                 hasqdivltcg<2023, (default)> = [False]
#               dwks19<2023, (default)> = [0.]
#                 dwks14<2023, (default)> = [0.]
#                 filing_status<2023, (default)> = ['JOINT']
#                 taxable_income<2023, (default)> = [172300.]
#                 dwks10<2023, (default)> = [0.]
#                 hasqdivltcg<2023, (default)> = [False]
#               unrecaptured_section_1250_gain<2023, (default)> = [0.]
#               sep<2023, (default)> = [1]
#               foreign_tax_credit<2023, (default)> = [0.]
#               amt_form_completed<2023, (default)> = [False]
#               foreign_tax_credit<2023, (default)> = [0.]
#               taxbc<2023, (default)> = [28521.]
#                 regular_tax_before_credits<2023, (default)> = [28521.]
#                   filing_status<2023, (default)> = ['JOINT']
#                   taxable_income<2023, (default)> = [172300.]
#                   dwks14<2023, (default)> = [0.]
#                   dwks13<2023, (default)> = [0.]
#                   dwks19<2023, (default)> = [0.]
#                   dwks9<2023, (default)> = [0.]
#                   unrecaptured_section_1250_gain<2023, (default)> = [0.]
#                   dwks10<2023, (default)> = [0.]
#                   income_tax_main_rates<2023, (default)> = [28521.]
#                   hasqdivltcg<2023, (default)> = [False]
#               c05700<2023, (default)> = [0.]
#         net_investment_income_tax<2023, (default)> = [0.]
#           taxable_interest_income<2023, (default)> = [0. 0. 0. 0.]
#           dividend_income<2023, (default)> = [0. 0. 0. 0.]
#           c01000<2023, (default)> = [0.]
#           rental_income<2023, (default)> = [0. 0. 0. 0.]
#           filing_status<2023, (default)> = ['JOINT']
#           adjusted_gross_income<2023, (default)> = [200000.]
#         recapture_of_investment_credit<2023, (default)> = [0.]
#         unreported_payroll_tax<2023, (default)> = [0.]
#         qualified_retirement_penalty<2023, (default)> = [0.]
#         income_tax_capped_non_refundable_credits<2023, (default)> = [4300.]
#           income_tax_non_refundable_credits<2023, (default)> = [4300.]
#             cdcc<2023, (default)> = [300.]
#             elderly_disabled_credit<2023, (default)> = [0.]
#             non_refundable_ctc<2023, (default)> = [4000.]
#               ctc<2023, (default)> = [4000.]
#               refundable_ctc<2023, (default)> = [0.]
#             non_refundable_american_opportunity_credit<2023, (default)> = [0.]
#             lifetime_learning_credit<2023, (default)> = [0.]
#             retirement_savings_credit<2023, (default)> = [0.]
#             residential_clean_energy_credit<2023, (default)> = [0.]
#             energy_efficient_home_improvement_credit<2023, (default)> = [0.]
#             new_clean_vehicle_credit<2023, (default)> = [0.]
#             used_clean_vehicle_credit<2023, (default)> = [0.]
#           income_tax_unavailable_non_refundable_credits<2023, (default)> = [0.]
#             income_tax_before_credits<2023, (default)> = [28521.]
#             income_tax_non_refundable_credits<2023, (default)> = [4300.]
#             income_tax_non_refundable_credits<2023, (default)> = [4300.]
#       ma_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         MA<2023, (default)> = [False]
#       md_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         MD<2023, (default)> = [False]
#       ny_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         NY<2023, (default)> = [False]
#       or_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         or_income_tax_before_credits<2023, (default)> = [0.]
#           OR<2023, (default)> = [False]
#         or_non_refundable_credits<2023, (default)> = [0.]
#           or_exemption_credit<2023, (default)> = [0.]
#             OR<2023, (default)> = [False]
#       pa_income_tax<2023, (default)> = [0.]
#       ut_income_tax_before_refundable_credits<2023, (default)> = [8317.512]
#       wa_income_tax_before_refundable_credits<2023, (default)> = [0.]
#         WA<2023, (default)> = [False]
#       flat_tax<2023, (default)> = [0.]
#         positive_agi<2023, (default)> = [200000.]
